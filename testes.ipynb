# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import nltk
from nltk import bigrams
from nltk.corpus import stopwords
from collections import Counter

# %%
wos_retracted_papers = pd.read_excel('wos_search_retracted_paper_kw.xls')
wos_retracted_publications = pd.read_excel('wos_search_retracted_publication_kw.xls')
wos_retracted_papers2 = pd.read_excel('wos_search_retracted_paper_kw2.xls')
wos_search = pd.concat([wos_retracted_papers, wos_retracted_papers2, wos_retracted_publications])

# %%
wos_search.head()
# Out:
#   Publication Type                                            Authors  \
# 0                J                       da Silva, JAT; Dobranszki, J
# 1                J  Candal-Pedreira, C; Ross, JS; Ruano-Ravina, A;...
# 2                J                    Peng, H; Romero, DM; Horvat, EA
# 3                J                            Shepperd, M; Yousefi, L
# 4                J  Bulow, W; Godskesen, TE; Helgesson, G; Eriksso...
#
#    Book Authors Book Editors Book Group Authors  \
# 0           NaN          NaN                NaN
# 1           NaN          NaN                NaN
# 2           NaN          NaN                NaN
# 3           NaN          NaN                NaN
# 4           NaN          NaN                NaN
#
#                                    Author Full Names  Book Author Full Names  \
# 0     da Silva, Jaime A. Teixeira; Dobranszki, Judit                     NaN
# 1  Candal-Pedreira, Cristina; Ross, Joseph S.; Ru...                     NaN
# 2  Peng, Hao; Romero, Daniel M.; Horvat, Emoke-Agnes                     NaN
# 3                   Shepperd, Martin; Yousefi, Leila                     NaN
# 4  Bulow, William; Godskesen, Tove E.; Helgesson,...                     NaN
#
#   Group Authors                                      Article Title  \
# 0           NaN                      Highly cited retracted papers
# 1           NaN  Retracted papers originating from paper mills:...
# 2           NaN  Dynamics of cross-platform attention to retrac...
# 3           NaN  An analysis of retracted papers in Computer Sc...
# 4           NaN           Why unethical papers should be retracted
#
#                                         Source Title  ...  \
# 0                                     SCIENTOMETRICS  ...
# 1                        BMJ-BRITISH MEDICAL JOURNAL  ...
# 2  PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCE...  ...
# 3                                           PLOS ONE  ...
# 4                          JOURNAL OF MEDICAL ETHICS  ...
#
#                                 Web of Science Index  \
# 0  Science Citation Index Expanded (SCI-EXPANDED)...
# 1     Science Citation Index Expanded (SCI-EXPANDED)
# 2     Science Citation Index Expanded (SCI-EXPANDED)
# 3     Science Citation Index Expanded (SCI-EXPANDED)
# 4  Science Citation Index Expanded (SCI-EXPANDED)...
#
#                                       Research Areas IDS Number   Pubmed Id  \
# 0  Computer Science; Information Science & Librar...      EL0VI         NaN
# 1                        General & Internal Medicine      6T3GK  36442874.0
# 2                Science & Technology - Other Topics      3R1VC  35700358.0
# 3                Science & Technology - Other Topics      F8JN8  37159472.0
# 4  Social Sciences - Other Topics; Medical Ethics...      XJ7MF  32792346.0
#
#                    Open Access Designations Highly Cited Status  \
# 0                                       NaN                 NaN
# 1                   hybrid, Green Published                 NaN
# 2  hybrid, Green Submitted, Green Published                 NaN
# 3    Green Published, Green Submitted, gold                 NaN
# 4                                       NaN                 NaN
#
#   Hot Paper Status Date of Export   UT (Unique WOS ID) Web of Science Record
# 0              NaN     2023-08-22  WOS:000394339500030                     0
# 1              NaN     2023-08-22  WOS:000893566800005                     0
# 2              NaN     2023-08-22  WOS:000838706700008                     0
# 3              NaN     2023-08-22  WOS:000984757900018                     0
# 4              NaN     2023-08-22  WOS:000726966400031                     0
#
# [5 rows x 72 columns]

# %%
wos_search.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2019 entries, 0 to 587
# Data columns (total 72 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Publication Type            2019 non-null   object
#  1   Authors                     2019 non-null   object
#  2   Book Authors                0 non-null      float64
#  3   Book Editors                151 non-null    object
#  4   Book Group Authors          144 non-null    object
#  5   Author Full Names           2019 non-null   object
#  6   Book Author Full Names      0 non-null      float64
#  7   Group Authors               8 non-null      object
#  8   Article Title               2019 non-null   object
#  9   Source Title                2019 non-null   object
#  10  Book Series Title           173 non-null    object
#  11  Book Series Subtitle        0 non-null      float64
#  12  Language                    2019 non-null   object
#  13  Document Type               2019 non-null   object
#  14  Conference Title            346 non-null    object
#  15  Conference Date             346 non-null    object
#  16  Conference Location         346 non-null    object
#  17  Conference Sponsor          277 non-null    object
#  18  Conference Host             59 non-null     object
#  19  Author Keywords             1236 non-null   object
#  20  Keywords Plus               1250 non-null   object
#  21  Abstract                    1913 non-null   object
#  22  Addresses                   1783 non-null   object
#  23  Affiliations                1674 non-null   object
#  24  Reprint Addresses           1780 non-null   object
#  25  Email Addresses             1562 non-null   object
#  26  Researcher Ids              937 non-null    object
#  27  ORCIDs                      1068 non-null   object
#  28  Funding Orgs                713 non-null    object
#  29  Funding Name Preferred      711 non-null    object
#  30  Funding Text                682 non-null    object
#  31  Cited References            0 non-null      float64
#  32  Cited Reference Count       2019 non-null   int64
#  33  Times Cited, WoS Core       2019 non-null   int64
#  34  Times Cited, All Databases  2019 non-null   int64
#  35  180 Day Usage Count         2019 non-null   int64
#  36  Since 2013 Usage Count      2019 non-null   int64
#  37  Publisher                   2019 non-null   object
#  38  Publisher City              2019 non-null   object
#  39  Publisher Address           2019 non-null   object
#  40  ISSN                        1826 non-null   object
#  41  eISSN                       1288 non-null   object
#  42  ISBN                        270 non-null    object
#  43  Journal Abbreviation        1903 non-null   object
#  44  Journal ISO Abbreviation    1728 non-null   object
#  45  Publication Date            1513 non-null   object
#  46  Publication Year            2019 non-null   int64
#  47  Volume                      1756 non-null   object
#  48  Issue                       1438 non-null   object
#  49  Part Number                 42 non-null     object
#  50  Supplement                  8 non-null      object
#  51  Special Issue               59 non-null     object
#  52  Meeting Abstract            0 non-null      float64
#  53  Start Page                  1577 non-null   object
#  54  End Page                    1577 non-null   object
#  55  Article Number              402 non-null    object
#  56  DOI                         1712 non-null   object
#  57  DOI Link                    1712 non-null   float64
#  58  Book DOI                    0 non-null      float64
#  59  Early Access Date           251 non-null    object
#  60  Number of Pages             2019 non-null   int64
#  61  WoS Categories              2019 non-null   object
#  62  Web of Science Index        2019 non-null   object
#  63  Research Areas              2019 non-null   object
#  64  IDS Number                  2019 non-null   object
#  65  Pubmed Id                   739 non-null    float64
#  66  Open Access Designations    956 non-null    object
#  67  Highly Cited Status         0 non-null      float64
#  68  Hot Paper Status            0 non-null      float64
#  69  Date of Export              2019 non-null   object
#  70  UT (Unique WOS ID)          2019 non-null   object
#  71  Web of Science Record       2019 non-null   int64
# dtypes: float64(10), int64(8), object(54)
# memory usage: 1.1+ MB

# %%
wos_search.drop_duplicates()
# Out:
#     Publication Type                                            Authors  \
# 0                  J                       da Silva, JAT; Dobranszki, J
# 1                  J  Candal-Pedreira, C; Ross, JS; Ruano-Ravina, A;...
# 2                  J                    Peng, H; Romero, DM; Horvat, EA
# 3                  J                            Shepperd, M; Yousefi, L
# 4                  J  Bulow, W; Godskesen, TE; Helgesson, G; Eriksso...
# ..               ...                                                ...
# 582                J       Hohlfeld, A; Ebrahim, S; Shaik, MZ; Kredo, T
# 583                J                       Hata, Y; Goto, H; Yoshimi, M
# 584                J                             Miyazaki, M; Hayano, R
# 586                J  Reis, S; Metzendorf, MI; Kuehn, R; Popp, M; Ga...
# 587                J                                           Semal, J
#
#      Book Authors Book Editors Book Group Authors  \
# 0             NaN          NaN                NaN
# 1             NaN          NaN                NaN
# 2             NaN          NaN                NaN
# 3             NaN          NaN                NaN
# 4             NaN          NaN                NaN
# ..            ...          ...                ...
# 582           NaN          NaN                NaN
# 583           NaN          NaN                NaN
# 584           NaN          NaN                NaN
# 586           NaN          NaN                NaN
# 587           NaN          NaN                NaN
#
#                                      Author Full Names  \
# 0       da Silva, Jaime A. Teixeira; Dobranszki, Judit
# 1    Candal-Pedreira, Cristina; Ross, Joseph S.; Ru...
# 2    Peng, Hao; Romero, Daniel M.; Horvat, Emoke-Agnes
# 3                     Shepperd, Martin; Yousefi, Leila
# 4    Bulow, William; Godskesen, Tove E.; Helgesson,...
# ..                                                 ...
# 582  Hohlfeld, Ameer; Ebrahim, Sumayyah; Shaik, Muh...
# 583   Hata, Yoshiya; Goto, Hiroyuki; Yoshimi, Masayuki
# 584                    Miyazaki, Makoto; Hayano, Ryugo
# 586  Reis, Stefanie; Metzendorf, Maria-Inti; Kuehn,...
# 587                                        Semal, Jean
#
#      Book Author Full Names Group Authors  \
# 0                       NaN           NaN
# 1                       NaN           NaN
# 2                       NaN           NaN
# 3                       NaN           NaN
# 4                       NaN           NaN
# ..                      ...           ...
# 582                     NaN           NaN
# 583                     NaN           NaN
# 584                     NaN           NaN
# 586                     NaN           NaN
# 587                     NaN           NaN
#
#                                          Article Title  \
# 0                        Highly cited retracted papers
# 1    Retracted papers originating from paper mills:...
# 2    Dynamics of cross-platform attention to retrac...
# 3    An analysis of retracted papers in Computer Sc...
# 4             Why unethical papers should be retracted
# ..                                                 ...
# 582  Circumcision devices versus standard surgical ...
# 583  RETRACTED: Preliminary Analysis of Strong Grou...
# 584  RETRACTED: Individual external dose monitoring...
# 586  Nirmatrelvir combined with ritonavir for preve...
# 587  Patentability of living organisms: From biopat...
#
#                                           Source Title  ...  \
# 0                                       SCIENTOMETRICS  ...
# 1                          BMJ-BRITISH MEDICAL JOURNAL  ...
# 2    PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCE...  ...
# 3                                             PLOS ONE  ...
# 4                            JOURNAL OF MEDICAL ETHICS  ...
# ..                                                 ...  ...
# 582            COCHRANE DATABASE OF SYSTEMATIC REVIEWS  ...
# 583                     SEISMOLOGICAL RESEARCH LETTERS  ...
# 584                 JOURNAL OF RADIOLOGICAL PROTECTION  ...
# 586            COCHRANE DATABASE OF SYSTEMATIC REVIEWS  ...
# 587                               CAHIERS AGRICULTURES  ...
#
#                                   Web of Science Index  \
# 0    Science Citation Index Expanded (SCI-EXPANDED)...
# 1       Science Citation Index Expanded (SCI-EXPANDED)
# 2       Science Citation Index Expanded (SCI-EXPANDED)
# 3       Science Citation Index Expanded (SCI-EXPANDED)
# 4    Science Citation Index Expanded (SCI-EXPANDED)...
# ..                                                 ...
# 582     Science Citation Index Expanded (SCI-EXPANDED)
# 583     Science Citation Index Expanded (SCI-EXPANDED)
# 584     Science Citation Index Expanded (SCI-EXPANDED)
# 586     Science Citation Index Expanded (SCI-EXPANDED)
# 587     Science Citation Index Expanded (SCI-EXPANDED)
#
#                                         Research Areas IDS Number   Pubmed Id  \
# 0    Computer Science; Information Science & Librar...      EL0VI         NaN
# 1                          General & Internal Medicine      6T3GK  36442874.0
# 2                  Science & Technology - Other Topics      3R1VC  35700358.0
# 3                  Science & Technology - Other Topics      F8JN8  37159472.0
# 4    Social Sciences - Other Topics; Medical Ethics...      XJ7MF  32792346.0
# ..                                                 ...        ...         ...
# 582                        General & Internal Medicine      RH9VR  33786810.0
# 583                          Geochemistry & Geophysics      DW7KY         NaN
# 584  Environmental Sciences & Ecology; Public, Envi...      EF5IK  27922832.0
# 586                        General & Internal Medicine      5B6JY  36126225.0
# 587                                        Agriculture      146ET         NaN
#
#                      Open Access Designations Highly Cited Status  \
# 0                                         NaN                 NaN
# 1                     hybrid, Green Published                 NaN
# 2    hybrid, Green Submitted, Green Published                 NaN
# 3      Green Published, Green Submitted, gold                 NaN
# 4                                         NaN                 NaN
# ..                                        ...                 ...
# 582                           Green Published                 NaN
# 583                                       NaN                 NaN
# 584                   Green Submitted, hybrid                 NaN
# 586           Green Published, Green Accepted                 NaN
# 587                                       NaN                 NaN
#
#     Hot Paper Status Date of Export   UT (Unique WOS ID) Web of Science Record
# 0                NaN     2023-08-22  WOS:000394339500030                     0
# 1                NaN     2023-08-22  WOS:000893566800005                     0
# 2                NaN     2023-08-22  WOS:000838706700008                     0
# 3                NaN     2023-08-22  WOS:000984757900018                     0
# 4                NaN     2023-08-22  WOS:000726966400031                     0
# ..               ...            ...                  ...                   ...
# 582              NaN     2023-08-22  WOS:000636560500007                     0
# 583              NaN     2023-08-22  WOS:000383830800001                     0
# 584              NaN     2023-08-22  WOS:000390363700001                     0
# 586              NaN     2023-08-22  WOS:000863675200004                     0
# 587              NaN     2023-08-22  WOS:000244918000008                     0
#
# [1865 rows x 72 columns]

# %%
#Load your DataFrame and preprocess the abstracts:

# Assuming your DataFrame has a column named 'abstract'
abstracts = wos_search['Abstract'].tolist()

# Preprocess abstracts by tokenizing and removing stopwords
stop_words = set(stopwords.words('english'))
abstracts_tokens = [nltk.word_tokenize(str(abstract).lower()) for abstract in abstracts]
abstracts_tokens = [[word for word in tokens if word.isalnum() and word not in stop_words] for tokens in abstracts_tokens]

# %%
#Generate bi-grams from the preprocessed abstracts:
abstracts_bigrams = [list(bigrams(tokens)) for tokens in abstracts_tokens]

# %%
#Count the frequency of each bi-gram:
all_bigrams = [bigram for abstract_bigrams in abstracts_bigrams for bigram in abstract_bigrams]
bigram_counts = Counter(all_bigrams)

# %%
#Get the most common bi-grams:
n_most_common = 20  # You can change this number to get more or fewer bi-grams
most_common_bigrams = bigram_counts.most_common(n_most_common)

least_common_bigrams = bigram_counts.most_common()[:-n_most_common-1:-1]

# %%
#Print or use the most common bi-grams:
for bigram, count in most_common_bigrams:
    print(' '.join(bigram), ':', count)
# Out:
# retracted articles : 284
# retracted papers : 270
# retracted publications : 220
# rights reserved : 174
# elsevier rights : 140
# retraction notices : 119
# paper presents : 110
# reasons retraction : 103
# scientific misconduct : 99
# peer review : 98
# et al : 97
# 95 ci : 97
# published online : 96
# papers retracted : 94
# articles retracted : 86
# wiley online : 83
# online library : 83
# retraction watch : 82
# research misconduct : 79
# retracted agreement : 79

# %%
for bigram, count in least_common_bigrams:
    print(' '.join(bigram), ':', count)
# Out:
# agricultural processes : 1
# complexity agricultural : 1
# within complexity : 1
# crops within : 1
# organisms crops : 1
# genes organisms : 1
# applied genes : 1
# rights applied : 1
# propert rights : 1
# relationships propert : 1
# expressing relationships : 1
# equation expressing : 1
# solve equation : 1
# come solve : 1
# time come : 1
# involved time : 1
# mixed property : 1
# protecting mixed : 1
# legal protecting : 1
# operational legal : 1

# %%
wos_search['Document Type'].value_counts()
# Out:
# Document Type
# Article                                            1078
# Proceedings Paper                                   280
# Article; Retracted Publication                      152
# Retraction                                          122
# Review                                               94
# Article; Proceedings Paper                           62
# News Item                                            58
# Editorial Material                                   50
# Correction                                           36
# Letter                                               32
# Article; Early Access                                26
# Retraction; Early Access                              6
# Letter; Retracted Publication                         3
# Meeting Abstract                                      3
# Proceedings Paper; Retracted Publication              3
# Review; Early Access                                  3
# Note                                                  2
# Review; Retracted Publication                         2
# Correction; Retracted Publication                     1
# Retraction; Retracted Publication                     1
# Article; Data Paper                                   1
# Item Withdrawal                                       1
# Letter; Early Access                                  1
# Article; Publication with Expression of Concern       1
# Expression of Concern; Retracted Publication          1
# Name: count, dtype: int64

# %%
filtered = wos_search[wos_search['Document Type'].str.contains('Retracted Publication')]
filtered['Article Title']
# Out:
# 216    RETRACTED: Discussion of Testing Paper Design ...
# 440    RETRACTED: The Simple Analysis of Paper-cut ar...
# 477    RETRACTED: Sirt3 activation attenuated oxidize...
# 606    RETRACTED: A New Method of Paper Defect Recogn...
# 668    RETRACTED: An overview of recently published m...
#                              ...
# 578    RETRACTED: Vitamin D Supplementation Affects t...
# 579    RETRACTED: High-dose omega-3 Fatty Acid Plus V...
# 580    RETRACTED: A highly concise and practical rout...
# 583    RETRACTED: Preliminary Analysis of Strong Grou...
# 584    RETRACTED: Individual external dose monitoring...
# Name: Article Title, Length: 163, dtype: object

# %%
filtered[~filtered['Article Title'].str.contains('RETRACTED:')]
# Out:
# Empty DataFrame
# Columns: [Publication Type, Authors, Book Authors, Book Editors, Book Group Authors, Author Full Names, Book Author Full Names, Group Authors, Article Title, Source Title, Book Series Title, Book Series Subtitle, Language, Document Type, Conference Title, Conference Date, Conference Location, Conference Sponsor, Conference Host, Author Keywords, Keywords Plus, Abstract, Addresses, Affiliations, Reprint Addresses, Email Addresses, Researcher Ids, ORCIDs, Funding Orgs, Funding Name Preferred, Funding Text, Cited References, Cited Reference Count, Times Cited, WoS Core, Times Cited, All Databases, 180 Day Usage Count, Since 2013 Usage Count, Publisher, Publisher City, Publisher Address, ISSN, eISSN, ISBN, Journal Abbreviation, Journal ISO Abbreviation, Publication Date, Publication Year, Volume, Issue, Part Number, Supplement, Special Issue, Meeting Abstract, Start Page, End Page, Article Number, DOI, DOI Link, Book DOI, Early Access Date, Number of Pages, WoS Categories, Web of Science Index, Research Areas, IDS Number, Pubmed Id, Open Access Designations, Highly Cited Status, Hot Paper Status, Date of Export, UT (Unique WOS ID), Web of Science Record]
# Index: []
#
# [0 rows x 72 columns]

# %%
wos_search = wos_search[~wos_search['Document Type'].str.contains('Retracted Publication')]
wos_search = wos_search[~wos_search['Document Type'].str.contains('Retraction')]

# %%
wos_search
# Out:
#     Publication Type                                            Authors  \
# 0                  J                       da Silva, JAT; Dobranszki, J
# 1                  J  Candal-Pedreira, C; Ross, JS; Ruano-Ravina, A;...
# 2                  J                    Peng, H; Romero, DM; Horvat, EA
# 3                  J                            Shepperd, M; Yousefi, L
# 4                  J  Bulow, W; Godskesen, TE; Helgesson, G; Eriksso...
# ..               ...                                                ...
# 581                J                     Mutter, TC; Ruth, CA; Dart, AB
# 582                J       Hohlfeld, A; Ebrahim, S; Shaik, MZ; Kredo, T
# 585                J        Baird, E; Williams, ACD; Hearn, L; Amris, K
# 586                J  Reis, S; Metzendorf, MI; Kuehn, R; Popp, M; Ga...
# 587                J                                           Semal, J
#
#      Book Authors Book Editors Book Group Authors  \
# 0             NaN          NaN                NaN
# 1             NaN          NaN                NaN
# 2             NaN          NaN                NaN
# 3             NaN          NaN                NaN
# 4             NaN          NaN                NaN
# ..            ...          ...                ...
# 581           NaN          NaN                NaN
# 582           NaN          NaN                NaN
# 585           NaN          NaN                NaN
# 586           NaN          NaN                NaN
# 587           NaN          NaN                NaN
#
#                                      Author Full Names  \
# 0       da Silva, Jaime A. Teixeira; Dobranszki, Judit
# 1    Candal-Pedreira, Cristina; Ross, Joseph S.; Ru...
# 2    Peng, Hao; Romero, Daniel M.; Horvat, Emoke-Agnes
# 3                     Shepperd, Martin; Yousefi, Leila
# 4    Bulow, William; Godskesen, Tove E.; Helgesson,...
# ..                                                 ...
# 581  Mutter, Thomas C.; Ruth, Chelsea A.; Dart, All...
# 582  Hohlfeld, Ameer; Ebrahim, Sumayyah; Shaik, Muh...
# 585  Baird, Emma; Williams, Amanda C. de C.; Hearn,...
# 586  Reis, Stefanie; Metzendorf, Maria-Inti; Kuehn,...
# 587                                        Semal, Jean
#
#      Book Author Full Names Group Authors  \
# 0                       NaN           NaN
# 1                       NaN           NaN
# 2                       NaN           NaN
# 3                       NaN           NaN
# 4                       NaN           NaN
# ..                      ...           ...
# 581                     NaN           NaN
# 582                     NaN           NaN
# 585                     NaN           NaN
# 586                     NaN           NaN
# 587                     NaN           NaN
#
#                                          Article Title  \
# 0                        Highly cited retracted papers
# 1    Retracted papers originating from paper mills:...
# 2    Dynamics of cross-platform attention to retrac...
# 3    An analysis of retracted papers in Computer Sc...
# 4             Why unethical papers should be retracted
# ..                                                 ...
# 581  Hydroxyethyl starch (HES) versus other fluid t...
# 582  Circumcision devices versus standard surgical ...
# 585  Interventions for treating persistent pain in ...
# 586  Nirmatrelvir combined with ritonavir for preve...
# 587  Patentability of living organisms: From biopat...
#
#                                           Source Title  ...  \
# 0                                       SCIENTOMETRICS  ...
# 1                          BMJ-BRITISH MEDICAL JOURNAL  ...
# 2    PROCEEDINGS OF THE NATIONAL ACADEMY OF SCIENCE...  ...
# 3                                             PLOS ONE  ...
# 4                            JOURNAL OF MEDICAL ETHICS  ...
# ..                                                 ...  ...
# 581            COCHRANE DATABASE OF SYSTEMATIC REVIEWS  ...
# 582            COCHRANE DATABASE OF SYSTEMATIC REVIEWS  ...
# 585            COCHRANE DATABASE OF SYSTEMATIC REVIEWS  ...
# 586            COCHRANE DATABASE OF SYSTEMATIC REVIEWS  ...
# 587                               CAHIERS AGRICULTURES  ...
#
#                                   Web of Science Index  \
# 0    Science Citation Index Expanded (SCI-EXPANDED)...
# 1       Science Citation Index Expanded (SCI-EXPANDED)
# 2       Science Citation Index Expanded (SCI-EXPANDED)
# 3       Science Citation Index Expanded (SCI-EXPANDED)
# 4    Science Citation Index Expanded (SCI-EXPANDED)...
# ..                                                 ...
# 581     Science Citation Index Expanded (SCI-EXPANDED)
# 582     Science Citation Index Expanded (SCI-EXPANDED)
# 585  Science Citation Index Expanded (SCI-EXPANDED)...
# 586     Science Citation Index Expanded (SCI-EXPANDED)
# 587     Science Citation Index Expanded (SCI-EXPANDED)
#
#                                         Research Areas IDS Number   Pubmed Id  \
# 0    Computer Science; Information Science & Librar...      EL0VI         NaN
# 1                          General & Internal Medicine      6T3GK  36442874.0
# 2                  Science & Technology - Other Topics      3R1VC  35700358.0
# 3                  Science & Technology - Other Topics      F8JN8  37159472.0
# 4    Social Sciences - Other Topics; Medical Ethics...      XJ7MF  32792346.0
# ..                                                 ...        ...         ...
# 581                        General & Internal Medicine      193OD  23881659.0
# 582                        General & Internal Medicine      RH9VR  33786810.0
# 585                        General & Internal Medicine      FF3QG  28820231.0
# 586                        General & Internal Medicine      5B6JY  36126225.0
# 587                                        Agriculture      146ET         NaN
#
#                      Open Access Designations Highly Cited Status  \
# 0                                         NaN                 NaN
# 1                     hybrid, Green Published                 NaN
# 2    hybrid, Green Submitted, Green Published                 NaN
# 3      Green Published, Green Submitted, gold                 NaN
# 4                                         NaN                 NaN
# ..                                        ...                 ...
# 581                                       NaN                 NaN
# 582                           Green Published                 NaN
# 585                           Green Published                 NaN
# 586           Green Published, Green Accepted                 NaN
# 587                                       NaN                 NaN
#
#     Hot Paper Status Date of Export   UT (Unique WOS ID) Web of Science Record
# 0                NaN     2023-08-22  WOS:000394339500030                     0
# 1                NaN     2023-08-22  WOS:000893566800005                     0
# 2                NaN     2023-08-22  WOS:000838706700008                     0
# 3                NaN     2023-08-22  WOS:000984757900018                     0
# 4                NaN     2023-08-22  WOS:000726966400031                     0
# ..               ...            ...                  ...                   ...
# 581              NaN     2023-08-22  WOS:000322568300017                     0
# 582              NaN     2023-08-22  WOS:000636560500007                     0
# 585              NaN     2023-08-22  WOS:000408828100023                     0
# 586              NaN     2023-08-22  WOS:000863675200004                     0
# 587              NaN     2023-08-22  WOS:000244918000008                     0
#
# [1728 rows x 72 columns]

# %%
wos_search[wos_search['Document Type']=='Retraction']
# Out:
# Empty DataFrame
# Columns: [Publication Type, Authors, Book Authors, Book Editors, Book Group Authors, Author Full Names, Book Author Full Names, Group Authors, Article Title, Source Title, Book Series Title, Book Series Subtitle, Language, Document Type, Conference Title, Conference Date, Conference Location, Conference Sponsor, Conference Host, Author Keywords, Keywords Plus, Abstract, Addresses, Affiliations, Reprint Addresses, Email Addresses, Researcher Ids, ORCIDs, Funding Orgs, Funding Name Preferred, Funding Text, Cited References, Cited Reference Count, Times Cited, WoS Core, Times Cited, All Databases, 180 Day Usage Count, Since 2013 Usage Count, Publisher, Publisher City, Publisher Address, ISSN, eISSN, ISBN, Journal Abbreviation, Journal ISO Abbreviation, Publication Date, Publication Year, Volume, Issue, Part Number, Supplement, Special Issue, Meeting Abstract, Start Page, End Page, Article Number, DOI, DOI Link, Book DOI, Early Access Date, Number of Pages, WoS Categories, Web of Science Index, Research Areas, IDS Number, Pubmed Id, Open Access Designations, Highly Cited Status, Hot Paper Status, Date of Export, UT (Unique WOS ID), Web of Science Record]
# Index: []
#
# [0 rows x 72 columns]

# %%
wos_search[wos_search['Article Title'].str.contains('RETRACTED:')]
# Out:
# Empty DataFrame
# Columns: [Publication Type, Authors, Book Authors, Book Editors, Book Group Authors, Author Full Names, Book Author Full Names, Group Authors, Article Title, Source Title, Book Series Title, Book Series Subtitle, Language, Document Type, Conference Title, Conference Date, Conference Location, Conference Sponsor, Conference Host, Author Keywords, Keywords Plus, Abstract, Addresses, Affiliations, Reprint Addresses, Email Addresses, Researcher Ids, ORCIDs, Funding Orgs, Funding Name Preferred, Funding Text, Cited References, Cited Reference Count, Times Cited, WoS Core, Times Cited, All Databases, 180 Day Usage Count, Since 2013 Usage Count, Publisher, Publisher City, Publisher Address, ISSN, eISSN, ISBN, Journal Abbreviation, Journal ISO Abbreviation, Publication Date, Publication Year, Volume, Issue, Part Number, Supplement, Special Issue, Meeting Abstract, Start Page, End Page, Article Number, DOI, DOI Link, Book DOI, Early Access Date, Number of Pages, WoS Categories, Web of Science Index, Research Areas, IDS Number, Pubmed Id, Open Access Designations, Highly Cited Status, Hot Paper Status, Date of Export, UT (Unique WOS ID), Web of Science Record]
# Index: []
#
# [0 rows x 72 columns]

# %%
year_counts = wos_search[wos_search['Publication Year'] !=2023]['Publication Year'].value_counts().sort_index()

# %%
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.plot(year_counts.index, year_counts.values, marker='o')

# Annotate each data point with its count
for year, count in zip(year_counts.index, year_counts.values):
    plt.annotate(str(count), (year, count), textcoords="offset points", xytext=(0,10), ha='center')

plt.xlabel('Publication Year')
plt.ylabel('Count of Observations')
plt.title('Publication Year vs. Count of Observations')
plt.grid(True)
plt.show()
