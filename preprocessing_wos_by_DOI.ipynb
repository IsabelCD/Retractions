# %% [markdown]
# The purpose of this Notebook is to join the datasets from the different sources into the following datasets:
# - *retractions*: this dataset will join data from retraction watch database (RW) and bibliometric data of retractions in Web of Science (RD).
# - *retracted_in_journals*: this dataset will join data from retraction watch database (RW), journal metrics from scimajor, and bibliometric data of all articles in best ranked journals (JD).

# %% [markdown]
# * [Chapter 0 - Libraries](#chapter0)
# * [Chapter 1 - Individual Analysis](#chapter1)
#     * [1.1 - Retraction Watch Database (RWD)](#section_1_1)
#     * [1.2 - Control Set (CS)](#section_1_2)
#     * [1.3 - Citation Data (CIT)](#section_1_3)
#     * [1.4 - Corrections Data (COR)](#section_1_4)
# * [Chapter 2 - Merge Data](#chapter2)
#     * [2.1 - Retraction Data (RD)](#section_2_1)

# %% [markdown]
# <div class="alert alert-block alert-info" style = "background:#d0de6f; color:#000000; border:0;">
#
# # Chapter 0 - Libraries <a class="anchor" id="chapter0"></a>

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import re
#import matplotlib.pyplot as plt
#import seaborn as sns
#import plotly.express as px

# %% [markdown]
# <div class="alert alert-block alert-info" style = "background:#d0de6f; color:#000000; border:0;">
#
# # Chapter 1 - Individual Analysis <a class="anchor" id="chapter1"></a>

# %% [markdown]
# <a class="anchor">
#
# ## 1.1 - Retraction Watch Database (RWD) <a class="anchor" id="section_1_1"></a>

# %%
rwd = pd.read_excel('./retractions_data/retraction_watch_database.xlsx', dtype={'RetractionPubMedID': object, 'OriginalPaperPubMedID': object})
rwd.head()
# Out:
#    Record ID                                              Title  \
# 0      47271  Binding of DCC by Netrin-1 to Mediate Axon Gui...
# 1      47270  Hierarchical Organization of Guidance Receptor...
# 2      47243  Therapeutic potential of targeting IRES-depend...
# 3      47233  A classifier based on 273 urinary peptides pre...
# 4      47227  Age, Gender Demographics and Comorbidity Preva...
#
#                                              Subject  \
# 0  (BLS) Biology - Cellular;(BLS) Biology - Gener...
# 1  (BLS) Biochemistry;(BLS) Biology - General;(BL...
# 2  (BLS) Biochemistry;(BLS) Biology - Cancer;(BLS...
# 3  (BLS) Biochemistry;(HSC) Medicine - Cardiovasc...
# 4  (HSC) Biostatistics/Epidemiology;(HSC) Medicin...
#
#                                          Institution  \
# 0  Departments of Anatomy and of Biochemistry and...
# 1  Department of Anatomy and Department of Bioche...
# 2  Division of Hematology-Oncology, UCLA-Greater ...
# 3  Department of Nephrology, The Third Affiliated...
# 4  Department of Orthopaedics, Dhanalakshmi Srini...
#
#                             Journal  \
# 0                           Science
# 1                           Science
# 2                          Oncogene
# 3           Journal of Hypertension
# 4  Journal of Coastal Life Medicine
#
#                                            Publisher        Country  \
# 0  American Association for the Advancement of Sc...  United States
# 1  American Association for the Advancement of Sc...  United States
# 2                 Springer - Nature Publishing Group  United States
# 3     Wolters Kluwer - Lippincott Williams & Wilkins          China
# 4                   Journal of Coastal Life Medicine          India
#
#                                               Author  \
# 0  Elke Stein;Yimin Zou;Mu-ming Poo;Marc Tessier-...
# 1                    Elke Stein;Marc Tessier-Lavigne
# 2  Y Shi;Y Yang;C Bardeleben;B Holmes;J Gera;Alan...
# 3  Lirong Lin;Chunxuan Wang;Jiangwen Ren;Mei Mei;...
# 4  S Venkatesh Kumar;Mohith Singh;Gowtham Singh;K...
#
#                                                 URLS        ArticleType  \
# 0  https://retractionwatch.com/2023/08/31/stanfor...  Research Article;
# 1  https://retractionwatch.com/2023/08/31/stanfor...  Research Article;
# 2                                                NaN  Research Article;
# 3                                                NaN  Research Article;
# 4                                                NaN  Research Article;
#
#         RetractionDate                 RetractionDOI RetractionPubMedID  \
# 0  2023-08-31 00:00:00       10.1126/science.adk1521                  0
# 1  2023-08-31 00:00:00       10.1126/science.adk1517                  0
# 2  2023-08-31 00:00:00    10.1038/s41388-023-02820-5                  0
# 3  2023-08-30 00:00:00  10.1097/HJH.0000000000003551           37642599
# 4  2023-08-30 00:00:00                   unavailable                  0
#
#      OriginalPaperDate              OriginalPaperDOI OriginalPaperPubMedID  \
# 0  2001-03-09 00:00:00       10.1126/science.1059391              11239160
# 1  2001-02-08 00:00:00       10.1126/science.1058445              11239147
# 2  2015-05-11 00:00:00          10.1038/onc.2015.156              25961916
# 3  2023-08-01 00:00:00  10.1097/HJH.0000000000003467              37199562
# 4  2023-01-01 00:00:00                   unavailable                     0
#
#   RetractionNature                                             Reason  \
# 0       Retraction  +Investigation by Company/Institution;+Manipul...
# 1       Retraction  +Duplication of Image;+Investigation by Compan...
# 2       Retraction  +Concerns/Issues About Data;+Concerns/Issues A...
# 3       Retraction  +Concerns/Issues About Results;+Investigation ...
# 4       Retraction                     +Notice - Lack of;+Withdrawal;
#
#   Paywalled                                              Notes
# 0        No                                                NaN
# 1        No                                                NaN
# 2        No  see also: https://pubpeer.com/publications/704...
# 3        No  see also https://journals.lww.com/jhypertensio...
# 4        No  date of retraction unknown, article title repl...

# %%
rwd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42700 entries, 0 to 42699
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Record ID              42700 non-null  int64
#  1   Title                  42700 non-null  object
#  2   Subject                42700 non-null  object
#  3   Institution            42699 non-null  object
#  4   Journal                42700 non-null  object
#  5   Publisher              42700 non-null  object
#  6   Country                42700 non-null  object
#  7   Author                 42700 non-null  object
#  8   URLS                   21687 non-null  object
#  9   ArticleType            42700 non-null  object
#  10  RetractionDate         42700 non-null  object
#  11  RetractionDOI          42209 non-null  object
#  12  RetractionPubMedID     37599 non-null  object
#  13  OriginalPaperDate      42700 non-null  object
#  14  OriginalPaperDOI       40173 non-null  object
#  15  OriginalPaperPubMedID  37564 non-null  object
#  16  RetractionNature       42700 non-null  object
#  17  Reason                 42700 non-null  object
#  18  Paywalled              42700 non-null  object
#  19  Notes                  10253 non-null  object
# dtypes: int64(1), object(19)
# memory usage: 6.5+ MB

# %%
# put date variables in correct format
rwd['RetractionDate'] = pd.to_datetime(rwd['RetractionDate'], errors='coerce') #, infer_datetime_format=True
rwd['OriginalPaperDate'] = pd.to_datetime(rwd['OriginalPaperDate'])

# %%
# Check for NaN values in 'Digital Object Identifier (DOI)' column
rwd_filtered = rwd.dropna(subset=['RetractionDOI'])

# Filter rows starting with "http://dx.doi.org/"
rwd_filtered[rwd_filtered['RetractionDOI'].str.startswith("http://dx.doi.org/")]['RetractionDOI']
# Out:
# Series([], Name: RetractionDOI, dtype: object)

# %% [markdown]
# ### Duplicates

# %% [markdown]
# In theory, there should only be one DOI per article, and each retracted paper should only have one record in the database. This means that all DOIs should be unique.

# %%
rwd['OriginalPaperDOI'].nunique()
# Out:
# 36846

# %%
rwd['RetractionDOI'].nunique()
# Out:
# 36506

# %%
testing_dupes = rwd[rwd.duplicated(subset='OriginalPaperDOI', keep=False)]
testing_dupes['OriginalPaperDOI'].value_counts()
# Out:
# OriginalPaperDOI
# Unavailable                        2234
# unavailable                        1074
# 10.1136/jim-2021-SRMC                 6
# 10.1002/tox.21941                     2
# 10.1016/j.lfs.2019.116709             2
# 10.1038/s41598-021-03765-z            2
# 10.1007/s12275-012-2294-z             2
# 10.1016/j.cej.2011.04.016             2
# 10.1016/j.swevo.2021.100868           2
# 10.1016/j.esxm.2021.100447            2
# 10.1093/jge/aabc74                    2
# 10.1088/1742-2140/aaaf57              2
# 10.1088/1742-2140/aa953a              2
# 10.1016/j.carbpol.2019.115799         2
# 10.1001/archpediatrics.2012.999       2
# 10.1007/s13277-014-2995-5             2
# 10.3109/02699052.2016.1162060         2
# 10.1016/j.rapm.2005.05.009            2
# 10.1524/9783486834062.275             2
# Name: count, dtype: int64

# %%
filtered_dupes = testing_dupes[testing_dupes['OriginalPaperDOI'].str.lower() != 'unavailable'].sort_values('OriginalPaperDOI')
filtered_dupes
# Out:
#        Record ID                                              Title  \
# 21229      14089               Can Branding Improve School Lunches?
# 21230      11994               Can Branding Improve School Lunches?
# 5685       38940  Erratum to: Î±,Î²-Unsaturated aldehyde polluta...
# 5696       38375  Î±,Î²-Unsaturated aldehyde pollutant acrolein ...
# 6643       37342  Identification of the Vibrio vulnificus htpG G...
# ...          ...                                                ...
# 42578       4780  Phenylephrine stress in the evaluation of pati...
# 42579       4781  Thallium pulmonary scintigraphy. Relationship ...
# 42611       1494  Specific antigen exclusion and non-specific fa...
# 42613       4249  Concurrent measurement of plasma levels of vit...
# 42695      10433           Change of Venue and the Conflict of Laws
#
#                                                  Subject  \
# 21229  (B/T) Business - Marketing;(BLS) Nutrition;(SO...
# 21230  (B/T) Business - Marketing;(BLS) Nutrition;(SO...
# 5685          (BLS) Biology - Cellular;(BLS) Toxicology;
# 5696          (BLS) Biology - Cellular;(BLS) Toxicology;
# 6643                  (BLS) Genetics;(BLS) Microbiology;
# ...                                                  ...
# 42578  (HSC) Medicine - Cardiology;(HSC) Medicine - P...
# 42579  (HSC) Medicine - Cardiology;(HSC) Medicine - P...
# 42611                         (BLS) Biology - Molecular;
# 42613  (HSC) Medicine - Cardiovascular;(HSC) Medicine...
# 42695                            (SOC) Law/Legal Issues;
#
#                                              Institution  \
# 21229  Charles H. Dyson School of Applied Economics a...
# 21230  Charles H. Dyson School of Applied Economics a...
# 5685   Department of Clinical Immunology, Xijing Hosp...
# 5696   Department of Clinical Immunology, Xijing Hosp...
# 6643   Department of Agricultural Biotechnology, Seou...
# ...                                                  ...
# 42578  Department of Radiology, University of Califor...
# 42579  Department of Radiology, University of Califor...
# 42611  Department of Immunology, Institute of Child H...
# 42613  Endocrinology-Mineral Metabolism and Nephrolog...
# 42695                             University of Chicago;
#
#                                                  Journal  \
# 21229                                    JAMA Pediatrics
# 21230                                    JAMA Pediatrics
# 5685                            Environmental Toxicology
# 5696                            Environmental Toxicology
# 6643                             Journal of Microbiology
# ...                                                  ...
# 42578                            Investigative Radiology
# 42579                            Investigative Radiology
# 42611               Clinical and Experimental Immunology
# 42613  Translational Research: The Journal of Laborat...
# 42695               The University of Chicago Law Review
#
#                               Publisher              Country  \
# 21229                      JAMA Network        United States
# 21230                      JAMA Network        United States
# 5685                              Wiley  China;United States
# 5696                              Wiley  China;United States
# 6643                           Springer          South Korea
# ...                                 ...                  ...
# 42578                    Wolters Kluwer        United States
# 42579                    Wolters Kluwer        United States
# 42611              Blackwell Publishing       United Kingdom
# 42613                          Elsevier        United States
# 42695  University of Chicago Law School        United States
#
#                                                   Author  \
# 21229          Brian Wansink;David R Just;Collin R Payne
# 21230          Brian Wansink;David R Just;Collin R Payne
# 5685       Zhenbiao Wu;Emily Y He;Glenda I Scott;Jun Ren
# 5696       Zhenbiao Wu;Emily Y He;Glenda I Scott;Jun Ren
# 6643   Slae Choi;Kyungku Jang;Seulah Choi;Hee Jee Yun...
# ...                                                  ...
# 42578                                   Robert A Slutsky
# 42579                                   Robert A Slutsky
# 42611  S A Roberts;M C Reinhardt;R Paganelli;R J Levi...
# 42613  PW Lambert;PB DeOreo;BW Hollis;IY Fu;DJ Ginsbe...
# 42695                                    Brainerd Currie
#
#                                                     URLS  \
# 21229  http://retractionwatch.com/?s=brian+wansink;ht...
# 21230  http://retractionwatch.com/?s=brian+wansink;ht...
# 5685   https://retractionwatch.com/2022/07/25/univers...
# 5696   https://retractionwatch.com/2022/07/25/univers...
# 6643                                                 NaN
# ...                                                  ...
# 42578  http://retractionwatch.com/the-retraction-watc...
# 42579  http://retractionwatch.com/the-retraction-watc...
# 42611                                                NaN
# 42613                                                NaN
# 42695                                                NaN
#
#                                       ArticleType RetractionDate  \
# 21229  Letter;Research Article;Retracted Article;     2017-10-20
# 21230                    Letter;Research Article;     2017-09-21
# 5685              Correction/Erratum/Corrigendum;     2022-07-27
# 5696                            Research Article;     2022-07-27
# 6643                            Research Article;     2022-05-23
# ...                                           ...            ...
# 42578                           Research Article;     1986-02-01
# 42579                           Research Article;     1986-02-01
# 42611                           Research Article;     1985-01-01
# 42613                           Research Article;     1984-10-01
# 42695                           Research Article;     1960-02-01
#
#                           RetractionDOI RetractionPubMedID OriginalPaperDate  \
# 21229  10.1001/jamapediatrics.2017.4603                  0        2012-10-01
# 21230  10.1001/jamapediatrics.2017.3136           28973133        2012-10-01
# 5685                  10.1002/tox.23620           35894684        2021-09-12
# 5696                  10.1002/tox.23620           35894684        2013-12-23
# 6643          10.1007/s12275-022-1680-4           35606641        2012-08-25
# ...                                 ...                ...               ...
# 42578                               NaN            3514538        1983-03-01
# 42579                               NaN            3514538        1984-11-01
# 42611                               NaN            3882286        1981-07-01
# 42613                               NaN            6384395        1981-10-01
# 42695                               NaN                NaN        1955-02-01
#
#                       OriginalPaperDOI OriginalPaperPubMedID RetractionNature  \
# 21229  10.1001/archpediatrics.2012.999              22911396       Retraction
# 21230  10.1001/archpediatrics.2012.999              22911396       Retraction
# 5685                 10.1002/tox.21941              34514704       Retraction
# 5696                 10.1002/tox.21941              24376112       Retraction
# 6643         10.1007/s12275-012-2294-z              22923124       Retraction
# ...                                ...                   ...              ...
# 42578                              NaN               6345451       Retraction
# 42579                              NaN               6392156       Retraction
# 42611                              NaN               6171369       Retraction
# 42613                              NaN               6270222       Retraction
# 42695                              NaN                   NaN       Retraction
#
#                                                   Reason Paywalled  \
# 21229  +Breach of Policy by Author;+Error in Data;+Er...        No
# 21230  +Error in Analyses;+Error in Data;+Error in Me...        No
# 5685                             +Updated to Retraction;        No
# 5696   +Falsification/Fabrication of Image;+Investiga...        No
# 6643   +Concerns/Issues About Authorship;+Upgrade/Upd...        No
# ...                                                  ...       ...
# 42578  +Concerns/Issues About Results;+Legal Reasons/...        No
# 42579  +Concerns/Issues About Results;+Legal Reasons/...        No
# 42611  +Error in Analyses;+Results Not Reproducible;+...        No
# 42613  +Notice - Unable to Access via current resources;   Unknown
# 42695  +Error in Results and/or Conclusions;+Unreliab...       Yes
#
#                                                    Notes
# 21229  Journal previously named Archives of Pediatric...
# 21230  note: the paper was retracted again on October...
# 5685                                                 NaN
# 5696                                                 NaN
# 6643                                                 NaN
# ...                                                  ...
# 42578                                                NaN
# 42579  Article is Nov/Dec 1984 (vol. 19, iss. 6, no d...
# 42611              No DOI for Original/Notice 3/24/2017;
# 42613  Journal formerly known as: The Journal of Labo...
# 42695                                                NaN
#
# [2565 rows x 20 columns]

# %%
def find_changed_columns(group):
    changed_cols = group.apply(lambda x: x.nunique()).drop(['OriginalPaperDOI', 'Record ID'])
    value = changed_cols[changed_cols>1].index.to_list()
    return value


filtered_dupes.groupby('OriginalPaperDOI').apply(find_changed_columns).reset_index()
# Out:
#                    OriginalPaperDOI  \
# 0   10.1001/archpediatrics.2012.999
# 1                 10.1002/tox.21941
# 2         10.1007/s12275-012-2294-z
# 3         10.1007/s13277-014-2995-5
# 4     10.1016/j.carbpol.2019.115799
# 5         10.1016/j.cej.2011.04.016
# 6        10.1016/j.esxm.2021.100447
# 7         10.1016/j.lfs.2019.116709
# 8        10.1016/j.rapm.2005.05.009
# 9       10.1016/j.swevo.2021.100868
# 10       10.1038/s41598-021-03765-z
# 11         10.1088/1742-2140/aa953a
# 12         10.1088/1742-2140/aaaf57
# 13               10.1093/jge/aabc74
# 14            10.1136/jim-2021-SRMC
# 15        10.1524/9783486834062.275
# 16    10.3109/02699052.2016.1162060
#
#                                                     0
# 0   [ArticleType, RetractionDate, RetractionDOI, R...
# 1   [Title, ArticleType, OriginalPaperDate, Origin...
# 2   [RetractionDate, RetractionDOI, RetractionPubM...
# 3   [ArticleType, RetractionDate, RetractionDOI, R...
# 4   [RetractionDate, RetractionDOI, RetractionPubM...
# 5              [RetractionDate, RetractionDOI, Notes]
# 6   [RetractionDate, RetractionDOI, RetractionPubM...
# 7   [Subject, RetractionDate, RetractionDOI, Retra...
# 8   [RetractionDate, RetractionDOI, RetractionPubM...
# 9              [RetractionDate, RetractionDOI, Notes]
# 10  [RetractionDate, RetractionDOI, RetractionPubM...
# 11            [RetractionDate, RetractionDOI, Reason]
# 12            [RetractionDate, RetractionDOI, Reason]
# 13            [RetractionDate, RetractionDOI, Reason]
# 14  [Title, Institution, Country, Author, Retracti...
# 15                                   [RetractionDate]
# 16                                    [Title, Author]

# %%
# following code commented so as to not override the changed made in the file
# with pd.ExcelWriter('./wos_rd/DOI_Duplicated_RWD.xlsx') as writer:
#     filtered_dupes.groupby('OriginalPaperDOI').apply(find_changed_columns).reset_index().to_excel(writer, sheet_name= "Differing vars",index = False)
#     filtered_dupes.to_excel(writer, sheet_name = "Duplicate records",index = False)

# %%
rwd[rwd['OriginalPaperDOI']=='10.3109/02699052.2016.1162060']
# Out:
#        Record ID                                              Title  \
# 23288       8429  Are rehabilitation outcomes after anoxic brain...
# 23290       6000  The effect of demographic and clinical charact...
#
#                                                  Subject  Institution  \
# 23288  (HSC) Medicine - Neurology;(HSC) Medicine - Re...  Unavailable
# 23290  (HSC) Medicine - Neurology;(HSC) Medicine - Re...  Unavailable
#
#             Journal           Publisher              Country  \
# 23288  Brain Injury  Taylor and Francis  Netherlands;Unknown
# 23290  Brain Injury  Taylor and Francis  Netherlands;Unknown
#
#                                                   Author URLS  \
# 23288  Emre Adiguzel;Evren Yasar;Yasin Demir;Ismail S...  NaN
# 23290  Evren Yasar;Serdar Kesikburun;Ummugulsum Dogan...  NaN
#
#                       ArticleType RetractionDate  \
# 23288  Conference Abstract/Paper;     2016-08-17
# 23290  Conference Abstract/Paper;     2016-08-17
#
#                        RetractionDOI RetractionPubMedID OriginalPaperDate  \
# 23288  10.1080/02699052.2016.1210325           27533125        2016-05-19
# 23290  10.1080/02699052.2016.1210325           27533125        2016-05-19
#
#                     OriginalPaperDOI OriginalPaperPubMedID RetractionNature  \
# 23288  10.3109/02699052.2016.1162060              27196965       Retraction
# 23290  10.3109/02699052.2016.1162060              27196965       Retraction
#
#                                      Reason Paywalled  \
# 23288  +Notice - Limited or No Information;        No
# 23290  +Notice - Limited or No Information;        No
#
#                                                    Notes
# 23288  Part of Accepted Abstracts from the Internatio...
# 23290                                                NaN

# %%
def find_changed_columns(group):
    changed_cols = group.apply(lambda x: x.nunique()).drop(['OriginalPaperDOI', 'Record ID'])
    value = changed_cols[changed_cols>1].index.to_list()
    return value

filtered_dupes[(filtered_dupes['Record ID'] == 8429) | (filtered_dupes['Record ID'] == 6000)].groupby('OriginalPaperDOI').apply(find_changed_columns).reset_index()
# Out:
#                 OriginalPaperDOI                0
# 0  10.3109/02699052.2016.1162060  [Title, Author]

# %%
pd.set_option('display.max_colwidth', None)  # Show full content of columns
pd.set_option('display.max_rows', None)      # Display all rows

# %%
filtered_dupes[(filtered_dupes['Record ID'] == 30679) | (filtered_dupes['Record ID'] == 30686)]['Title']
# Out:
# 11353    Acute kidney injury and collapsing glomerulopathy associated with COVID-19 and APOL1 high risk genotype Abstract 621
# 11352    Acute kidney injury and collapsing glomerulopathy associated with COVID-19 and APOL1 high risk genotype Abstract 111
# Name: Title, dtype: object

# %%
filtered_dupes[(filtered_dupes['Record ID'] == 30687) | (filtered_dupes['Record ID'] == 30691)]['Title']
# Out:
# 11365    Filter clotting, anticoagulation and duration of sled in patients with COVID-19 and acute kidney injury Abstract 643
# 11364    Filter clotting, anticoagulation and duration of sled in patients with COVID-19 and acute kidney injury Abstract 112
# Name: Title, dtype: object

# %%
pd.reset_option('display.max_colwidth')
pd.reset_option('display.max_rows')

# %%
# records that should be deleted
records_to_delete = [6000, 2175, 7242]
rwd = rwd[~rwd['Record ID'].isin(records_to_delete)]

# %%
rwd.sort_values(by=['OriginalPaperDOI', 'OriginalPaperDate'], ascending=[True, False], inplace=True)

# Keep only the first occurrence of each unique DOI (the most recent date)
filtered_rwd = rwd.drop_duplicates(subset='OriginalPaperDOI')

# %% [markdown]
# ### Title analysis

# %%
rwd[rwd['Title'].str.startswith("Retracted:")]
# Out:
#        Record ID                                              Title  \
# 13359      45110  Retracted: Lifting the lid on lobbying in Indi...
# 1326       46570  Retracted: miR-214-3p Protects and Restores th...
#
#                                                  Subject  \
# 13359                                  (B/T) Government;
# 1326   (BLS) Biology - Molecular;(BLS) Genetics;(HSC)...
#
#                                              Institution  \
# 13359  Department of Management Studies, Indian Insti...
# 1326   Key Laboratory of Advanced Technologies of Mat...
#
#                                                  Journal Publisher Country  \
# 13359                          Journal of Public Affairs     Wiley   India
# 1326   Evidence-Based Complementary and Alternative M...   Hindawi   China
#
#                                     Author  \
# 13359  Pankaj K P Shreyaskar;Pramod Pathak
# 1326      Yuan Cheng;Qing He;Tao Jin;Na Li
#
#                                                     URLS        ArticleType  \
# 13359                                                NaN  Research Article;
# 1326   https://retractionwatch.com/2022/09/28/exclusi...  Research Article;
#
#       RetractionDate         RetractionDOI RetractionPubMedID  \
# 13359     2020-09-21       10.1002/pa.2423                  0
# 1326      2023-06-21  10.1155/2023/9823451           37388114
#
#       OriginalPaperDate      OriginalPaperDOI OriginalPaperPubMedID  \
# 13359        2020-09-21       10.1002/pa.2423                     0
# 1326         2022-07-18  10.1155/2022/1175935              35899226
#
#       RetractionNature                                             Reason  \
# 13359       Retraction  +Date of Retraction/Other Unknown;+Euphemisms ...
# 1326        Retraction  +Concerns/Issues About Data;+Concerns/Issues a...
#
#       Paywalled                                              Notes
# 13359        No                                                NaN
# 1326         No  See also: https://pubpeer.com/publications/C08...

# %%
rwd['Title'] = rwd['Title'].str.replace('Retracted:', '')

# %%
rwd[rwd['Title'].str.startswith("Retracted:")]
# Out:
# Empty DataFrame
# Columns: [Record ID, Title, Subject, Institution, Journal, Publisher, Country, Author, URLS, ArticleType, RetractionDate, RetractionDOI, RetractionPubMedID, OriginalPaperDate, OriginalPaperDOI, OriginalPaperPubMedID, RetractionNature, Reason, Paywalled, Notes]
# Index: []

# %%
rwd.iloc[[1326,13359]]
# Out:
#        Record ID                                              Title  \
# 12550      25797  LncRNA ATB promotes proliferation and metastas...
# 11996      44387  Preparation of self-healing anti-corrosion coa...
#
#                                                  Subject  \
# 12550  (BLS) Biochemistry;(BLS) Biology - Cancer;(BLS...
# 11996  (PHY) Engineering - Chemical;(PHY) Materials S...
#
#                                              Institution  \
# 12550  Department of Respiratory Medicine, The Affili...
# 11996  Department of Materials Engineering, Isfahan U...
#
#                                 Journal           Publisher Country  \
# 12550  Journal of Cellular Biochemistry               Wiley   China
# 11996               Surface Engineering  Taylor and Francis    Iran
#
#                                                   Author  \
# 12550  Yiwei Cao;Xiangjun Luo;Xiaoqian Ding;Shichao C...
# 11996          Sogand Abbaspour;Ali Ashrafi;Mehdi Salehi
#
#                                                     URLS        ArticleType  \
# 12550  http://retractionwatch.com/2021/03/08/journal-...  Research Article;
# 11996                                                NaN  Research Article;
#
#       RetractionDate                  RetractionDOI RetractionPubMedID  \
# 12550     2020-12-15              10.1002/jcb.29877           33590514
# 11996     2021-02-01  10.1080/02670844.2021.1883242                  0
#
#       OriginalPaperDate               OriginalPaperDOI OriginalPaperPubMedID  \
# 12550        2018-04-25              10.1002/jcb.26894              29693289
# 11996        2019-11-21  10.1080/02670844.2019.1689641                     0
#
#       RetractionNature                                             Reason  \
# 12550       Retraction  +Concerns/Issues About Data;+Concerns/Issues a...
# 11996       Retraction  +Concerns/Issues About Image;+Concerns/Issues ...
#
#       Paywalled                                              Notes
# 12550        No  see also: https://pubpeer.com/publications/B2B...
# 11996        No                                                NaN

# %%
rwd[rwd['Title'].str.contains("(Withdrawn Publication)")]
# Out:
# C:\Users\isabe\AppData\Local\Temp\ipykernel_21056\2493679348.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   rwd[rwd['Title'].str.contains("(Withdrawn Publication)")]
# Empty DataFrame
# Columns: [Record ID, Title, Subject, Institution, Journal, Publisher, Country, Author, URLS, ArticleType, RetractionDate, RetractionDOI, RetractionPubMedID, OriginalPaperDate, OriginalPaperDOI, OriginalPaperPubMedID, RetractionNature, Reason, Paywalled, Notes]
# Index: []

# %% [markdown]
# ## Title Analysis

# %%
# Remove spaces at the end of the string
rwd['Title'] = rwd['Title'].str.rstrip()

#lower case string
rwd['Title'] = rwd['Title'].str.lower()

# %%
rwd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 42697 entries, 29155 to 42695
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Record ID              42697 non-null  int64
#  1   Title                  42697 non-null  object
#  2   Subject                42697 non-null  object
#  3   Institution            42696 non-null  object
#  4   Journal                42697 non-null  object
#  5   Publisher              42697 non-null  object
#  6   Country                42697 non-null  object
#  7   Author                 42697 non-null  object
#  8   URLS                   21686 non-null  object
#  9   ArticleType            42697 non-null  object
#  10  RetractionDate         42697 non-null  datetime64[ns]
#  11  RetractionDOI          42206 non-null  object
#  12  RetractionPubMedID     37596 non-null  object
#  13  OriginalPaperDate      42697 non-null  datetime64[ns]
#  14  OriginalPaperDOI       40170 non-null  object
#  15  OriginalPaperPubMedID  37561 non-null  object
#  16  RetractionNature       42697 non-null  object
#  17  Reason                 42697 non-null  object
#  18  Paywalled              42697 non-null  object
#  19  Notes                  10251 non-null  object
# dtypes: datetime64[ns](2), int64(1), object(17)
# memory usage: 6.8+ MB

# %% [markdown]
# <a class="anchor">
#
# ## 1.2 - Web of Science Data <a class="anchor" id="section_1_2"></a>

# %%
import pyarrow.parquet as pq

# %%
wos_dois_imported = pq.read_table("../thesis_data/processed_data/WoS_RWD_DOIS.parquet").to_pandas()

# %%
wos_dois_imported.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21054 entries, 0 to 21053
# Data columns (total 73 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   AU        21054 non-null  object
#  1   AF        21051 non-null  object
#  2   CR        20943 non-null  object
#  3   AB        19481 non-null  object
#  4   AR        6038 non-null   object
#  5   BE        161 non-null    object
#  6   BN        110 non-null    object
#  7   BP        14782 non-null  object
#  8   C1        20491 non-null  object
#  9   C3        18706 non-null  object
#  10  CA        54 non-null     object
#  11  CL        403 non-null    object
#  12  CT        403 non-null    object
#  13  CY        403 non-null    object
#  14  DA        21054 non-null  object
#  15  DE        13002 non-null  object
#  16  DI        21054 non-null  object
#  17  DT        21054 non-null  object
#  18  EA        2257 non-null   object
#  19  EF        724 non-null    object
#  20  EI        17538 non-null  object
#  21  EM        19617 non-null  object
#  22  EP        14782 non-null  object
#  23  ER        21054 non-null  object
#  24  FU        9005 non-null   object
#  25  FX        8603 non-null   object
#  26  GA        21054 non-null  object
#  27  GP        11 non-null     object
#  28  HC        47 non-null     object
#  29  HO        42 non-null     object
#  30  HP        47 non-null     object
#  31  ID        17378 non-null  object
#  32  IS        14970 non-null  object
#  33  J9        21054 non-null  object
#  34  JI        20884 non-null  object
#  35  LA        21054 non-null  object
#  36  MA        11 non-null     object
#  37  NR        21054 non-null  object
#  38  OA        12129 non-null  object
#  39  OI        8628 non-null   object
#  40  PA        21053 non-null  object
#  41  PD        18458 non-null  object
#  42  PG        21054 non-null  object
#  43  PI        21053 non-null  object
#  44  PM        13884 non-null  object
#  45  PN        429 non-null    object
#  46  PT        21054 non-null  object
#  47  PU        21053 non-null  object
#  48  PY        21054 non-null  float64
#  49  RI        10714 non-null  object
#  50  RP        20368 non-null  object
#  51  SC        21052 non-null  object
#  52  SE        105 non-null    object
#  53  SI        477 non-null    object
#  54  SN        19537 non-null  object
#  55  SO        21054 non-null  object
#  56  SP        212 non-null    object
#  57  SU        274 non-null    object
#  58  TC        21054 non-null  float64
#  59  TI        21054 non-null  object
#  60  U1        21054 non-null  object
#  61  U2        21054 non-null  object
#  62  UT        21054 non-null  object
#  63  VL        20309 non-null  object
#  64  WC        21052 non-null  object
#  65  WE        21054 non-null  object
#  66  Z9        21054 non-null  object
#  67  DB        21054 non-null  object
#  68  AU_UN     20495 non-null  object
#  69  AU1_UN    21054 non-null  object
#  70  AU_UN_NR  0 non-null      object
#  71  SR_FULL   21054 non-null  object
#  72  SR        21054 non-null  object
# dtypes: float64(2), object(71)
# memory usage: 11.7+ MB

# %%
wos_dois = wos_dois_imported.copy()

# %%
wos_dois.filter(like='X.').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21054 entries, 0 to 21053
# Empty DataFrame

# %%
wos_dois.columns
# Out:
# Index(['AU', 'AF', 'CR', 'AB', 'AR', 'BE', 'BN', 'BP', 'C1', 'C3', 'CA', 'CL',
#        'CT', 'CY', 'DA', 'DE', 'DI', 'DT', 'EA', 'EF', 'EI', 'EM', 'EP', 'ER',
#        'FU', 'FX', 'GA', 'GP', 'HC', 'HO', 'HP', 'ID', 'IS', 'J9', 'JI', 'LA',
#        'MA', 'NR', 'OA', 'OI', 'PA', 'PD', 'PG', 'PI', 'PM', 'PN', 'PT', 'PU',
#        'PY', 'RI', 'RP', 'SC', 'SE', 'SI', 'SN', 'SO', 'SP', 'SU', 'TC', 'TI',
#        'U1', 'U2', 'UT', 'VL', 'WC', 'WE', 'Z9', 'DB', 'AU_UN', 'AU1_UN',
#        'AU_UN_NR', 'SR_FULL', 'SR'],
#       dtype='object')

# %%
rename_columns = {
    'AU': "authors", 
    'AF': "author_fullnames", #
    'CR': "cited_references", 
    'AB': "abstract", 
    'AR': "article_number", 
    'BE': "editors", 
    'BN': "isbn", 
    'BP': "beginning_page", #
    'C1': "author_address", 
    'C3': "author_institution", ###
    'CA': "group_authors", ##
    'CL': "conference_location", #
    'CT': "conference_title", #
    'CY': "conference_date", #
    'DA': "date_report_generated", 
    'DE': "author_keywords", 
    'DI': "doi", 
    'DT': "document_type", 
    'EA': "early_access_date", #
    'EF': "ef", #
    'EI': "eissn", #
    'EM':"email_address", 
    'EP': "ending_page", #
    'ER': "end_of_record", #
    'FU': "funding_agency_and_grant_number", 
    'FX': "funding_text", 
    'GA': "document_delivery_number", 
    'GP': "book_group_authors", ##
    'HC': "esi_highly_cited", ##
    'HO': "conference_host", #
    'HP': "esi_hot_paper", ##
    'ID': "keywords_plus", 
    'IS': "issue", #
    'J9': "29_character_source_abv", 
    'JI': "iso_source_abv", 
    'LA': "language", 
    'MA': "meeting_abstract", ##
    'NR': "cited_reference_count", 
    'OA': "open_access_indicator", 
    'OI': "orcid", #
    'PA': "publisher_address", 
    'PD': "publication_date", #
    'PG': "page_count", #
    'PI': "publisher_city", #
    'PM': "pubmed_id", #
    'PN': "part_number",
    'PT': "publication_type", # (J=Journal; B=Book; S=Series; P=Patent)
    'PU': "publisher", 
    'PY': "year_published",  
    'RI': "researcher_id_nr", ##
    'RP': "reprint_address", 
    'SC': "research_areas",
    'SE': "book_series_title", 
    'SI': "special_issue", #
    'SN': "issn", 
    'SO': "publication_name", 
    'SP': "conference_sponsors", #
    'SU': "supplement", #
    'TC': "wos_core_collection_times_cited_count", 
    'TI': "document_title", 
    'U1': "usage_count_last_180_days", #
    'U2': "usage_count_since_2013", 
    'UT': "accession_number",
    'VL': "volume", 
    'WC': "wos_categories", #
    'WE': "we", #
    'Z9': "total_times_cited_count", #
    'DB': "database", 
    'AU_UN': "authors_affiliations", 
    'AU1_UN': "corresponding_author_affiliation",
    'AU_UN_NR': "not_recognized_affiliations", 
    'SR_FULL': "short_full_reference", 
    'SR': "short_reference"

}

wos_dois.rename(columns = rename_columns, inplace = True)
wos_dois.columns
# Out:
# Index(['authors', 'author_fullnames', 'cited_references', 'abstract',
#        'article_number', 'editors', 'isbn', 'beginning_page', 'author_address',
#        'author_institution', 'group_authors', 'conference_location',
#        'conference_title', 'conference_date', 'date_report_generated',
#        'author_keywords', 'doi', 'document_type', 'early_access_date', 'ef',
#        'eissn', 'email_address', 'ending_page', 'end_of_record',
#        'funding_agency_and_grant_number', 'funding_text',
#        'document_delivery_number', 'book_group_authors', 'esi_highly_cited',
#        'conference_host', 'esi_hot_paper', 'keywords_plus', 'issue',
#        '29_character_source_abv', 'iso_source_abv', 'language',
#        'meeting_abstract', 'cited_reference_count', 'open_access_indicator',
#        'orcid', 'publisher_address', 'publication_date', 'page_count',
#        'publisher_city', 'pubmed_id', 'part_number', 'publication_type',
#        'publisher', 'year_published', 'researcher_id_nr', 'reprint_address',
#        'research_areas', 'book_series_title', 'special_issue', 'issn',
#        'publication_name', 'conference_sponsors', 'supplement',
#        'wos_core_collection_times_cited_count', 'document_title',
#        'usage_count_last_180_days', 'usage_count_since_2013',
#        'accession_number', 'volume', 'wos_categories', 'we',
#        'total_times_cited_count', 'database', 'authors_affiliations',
#        'corresponding_author_affiliation', 'not_recognized_affiliations',
#        'short_full_reference', 'short_reference'],
#       dtype='object')

# %%
variables_to_keep = [
       'authors', 'author_fullnames', 'cited_references', 'abstract', 
       'author_keywords', 'doi', 'document_type', 'funding_agency_and_grant_number', 
       'esi_highly_cited', 'esi_hot_paper', 'keywords_plus', 'language', 'early_access_date',
       'cited_reference_count', 'open_access_indicator', 'orcid',  'publication_date', 
       'page_count', 'pubmed_id', 'publication_type', 'publisher', 'year_published', 'researcher_id_nr', 
       'research_areas', 'issn', 'publication_name', 'wos_core_collection_times_cited_count', 'document_title',
       'wos_categories', 'total_times_cited_count','authors_affiliations', 'corresponding_author_affiliation'
       ]


wos_dois = wos_dois[variables_to_keep]

# %%
wos_dois.select_dtypes(include=['object']).columns
# Out:
# Index(['authors', 'author_fullnames', 'cited_references', 'abstract',
#        'author_keywords', 'doi', 'document_type',
#        'funding_agency_and_grant_number', 'esi_highly_cited', 'esi_hot_paper',
#        'keywords_plus', 'language', 'early_access_date',
#        'cited_reference_count', 'open_access_indicator', 'orcid',
#        'publication_date', 'page_count', 'pubmed_id', 'publication_type',
#        'publisher', 'researcher_id_nr', 'research_areas', 'issn',
#        'publication_name', 'document_title', 'wos_categories',
#        'total_times_cited_count', 'authors_affiliations',
#        'corresponding_author_affiliation'],
#       dtype='object')

# %%
wos_dois['total_times_cited_count'].value_counts()
# Out:
# total_times_cited_count
# 1      2042
# 0      1697
# 2      1459
# 3      1188
# 4      1014
#        ...
# 309       1
# 459       1
# 405       1
# 152       1
# 204       1
# Name: count, Length: 425, dtype: int64

# %%
new_data_types = {'cited_reference_count': 'Int64', 
                'page_count': 'Int64',
                'total_times_cited_count': 'Int64', 
                'year_published': 'Int64'}


for col, dtype in new_data_types.items():
    wos_dois[col] = pd.array(wos_dois[col],dtype = pd.Int64Dtype())

wos_dois['early_access_date'] = pd.to_datetime(wos_dois['early_access_date'], format='%b %Y')

# %%
wos_dois.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21054 entries, 0 to 21053
# Data columns (total 32 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   authors                                21054 non-null  object
#  1   author_fullnames                       21051 non-null  object
#  2   cited_references                       20943 non-null  object
#  3   abstract                               19481 non-null  object
#  4   author_keywords                        13002 non-null  object
#  5   doi                                    21054 non-null  object
#  6   document_type                          21054 non-null  object
#  7   funding_agency_and_grant_number        9005 non-null   object
#  8   esi_highly_cited                       47 non-null     object
#  9   esi_hot_paper                          47 non-null     object
#  10  keywords_plus                          17378 non-null  object
#  11  language                               21054 non-null  object
#  12  early_access_date                      2257 non-null   datetime64[ns]
#  13  cited_reference_count                  21054 non-null  Int64
#  14  open_access_indicator                  12129 non-null  object
#  15  orcid                                  8628 non-null   object
#  16  publication_date                       18458 non-null  object
#  17  page_count                             21054 non-null  Int64
#  18  pubmed_id                              13884 non-null  object
#  19  publication_type                       21054 non-null  object
#  20  publisher                              21053 non-null  object
#  21  year_published                         21054 non-null  Int64
#  22  researcher_id_nr                       10714 non-null  object
#  23  research_areas                         21052 non-null  object
#  24  issn                                   19537 non-null  object
#  25  publication_name                       21054 non-null  object
#  26  wos_core_collection_times_cited_count  21054 non-null  float64
#  27  document_title                         21054 non-null  object
#  28  wos_categories                         21052 non-null  object
#  29  total_times_cited_count                21054 non-null  Int64
#  30  authors_affiliations                   20495 non-null  object
#  31  corresponding_author_affiliation       21054 non-null  object
# dtypes: Int64(4), datetime64[ns](1), float64(1), object(26)
# memory usage: 5.2+ MB

# %%
wos_dois = wos_dois[wos_dois['year_published']<2023]

# %%
wos_dois.describe().T
# Out:
#                                          count                           mean  \
# early_access_date                         2027  2020-11-06 01:52:14.681795840
# cited_reference_count                  20727.0                      36.205288
# page_count                             20727.0                       10.17523
# year_published                         20727.0                    2014.803155
# wos_core_collection_times_cited_count  20727.0                      23.465528
# total_times_cited_count                20727.0                       26.08665
#
#                                                        min  \
# early_access_date                      2017-08-01 00:00:00
# cited_reference_count                                  0.0
# page_count                                             0.0
# year_published                                      1940.0
# wos_core_collection_times_cited_count                  0.0
# total_times_cited_count                                0.0
#
#                                                        25%  \
# early_access_date                      2020-04-01 00:00:00
# cited_reference_count                                 22.0
# page_count                                             7.0
# year_published                                      2011.0
# wos_core_collection_times_cited_count                  2.0
# total_times_cited_count                                3.0
#
#                                                        50%  \
# early_access_date                      2020-11-01 00:00:00
# cited_reference_count                                 32.0
# page_count                                             9.0
# year_published                                      2017.0
# wos_core_collection_times_cited_count                  8.0
# total_times_cited_count                                9.0
#
#                                                        75%  \
# early_access_date                      2021-06-01 00:00:00
# cited_reference_count                                 45.0
# page_count                                            12.0
# year_published                                      2020.0
# wos_core_collection_times_cited_count                 23.0
# total_times_cited_count                               25.0
#
#                                                        max        std
# early_access_date                      2024-01-01 00:00:00        NaN
# cited_reference_count                                912.0  27.119912
# page_count                                           572.0   9.837019
# year_published                                      2022.0   6.714835
# wos_core_collection_times_cited_count               2540.0  61.874001
# total_times_cited_count                             2646.0  69.575116

# %%
wos_dois[wos_dois.duplicated()].shape[0]
# Out:
# 2

# %%
wos_dois.shape
# Out:
# (20727, 32)

# %%
# Replace all NaN values with a common value (e.g., a string)
wos_dois = wos_dois.fillna('This is a missing value')

# Use drop_duplicates to remove duplicates with 'NaN' values
wos_dois.drop_duplicates(inplace=True)

# Now, you can replace the 'NaN' values with NaN again if needed
wos_dois = wos_dois.replace('This is a missing value', np.nan)

# %%
wos_dois.shape
# Out:
# (20725, 32)

# %%
wos_dois['publication_date']
# Out:
# 0              SEP 9
# 1                AUG
# 3           2021 SEP
# 4        2021 APR 27
# 5        2021 APR 15
#             ...
# 21026          DEC 1
# 21027       2021 FEB
# 21049         NOV 23
# 21051            APR
# 21052          APR 7
# Name: publication_date, Length: 20725, dtype: object

# %%
wos_dois['publication_date'].fillna('JAN 1', inplace=True)

wos_dois['publication_date'] = pd.to_datetime(wos_dois['publication_date'] + ' ' + wos_dois['year_published'].astype(str), errors='coerce')
wos_dois['publication_date'].fillna(pd.to_datetime('JAN 01 ' + wos_dois['year_published'].astype(str), format='%b %d %Y'), inplace=True)

# Sort the DataFrame by DOI and 'Publication Date' in descending order
wos_dois.sort_values(by=['doi', 'publication_date'], ascending=[True, False], inplace=True)
# Out:
# C:\Users\isabe\AppData\Local\Temp\ipykernel_21056\4019169025.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   wos_dois['publication_date'] = pd.to_datetime(wos_dois['publication_date'] + ' ' + wos_dois['year_published'].astype(str), errors='coerce')

# %%
# Check for NaN values in 'doi' column
wos_dois_filtered = wos_dois.dropna(subset=['doi'])

# Filter rows starting with "http://dx.doi.org/"
wos_dois_filtered[wos_dois_filtered['doi'].str.startswith("http://dx.doi.org/")]['doi']
# Out:
# Series([], Name: doi, dtype: object)

# %%
wos_dois['doi'] = wos_dois['doi'].str.replace('http://dx.doi.org/', '')

# %% [markdown]
# ### Title Analysis

# %%
wos_dois.columns
# Out:
# Index(['authors', 'author_fullnames', 'cited_references', 'abstract',
#        'author_keywords', 'doi', 'document_type',
#        'funding_agency_and_grant_number', 'esi_highly_cited', 'esi_hot_paper',
#        'keywords_plus', 'language', 'early_access_date',
#        'cited_reference_count', 'open_access_indicator', 'orcid',
#        'publication_date', 'page_count', 'pubmed_id', 'publication_type',
#        'publisher', 'year_published', 'researcher_id_nr', 'research_areas',
#        'issn', 'publication_name', 'wos_core_collection_times_cited_count',
#        'document_title', 'wos_categories', 'total_times_cited_count',
#        'authors_affiliations', 'corresponding_author_affiliation'],
#       dtype='object')

# %%
wos_dois[(~wos_dois['document_title'].str.startswith("RETRACTED: ")) & (~wos_dois['document_title'].str.contains("(Withdrawn Publication)")) & ((~wos_dois['document_title'].str.contains("Retracted Article. See")))]
# Out:
# C:\Users\isabe\AppData\Local\Temp\ipykernel_21056\2993378316.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   wos_dois[(~wos_dois['document_title'].str.startswith("RETRACTED: ")) & (~wos_dois['document_title'].str.contains("(Withdrawn Publication)")) & ((~wos_dois['document_title'].str.contains("Retracted Article. See")))]
#                                                  authors  \
# 9916                                      DAS RR;SINGH M
# 20227  FAVINI N;HOCKENBERRY JM;GILMAN M;JAIN S;ONG MK...
# 8143   ROSCHER I;FALK RS;VOS L;CLAUSEN OPF;HELSING P;...
# 4139                  YOUSAF A;LEE JS;FANG W;KOLODNEY MS
# 10542  HOLLON SD;DERUBEIS RJ;FAWCETT J;AMSTERDAM JD;S...
# ...                                                  ...
# 15421                     POEHLMAN ET;TOTH MJ;GARDNER AW
# 20180                           ZHANG J;XIA X;LI S;RAN W
# 20427                        BLUM K;BADGAIYAN RD;GOLD MS
# 8510   GHANDHARI H;SAFARI MB;AMERI E;KHEIRABADI H;TAB...
# 19747                                      LEE CJ;KIM LH
#
#                                         author_fullnames  \
# 9916                     DAS, RASHMI RANJAN;SINGH, MEENU
# 20227  FAVINI, NATHAN;HOCKENBERRY, JASON M.;GILMAN, M...
# 8143   ROSCHER, INGRID;FALK, RAGNHILD S.;VOS, LINDA;C...
# 4139   YOUSAF, AHMED;LEE, JUSTIN;FANG, WEI;KOLODNEY, ...
# 10542  HOLLON, STEVEN D.;DERUBEIS, ROBERT J.;FAWCETT,...
# ...                                                  ...
# 15421                  POEHLMAN, ET;TOTH, MJ;GARDNER, AW
# 20180                   ZHANG, J.;XIA, X.;LI, S.;RAN, W.
# 20427  BLUM, KENNETH;BADGAIYAN, RAJENDRA D.;GOLD, MAR...
# 8510   GHANDHARI, HASAN;SAFARI, MIR BAHRAM;AMERI, EBR...
# 19747                       LEE, CHANG JIN;KIM, LAE HYUN
#
#                                         cited_references  \
# 9916   EBY GA, 2010, MED HYPOTHESES, V74, P482, DOI 1...
# 20227  CAREY K, 2016, HEALTH AFFAIR, V35, P1918, DOI ...
# 8143   ALAM M, 2001, NEW ENGL J MED, V344, P975, DOI ...
# 4139   ANONYMOUS, 2007, UK BIOB RAT DES DEV;BRENNER M...
# 10542  BECK A. T., 1979, COGNITIVE THERAPY OF DEPRESS...
# ...                                                  ...
# 15421  ALOIA JF, 1991, AM J CLIN NUTR, V53, P1378, DO...
# 20180                          ZHANG JC, 2018, PEERJ, V6
# 20427  ADDAD M, 1989, MED LAW, V8, P611;ALLEN CLIFFOR...
# 8510   AMERI E, 2017, CLIN SPINE SURG, V30, PE485, DO...
# 19747  LEE CJ, 2019, KOREAN CHEM ENG RES, V57, P790, ...
#
#                                                 abstract  \
# 9916   CLINICAL QUESTION: IS ORAL ZINC ASSOCIATED WIT...
# 20227                                                NaN
# 8143   IMPORTANCE CUTANEOUS SQUAMOUS CELL CARCINOMA (...
# 4139   IMPORTANCE ALOPECIA AREATA (AA) IS A COMPLEX I...
# 10542  IMPORTANCE ANTIDEPRESSANT MEDICATION (ADM) IS ...
# ...                                                  ...
# 15421  OBJECTIVE: TO DESCRIBE THE EFFECTS OF MENOPAUS...
# 20180                                                NaN
# 20427                                                NaN
# 8510   INTRODUCTION: THE SPINAL CORRECTION AND FUSION...
# 19747                                                NaN
#
#                                          author_keywords  \
# 9916                                                 NaN
# 20227                                                NaN
# 8143                                                 NaN
# 4139                                                 NaN
# 10542                                                NaN
# ...                                                  ...
# 15421                                                NaN
# 20180                                                NaN
# 20427                                                NaN
# 8510   ANTERIOR CORRECTION WITH FUSION SURGERY; COBB ...
# 19747                                                NaN
#
#                                            doi  \
# 9916                    10.1001/jama.2014.1404
# 20227                   10.1001/jama.2017.1469
# 8143            10.1001/jamadermatol.2017.6428
# 4139            10.1001/jamadermatol.2021.0144
# 10542         10.1001/jamapsychiatry.2014.1054
# ...                                        ...
# 15421  10.7326/0003-4819-123-9-199511010-00005
# 20180                       10.7717/peerj.4267
# 20427                       10.7759/cureus.290
# 8510             10.7860/JCDR/2017/29396.11006
# 19747               10.9713/kcer.2019.57.6.790
#
#                                    document_type  \
# 9916   EDITORIAL MATERIAL; WITHDRAWN PUBLICATION
# 20227                                     LETTER
# 8143                                     ARTICLE
# 4139                       ARTICLE; EARLY ACCESS
# 10542                                    ARTICLE
# ...                                          ...
# 15421                                       NOTE
# 20180                                 RETRACTION
# 20427                                 RETRACTION
# 8510              ARTICLE; WITHDRAWN PUBLICATION
# 19747                                 RETRACTION
#
#                          funding_agency_and_grant_number esi_highly_cited  \
# 9916                                                 NaN              NaN
# 20227                     ROBERT WOOD JOHNSON FOUNDATION              NaN
# 8143   OSLO UNIVERSITY HOSPITAL; CANCER REGISTRY OF N...              NaN
# 4139                        WILLIAMWELTON ENDOWMENT FUND              NaN
# 10542  NATIONAL INSTITUTE OF MENTAL HEALTH [MH60713, ...              NaN
# ...                                                  ...              ...
# 15421  NIA NIH HHS [AG-07857, T32-AG00219, KO4-AG0056...              NaN
# 20180                                                NaN              NaN
# 20427  LIFE EXTENSION FOUNDATION, FT. LAUDERDALE, FL....              NaN
# 8510                                                 NaN              NaN
# 19747                                                NaN              NaN
#
#       esi_hot_paper  ...                                   researcher_id_nr  \
# 9916            NaN  ...                                                NaN
# 20227           NaN  ...  ONG, MICHAEL K/F-7397-2013; ONG, MICHAEL/AAR-3...
# 8143            NaN  ...                   FALK, RAGNHILD SØRUM/H-5613-2019
# 4139            NaN  ...                                                NaN
# 10542           NaN  ...                    DERUBEIS, ROBERT J./A-1049-2007
# ...             ...  ...                                                ...
# 15421           NaN  ...                                                NaN
# 20180           NaN  ...                                                NaN
# 20427           NaN  ...                  BADGAIYAN, RAJENDRA D/B-8183-2012
# 8510            NaN  ...  SAFARI, MIR BAHRAM/N-5081-2017; GHANDHARI, HAS...
# 19747           NaN  ...                                                NaN
#
#                             research_areas       issn  \
# 9916           GENERAL & INTERNAL MEDICINE  0098-7484
# 20227          GENERAL & INTERNAL MEDICINE  0098-7484
# 8143                           DERMATOLOGY  2168-6068
# 4139                           DERMATOLOGY  2168-6068
# 10542                           PSYCHIATRY  2168-622X
# ...                                    ...        ...
# 15421          GENERAL & INTERNAL MEDICINE  0003-4819
# 20180  SCIENCE & TECHNOLOGY - OTHER TOPICS  2167-8359
# 20427          GENERAL & INTERNAL MEDICINE        NaN
# 8510           GENERAL & INTERNAL MEDICINE  2249-782X
# 19747                          ENGINEERING  0304-128X
#
#                                        publication_name  \
# 9916   JAMA-JOURNAL OF THE AMERICAN MEDICAL ASSOCIATION
# 20227  JAMA-JOURNAL OF THE AMERICAN MEDICAL ASSOCIATION
# 8143                                   JAMA DERMATOLOGY
# 4139                                   JAMA DERMATOLOGY
# 10542                                   JAMA PSYCHIATRY
# ...                                                 ...
# 15421                       ANNALS OF INTERNAL MEDICINE
# 20180                                             PEERJ
# 20427                 CUREUS JOURNAL OF MEDICAL SCIENCE
# 8510        JOURNAL OF CLINICAL AND DIAGNOSTIC RESEARCH
# 19747              KOREAN CHEMICAL ENGINEERING RESEARCH
#
#       wos_core_collection_times_cited_count  \
# 9916                                    9.0
# 20227                                  18.0
# 8143                                   60.0
# 4139                                    3.0
# 10542                                 122.0
# ...                                     ...
# 15421                                 403.0
# 20180                                   1.0
# 20427                                   6.0
# 8510                                    1.0
# 19747                                   0.0
#
#                                           document_title  \
# 9916   ORAL ZINC FOR THE COMMON COLD (WITHDRAWN PUBLI...
# 20227  COMPARATIVE TRENDS IN PAYMENT ADJUSTMENTS BETW...
# 8143   VALIDATING 4 STAGING SYSTEMS FOR CUTANEOUS SQU...
# 4139   ASSOCIATION BETWEEN ALOPECIA AREATA AND NATURA...
# 10542  EFFECT OF COGNITIVE THERAPY WITH ANTIDEPRESSAN...
# ...                                                  ...
# 15421  CHANGES IN ENERGY-BALANCE AND BODY-COMPOSITION...
# 20180  RETRACTION: RESPONSE OF METHANE PRODUCTION VIA...
# 20427  RETRACTION: HYPERSEXUALITY ADDICTION AND WITHD...
# 8510   CORRELATION CURVE CORRECTION AND SPINAL LENGTH...
# 19747  RETRACTION: CHARACTERISTICS OF DUST EXPLOSION ...
#
#                      wos_categories  total_times_cited_count  \
# 9916   MEDICINE, GENERAL & INTERNAL                       10
# 20227  MEDICINE, GENERAL & INTERNAL                       19
# 8143                    DERMATOLOGY                       61
# 4139                    DERMATOLOGY                        3
# 10542                    PSYCHIATRY                      138
# ...                             ...                      ...
# 15421  MEDICINE, GENERAL & INTERNAL                      457
# 20180    MULTIDISCIPLINARY SCIENCES                        1
# 20427  MEDICINE, GENERAL & INTERNAL                        6
# 8510   MEDICINE, GENERAL & INTERNAL                        1
# 19747         ENGINEERING, CHEMICAL                        0
#
#                                     authors_affiliations  \
# 9916   ALL INDIA INSTITUTE OF MEDICAL SCIENCES (AIIMS...
# 20227  UNIVERSITY OF CALIFORNIA SYSTEM; UNIVERSITY OF...
# 8143   UNIVERSITY OF OSLO; UNIVERSITY OF OSLO; UNIVER...
# 4139                            WEST VIRGINIA UNIVERSITY
# 10542  VANDERBILT UNIVERSITY; UNIVERSITY OF PENNSYLVA...
# ...                                                  ...
# 15421  UNIVERSITY SYSTEM OF MARYLAND; UNIVERSITY OF M...
# 20180                                                NaN
# 20427                                                NaN
# 8510   IRAN UNIVERSITY OF MEDICAL SCIENCES; URMIA UNI...
# 19747  SEOUL NATIONAL UNIVERSITY OF SCIENCE AND TECHN...
#
#       corresponding_author_affiliation
# 9916    POSTGRAD INST MED EDUC AND RES
# 20227                       EMORY UNIV
# 8143                    OSLO UNIV HOSP
# 4139                WEST VIRGINIA UNIV
# 10542                  VANDERBILT UNIV
# ...                                ...
# 15421              VET AFFAIRS MED CTR
# 20180                      NOTREPORTED
# 20427                      NOTREPORTED
# 8510                URMIA UNIV MED SCI
# 19747  SEOUL NATL UNIV SCI AND TECHNOL
#
# [2212 rows x 32 columns]

# %%
wos_dois[(wos_dois['document_title'].str.startswith("RETRACTED: ")) | (wos_dois['document_title'].str.contains("(Withdrawn Publication)")) | ((wos_dois['document_title'].str.contains("Retracted Article. See")))]
# Out:
# C:\Users\isabe\AppData\Local\Temp\ipykernel_21056\1192745157.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   wos_dois[(wos_dois['document_title'].str.startswith("RETRACTED: ")) | (wos_dois['document_title'].str.contains("(Withdrawn Publication)")) | ((wos_dois['document_title'].str.contains("Retracted Article. See")))]
#                                                  authors  \
# 10235                  SATO Y;KANOKO T;SATOH K;IWAMOTO J
# 10236                  SATO Y;IWAMOTO J;KANOKO T;SATOH K
# 15186  PANAGIOTAKOS DB;KROMHOUT D;MENOTTI A;CHRYSOHOO...
# 20101                          WANSINK B;TAL A;SHIMIZU M
# 13201                             FUJII Y;TANAKA H;ITO M
# ...                                                  ...
# 6086   BISWAS S;VERMA R;BHATIA VK;CHAUDHARY AK;CHANDR...
# 6244                                   JAIN MJ;MAVANI KJ
# 8989                           SHAH AF;BATRA M;QURESHI A
# 7864                        PATRO S;MOHAPATRA S;MISHRA S
# 9449   LIU XC;JIA WX;WANG H;WANG YL;MA JX;WANG H;ZHOU...
#
#                                         author_fullnames  \
# 10235              SATO, Y;KANOKO, T;SATOH, K;IWAMOTO, J
# 10236              SATO, Y;IWAMOTO, J;KANOKO, T;SATOH, K
# 15186  PANAGIOTAKOS, DB;KROMHOUT, D;MENOTTI, A;CHRYSO...
# 20101          WANSINK, BRIAN;TAL, ANER;SHIMIZU, MITSURU
# 13201                          FUJII, Y;TANAKA, H;ITO, M
# ...                                                  ...
# 6086   BISWAS, SONIYA;VERMA, REETU;BHATIA, VINOD KUMA...
# 6244                    JAIN, MOHIT J.;MAVANI, KINJAL J.
# 8989     SHAH, AASIM FAROOQ;BATRA, MANU;QURESHI, AMBRINA
# 7864   PATRO, SWADHEENA;MOHAPATRA, SATYAJIT;MISHRA, S...
# 9449   LIU, XIAOCHEN;JIA, WENXIAO;WANG, HONG;WANG, YU...
#
#                                         cited_references  \
# 10235  ANONYMOUS, COCHRANE DATABASE SY;BISCHOFF-FERRA...
# 10236  CHAPUY MC, 1992, NEW ENGL J MED, V327, P1637, ...
# 15186  ANDERSON JT, 1956, CLIN CHEM, V2, P145;BENETOS...
# 20101  FROST G, 1987, HUM NUTR-APPL NUTR, V41A, P47;G...
# 13201  ABRAMOWITZ MD, 1983, ANESTHESIOLOGY, V59, P579...
# ...                                                  ...
# 6086   ASIDA SM, 2012, EGYPT J ANAESTH, V28, P55, DOI...
# 6244   ANDERSON JOHN T, 2004, IOWA ORTHOP J, V24, P53...
# 8989   ACHARYA S, 2009, INT J DENT HYG, V7, P102, DOI...
# 7864   AHLBERG KMF, 1995, INT ENDOD J, V28, P30, DOI ...
# 9449   CAPUANO SV, 2003, INFECT IMMUN, V71, P5831, DO...
#
#                                                 abstract  \
# 10235  BACKGROUND: A HIGH INCIDENCE OF FRACTURES, PAR...
# 10236  BACKGROUND: THERE IS A HIGH INCIDENCE OF HIP F...
# 15186  BACKGROUND: HYPERTENSION IS A DOMINANT CHARACT...
# 20101                                                NaN
# 13201  BACKGROUND: POSTOPERATIVE VOMITING (POV) AFTER...
# ...                                                  ...
# 6086   INTRODUCTION: POSTOPERATIVE PAIN AFTER THORACO...
# 6244   INTRODUCTION: THE MANAGEMENT OF HIGHLY COMMINU...
# 8989   INTRODUCTION: ORAL HEALTH IS A KEY COMPONENT O...
# 7864   INTRODUCTION: IT IS CLINICALLY VERY IMPORTANT ...
# 9449   THIS STUDY AIMED TO ESTABLISH A SPINAL TUBERCU...
#
#                                          author_keywords  \
# 10235                                                NaN
# 10236                                                NaN
# 15186                                                NaN
# 20101                                                NaN
# 13201                                                NaN
# ...                                                  ...
# 6086            BUPIVACAINE; FENTANYL; PAINFUL SURGERIES
# 6244   DISTAL END RADIUS FRACTURES; DYNAMIC COMPRESSI...
# 8989   POSTPARTUM FEMALES; PREGNANT WOMEN; PERIODONTA...
# 7864   EVALUATION STUDIES; OBTURATION; PREMETREXED; T...
# 9449                                                 NaN
#
#                                    doi                   document_type  \
# 10235     10.1001/archinte.165.15.1737  ARTICLE; RETRACTED PUBLICATION
# 10236     10.1001/archinte.165.15.1743  ARTICLE; RETRACTED PUBLICATION
# 15186     10.1001/archinte.165.18.2142  ARTICLE; RETRACTED PUBLICATION
# 20101  10.1001/archinternmed.2012.1278   LETTER; RETRACTED PUBLICATION
# 13201        10.1001/archopht.123.1.25  ARTICLE; RETRACTED PUBLICATION
# ...                                ...                             ...
# 6086      10.7860/JCDR/2016/19159.8489  ARTICLE; RETRACTED PUBLICATION
# 6244      10.7860/JCDR/2016/21926.9036  ARTICLE; RETRACTED PUBLICATION
# 8989      10.7860/JCDR/2017/25862.9769  ARTICLE; RETRACTED PUBLICATION
# 7864     10.7860/JCDR/2019/32601.12609  ARTICLE; RETRACTED PUBLICATION
# 9449       10.7883/yoken.JJID.2014.147  ARTICLE; RETRACTED PUBLICATION
#
#                          funding_agency_and_grant_number esi_highly_cited  \
# 10235                                                NaN              NaN
# 10236                                                NaN              NaN
# 15186                                                NaN              NaN
# 20101                                                NaN              NaN
# 13201                                                NaN              NaN
# ...                                                  ...              ...
# 6086                                                 NaN              NaN
# 6244                                                 NaN              NaN
# 8989                                                 NaN              NaN
# 7864                                                 NaN              NaN
# 9449   NATIONAL NATURAL SCIENCE FOUNDATION OF CHINA [...              NaN
#
#       esi_hot_paper  ...                                   researcher_id_nr  \
# 10235           NaN  ...                                                NaN
# 10236           NaN  ...                                                NaN
# 15186           NaN  ...  PANAGIOTAKOS, DEMOSTHENES/K-8294-2019; PANAGIO...
# 20101           NaN  ...                                                NaN
# 13201           NaN  ...                                                NaN
# ...             ...  ...                                                ...
# 6086            NaN  ...                      CHAUDHARY, AJAY K/A-1399-2015
# 6244            NaN  ...                          JAIN, MOHIT/AAY-4869-2020
# 8989            NaN  ...                                                NaN
# 7864            NaN  ...                     PATRO, SWADHEENA/AAZ-8764-2021
# 9449            NaN  ...                                                NaN
#
#                     research_areas       issn  \
# 10235  GENERAL & INTERNAL MEDICINE  0003-9926
# 10236  GENERAL & INTERNAL MEDICINE  0003-9926
# 15186  GENERAL & INTERNAL MEDICINE  0003-9926
# 20101  GENERAL & INTERNAL MEDICINE  0003-9926
# 13201                OPHTHALMOLOGY  0003-9950
# ...                            ...        ...
# 6086   GENERAL & INTERNAL MEDICINE  2249-782X
# 6244   GENERAL & INTERNAL MEDICINE  2249-782X
# 8989   GENERAL & INTERNAL MEDICINE  2249-782X
# 7864   GENERAL & INTERNAL MEDICINE  2249-782X
# 9449           INFECTIOUS DISEASES  1344-6304
#
#                                   publication_name  \
# 10235                ARCHIVES OF INTERNAL MEDICINE
# 10236                ARCHIVES OF INTERNAL MEDICINE
# 15186                ARCHIVES OF INTERNAL MEDICINE
# 20101                ARCHIVES OF INTERNAL MEDICINE
# 13201                    ARCHIVES OF OPHTHALMOLOGY
# ...                                            ...
# 6086   JOURNAL OF CLINICAL AND DIAGNOSTIC RESEARCH
# 6244   JOURNAL OF CLINICAL AND DIAGNOSTIC RESEARCH
# 8989   JOURNAL OF CLINICAL AND DIAGNOSTIC RESEARCH
# 7864   JOURNAL OF CLINICAL AND DIAGNOSTIC RESEARCH
# 9449       JAPANESE JOURNAL OF INFECTIOUS DISEASES
#
#       wos_core_collection_times_cited_count  \
# 10235                                  48.0
# 10236                                 113.0
# 15186                                  53.0
# 20101                                  14.0
# 13201                                  10.0
# ...                                     ...
# 6086                                   19.0
# 6244                                    9.0
# 8989                                    6.0
# 7864                                    0.0
# 9449                                    7.0
#
#                                           document_title  \
# 10235  RETRACTED: THE PREVENTION OF HIP FRACTURE WITH...
# 10236  RETRACTED: RISEDRONATE SODIUM THERAPY FOR PREV...
# 15186  RETRACTED: THE RELATION BETWEEN PULSE PRESSURE...
# 20101  RETRACTED: FIRST FOODS MOST: AFTER 18-HOUR FAS...
# 13201  RETRACTED: A RANDOMIZED CLINICAL TRIAL OF A SI...
# ...                                                  ...
# 6086   RETRACTED: COMPARISON BETWEEN THORACIC EPIDURA...
# 6244   RETRACTED: A COMPREHENSIVE STUDY OF INTERNAL D...
# 8989   RETRACTED: EVALUATION OF IMPACT OF PREGNANCY O...
# 7864   RETRACTED: COMPARATIVE EVALUATION OF APICAL MI...
# 9449   RETRACTED: ESTABLISHMENT OF A RABBIT MODEL OF ...
#
#                      wos_categories  total_times_cited_count  \
# 10235  MEDICINE, GENERAL & INTERNAL                       52
# 10236  MEDICINE, GENERAL & INTERNAL                      119
# 15186  MEDICINE, GENERAL & INTERNAL                       55
# 20101  MEDICINE, GENERAL & INTERNAL                       14
# 13201                 OPHTHALMOLOGY                       11
# ...                             ...                      ...
# 6086   MEDICINE, GENERAL & INTERNAL                       21
# 6244   MEDICINE, GENERAL & INTERNAL                       10
# 8989   MEDICINE, GENERAL & INTERNAL                        7
# 7864   MEDICINE, GENERAL & INTERNAL                        0
# 9449            INFECTIOUS DISEASES                       14
#
#                                     authors_affiliations  \
# 10235  HIROSAKI UNIVERSITY; HIROSAKI UNIVERSITY; KEIO...
# 10236  KEIO UNIVERSITY; HIROSAKI UNIVERSITY; HIROSAKI...
# 15186  HAROKOPIO UNIVERSITY ATHENS; NETHERLANDS NATIO...
# 20101                                 CORNELL UNIVERSITY
# 13201        TORIDE KYODO GEN HOSP;TORIDE KYODO GEN HOSP
# ...                                                  ...
# 6086                    KING GEORGE'S MEDICAL UNIVERSITY
# 6244    SANJEEVANI MULTISPECIAL HOSP;MARATHA MANDAL INST
# 8989                   DOW UNIVERSITY OF HEALTH SCIENCES
# 7864   SIKSHA 'O' ANUSANDHAN UNIVERSITY; SIKSHA 'O' A...
# 9449   XINJIANG MEDICAL UNIVERSITY; XINJIANG MEDICAL ...
#
#       corresponding_author_affiliation
# 10235                      MITATE HOSP
# 10236                      MITATE HOSP
# 15186        DB (CORRESPONDING AUTHOR)
# 20101                     CORNELL UNIV
# 13201                     UNIV TSUKUBA
# ...                                ...
# 6086          R (CORRESPONDING AUTHOR)
# 6244         MJ (CORRESPONDING AUTHOR)
# 8989                GOVT COLL AND HOSP
# 7864                          SOA UNIV
# 9449                 XINJIANG MED UNIV
#
# [18513 rows x 32 columns]

# %%
# Remove the Alterations to the name of the article
wos_dois['document_title'] = wos_dois['document_title'].str.replace('RETRACTED: ', '')
wos_dois['document_title'] = wos_dois['document_title'].str.replace('(Withdrawn Publication)', '')
wos_dois['document_title'] = wos_dois['document_title'].str.replace('(Withdrawn publication)', '')
wos_dois['document_title'] = wos_dois['document_title'].str.replace('</bold>', '')
wos_dois['document_title'] = wos_dois['document_title'].str.replace('<bold>', '')

# %%
# Some records include variations of the phrase "(Retracted article. See XX)". 
# Where XX is has variable length and characters, but always ends with ")"
def remove_retraction_phrase(title):

    # Define the pattern to match the retraction phrase
    pattern = r'\(retracted article\. see [^\)]+\)'
    return re.sub(pattern, '', str.lower(title)).strip()

# Apply the function to the 'Document Title' column
wos_dois['document_title'] = wos_dois['document_title'].apply(remove_retraction_phrase)

# %%
def remove_retraction_phrase(title):

    # Define the pattern to match the retraction phrase
    pattern = r'\(withdrawal of [^\)]+\)'
    return re.sub(pattern, '', str.lower(title)).strip()

# Apply the function to the 'Document Title' column
wos_dois['document_title'] = wos_dois['document_title'].apply(remove_retraction_phrase)

# %%
# Remove spaces at the end of the string
wos_dois['document_title'] = wos_dois['document_title'].str.rstrip()

#lower case string
wos_dois['document_title'] = wos_dois['document_title'].str.lower()

# %% [markdown]
# ### Duplicates

# %%
wos_dois[wos_dois.duplicated(subset='doi', keep=False)].shape
# Out:
# (216, 32)

# %%
wos_dois['doi'].nunique()
# Out:
# 20617

# %%
wos_dois.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20725 entries, 10235 to 19747
# Data columns (total 32 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   authors                                20725 non-null  object
#  1   author_fullnames                       20723 non-null  object
#  2   cited_references                       20620 non-null  object
#  3   abstract                               19231 non-null  object
#  4   author_keywords                        12766 non-null  object
#  5   doi                                    20725 non-null  object
#  6   document_type                          20725 non-null  object
#  7   funding_agency_and_grant_number        8917 non-null   object
#  8   esi_highly_cited                       47 non-null     object
#  9   esi_hot_paper                          47 non-null     object
#  10  keywords_plus                          17196 non-null  object
#  11  language                               20725 non-null  object
#  12  early_access_date                      2027 non-null   datetime64[ns]
#  13  cited_reference_count                  20725 non-null  Int64
#  14  open_access_indicator                  11982 non-null  object
#  15  orcid                                  8492 non-null   object
#  16  publication_date                       20725 non-null  datetime64[ns]
#  17  page_count                             20725 non-null  Int64
#  18  pubmed_id                              13763 non-null  object
#  19  publication_type                       20725 non-null  object
#  20  publisher                              20724 non-null  object
#  21  year_published                         20725 non-null  Int64
#  22  researcher_id_nr                       10556 non-null  object
#  23  research_areas                         20723 non-null  object
#  24  issn                                   19222 non-null  object
#  25  publication_name                       20725 non-null  object
#  26  wos_core_collection_times_cited_count  20725 non-null  float64
#  27  document_title                         20725 non-null  object
#  28  wos_categories                         20723 non-null  object
#  29  total_times_cited_count                20725 non-null  Int64
#  30  authors_affiliations                   20182 non-null  object
#  31  corresponding_author_affiliation       20725 non-null  object
# dtypes: Int64(4), datetime64[ns](2), float64(1), object(25)
# memory usage: 5.3+ MB

# %%
#control_set.iloc[[2,6,36,58,60,65,67,68]]

# %%
wos_dois['doi'].value_counts()
# Out:
# doi
# 10.1186/1479-5876-6-27        2
# 10.1186/ar4300                2
# 10.1177/1533033819861971      2
# 10.1177/1533033819870209      2
# 10.1177/1533033819870791      2
#                              ..
# 10.1016/j.omtn.2019.06.003    1
# 10.1016/j.omtn.2019.05.020    1
# 10.1016/j.omtn.2019.05.014    1
# 10.1016/j.omtn.2019.02.022    1
# 10.9713/kcer.2019.57.6.790    1
# Name: count, Length: 20617, dtype: int64

# %%
wos_dois.shape
# Out:
# (20725, 32)

# %%
wos_dois[wos_dois.duplicated(subset='doi', keep=False)]
# Out:
#                                                  authors  \
# 2865        YU L;LI HT;LIU WH;ZHANG LG;TIAN Q;LI HR;LI M
# 2866        YU L;LI HT;LIU WH;ZHANG LG;TIAN Q;LI HR;LI M
# 20732                                  BISWAS S;RAHMAN I
# 14734                                  BISWAS S;RAHMAN I
# 16487  ALLAM AA;EL-GHAREEB AW;ABDUL-HAMID M;BAKERY AE...
# ...                                                  ...
# 17688        YANG J;MOHSENI E;BEHFOROUZ B;KHOTBEHSARA MM
# 301                          FANG X;TONG KZ;WANG X;NI HF
# 324                          FANG X;TONG KZ;WANG X;NI HF
# 20789                     POEHLMAN ET;TOTH MJ;GARDNER AW
# 15421                     POEHLMAN ET;TOTH MJ;GARDNER AW
#
#                                         author_fullnames  \
# 2865   YU, LING;LI, HAITING;LIU, WENHU;ZHANG, LIGONG;...
# 2866   YU, LING;LI, HAITING;LIU, WENHU;ZHANG, LIGONG;...
# 20732                       BISWAS, SAIBAL;RAHMAN, IRFAN
# 14734                       BISWAS, SAIBAL;RAHMAN, IRFAN
# 16487  ALLAM, AHMED ALY;EL-GHAREEB, ABDEL WHAAB;ABDUL...
# ...                                                  ...
# 17688  YANG, JIAN;MOHSENI, EHSAN;BEHFOROUZ, BABAK;KHO...
# 301        FANG, XING;TONG, KE-ZHEN;WANG, XIN;NI, HUA-FU
# 324        FANG, XING;TONG, KE-ZHEN;WANG, XIN;NI, HUA-FU
# 20789                  POEHLMAN, ET;TOTH, MJ;GARDNER, AW
# 15421                  POEHLMAN, ET;TOTH, MJ;GARDNER, AW
#
#                                         cited_references  \
# 2865   ALKASIR R, 2017, PROTEIN CELL, V8, P90, DOI 10...
# 2866   ALKASIR R, 2017, PROTEIN CELL, V8, P90, DOI 10...
# 20732  BISWAS S, 2008, MOL NUTR FOOD RES, V52, P987, ...
# 14734  ABE Y, 1999, PHARMACOL RES, V39, P41, DOI 10.1...
# 16487  ABDUL-HAMID M., 2005, J EGYPT GER SOC ZOOL, V2...
# ...                                                  ...
# 17688  ANONYMOUS, 2003, ANN BOOK ASTM STAND, V04.05;A...
# 301    FANG X, 2022, J OLEO SCI, V71, P1695, DOI 10.5...
# 324    ALVAREZ N, 2018, INORG CHIM ACTA, V483, P61, D...
# 20789  POEHLMAN ET, 1995, ANN INTERN MED, V123, P673,...
# 15421  ALOIA JF, 1991, AM J CLIN NUTR, V53, P1378, DO...
#
#                                                 abstract  \
# 2865   BACKGROUND: NUMEROUS MICRORNAS (MIRNAS) HAVE B...
# 2866   BACKGROUND: NUMEROUS MICRORNAS (MIRNAS) HAVE B...
# 20732                                                NaN
# 14734  THE EXPRESSION OF NF-KAPPAB (NF-KAPPA B)-DEPEN...
# 16487  ACRYLAMIDE HAS BEEN EMPLOYED AS AN EXPERIMENTA...
# ...                                                  ...
# 17688  IN THIS PAPER, THE EFFECTS OF USING CR2O3 AND ...
# 301    IN THIS STUDY, TWO NEW MIXED-LIGAND COORDINATI...
# 324    IN THIS STUDY, TWO NEW MIXED-LIGAND COORDINATI...
# 20789                                                NaN
# 15421  OBJECTIVE: TO DESCRIBE THE EFFECTS OF MENOPAUS...
#
#                                          author_keywords  \
# 2865   AKT3; ALZHEIMER'S DISEASE; APOPTOSIS; DIAGNOSI...
# 2866   AKT3; ALZHEIMER'S DISEASE; APOPTOSIS; DIAGNOSI...
# 20732                                                NaN
# 14734  ASTHMA; CHRONIC OBSTRUCTIVE PULMONARY DISEASE;...
# 16487  ACRYLAMIDE; LIVER DEVELOPMENT; LIPID PEROXIDAT...
# ...                                                  ...
# 17688  SELF-COMPACTING MORTAR; CR2O3 NANOPARTICLES; Z...
# 301    COORDINATION POLYMERS; MIXED-LIGAND; X-RAY DIF...
# 324    COORDINATION POLYMERS; MIXED-LIGAND; X-RAY DIF...
# 20789                                                NaN
# 15421                                                NaN
#
#                                            doi  \
# 2865                         10.1002/mgg3.1548
# 2866                         10.1002/mgg3.1548
# 20732                   10.1002/mnfr.200700259
# 14734                   10.1002/mnfr.200700259
# 16487                10.1007/s00204-009-0475-2
# ...                                        ...
# 17688                       10.3139/146.111245
# 301                       10.5650/jos.ess20047
# 324                       10.5650/jos.ess20047
# 20789  10.7326/0003-4819-123-9-199511010-00005
# 15421  10.7326/0003-4819-123-9-199511010-00005
#
#                                       document_type  \
# 2865                                        ARTICLE
# 2866   ARTICLE; EARLY ACCESS; RETRACTED PUBLICATION
# 20732                                    CORRECTION
# 14734                 REVIEW; RETRACTED PUBLICATION
# 16487                ARTICLE; RETRACTED PUBLICATION
# ...                                             ...
# 17688                ARTICLE; RETRACTED PUBLICATION
# 301               RETRACTION; RETRACTED PUBLICATION
# 324                                         ARTICLE
# 20789                                    CORRECTION
# 15421                                          NOTE
#
#                          funding_agency_and_grant_number esi_highly_cited  \
# 2865                                                 NaN              NaN
# 2866                                                 NaN              NaN
# 20732                                                NaN              NaN
# 14734   NIEHS NIH HHS [ES-01247] FUNDING SOURCE: MEDLINE              NaN
# 16487                                                NaN              NaN
# ...                                                  ...              ...
# 17688                                                NaN              NaN
# 301                                                  NaN              NaN
# 324                                                  NaN              NaN
# 20789                                                NaN              NaN
# 15421  NIA NIH HHS [AG-07857, T32-AG00219, KO4-AG0056...              NaN
#
#       esi_hot_paper  ...                                   researcher_id_nr  \
# 2865            NaN  ...                                                NaN
# 2866            NaN  ...                                                NaN
# 20732           NaN  ...                                                NaN
# 14734           NaN  ...                                                NaN
# 16487           NaN  ...                                                NaN
# ...             ...  ...                                                ...
# 17688           NaN  ...  YANG, JIAN/AHB-7153-2022; BEHFOROUZ, BABAK/AAC...
# 301             NaN  ...                                                NaN
# 324             NaN  ...                                                NaN
# 20789           NaN  ...                                                NaN
# 15421           NaN  ...                                                NaN
#
#                                research_areas       issn  \
# 2865                      GENETICS & HEREDITY  2324-9269
# 2866                      GENETICS & HEREDITY  2324-9269
# 20732               FOOD SCIENCE & TECHNOLOGY  1613-4125
# 14734               FOOD SCIENCE & TECHNOLOGY  1613-4125
# 16487                              TOXICOLOGY  0340-5761
# ...                                       ...        ...
# 17688  METALLURGY & METALLURGICAL ENGINEERING  1862-5282
# 301      CHEMISTRY; FOOD SCIENCE & TECHNOLOGY  1345-8957
# 324      CHEMISTRY; FOOD SCIENCE & TECHNOLOGY  1345-8957
# 20789             GENERAL & INTERNAL MEDICINE  0003-4819
# 15421             GENERAL & INTERNAL MEDICINE  0003-4819
#
#                                   publication_name  \
# 2865         MOLECULAR GENETICS & GENOMIC MEDICINE
# 2866         MOLECULAR GENETICS & GENOMIC MEDICINE
# 20732          MOLECULAR NUTRITION & FOOD RESEARCH
# 14734          MOLECULAR NUTRITION & FOOD RESEARCH
# 16487                       ARCHIVES OF TOXICOLOGY
# ...                                            ...
# 17688  INTERNATIONAL JOURNAL OF MATERIALS RESEARCH
# 301                        JOURNAL OF OLEO SCIENCE
# 324                        JOURNAL OF OLEO SCIENCE
# 20789                  ANNALS OF INTERNAL MEDICINE
# 15421                  ANNALS OF INTERNAL MEDICINE
#
#       wos_core_collection_times_cited_count  \
# 2865                                   19.0
# 2866                                   19.0
# 20732                                   0.0
# 14734                                  43.0
# 16487                                   0.0
# ...                                     ...
# 17688                                   0.0
# 301                                     1.0
# 324                                     1.0
# 20789                                   3.0
# 15421                                 403.0
#
#                                           document_title  \
# 2865   mir-485-3p serves as a biomarker and therapeut...
# 2866   mir-485-3p serves as a biomarker and therapeut...
# 20732  modulation of steroid activity in chronic infl...
# 14734  modulation of steroid activity in chronic infl...
# 16487  effect of prenatal and perinatal acrylamide on...
# ...                                                  ...
# 17688  an experimental investigation into the effects...
# 301    retraction: two mixed-ligand coordination poly...
# 324    two mixed-ligand coordination polymers: crysta...
# 20789  changes in energy balance and body composition...
# 15421  changes in energy-balance and body-composition...
#
#                                       wos_categories  total_times_cited_count  \
# 2865                             GENETICS & HEREDITY                       20
# 2866                             GENETICS & HEREDITY                       20
# 20732                      FOOD SCIENCE & TECHNOLOGY                        0
# 14734                      FOOD SCIENCE & TECHNOLOGY                       49
# 16487                                     TOXICOLOGY                        0
# ...                                              ...                      ...
# 17688         METALLURGY & METALLURGICAL ENGINEERING                        0
# 301    CHEMISTRY, APPLIED; FOOD SCIENCE & TECHNOLOGY                        1
# 324    CHEMISTRY, APPLIED; FOOD SCIENCE & TECHNOLOGY                        1
# 20789                   MEDICINE, GENERAL & INTERNAL                        3
# 15421                   MEDICINE, GENERAL & INTERNAL                      457
#
#                                     authors_affiliations  \
# 2865                          SHENGLI OILFIELD CENT HOSP
# 2866                          SHENGLI OILFIELD CENT HOSP
# 20732                                                NaN
# 14734                            UNIVERSITY OF ROCHESTER
# 16487  EGYPTIAN KNOWLEDGE BANK (EKB); BENI SUEF UNIVE...
# ...                                                  ...
# 17688  SHANGHAI JIAO TONG UNIVERSITY; UNIVERSITY OF G...
# 301                                                  NaN
# 324      BEILUN PEOPLES HOSP;NINGBO YINZHOU PEOPLES HOSP
# 20789                                                NaN
# 15421  UNIVERSITY SYSTEM OF MARYLAND; UNIVERSITY OF M...
#
#       corresponding_author_affiliation
# 2865        SHENGLI OILFIELD CENT HOSP
# 2866        SHENGLI OILFIELD CENT HOSP
# 20732                      NOTREPORTED
# 14734                   UNIV ROCHESTER
# 16487         OREGON HLTH AND SCI UNIV
# ...                                ...
# 17688                      UNIV GUILAN
# 301                        NOTREPORTED
# 324                BEILUN PEOPLES HOSP
# 20789                      NOTREPORTED
# 15421              VET AFFAIRS MED CTR
#
# [216 rows x 32 columns]

# %%
testing_dupes = wos_dois[wos_dois.duplicated(subset='doi', keep=False)]
testing_dupes['doi'].value_counts()
# Out:
# doi
# 10.1002/mgg3.1548                          2
# 10.1159/000099107                          2
# 10.1177/1533033819850189                   2
# 10.1177/1533033818821401                   2
# 10.1177/1466138108089466                   2
#                                           ..
# 10.1038/s41467-019-13388-8                 2
# 10.1038/s41419-018-1090-z                  2
# 10.1038/s41419-018-0978-y                  2
# 10.1038/s41388-018-0628-y                  2
# 10.7326/0003-4819-123-9-199511010-00005    2
# Name: count, Length: 108, dtype: int64

# %%
testing_dupes = testing_dupes.sort_values('doi')

# %%
testing_dupes
# Out:
#                                                  authors  \
# 2865        YU L;LI HT;LIU WH;ZHANG LG;TIAN Q;LI HR;LI M
# 2866        YU L;LI HT;LIU WH;ZHANG LG;TIAN Q;LI HR;LI M
# 20732                                  BISWAS S;RAHMAN I
# 14734                                  BISWAS S;RAHMAN I
# 16487  ALLAM AA;EL-GHAREEB AW;ABDUL-HAMID M;BAKERY AE...
# ...                                                  ...
# 17688        YANG J;MOHSENI E;BEHFOROUZ B;KHOTBEHSARA MM
# 301                          FANG X;TONG KZ;WANG X;NI HF
# 324                          FANG X;TONG KZ;WANG X;NI HF
# 20789                     POEHLMAN ET;TOTH MJ;GARDNER AW
# 15421                     POEHLMAN ET;TOTH MJ;GARDNER AW
#
#                                         author_fullnames  \
# 2865   YU, LING;LI, HAITING;LIU, WENHU;ZHANG, LIGONG;...
# 2866   YU, LING;LI, HAITING;LIU, WENHU;ZHANG, LIGONG;...
# 20732                       BISWAS, SAIBAL;RAHMAN, IRFAN
# 14734                       BISWAS, SAIBAL;RAHMAN, IRFAN
# 16487  ALLAM, AHMED ALY;EL-GHAREEB, ABDEL WHAAB;ABDUL...
# ...                                                  ...
# 17688  YANG, JIAN;MOHSENI, EHSAN;BEHFOROUZ, BABAK;KHO...
# 301        FANG, XING;TONG, KE-ZHEN;WANG, XIN;NI, HUA-FU
# 324        FANG, XING;TONG, KE-ZHEN;WANG, XIN;NI, HUA-FU
# 20789                  POEHLMAN, ET;TOTH, MJ;GARDNER, AW
# 15421                  POEHLMAN, ET;TOTH, MJ;GARDNER, AW
#
#                                         cited_references  \
# 2865   ALKASIR R, 2017, PROTEIN CELL, V8, P90, DOI 10...
# 2866   ALKASIR R, 2017, PROTEIN CELL, V8, P90, DOI 10...
# 20732  BISWAS S, 2008, MOL NUTR FOOD RES, V52, P987, ...
# 14734  ABE Y, 1999, PHARMACOL RES, V39, P41, DOI 10.1...
# 16487  ABDUL-HAMID M., 2005, J EGYPT GER SOC ZOOL, V2...
# ...                                                  ...
# 17688  ANONYMOUS, 2003, ANN BOOK ASTM STAND, V04.05;A...
# 301    FANG X, 2022, J OLEO SCI, V71, P1695, DOI 10.5...
# 324    ALVAREZ N, 2018, INORG CHIM ACTA, V483, P61, D...
# 20789  POEHLMAN ET, 1995, ANN INTERN MED, V123, P673,...
# 15421  ALOIA JF, 1991, AM J CLIN NUTR, V53, P1378, DO...
#
#                                                 abstract  \
# 2865   BACKGROUND: NUMEROUS MICRORNAS (MIRNAS) HAVE B...
# 2866   BACKGROUND: NUMEROUS MICRORNAS (MIRNAS) HAVE B...
# 20732                                                NaN
# 14734  THE EXPRESSION OF NF-KAPPAB (NF-KAPPA B)-DEPEN...
# 16487  ACRYLAMIDE HAS BEEN EMPLOYED AS AN EXPERIMENTA...
# ...                                                  ...
# 17688  IN THIS PAPER, THE EFFECTS OF USING CR2O3 AND ...
# 301    IN THIS STUDY, TWO NEW MIXED-LIGAND COORDINATI...
# 324    IN THIS STUDY, TWO NEW MIXED-LIGAND COORDINATI...
# 20789                                                NaN
# 15421  OBJECTIVE: TO DESCRIBE THE EFFECTS OF MENOPAUS...
#
#                                          author_keywords  \
# 2865   AKT3; ALZHEIMER'S DISEASE; APOPTOSIS; DIAGNOSI...
# 2866   AKT3; ALZHEIMER'S DISEASE; APOPTOSIS; DIAGNOSI...
# 20732                                                NaN
# 14734  ASTHMA; CHRONIC OBSTRUCTIVE PULMONARY DISEASE;...
# 16487  ACRYLAMIDE; LIVER DEVELOPMENT; LIPID PEROXIDAT...
# ...                                                  ...
# 17688  SELF-COMPACTING MORTAR; CR2O3 NANOPARTICLES; Z...
# 301    COORDINATION POLYMERS; MIXED-LIGAND; X-RAY DIF...
# 324    COORDINATION POLYMERS; MIXED-LIGAND; X-RAY DIF...
# 20789                                                NaN
# 15421                                                NaN
#
#                                            doi  \
# 2865                         10.1002/mgg3.1548
# 2866                         10.1002/mgg3.1548
# 20732                   10.1002/mnfr.200700259
# 14734                   10.1002/mnfr.200700259
# 16487                10.1007/s00204-009-0475-2
# ...                                        ...
# 17688                       10.3139/146.111245
# 301                       10.5650/jos.ess20047
# 324                       10.5650/jos.ess20047
# 20789  10.7326/0003-4819-123-9-199511010-00005
# 15421  10.7326/0003-4819-123-9-199511010-00005
#
#                                       document_type  \
# 2865                                        ARTICLE
# 2866   ARTICLE; EARLY ACCESS; RETRACTED PUBLICATION
# 20732                                    CORRECTION
# 14734                 REVIEW; RETRACTED PUBLICATION
# 16487                ARTICLE; RETRACTED PUBLICATION
# ...                                             ...
# 17688                ARTICLE; RETRACTED PUBLICATION
# 301               RETRACTION; RETRACTED PUBLICATION
# 324                                         ARTICLE
# 20789                                    CORRECTION
# 15421                                          NOTE
#
#                          funding_agency_and_grant_number esi_highly_cited  \
# 2865                                                 NaN              NaN
# 2866                                                 NaN              NaN
# 20732                                                NaN              NaN
# 14734   NIEHS NIH HHS [ES-01247] FUNDING SOURCE: MEDLINE              NaN
# 16487                                                NaN              NaN
# ...                                                  ...              ...
# 17688                                                NaN              NaN
# 301                                                  NaN              NaN
# 324                                                  NaN              NaN
# 20789                                                NaN              NaN
# 15421  NIA NIH HHS [AG-07857, T32-AG00219, KO4-AG0056...              NaN
#
#       esi_hot_paper  ...                                   researcher_id_nr  \
# 2865            NaN  ...                                                NaN
# 2866            NaN  ...                                                NaN
# 20732           NaN  ...                                                NaN
# 14734           NaN  ...                                                NaN
# 16487           NaN  ...                                                NaN
# ...             ...  ...                                                ...
# 17688           NaN  ...  YANG, JIAN/AHB-7153-2022; BEHFOROUZ, BABAK/AAC...
# 301             NaN  ...                                                NaN
# 324             NaN  ...                                                NaN
# 20789           NaN  ...                                                NaN
# 15421           NaN  ...                                                NaN
#
#                                research_areas       issn  \
# 2865                      GENETICS & HEREDITY  2324-9269
# 2866                      GENETICS & HEREDITY  2324-9269
# 20732               FOOD SCIENCE & TECHNOLOGY  1613-4125
# 14734               FOOD SCIENCE & TECHNOLOGY  1613-4125
# 16487                              TOXICOLOGY  0340-5761
# ...                                       ...        ...
# 17688  METALLURGY & METALLURGICAL ENGINEERING  1862-5282
# 301      CHEMISTRY; FOOD SCIENCE & TECHNOLOGY  1345-8957
# 324      CHEMISTRY; FOOD SCIENCE & TECHNOLOGY  1345-8957
# 20789             GENERAL & INTERNAL MEDICINE  0003-4819
# 15421             GENERAL & INTERNAL MEDICINE  0003-4819
#
#                                   publication_name  \
# 2865         MOLECULAR GENETICS & GENOMIC MEDICINE
# 2866         MOLECULAR GENETICS & GENOMIC MEDICINE
# 20732          MOLECULAR NUTRITION & FOOD RESEARCH
# 14734          MOLECULAR NUTRITION & FOOD RESEARCH
# 16487                       ARCHIVES OF TOXICOLOGY
# ...                                            ...
# 17688  INTERNATIONAL JOURNAL OF MATERIALS RESEARCH
# 301                        JOURNAL OF OLEO SCIENCE
# 324                        JOURNAL OF OLEO SCIENCE
# 20789                  ANNALS OF INTERNAL MEDICINE
# 15421                  ANNALS OF INTERNAL MEDICINE
#
#       wos_core_collection_times_cited_count  \
# 2865                                   19.0
# 2866                                   19.0
# 20732                                   0.0
# 14734                                  43.0
# 16487                                   0.0
# ...                                     ...
# 17688                                   0.0
# 301                                     1.0
# 324                                     1.0
# 20789                                   3.0
# 15421                                 403.0
#
#                                           document_title  \
# 2865   mir-485-3p serves as a biomarker and therapeut...
# 2866   mir-485-3p serves as a biomarker and therapeut...
# 20732  modulation of steroid activity in chronic infl...
# 14734  modulation of steroid activity in chronic infl...
# 16487  effect of prenatal and perinatal acrylamide on...
# ...                                                  ...
# 17688  an experimental investigation into the effects...
# 301    retraction: two mixed-ligand coordination poly...
# 324    two mixed-ligand coordination polymers: crysta...
# 20789  changes in energy balance and body composition...
# 15421  changes in energy-balance and body-composition...
#
#                                       wos_categories  total_times_cited_count  \
# 2865                             GENETICS & HEREDITY                       20
# 2866                             GENETICS & HEREDITY                       20
# 20732                      FOOD SCIENCE & TECHNOLOGY                        0
# 14734                      FOOD SCIENCE & TECHNOLOGY                       49
# 16487                                     TOXICOLOGY                        0
# ...                                              ...                      ...
# 17688         METALLURGY & METALLURGICAL ENGINEERING                        0
# 301    CHEMISTRY, APPLIED; FOOD SCIENCE & TECHNOLOGY                        1
# 324    CHEMISTRY, APPLIED; FOOD SCIENCE & TECHNOLOGY                        1
# 20789                   MEDICINE, GENERAL & INTERNAL                        3
# 15421                   MEDICINE, GENERAL & INTERNAL                      457
#
#                                     authors_affiliations  \
# 2865                          SHENGLI OILFIELD CENT HOSP
# 2866                          SHENGLI OILFIELD CENT HOSP
# 20732                                                NaN
# 14734                            UNIVERSITY OF ROCHESTER
# 16487  EGYPTIAN KNOWLEDGE BANK (EKB); BENI SUEF UNIVE...
# ...                                                  ...
# 17688  SHANGHAI JIAO TONG UNIVERSITY; UNIVERSITY OF G...
# 301                                                  NaN
# 324      BEILUN PEOPLES HOSP;NINGBO YINZHOU PEOPLES HOSP
# 20789                                                NaN
# 15421  UNIVERSITY SYSTEM OF MARYLAND; UNIVERSITY OF M...
#
#       corresponding_author_affiliation
# 2865        SHENGLI OILFIELD CENT HOSP
# 2866        SHENGLI OILFIELD CENT HOSP
# 20732                      NOTREPORTED
# 14734                   UNIV ROCHESTER
# 16487         OREGON HLTH AND SCI UNIV
# ...                                ...
# 17688                      UNIV GUILAN
# 301                        NOTREPORTED
# 324                BEILUN PEOPLES HOSP
# 20789                      NOTREPORTED
# 15421              VET AFFAIRS MED CTR
#
# [216 rows x 32 columns]

# %%
testing_dupes.to_excel('../testing_dupes_wos_dois.xlsx', index= False)

# %%
wos_dois['document_type'].value_counts()
# Out:
# document_type
# ARTICLE; RETRACTED PUBLICATION                             15769
# ARTICLE; EARLY ACCESS; RETRACTED PUBLICATION                 930
# ARTICLE; EARLY ACCESS                                        918
# REVIEW; RETRACTED PUBLICATION                                867
# RETRACTION                                                   609
#                                                            ...
# EDITORIAL MATERIAL; EARLY ACCESS; WITHDRAWN PUBLICATION        1
# BIOGRAPHICAL-ITEM; RETRACTED PUBLICATION                       1
# ARTICLE; DATA PAPER; EARLY ACCESS                              1
# ITEM WITHDRAWAL; RETRACTED PUBLICATION                         1
# NOTE                                                           1
# Name: count, Length: 62, dtype: int64

# %%
wos_dois['publication_name'].value_counts()
# Out:
# publication_name
# PLOS ONE                                                   633
# JOURNAL OF AMBIENT INTELLIGENCE AND HUMANIZED COMPUTING    419
# JOURNAL OF BIOLOGICAL CHEMISTRY                            368
# EVIDENCE-BASED COMPLEMENTARY AND ALTERNATIVE MEDICINE      332
# JOURNAL OF HEALTHCARE ENGINEERING                          270
#                                                           ...
# SEMINARS IN ULTRASOUND CT AND MRI                            1
# SEMINARS IN PERINATOLOGY                                     1
# JOURNAL OF CHILD SCIENCE                                     1
# EXPERIMENTAL AND CLINICAL ENDOCRINOLOGY & DIABETES           1
# KOREAN CHEMICAL ENGINEERING RESEARCH                         1
# Name: count, Length: 4316, dtype: int64

# %%
unique_counts = testing_dupes[testing_dupes['doi']=='10.1038/nrm1196'].nunique()
unique_counts[unique_counts > 1].index
# Out:
# Index([], dtype='object')

# %%
wos_dois.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20725 entries, 10235 to 19747
# Data columns (total 32 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   authors                                20725 non-null  object
#  1   author_fullnames                       20723 non-null  object
#  2   cited_references                       20620 non-null  object
#  3   abstract                               19231 non-null  object
#  4   author_keywords                        12766 non-null  object
#  5   doi                                    20725 non-null  object
#  6   document_type                          20725 non-null  object
#  7   funding_agency_and_grant_number        8917 non-null   object
#  8   esi_highly_cited                       47 non-null     object
#  9   esi_hot_paper                          47 non-null     object
#  10  keywords_plus                          17196 non-null  object
#  11  language                               20725 non-null  object
#  12  early_access_date                      2027 non-null   datetime64[ns]
#  13  cited_reference_count                  20725 non-null  Int64
#  14  open_access_indicator                  11982 non-null  object
#  15  orcid                                  8492 non-null   object
#  16  publication_date                       20725 non-null  datetime64[ns]
#  17  page_count                             20725 non-null  Int64
#  18  pubmed_id                              13763 non-null  object
#  19  publication_type                       20725 non-null  object
#  20  publisher                              20724 non-null  object
#  21  year_published                         20725 non-null  Int64
#  22  researcher_id_nr                       10556 non-null  object
#  23  research_areas                         20723 non-null  object
#  24  issn                                   19222 non-null  object
#  25  publication_name                       20725 non-null  object
#  26  wos_core_collection_times_cited_count  20725 non-null  float64
#  27  document_title                         20725 non-null  object
#  28  wos_categories                         20723 non-null  object
#  29  total_times_cited_count                20725 non-null  Int64
#  30  authors_affiliations                   20182 non-null  object
#  31  corresponding_author_affiliation       20725 non-null  object
# dtypes: Int64(4), datetime64[ns](2), float64(1), object(25)
# memory usage: 5.3+ MB

# %%
# number of different values per DOI
aux = testing_dupes.groupby('doi').nunique()

# number of variables that differ for each DOI
aux.gt(1).sum(axis=1).sort_values()
# Out:
# doi
# 10.1007/s10586-018-2296-7         2
# 10.1177/1466138108089466          3
# 10.1007/s10735-016-9659-2         3
# 10.1038/ncb3547                   4
# 10.1007/s11010-013-1650-6         4
#                                  ..
# 10.1159/000099107                14
# 10.1109/IFITA.2009.315           15
# 10.1371/journal.ppat.0020025     16
# 10.1080/21645515.2017.1349046    16
# 10.1007/s11069-007-9148-8        16
# Length: 108, dtype: int64

# %%
# variables that differ in duplicates
aux.columns[aux.max() > 1]
# Out:
# Index(['authors', 'author_fullnames', 'cited_references', 'abstract',
#        'author_keywords', 'document_type', 'funding_agency_and_grant_number',
#        'keywords_plus', 'cited_reference_count', 'open_access_indicator',
#        'orcid', 'publication_date', 'page_count', 'pubmed_id', 'publisher',
#        'year_published', 'researcher_id_nr', 'research_areas', 'issn',
#        'publication_name', 'wos_core_collection_times_cited_count',
#        'document_title', 'wos_categories', 'total_times_cited_count',
#        'authors_affiliations', 'corresponding_author_affiliation'],
#       dtype='object')

# %% [markdown]
# From the list of variables that were listed above as having different values for the same DOI, only the variables that are going to be necessary in the methodology will be individually inspected. That includes the following:
# - 'authors',
# - 'author_keywords',
# - 'keywords_plus',
# - 'cited_references',
# - 'abstract',
# - 'affiliations',
# - 'eissn',
# - 'funding_agency_and_grant_number',
# - 'issn',
# - 'iso_source_abv',
# - 'publication_name',
# - 'month',
# - 'cited_reference_count',
# - 'open_access_indicator',
# - 'publisher',
# - 'research_areas',
# - 'researcher_id_numbers',
# - 'wos_core_collection_times_cited_count',
# - 'document_title',
# - 'document_type',
# - 'wos_categories',
# - 'year_published',
# - 'authors_affiliations',
# - 'corresponding_author_affiliation',
# - 'publication_date'

# %%
# Keep only the first occurrence of each unique DOI (the most recent date)
filtered_wos = wos_dois.drop_duplicates(subset='doi')

# %% [markdown]
# ### Abstract pre-processing

# %%
wos_dois.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20725 entries, 10235 to 19747
# Data columns (total 32 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   authors                                20725 non-null  object
#  1   author_fullnames                       20723 non-null  object
#  2   cited_references                       20620 non-null  object
#  3   abstract                               19231 non-null  object
#  4   author_keywords                        12766 non-null  object
#  5   doi                                    20725 non-null  object
#  6   document_type                          20725 non-null  object
#  7   funding_agency_and_grant_number        8917 non-null   object
#  8   esi_highly_cited                       47 non-null     object
#  9   esi_hot_paper                          47 non-null     object
#  10  keywords_plus                          17196 non-null  object
#  11  language                               20725 non-null  object
#  12  early_access_date                      2027 non-null   datetime64[ns]
#  13  cited_reference_count                  20725 non-null  Int64
#  14  open_access_indicator                  11982 non-null  object
#  15  orcid                                  8492 non-null   object
#  16  publication_date                       20725 non-null  datetime64[ns]
#  17  page_count                             20725 non-null  Int64
#  18  pubmed_id                              13763 non-null  object
#  19  publication_type                       20725 non-null  object
#  20  publisher                              20724 non-null  object
#  21  year_published                         20725 non-null  Int64
#  22  researcher_id_nr                       10556 non-null  object
#  23  research_areas                         20723 non-null  object
#  24  issn                                   19222 non-null  object
#  25  publication_name                       20725 non-null  object
#  26  wos_core_collection_times_cited_count  20725 non-null  float64
#  27  document_title                         20725 non-null  object
#  28  wos_categories                         20723 non-null  object
#  29  total_times_cited_count                20725 non-null  Int64
#  30  authors_affiliations                   20182 non-null  object
#  31  corresponding_author_affiliation       20725 non-null  object
# dtypes: Int64(4), datetime64[ns](2), float64(1), object(25)
# memory usage: 5.3+ MB

# %%
control_abstract = wos_dois[['doi','abstract']].dropna(inplace=False)

# %%
import re

# %%
import string

# %%
# Remove punctuation 
punctuation = string.punctuation
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %% [markdown]
# Get the unicode characters that are not punctuation and that do not add value to sentiment

# %%
def count_special_characters(string, char_counts):
  """
  Function that counts the number of characters that are not alphanumerical nor punctuation
  """
  for char in string:
      if not char.isalnum() and char not in punctuation:
          char_counts[char] = char_counts.get(char, 0) + 1

# %%
invalid_char_counts = {}

control_abstract["abstract"].apply(lambda x: count_special_characters(x, invalid_char_counts))

print(invalid_char_counts)
# Out:
# {' ': 4026148}

# %% [markdown]
# Remove html and markdown symbols

# %%
html_mkdown_regex = r'(?!<[ \d$])<[^>]+>|&[a-zA-Z]+;|\*\*+|__'

# %% [markdown]
# Remove Regular expressions:
# - Emails
# - URLs

# %%
def replace_emails(text):
  """
  Replaces email addresses in a given text with a generic placeholder.
  """
  email_pattern = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
  cleaned_text = re.sub(email_pattern, 'email', text)
  return cleaned_text

# %%
def replace_urls(text):
  """
  Replaces urls in a given text with a generic placeholder.
  """
  url_pattern = r'http\S+|www\S+'
  cleaned_text = re.sub(url_pattern, 'url', text)
  return cleaned_text

# %% [markdown]
# Stopwords

# %%
from nltk.corpus import stopwords

# %%
def remove_stop_words(text, language):
  stop = set(stopwords.words(language))
  if stop:
    return " ".join([word for word in text.split() if word not in stop])
  else:
    return text

# %%
# example usage
remove_stop_words('Hello, this is a test of stop word removal', "english")
# Out:
# 'Hello, test stop word removal'

# %% [markdown]
# Word Contractions

# %%
import contractions

# %%
words_with_contractions = ["can't", "don't", "aren't", "there's", "couldn't", "didn't"]

for word in words_with_contractions:
  print(contractions.fix(word))
# Out:
# cannot
# do not
# are not
# there is
# could not
# did not

# %% [markdown]
# ### Export dataset

# %%
wos_dois.to_parquet('./retractions_data/wos_dois.parquet', index = False)

# %% [markdown]
# <div class="alert alert-block alert-info" style = "background:#d0de6f; color:#000000; border:0;">
#
# # Chapter 2 - Merge Data <a class="anchor" id="chapter2"></a>

# %% [markdown]
# <a class="anchor">
#
# ## 2.1 -Retractions Data (rwd+wos) <a class="anchor" id="section_4_1"></a>

# %%
filtered_rwd.shape
#filtered_wos.shape
# Out:
# (36847, 20)

# %%
processed_data_retractions = filtered_rwd.merge(filtered_wos, how= 'inner', left_on= 'OriginalPaperDOI', right_on= 'doi')
processed_data_retractions
# Out:
#        Record ID                                              Title  \
# 0           5729  The prevention of hip fracture with risedronat...
# 1           5728  Risedronate sodium therapy for prevention of h...
# 2            895  The Relation Between Pulse Pressure and Cardio...
# 3          19230  First Foods Most: After 18-Hour Fast, People D...
# 4            938  A Randomized Clinical Trial of a Single Dose o...
# ...          ...                                                ...
# 20255      23657  A Comprehensive Study of Internal Distraction ...
# 20256      18340  Evaluation of Impact of Pregnancy on Oral Heal...
# 20257      30813  Correlation Curve Correction and Spinal Length...
# 20258      30815  Comparative Evaluation of Apical Microleakage ...
# 20259      44706  Establishment of a Rabbit Model of Spinal Tube...
#
#                                                  Subject  \
# 0      (HSC) Medicine - Geriatric;(HSC) Medicine - Ne...
# 1      (HSC) Medicine - Neurology;(HSC) Medicine - Re...
# 2      (HSC) Biostatistics/Epidemiology;(HSC) Medicin...
# 3                      (BLS) Nutrition;(SOC) Psychology;
# 4      (HSC) Medicine - Ophthalmology;(HSC) Medicine ...
# ...                                                  ...
# 20255  (HSC) Medicine - Orthopedics;(HSC) Medicine - ...
# 20256  (HSC) Medicine - Dentistry;(HSC) Medicine - Ob...
# 20257  (HSC) Biostatistics/Epidemiology;(HSC) Medicin...
# 20258  (BLS) Biochemistry;(BLS) Biology - Cellular;(H...
# 20259  (BLS) Biology - Cellular;(BLS) Microbiology;(H...
#
#                                              Institution  \
# 0      Department of Neurology, Mitate Hospital, Taga...
# 1      Department of Neurology, Mitate Hospital, Taga...
# 2      Department of Dietetics and Nutrition, Harokop...
# 3      Dyson School of Applied Economics and Manageme...
# 4      Department of Anesthesiology, Toride Kyodo Gen...
# ...                                                  ...
# 20255  Department of Orthopaedics, Sanjeevani Multisp...
# 20256  Department of Public Health Dentistry, Governm...
# 20257  Department of Orthopaedic, Bone and Joint Reco...
# 20258  Department of Conservative Dentistry and Endod...
# 20259  Department of Image, the First Affiliated Hosp...
#
#                                                  Journal  \
# 0                          Archives of Internal Medicine
# 1                          Archives of Internal Medicine
# 2                                 JAMA Internal Medicine
# 3                                 JAMA Internal Medicine
# 4                                     JAMA Ophthalmology
# ...                                                  ...
# 20255  Journal of Clinical and Diagnostic Research (J...
# 20256  Journal of Clinical and Diagnostic Research (J...
# 20257  Journal of Clinical and Diagnostic Research (J...
# 20258  Journal of Clinical and Diagnostic Research (J...
# 20259            Japanese Journal of Infectious Diseases
#
#                                                Publisher  \
# 0                                           JAMA Network
# 1                                           JAMA Network
# 2                                           JAMA Network
# 3                           American Medical Association
# 4                           American Medical Association
# ...                                                  ...
# 20255             JCDR Research and Publications Limited
# 20256             JCDR Research and Publications Limited
# 20257             JCDR Research and Publications Limited
# 20258             JCDR Research and Publications Limited
# 20259  National Institute of Infectious Diseases, Jap...
#
#                                                  Country  \
# 0                                                  Japan
# 1                                                  Japan
# 2      Finland;Greece;Italy;Japan;Netherlands;Serbia;...
# 3                                          United States
# 4                                                  Japan
# ...                                                  ...
# 20255                                              India
# 20256                               India;Nepal;Pakistan
# 20257                                               Iran
# 20258                                              India
# 20259                                              Japan
#
#                                                   Author  \
# 0      Yoshihiro Sato;Tomohiro Kanoko;Kei Satoh;Jun I...
# 1             Yoshihiro Sato;Jun Iwamoto;Tomohiro Kanoko
# 2      Demosthenes B Panagiotakos;Daan Kromhout;Aless...
# 3                 Brian Wansink;Aner Tal;Mitsuru Shimizu
# 4           Yoshitaka Fujii;Hiroyoshi Tanaka;Mutsuko Ito
# ...                                                  ...
# 20255                       Mohit J Jain;Kinjal J Mavani
# 20256       Aasim Farooq Shah;Manu Batra;Ambrina Qureshi
# 20257  Hasan Ghandhari;Mir Bahram Safari;Ebrahim Amer...
# 20258   Swadheena Patro;Satyajit Mohapatra;Sumita Mishra
# 20259  Xiaochen Liu;Wenxiao Jia;Hong Wang;Yunling Wan...
#
#                                                     URLS  \
# 0      http://retractionwatch.com/2016/06/03/jama-jou...
# 1      http://retractionwatch.com/2016/06/03/jama-jou...
# 2                                                    NaN
# 3      http://retractionwatch.com/2018/04/13/caught-o...
# 4      http://retractionwatch.com/2012/06/18/three-mo...
# ...                                                  ...
# 20255                                                NaN
# 20256                                                NaN
# 20257                                                NaN
# 20258                                                NaN
# 20259                                                NaN
#
#                             ArticleType  ...  \
# 0      Clinical Study;Research Article;  ...
# 1                     Research Article;  ...
# 2                     Research Article;  ...
# 3              Letter;Research Article;  ...
# 4                       Clinical Study;  ...
# ...                                 ...  ...
# 20255                   Clinical Study;  ...
# 20256                 Research Article;  ...
# 20257                   Clinical Study;  ...
# 20258                 Research Article;  ...
# 20259                 Research Article;  ...
#
#                                         researcher_id_nr  \
# 0                                                    NaN
# 1                                                    NaN
# 2      PANAGIOTAKOS, DEMOSTHENES/K-8294-2019; PANAGIO...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20255                          JAIN, MOHIT/AAY-4869-2020
# 20256                                                NaN
# 20257  SAFARI, MIR BAHRAM/N-5081-2017; GHANDHARI, HAS...
# 20258                     PATRO, SWADHEENA/AAZ-8764-2021
# 20259                                                NaN
#
#                     research_areas       issn  \
# 0      GENERAL & INTERNAL MEDICINE  0003-9926
# 1      GENERAL & INTERNAL MEDICINE  0003-9926
# 2      GENERAL & INTERNAL MEDICINE  0003-9926
# 3      GENERAL & INTERNAL MEDICINE  0003-9926
# 4                    OPHTHALMOLOGY  0003-9950
# ...                            ...        ...
# 20255  GENERAL & INTERNAL MEDICINE  2249-782X
# 20256  GENERAL & INTERNAL MEDICINE  2249-782X
# 20257  GENERAL & INTERNAL MEDICINE  2249-782X
# 20258  GENERAL & INTERNAL MEDICINE  2249-782X
# 20259          INFECTIOUS DISEASES  1344-6304
#
#                                   publication_name  \
# 0                    ARCHIVES OF INTERNAL MEDICINE
# 1                    ARCHIVES OF INTERNAL MEDICINE
# 2                    ARCHIVES OF INTERNAL MEDICINE
# 3                    ARCHIVES OF INTERNAL MEDICINE
# 4                        ARCHIVES OF OPHTHALMOLOGY
# ...                                            ...
# 20255  JOURNAL OF CLINICAL AND DIAGNOSTIC RESEARCH
# 20256  JOURNAL OF CLINICAL AND DIAGNOSTIC RESEARCH
# 20257  JOURNAL OF CLINICAL AND DIAGNOSTIC RESEARCH
# 20258  JOURNAL OF CLINICAL AND DIAGNOSTIC RESEARCH
# 20259      JAPANESE JOURNAL OF INFECTIOUS DISEASES
#
#       wos_core_collection_times_cited_count  \
# 0                                      48.0
# 1                                     113.0
# 2                                      53.0
# 3                                      14.0
# 4                                      10.0
# ...                                     ...
# 20255                                   9.0
# 20256                                   6.0
# 20257                                   1.0
# 20258                                   0.0
# 20259                                   7.0
#
#                                           document_title  \
# 0      the prevention of hip fracture with risedronat...
# 1      risedronate sodium therapy for prevention of h...
# 2      the relation between pulse pressure and cardio...
# 3      first foods most: after 18-hour fast, people d...
# 4      a randomized clinical trial of a single dose o...
# ...                                                  ...
# 20255  a comprehensive study of internal distraction ...
# 20256  evaluation of impact of pregnancy on oral heal...
# 20257  correlation curve correction and spinal length...
# 20258  comparative evaluation of apical microleakage ...
# 20259  establishment of a rabbit model of spinal tube...
#
#                      wos_categories total_times_cited_count  \
# 0      MEDICINE, GENERAL & INTERNAL                      52
# 1      MEDICINE, GENERAL & INTERNAL                     119
# 2      MEDICINE, GENERAL & INTERNAL                      55
# 3      MEDICINE, GENERAL & INTERNAL                      14
# 4                     OPHTHALMOLOGY                      11
# ...                             ...                     ...
# 20255  MEDICINE, GENERAL & INTERNAL                      10
# 20256  MEDICINE, GENERAL & INTERNAL                       7
# 20257  MEDICINE, GENERAL & INTERNAL                       1
# 20258  MEDICINE, GENERAL & INTERNAL                       0
# 20259           INFECTIOUS DISEASES                      14
#
#                                     authors_affiliations  \
# 0      HIROSAKI UNIVERSITY; HIROSAKI UNIVERSITY; KEIO...
# 1      KEIO UNIVERSITY; HIROSAKI UNIVERSITY; HIROSAKI...
# 2      HAROKOPIO UNIVERSITY ATHENS; NETHERLANDS NATIO...
# 3                                     CORNELL UNIVERSITY
# 4            TORIDE KYODO GEN HOSP;TORIDE KYODO GEN HOSP
# ...                                                  ...
# 20255   SANJEEVANI MULTISPECIAL HOSP;MARATHA MANDAL INST
# 20256                  DOW UNIVERSITY OF HEALTH SCIENCES
# 20257  IRAN UNIVERSITY OF MEDICAL SCIENCES; URMIA UNI...
# 20258  SIKSHA 'O' ANUSANDHAN UNIVERSITY; SIKSHA 'O' A...
# 20259  XINJIANG MEDICAL UNIVERSITY; XINJIANG MEDICAL ...
#
#       corresponding_author_affiliation
# 0                          MITATE HOSP
# 1                          MITATE HOSP
# 2            DB (CORRESPONDING AUTHOR)
# 3                         CORNELL UNIV
# 4                         UNIV TSUKUBA
# ...                                ...
# 20255        MJ (CORRESPONDING AUTHOR)
# 20256               GOVT COLL AND HOSP
# 20257               URMIA UNIV MED SCI
# 20258                         SOA UNIV
# 20259                XINJIANG MED UNIV
#
# [20260 rows x 52 columns]

# %%
processed_data_retractions['doi'].value_counts()
# Out:
# doi
# 10.1001/archinte.165.15.1737    1
# 10.1155/2021/9968016            1
# 10.1155/2021/9985041            1
# 10.1155/2021/9984003            1
# 10.1155/2021/9983023            1
#                                ..
# 10.1016/j.neucom.2016.07.081    1
# 10.1016/j.neucom.2015.03.059    1
# 10.1016/j.neucom.2013.08.027    1
# 10.1016/j.neucom.2012.06.051    1
# 10.7883/yoken.JJID.2014.147     1
# Name: count, Length: 20260, dtype: int64

# %%
# rwd_wo_doi = rwd[rwd['OriginalPaperDOI'].isnull() | (rwd['OriginalPaperDOI'] == '')]
# wos_dois_wo_doi = wos_dois[wos_dois['doi'].isnull() | (wos_dois['doi'] == '')]
# data_retractions_by_title = rwd_wo_doi.merge(wos_dois, how= 'inner', left_on= 'Title', right_on= 'document_title')
# processed_data_retractions = pd.concat([processed_data_retractions, data_retractions_by_title], ignore_index = True)
# processed_data_retractions = processed_data_retractions.drop_duplicates()

# %%
processed_data_retractions
# Out:
#        Record ID                                              Title  \
# 0           5729  The prevention of hip fracture with risedronat...
# 1           5728  Risedronate sodium therapy for prevention of h...
# 2            895  The Relation Between Pulse Pressure and Cardio...
# 3          19230  First Foods Most: After 18-Hour Fast, People D...
# 4            938  A Randomized Clinical Trial of a Single Dose o...
# ...          ...                                                ...
# 20255      23657  A Comprehensive Study of Internal Distraction ...
# 20256      18340  Evaluation of Impact of Pregnancy on Oral Heal...
# 20257      30813  Correlation Curve Correction and Spinal Length...
# 20258      30815  Comparative Evaluation of Apical Microleakage ...
# 20259      44706  Establishment of a Rabbit Model of Spinal Tube...
#
#                                                  Subject  \
# 0      (HSC) Medicine - Geriatric;(HSC) Medicine - Ne...
# 1      (HSC) Medicine - Neurology;(HSC) Medicine - Re...
# 2      (HSC) Biostatistics/Epidemiology;(HSC) Medicin...
# 3                      (BLS) Nutrition;(SOC) Psychology;
# 4      (HSC) Medicine - Ophthalmology;(HSC) Medicine ...
# ...                                                  ...
# 20255  (HSC) Medicine - Orthopedics;(HSC) Medicine - ...
# 20256  (HSC) Medicine - Dentistry;(HSC) Medicine - Ob...
# 20257  (HSC) Biostatistics/Epidemiology;(HSC) Medicin...
# 20258  (BLS) Biochemistry;(BLS) Biology - Cellular;(H...
# 20259  (BLS) Biology - Cellular;(BLS) Microbiology;(H...
#
#                                              Institution  \
# 0      Department of Neurology, Mitate Hospital, Taga...
# 1      Department of Neurology, Mitate Hospital, Taga...
# 2      Department of Dietetics and Nutrition, Harokop...
# 3      Dyson School of Applied Economics and Manageme...
# 4      Department of Anesthesiology, Toride Kyodo Gen...
# ...                                                  ...
# 20255  Department of Orthopaedics, Sanjeevani Multisp...
# 20256  Department of Public Health Dentistry, Governm...
# 20257  Department of Orthopaedic, Bone and Joint Reco...
# 20258  Department of Conservative Dentistry and Endod...
# 20259  Department of Image, the First Affiliated Hosp...
#
#                                                  Journal  \
# 0                          Archives of Internal Medicine
# 1                          Archives of Internal Medicine
# 2                                 JAMA Internal Medicine
# 3                                 JAMA Internal Medicine
# 4                                     JAMA Ophthalmology
# ...                                                  ...
# 20255  Journal of Clinical and Diagnostic Research (J...
# 20256  Journal of Clinical and Diagnostic Research (J...
# 20257  Journal of Clinical and Diagnostic Research (J...
# 20258  Journal of Clinical and Diagnostic Research (J...
# 20259            Japanese Journal of Infectious Diseases
#
#                                                Publisher  \
# 0                                           JAMA Network
# 1                                           JAMA Network
# 2                                           JAMA Network
# 3                           American Medical Association
# 4                           American Medical Association
# ...                                                  ...
# 20255             JCDR Research and Publications Limited
# 20256             JCDR Research and Publications Limited
# 20257             JCDR Research and Publications Limited
# 20258             JCDR Research and Publications Limited
# 20259  National Institute of Infectious Diseases, Jap...
#
#                                                  Country  \
# 0                                                  Japan
# 1                                                  Japan
# 2      Finland;Greece;Italy;Japan;Netherlands;Serbia;...
# 3                                          United States
# 4                                                  Japan
# ...                                                  ...
# 20255                                              India
# 20256                               India;Nepal;Pakistan
# 20257                                               Iran
# 20258                                              India
# 20259                                              Japan
#
#                                                   Author  \
# 0      Yoshihiro Sato;Tomohiro Kanoko;Kei Satoh;Jun I...
# 1             Yoshihiro Sato;Jun Iwamoto;Tomohiro Kanoko
# 2      Demosthenes B Panagiotakos;Daan Kromhout;Aless...
# 3                 Brian Wansink;Aner Tal;Mitsuru Shimizu
# 4           Yoshitaka Fujii;Hiroyoshi Tanaka;Mutsuko Ito
# ...                                                  ...
# 20255                       Mohit J Jain;Kinjal J Mavani
# 20256       Aasim Farooq Shah;Manu Batra;Ambrina Qureshi
# 20257  Hasan Ghandhari;Mir Bahram Safari;Ebrahim Amer...
# 20258   Swadheena Patro;Satyajit Mohapatra;Sumita Mishra
# 20259  Xiaochen Liu;Wenxiao Jia;Hong Wang;Yunling Wan...
#
#                                                     URLS  \
# 0      http://retractionwatch.com/2016/06/03/jama-jou...
# 1      http://retractionwatch.com/2016/06/03/jama-jou...
# 2                                                    NaN
# 3      http://retractionwatch.com/2018/04/13/caught-o...
# 4      http://retractionwatch.com/2012/06/18/three-mo...
# ...                                                  ...
# 20255                                                NaN
# 20256                                                NaN
# 20257                                                NaN
# 20258                                                NaN
# 20259                                                NaN
#
#                             ArticleType  ...  \
# 0      Clinical Study;Research Article;  ...
# 1                     Research Article;  ...
# 2                     Research Article;  ...
# 3              Letter;Research Article;  ...
# 4                       Clinical Study;  ...
# ...                                 ...  ...
# 20255                   Clinical Study;  ...
# 20256                 Research Article;  ...
# 20257                   Clinical Study;  ...
# 20258                 Research Article;  ...
# 20259                 Research Article;  ...
#
#                                         researcher_id_nr  \
# 0                                                    NaN
# 1                                                    NaN
# 2      PANAGIOTAKOS, DEMOSTHENES/K-8294-2019; PANAGIO...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20255                          JAIN, MOHIT/AAY-4869-2020
# 20256                                                NaN
# 20257  SAFARI, MIR BAHRAM/N-5081-2017; GHANDHARI, HAS...
# 20258                     PATRO, SWADHEENA/AAZ-8764-2021
# 20259                                                NaN
#
#                     research_areas       issn  \
# 0      GENERAL & INTERNAL MEDICINE  0003-9926
# 1      GENERAL & INTERNAL MEDICINE  0003-9926
# 2      GENERAL & INTERNAL MEDICINE  0003-9926
# 3      GENERAL & INTERNAL MEDICINE  0003-9926
# 4                    OPHTHALMOLOGY  0003-9950
# ...                            ...        ...
# 20255  GENERAL & INTERNAL MEDICINE  2249-782X
# 20256  GENERAL & INTERNAL MEDICINE  2249-782X
# 20257  GENERAL & INTERNAL MEDICINE  2249-782X
# 20258  GENERAL & INTERNAL MEDICINE  2249-782X
# 20259          INFECTIOUS DISEASES  1344-6304
#
#                                   publication_name  \
# 0                    ARCHIVES OF INTERNAL MEDICINE
# 1                    ARCHIVES OF INTERNAL MEDICINE
# 2                    ARCHIVES OF INTERNAL MEDICINE
# 3                    ARCHIVES OF INTERNAL MEDICINE
# 4                        ARCHIVES OF OPHTHALMOLOGY
# ...                                            ...
# 20255  JOURNAL OF CLINICAL AND DIAGNOSTIC RESEARCH
# 20256  JOURNAL OF CLINICAL AND DIAGNOSTIC RESEARCH
# 20257  JOURNAL OF CLINICAL AND DIAGNOSTIC RESEARCH
# 20258  JOURNAL OF CLINICAL AND DIAGNOSTIC RESEARCH
# 20259      JAPANESE JOURNAL OF INFECTIOUS DISEASES
#
#       wos_core_collection_times_cited_count  \
# 0                                      48.0
# 1                                     113.0
# 2                                      53.0
# 3                                      14.0
# 4                                      10.0
# ...                                     ...
# 20255                                   9.0
# 20256                                   6.0
# 20257                                   1.0
# 20258                                   0.0
# 20259                                   7.0
#
#                                           document_title  \
# 0      the prevention of hip fracture with risedronat...
# 1      risedronate sodium therapy for prevention of h...
# 2      the relation between pulse pressure and cardio...
# 3      first foods most: after 18-hour fast, people d...
# 4      a randomized clinical trial of a single dose o...
# ...                                                  ...
# 20255  a comprehensive study of internal distraction ...
# 20256  evaluation of impact of pregnancy on oral heal...
# 20257  correlation curve correction and spinal length...
# 20258  comparative evaluation of apical microleakage ...
# 20259  establishment of a rabbit model of spinal tube...
#
#                      wos_categories total_times_cited_count  \
# 0      MEDICINE, GENERAL & INTERNAL                      52
# 1      MEDICINE, GENERAL & INTERNAL                     119
# 2      MEDICINE, GENERAL & INTERNAL                      55
# 3      MEDICINE, GENERAL & INTERNAL                      14
# 4                     OPHTHALMOLOGY                      11
# ...                             ...                     ...
# 20255  MEDICINE, GENERAL & INTERNAL                      10
# 20256  MEDICINE, GENERAL & INTERNAL                       7
# 20257  MEDICINE, GENERAL & INTERNAL                       1
# 20258  MEDICINE, GENERAL & INTERNAL                       0
# 20259           INFECTIOUS DISEASES                      14
#
#                                     authors_affiliations  \
# 0      HIROSAKI UNIVERSITY; HIROSAKI UNIVERSITY; KEIO...
# 1      KEIO UNIVERSITY; HIROSAKI UNIVERSITY; HIROSAKI...
# 2      HAROKOPIO UNIVERSITY ATHENS; NETHERLANDS NATIO...
# 3                                     CORNELL UNIVERSITY
# 4            TORIDE KYODO GEN HOSP;TORIDE KYODO GEN HOSP
# ...                                                  ...
# 20255   SANJEEVANI MULTISPECIAL HOSP;MARATHA MANDAL INST
# 20256                  DOW UNIVERSITY OF HEALTH SCIENCES
# 20257  IRAN UNIVERSITY OF MEDICAL SCIENCES; URMIA UNI...
# 20258  SIKSHA 'O' ANUSANDHAN UNIVERSITY; SIKSHA 'O' A...
# 20259  XINJIANG MEDICAL UNIVERSITY; XINJIANG MEDICAL ...
#
#       corresponding_author_affiliation
# 0                          MITATE HOSP
# 1                          MITATE HOSP
# 2            DB (CORRESPONDING AUTHOR)
# 3                         CORNELL UNIV
# 4                         UNIV TSUKUBA
# ...                                ...
# 20255        MJ (CORRESPONDING AUTHOR)
# 20256               GOVT COLL AND HOSP
# 20257               URMIA UNIV MED SCI
# 20258                         SOA UNIV
# 20259                XINJIANG MED UNIV
#
# [20260 rows x 52 columns]

# %%
#data_retractions_by_title

# %%
processed_data_retractions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20260 entries, 0 to 20259
# Data columns (total 52 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Record ID                              20260 non-null  int64
#  1   Title                                  20260 non-null  object
#  2   Subject                                20260 non-null  object
#  3   Institution                            20259 non-null  object
#  4   Journal                                20260 non-null  object
#  5   Publisher                              20260 non-null  object
#  6   Country                                20260 non-null  object
#  7   Author                                 20260 non-null  object
#  8   URLS                                   7933 non-null   object
#  9   ArticleType                            20260 non-null  object
#  10  RetractionDate                         20260 non-null  datetime64[ns]
#  11  RetractionDOI                          20085 non-null  object
#  12  RetractionPubMedID                     19494 non-null  object
#  13  OriginalPaperDate                      20260 non-null  datetime64[ns]
#  14  OriginalPaperDOI                       20260 non-null  object
#  15  OriginalPaperPubMedID                  19527 non-null  object
#  16  RetractionNature                       20260 non-null  object
#  17  Reason                                 20260 non-null  object
#  18  Paywalled                              20260 non-null  object
#  19  Notes                                  5095 non-null   object
#  20  authors                                20260 non-null  object
#  21  author_fullnames                       20258 non-null  object
#  22  cited_references                       20158 non-null  object
#  23  abstract                               18796 non-null  object
#  24  author_keywords                        12648 non-null  object
#  25  doi                                    20260 non-null  object
#  26  document_type                          20260 non-null  object
#  27  funding_agency_and_grant_number        8672 non-null   object
#  28  esi_highly_cited                       45 non-null     object
#  29  esi_hot_paper                          45 non-null     object
#  30  keywords_plus                          16770 non-null  object
#  31  language                               20260 non-null  object
#  32  early_access_date                      2017 non-null   datetime64[ns]
#  33  cited_reference_count                  20260 non-null  Int64
#  34  open_access_indicator                  11727 non-null  object
#  35  orcid                                  8287 non-null   object
#  36  publication_date                       20260 non-null  datetime64[ns]
#  37  page_count                             20260 non-null  Int64
#  38  pubmed_id                              13481 non-null  object
#  39  publication_type                       20260 non-null  object
#  40  publisher                              20259 non-null  object
#  41  year_published                         20260 non-null  Int64
#  42  researcher_id_nr                       10312 non-null  object
#  43  research_areas                         20258 non-null  object
#  44  issn                                   18926 non-null  object
#  45  publication_name                       20260 non-null  object
#  46  wos_core_collection_times_cited_count  20260 non-null  float64
#  47  document_title                         20260 non-null  object
#  48  wos_categories                         20258 non-null  object
#  49  total_times_cited_count                20260 non-null  Int64
#  50  authors_affiliations                   19733 non-null  object
#  51  corresponding_author_affiliation       20260 non-null  object
# dtypes: Int64(4), datetime64[ns](4), float64(1), int64(1), object(42)
# memory usage: 8.1+ MB

# %% [markdown]
# <a class="anchor">
#
# ## 2.2 -Retractions Data with journals (rwd_wos+scimago) <a class="anchor" id="section_4_1"></a>

# %%
journals = pd.read_csv('../scimagojr_2022.csv', sep=';')
journals.head(5)
# Out:
#    Rank  Sourceid                                  Title     Type  \
# 0     1     28773     Ca-A Cancer Journal for Clinicians  journal
# 1     2     29431         Quarterly Journal of Economics  journal
# 2     3     20315  Nature Reviews Molecular Cell Biology  journal
# 3     4     18434                                   Cell  journal
# 4     5     15847        New England Journal of Medicine  journal
#
#                  Issn     SJR SJR Best Quartile  H index  Total Docs. (2022)  \
# 0  15424863, 00079235  86,091                Q1      198                  44
# 1  00335533, 15314650  36,730                Q1      292                  36
# 2  14710072, 14710080  34,201                Q1      485                 121
# 3  00928674, 10974172  26,494                Q1      856                 420
# 4  00284793, 15334406  26,015                Q1     1130                1410
#
#    Total Docs. (3years)  ...  Total Cites (3years)  Citable Docs. (3years)  \
# 0                   118  ...                 30318                      85
# 1                   122  ...                  2141                     122
# 2                   328  ...                 13331                     156
# 3                  1637  ...                 67791                    1440
# 4                  4561  ...                133956                    1854
#
#    Cites / Doc. (2years) Ref. / Doc.         Country            Region  \
# 0                 299,99       97,00   United States  Northern America
# 1                  14,83       66,61  United Kingdom    Western Europe
# 2                  35,47       89,29  United Kingdom    Western Europe
# 3                  43,80       65,74   United States  Northern America
# 4                  33,93       10,21   United States  Northern America
#
#                         Publisher   Coverage  \
# 0                 Wiley-Blackwell  1950-2022
# 1         Oxford University Press  1886-2022
# 2         Nature Publishing Group  2000-2022
# 3                      Cell Press  1974-2022
# 4  Massachussetts Medical Society  1945-2022
#
#                                           Categories  \
# 0                     Hematology (Q1); Oncology (Q1)
# 1                    Economics and Econometrics (Q1)
# 2          Cell Biology (Q1); Molecular Biology (Q1)
# 3  Biochemistry, Genetics and Molecular Biology (...
# 4                      Medicine (miscellaneous) (Q1)
#
#                                           Areas
# 0                                      Medicine
# 1           Economics, Econometrics and Finance
# 2  Biochemistry, Genetics and Molecular Biology
# 3  Biochemistry, Genetics and Molecular Biology
# 4                                      Medicine
#
# [5 rows x 21 columns]

# %%
journals['SJR Best Quartile'].value_counts()
# Out:
# SJR Best Quartile
# Q1    7186
# Q2    5393
# Q3    3735
# Q4    1702
# -       20
# Name: count, dtype: int64

# %%
quartiles = journals[['Issn','SJR Best Quartile']]
quartiles.loc[:, 'Issn'] = quartiles['Issn'].str.split(',')
quartiles = quartiles.explode('Issn')
quartiles['Issn'] = quartiles['Issn'].str.replace(' ', '')
quartiles = quartiles[quartiles['Issn'].str.strip() != ""]
quartiles
# Out:
#            Issn SJR Best Quartile
# 0      15424863                Q1
# 0      00079235                Q1
# 1      00335533                Q1
# 1      15314650                Q1
# 2      14710072                Q1
# ...         ...               ...
# 18031  18780814                 -
# 18032  01795953                 -
# 18033  00428779                 -
# 18034  18293824                 -
# 18035  23078960                 -
#
# [30010 rows x 2 columns]

# %%
quartiles.to_excel('quartiles.xlsx')

# %%
processed_data_retractions['issn'] = processed_data_retractions['issn'].str.replace('-', '')

# %%
rw_merged = processed_data_retractions.merge(quartiles, how='left', left_on='issn', right_on='Issn')

# %%
rw_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20260 entries, 0 to 20259
# Data columns (total 54 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Record ID                              20260 non-null  int64
#  1   Title                                  20260 non-null  object
#  2   Subject                                20260 non-null  object
#  3   Institution                            20259 non-null  object
#  4   Journal                                20260 non-null  object
#  5   Publisher                              20260 non-null  object
#  6   Country                                20260 non-null  object
#  7   Author                                 20260 non-null  object
#  8   URLS                                   7933 non-null   object
#  9   ArticleType                            20260 non-null  object
#  10  RetractionDate                         20260 non-null  datetime64[ns]
#  11  RetractionDOI                          20085 non-null  object
#  12  RetractionPubMedID                     19494 non-null  object
#  13  OriginalPaperDate                      20260 non-null  datetime64[ns]
#  14  OriginalPaperDOI                       20260 non-null  object
#  15  OriginalPaperPubMedID                  19527 non-null  object
#  16  RetractionNature                       20260 non-null  object
#  17  Reason                                 20260 non-null  object
#  18  Paywalled                              20260 non-null  object
#  19  Notes                                  5095 non-null   object
#  20  authors                                20260 non-null  object
#  21  author_fullnames                       20258 non-null  object
#  22  cited_references                       20158 non-null  object
#  23  abstract                               18796 non-null  object
#  24  author_keywords                        12648 non-null  object
#  25  doi                                    20260 non-null  object
#  26  document_type                          20260 non-null  object
#  27  funding_agency_and_grant_number        8672 non-null   object
#  28  esi_highly_cited                       45 non-null     object
#  29  esi_hot_paper                          45 non-null     object
#  30  keywords_plus                          16770 non-null  object
#  31  language                               20260 non-null  object
#  32  early_access_date                      2017 non-null   datetime64[ns]
#  33  cited_reference_count                  20260 non-null  Int64
#  34  open_access_indicator                  11727 non-null  object
#  35  orcid                                  8287 non-null   object
#  36  publication_date                       20260 non-null  datetime64[ns]
#  37  page_count                             20260 non-null  Int64
#  38  pubmed_id                              13481 non-null  object
#  39  publication_type                       20260 non-null  object
#  40  publisher                              20259 non-null  object
#  41  year_published                         20260 non-null  Int64
#  42  researcher_id_nr                       10312 non-null  object
#  43  research_areas                         20258 non-null  object
#  44  issn                                   18926 non-null  object
#  45  publication_name                       20260 non-null  object
#  46  wos_core_collection_times_cited_count  20260 non-null  float64
#  47  document_title                         20260 non-null  object
#  48  wos_categories                         20258 non-null  object
#  49  total_times_cited_count                20260 non-null  Int64
#  50  authors_affiliations                   19733 non-null  object
#  51  corresponding_author_affiliation       20260 non-null  object
#  52  Issn                                   17604 non-null  object
#  53  SJR Best Quartile                      17604 non-null  object
# dtypes: Int64(4), datetime64[ns](4), float64(1), int64(1), object(44)
# memory usage: 8.4+ MB

# %%
rw_merged['SJR Best Quartile'].value_counts()
# Out:
# SJR Best Quartile
# Q1    9761
# Q2    6192
# Q3    1178
# Q4     239
# -      234
# Name: count, dtype: int64

# %%
rw_merged.groupby('SJR Best Quartile')['issn'].nunique()
# Out:
# SJR Best Quartile
# -        2
# Q1    1985
# Q2    1203
# Q3     443
# Q4      81
# Name: issn, dtype: int64

# %%
rw_merged['issn'].nunique() - rw_merged['Issn'].nunique()
# Out:
# 308

# %%
rw_merged['Issn'].nunique()
# Out:
# 3714

# %%
datetime_variable_conversion = {"RetractionDate": "object",
                                "OriginalPaperDate": "object",
                                "publication_date": "object",
                                "early_access_date": "object"
                                }

rw_merged = rw_merged.astype(datetime_variable_conversion)

# %%
rw_merged.to_excel('./retractions_data/rw_wos_scimago_by_dois.xlsx', index = False)
