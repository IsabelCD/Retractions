# %% [markdown]
# The purpose of this Notebook is to join the datasets from the different sources into the following datasets:
# - *retractions*: this dataset will join data from retraction watch database (RW) and bibliometric data of retractions in Web of Science (RD).
# - *retracted_in_journals*: this dataset will join data from retraction watch database (RW), journal metrics from scimajor, and bibliometric data of all articles in best ranked journals (JD).

# %% [markdown]
# * [Chapter 0 - Libraries](#chapter0)
# * [Chapter 1 - Individual Analysis](#chapter1)
#     * [1.1 - Retraction Watch Database (RWD)](#section_1_1)
#     * [1.2 - Control Set (CS)](#section_1_2)
#     * [1.3 - Citation Data (CIT)](#section_1_3)
#     * [1.4 - Corrections Data (COR)](#section_1_4)
# * [Chapter 2 - Merge Data](#chapter2)
#     * [2.1 - Retraction Data (RD)](#section_2_1)

# %% [markdown]
# <div class="alert alert-block alert-info" style = "background:#d0de6f; color:#000000; border:0;">
#
# # Chapter 0 - Libraries <a class="anchor" id="chapter0"></a>

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import re
#import matplotlib.pyplot as plt
#import seaborn as sns
#import plotly.express as px

# %% [markdown]
# <div class="alert alert-block alert-info" style = "background:#d0de6f; color:#000000; border:0;">
#
# # Chapter 1 - Individual Analysis <a class="anchor" id="chapter1"></a>

# %% [markdown]
# <a class="anchor">
#
# ## 1.1 - Retraction Watch Database (RWD) <a class="anchor" id="section_1_1"></a>

# %%
rwd = pd.read_excel('./retractions_data/retraction_watch_database.xlsx', dtype={'RetractionPubMedID': object, 'OriginalPaperPubMedID': object})
rwd.head()
# Out:
#    Record ID                                              Title  \
# 0      47271  Binding of DCC by Netrin-1 to Mediate Axon Gui...
# 1      47270  Hierarchical Organization of Guidance Receptor...
# 2      47243  Therapeutic potential of targeting IRES-depend...
# 3      47233  A classifier based on 273 urinary peptides pre...
# 4      47227  Age, Gender Demographics and Comorbidity Preva...
#
#                                              Subject  \
# 0  (BLS) Biology - Cellular;(BLS) Biology - Gener...
# 1  (BLS) Biochemistry;(BLS) Biology - General;(BL...
# 2  (BLS) Biochemistry;(BLS) Biology - Cancer;(BLS...
# 3  (BLS) Biochemistry;(HSC) Medicine - Cardiovasc...
# 4  (HSC) Biostatistics/Epidemiology;(HSC) Medicin...
#
#                                          Institution  \
# 0  Departments of Anatomy and of Biochemistry and...
# 1  Department of Anatomy and Department of Bioche...
# 2  Division of Hematology-Oncology, UCLA-Greater ...
# 3  Department of Nephrology, The Third Affiliated...
# 4  Department of Orthopaedics, Dhanalakshmi Srini...
#
#                             Journal  \
# 0                           Science
# 1                           Science
# 2                          Oncogene
# 3           Journal of Hypertension
# 4  Journal of Coastal Life Medicine
#
#                                            Publisher        Country  \
# 0  American Association for the Advancement of Sc...  United States
# 1  American Association for the Advancement of Sc...  United States
# 2                 Springer - Nature Publishing Group  United States
# 3     Wolters Kluwer - Lippincott Williams & Wilkins          China
# 4                   Journal of Coastal Life Medicine          India
#
#                                               Author  \
# 0  Elke Stein;Yimin Zou;Mu-ming Poo;Marc Tessier-...
# 1                    Elke Stein;Marc Tessier-Lavigne
# 2  Y Shi;Y Yang;C Bardeleben;B Holmes;J Gera;Alan...
# 3  Lirong Lin;Chunxuan Wang;Jiangwen Ren;Mei Mei;...
# 4  S Venkatesh Kumar;Mohith Singh;Gowtham Singh;K...
#
#                                                 URLS        ArticleType  \
# 0  https://retractionwatch.com/2023/08/31/stanfor...  Research Article;
# 1  https://retractionwatch.com/2023/08/31/stanfor...  Research Article;
# 2                                                NaN  Research Article;
# 3                                                NaN  Research Article;
# 4                                                NaN  Research Article;
#
#         RetractionDate                 RetractionDOI RetractionPubMedID  \
# 0  2023-08-31 00:00:00       10.1126/science.adk1521                  0
# 1  2023-08-31 00:00:00       10.1126/science.adk1517                  0
# 2  2023-08-31 00:00:00    10.1038/s41388-023-02820-5                  0
# 3  2023-08-30 00:00:00  10.1097/HJH.0000000000003551           37642599
# 4  2023-08-30 00:00:00                   unavailable                  0
#
#      OriginalPaperDate              OriginalPaperDOI OriginalPaperPubMedID  \
# 0  2001-03-09 00:00:00       10.1126/science.1059391              11239160
# 1  2001-02-08 00:00:00       10.1126/science.1058445              11239147
# 2  2015-05-11 00:00:00          10.1038/onc.2015.156              25961916
# 3  2023-08-01 00:00:00  10.1097/HJH.0000000000003467              37199562
# 4  2023-01-01 00:00:00                   unavailable                     0
#
#   RetractionNature                                             Reason  \
# 0       Retraction  +Investigation by Company/Institution;+Manipul...
# 1       Retraction  +Duplication of Image;+Investigation by Compan...
# 2       Retraction  +Concerns/Issues About Data;+Concerns/Issues A...
# 3       Retraction  +Concerns/Issues About Results;+Investigation ...
# 4       Retraction                     +Notice - Lack of;+Withdrawal;
#
#   Paywalled                                              Notes
# 0        No                                                NaN
# 1        No                                                NaN
# 2        No  see also: https://pubpeer.com/publications/704...
# 3        No  see also https://journals.lww.com/jhypertensio...
# 4        No  date of retraction unknown, article title repl...

# %%
rwd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42700 entries, 0 to 42699
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Record ID              42700 non-null  int64
#  1   Title                  42700 non-null  object
#  2   Subject                42700 non-null  object
#  3   Institution            42699 non-null  object
#  4   Journal                42700 non-null  object
#  5   Publisher              42700 non-null  object
#  6   Country                42700 non-null  object
#  7   Author                 42700 non-null  object
#  8   URLS                   21687 non-null  object
#  9   ArticleType            42700 non-null  object
#  10  RetractionDate         42700 non-null  object
#  11  RetractionDOI          42209 non-null  object
#  12  RetractionPubMedID     37599 non-null  object
#  13  OriginalPaperDate      42700 non-null  object
#  14  OriginalPaperDOI       40173 non-null  object
#  15  OriginalPaperPubMedID  37564 non-null  object
#  16  RetractionNature       42700 non-null  object
#  17  Reason                 42700 non-null  object
#  18  Paywalled              42700 non-null  object
#  19  Notes                  10253 non-null  object
# dtypes: int64(1), object(19)
# memory usage: 6.5+ MB

# %%
# put date variables in correct format
rwd['RetractionDate'] = pd.to_datetime(rwd['RetractionDate'], errors='coerce') #, infer_datetime_format=True
rwd['OriginalPaperDate'] = pd.to_datetime(rwd['OriginalPaperDate'])

# %%
# Check for NaN values in 'Digital Object Identifier (DOI)' column
rwd_filtered = rwd.dropna(subset=['RetractionDOI'])

# Filter rows starting with "http://dx.doi.org/"
rwd_filtered[rwd_filtered['RetractionDOI'].str.startswith("http://dx.doi.org/")]['RetractionDOI']
# Out:
# Series([], Name: RetractionDOI, dtype: object)

# %% [markdown]
# ### Duplicates

# %% [markdown]
# In theory, there should only be one DOI per article, and each retracted paper should only have one record in the database. This means that all DOIs should be unique.

# %%
rwd['OriginalPaperDOI'].nunique()
# Out:
# 36846

# %%
rwd['RetractionDOI'].nunique()
# Out:
# 36506

# %%
testing_dupes = rwd[rwd.duplicated(subset='OriginalPaperDOI', keep=False)]
testing_dupes['OriginalPaperDOI'].value_counts()
# Out:
# OriginalPaperDOI
# Unavailable                        2234
# unavailable                        1074
# 10.1136/jim-2021-SRMC                 6
# 10.1002/tox.21941                     2
# 10.1016/j.lfs.2019.116709             2
# 10.1038/s41598-021-03765-z            2
# 10.1007/s12275-012-2294-z             2
# 10.1016/j.cej.2011.04.016             2
# 10.1016/j.swevo.2021.100868           2
# 10.1016/j.esxm.2021.100447            2
# 10.1093/jge/aabc74                    2
# 10.1088/1742-2140/aaaf57              2
# 10.1088/1742-2140/aa953a              2
# 10.1016/j.carbpol.2019.115799         2
# 10.1001/archpediatrics.2012.999       2
# 10.1007/s13277-014-2995-5             2
# 10.3109/02699052.2016.1162060         2
# 10.1016/j.rapm.2005.05.009            2
# 10.1524/9783486834062.275             2
# Name: count, dtype: int64

# %%
filtered_dupes = testing_dupes[testing_dupes['OriginalPaperDOI'].str.lower() != 'unavailable'].sort_values('OriginalPaperDOI')
filtered_dupes
# Out:
#        Record ID                                              Title  \
# 21229      14089               Can Branding Improve School Lunches?
# 21230      11994               Can Branding Improve School Lunches?
# 5685       38940  Erratum to: Î±,Î²-Unsaturated aldehyde polluta...
# 5696       38375  Î±,Î²-Unsaturated aldehyde pollutant acrolein ...
# 6643       37342  Identification of the Vibrio vulnificus htpG G...
# ...          ...                                                ...
# 42578       4780  Phenylephrine stress in the evaluation of pati...
# 42579       4781  Thallium pulmonary scintigraphy. Relationship ...
# 42611       1494  Specific antigen exclusion and non-specific fa...
# 42613       4249  Concurrent measurement of plasma levels of vit...
# 42695      10433           Change of Venue and the Conflict of Laws
#
#                                                  Subject  \
# 21229  (B/T) Business - Marketing;(BLS) Nutrition;(SO...
# 21230  (B/T) Business - Marketing;(BLS) Nutrition;(SO...
# 5685          (BLS) Biology - Cellular;(BLS) Toxicology;
# 5696          (BLS) Biology - Cellular;(BLS) Toxicology;
# 6643                  (BLS) Genetics;(BLS) Microbiology;
# ...                                                  ...
# 42578  (HSC) Medicine - Cardiology;(HSC) Medicine - P...
# 42579  (HSC) Medicine - Cardiology;(HSC) Medicine - P...
# 42611                         (BLS) Biology - Molecular;
# 42613  (HSC) Medicine - Cardiovascular;(HSC) Medicine...
# 42695                            (SOC) Law/Legal Issues;
#
#                                              Institution  \
# 21229  Charles H. Dyson School of Applied Economics a...
# 21230  Charles H. Dyson School of Applied Economics a...
# 5685   Department of Clinical Immunology, Xijing Hosp...
# 5696   Department of Clinical Immunology, Xijing Hosp...
# 6643   Department of Agricultural Biotechnology, Seou...
# ...                                                  ...
# 42578  Department of Radiology, University of Califor...
# 42579  Department of Radiology, University of Califor...
# 42611  Department of Immunology, Institute of Child H...
# 42613  Endocrinology-Mineral Metabolism and Nephrolog...
# 42695                             University of Chicago;
#
#                                                  Journal  \
# 21229                                    JAMA Pediatrics
# 21230                                    JAMA Pediatrics
# 5685                            Environmental Toxicology
# 5696                            Environmental Toxicology
# 6643                             Journal of Microbiology
# ...                                                  ...
# 42578                            Investigative Radiology
# 42579                            Investigative Radiology
# 42611               Clinical and Experimental Immunology
# 42613  Translational Research: The Journal of Laborat...
# 42695               The University of Chicago Law Review
#
#                               Publisher              Country  \
# 21229                      JAMA Network        United States
# 21230                      JAMA Network        United States
# 5685                              Wiley  China;United States
# 5696                              Wiley  China;United States
# 6643                           Springer          South Korea
# ...                                 ...                  ...
# 42578                    Wolters Kluwer        United States
# 42579                    Wolters Kluwer        United States
# 42611              Blackwell Publishing       United Kingdom
# 42613                          Elsevier        United States
# 42695  University of Chicago Law School        United States
#
#                                                   Author  \
# 21229          Brian Wansink;David R Just;Collin R Payne
# 21230          Brian Wansink;David R Just;Collin R Payne
# 5685       Zhenbiao Wu;Emily Y He;Glenda I Scott;Jun Ren
# 5696       Zhenbiao Wu;Emily Y He;Glenda I Scott;Jun Ren
# 6643   Slae Choi;Kyungku Jang;Seulah Choi;Hee Jee Yun...
# ...                                                  ...
# 42578                                   Robert A Slutsky
# 42579                                   Robert A Slutsky
# 42611  S A Roberts;M C Reinhardt;R Paganelli;R J Levi...
# 42613  PW Lambert;PB DeOreo;BW Hollis;IY Fu;DJ Ginsbe...
# 42695                                    Brainerd Currie
#
#                                                     URLS  \
# 21229  http://retractionwatch.com/?s=brian+wansink;ht...
# 21230  http://retractionwatch.com/?s=brian+wansink;ht...
# 5685   https://retractionwatch.com/2022/07/25/univers...
# 5696   https://retractionwatch.com/2022/07/25/univers...
# 6643                                                 NaN
# ...                                                  ...
# 42578  http://retractionwatch.com/the-retraction-watc...
# 42579  http://retractionwatch.com/the-retraction-watc...
# 42611                                                NaN
# 42613                                                NaN
# 42695                                                NaN
#
#                                       ArticleType RetractionDate  \
# 21229  Letter;Research Article;Retracted Article;     2017-10-20
# 21230                    Letter;Research Article;     2017-09-21
# 5685              Correction/Erratum/Corrigendum;     2022-07-27
# 5696                            Research Article;     2022-07-27
# 6643                            Research Article;     2022-05-23
# ...                                           ...            ...
# 42578                           Research Article;     1986-02-01
# 42579                           Research Article;     1986-02-01
# 42611                           Research Article;     1985-01-01
# 42613                           Research Article;     1984-10-01
# 42695                           Research Article;     1960-02-01
#
#                           RetractionDOI RetractionPubMedID OriginalPaperDate  \
# 21229  10.1001/jamapediatrics.2017.4603                  0        2012-10-01
# 21230  10.1001/jamapediatrics.2017.3136           28973133        2012-10-01
# 5685                  10.1002/tox.23620           35894684        2021-09-12
# 5696                  10.1002/tox.23620           35894684        2013-12-23
# 6643          10.1007/s12275-022-1680-4           35606641        2012-08-25
# ...                                 ...                ...               ...
# 42578                               NaN            3514538        1983-03-01
# 42579                               NaN            3514538        1984-11-01
# 42611                               NaN            3882286        1981-07-01
# 42613                               NaN            6384395        1981-10-01
# 42695                               NaN                NaN        1955-02-01
#
#                       OriginalPaperDOI OriginalPaperPubMedID RetractionNature  \
# 21229  10.1001/archpediatrics.2012.999              22911396       Retraction
# 21230  10.1001/archpediatrics.2012.999              22911396       Retraction
# 5685                 10.1002/tox.21941              34514704       Retraction
# 5696                 10.1002/tox.21941              24376112       Retraction
# 6643         10.1007/s12275-012-2294-z              22923124       Retraction
# ...                                ...                   ...              ...
# 42578                              NaN               6345451       Retraction
# 42579                              NaN               6392156       Retraction
# 42611                              NaN               6171369       Retraction
# 42613                              NaN               6270222       Retraction
# 42695                              NaN                   NaN       Retraction
#
#                                                   Reason Paywalled  \
# 21229  +Breach of Policy by Author;+Error in Data;+Er...        No
# 21230  +Error in Analyses;+Error in Data;+Error in Me...        No
# 5685                             +Updated to Retraction;        No
# 5696   +Falsification/Fabrication of Image;+Investiga...        No
# 6643   +Concerns/Issues About Authorship;+Upgrade/Upd...        No
# ...                                                  ...       ...
# 42578  +Concerns/Issues About Results;+Legal Reasons/...        No
# 42579  +Concerns/Issues About Results;+Legal Reasons/...        No
# 42611  +Error in Analyses;+Results Not Reproducible;+...        No
# 42613  +Notice - Unable to Access via current resources;   Unknown
# 42695  +Error in Results and/or Conclusions;+Unreliab...       Yes
#
#                                                    Notes
# 21229  Journal previously named Archives of Pediatric...
# 21230  note: the paper was retracted again on October...
# 5685                                                 NaN
# 5696                                                 NaN
# 6643                                                 NaN
# ...                                                  ...
# 42578                                                NaN
# 42579  Article is Nov/Dec 1984 (vol. 19, iss. 6, no d...
# 42611              No DOI for Original/Notice 3/24/2017;
# 42613  Journal formerly known as: The Journal of Labo...
# 42695                                                NaN
#
# [2565 rows x 20 columns]

# %%
def find_changed_columns(group):
    changed_cols = group.apply(lambda x: x.nunique()).drop(['OriginalPaperDOI', 'Record ID'])
    value = changed_cols[changed_cols>1].index.to_list()
    return value


filtered_dupes.groupby('OriginalPaperDOI').apply(find_changed_columns).reset_index()
# Out:
#                    OriginalPaperDOI  \
# 0   10.1001/archpediatrics.2012.999
# 1                 10.1002/tox.21941
# 2         10.1007/s12275-012-2294-z
# 3         10.1007/s13277-014-2995-5
# 4     10.1016/j.carbpol.2019.115799
# 5         10.1016/j.cej.2011.04.016
# 6        10.1016/j.esxm.2021.100447
# 7         10.1016/j.lfs.2019.116709
# 8        10.1016/j.rapm.2005.05.009
# 9       10.1016/j.swevo.2021.100868
# 10       10.1038/s41598-021-03765-z
# 11         10.1088/1742-2140/aa953a
# 12         10.1088/1742-2140/aaaf57
# 13               10.1093/jge/aabc74
# 14            10.1136/jim-2021-SRMC
# 15        10.1524/9783486834062.275
# 16    10.3109/02699052.2016.1162060
#
#                                                     0
# 0   [ArticleType, RetractionDate, RetractionDOI, R...
# 1   [Title, ArticleType, OriginalPaperDate, Origin...
# 2   [RetractionDate, RetractionDOI, RetractionPubM...
# 3   [ArticleType, RetractionDate, RetractionDOI, R...
# 4   [RetractionDate, RetractionDOI, RetractionPubM...
# 5              [RetractionDate, RetractionDOI, Notes]
# 6   [RetractionDate, RetractionDOI, RetractionPubM...
# 7   [Subject, RetractionDate, RetractionDOI, Retra...
# 8   [RetractionDate, RetractionDOI, RetractionPubM...
# 9              [RetractionDate, RetractionDOI, Notes]
# 10  [RetractionDate, RetractionDOI, RetractionPubM...
# 11            [RetractionDate, RetractionDOI, Reason]
# 12            [RetractionDate, RetractionDOI, Reason]
# 13            [RetractionDate, RetractionDOI, Reason]
# 14  [Title, Institution, Country, Author, Retracti...
# 15                                   [RetractionDate]
# 16                                    [Title, Author]

# %%
# following code commented so as to not override the changed made in the file
# with pd.ExcelWriter('./wos_rd/DOI_Duplicated_RWD.xlsx') as writer:
#     filtered_dupes.groupby('OriginalPaperDOI').apply(find_changed_columns).reset_index().to_excel(writer, sheet_name= "Differing vars",index = False)
#     filtered_dupes.to_excel(writer, sheet_name = "Duplicate records",index = False)

# %%
rwd[rwd['OriginalPaperDOI']=='10.3109/02699052.2016.1162060']
# Out:
#        Record ID                                              Title  \
# 23288       8429  Are rehabilitation outcomes after anoxic brain...
# 23290       6000  The effect of demographic and clinical charact...
#
#                                                  Subject  Institution  \
# 23288  (HSC) Medicine - Neurology;(HSC) Medicine - Re...  Unavailable
# 23290  (HSC) Medicine - Neurology;(HSC) Medicine - Re...  Unavailable
#
#             Journal           Publisher              Country  \
# 23288  Brain Injury  Taylor and Francis  Netherlands;Unknown
# 23290  Brain Injury  Taylor and Francis  Netherlands;Unknown
#
#                                                   Author URLS  \
# 23288  Emre Adiguzel;Evren Yasar;Yasin Demir;Ismail S...  NaN
# 23290  Evren Yasar;Serdar Kesikburun;Ummugulsum Dogan...  NaN
#
#                       ArticleType RetractionDate  \
# 23288  Conference Abstract/Paper;     2016-08-17
# 23290  Conference Abstract/Paper;     2016-08-17
#
#                        RetractionDOI RetractionPubMedID OriginalPaperDate  \
# 23288  10.1080/02699052.2016.1210325           27533125        2016-05-19
# 23290  10.1080/02699052.2016.1210325           27533125        2016-05-19
#
#                     OriginalPaperDOI OriginalPaperPubMedID RetractionNature  \
# 23288  10.3109/02699052.2016.1162060              27196965       Retraction
# 23290  10.3109/02699052.2016.1162060              27196965       Retraction
#
#                                      Reason Paywalled  \
# 23288  +Notice - Limited or No Information;        No
# 23290  +Notice - Limited or No Information;        No
#
#                                                    Notes
# 23288  Part of Accepted Abstracts from the Internatio...
# 23290                                                NaN

# %%
def find_changed_columns(group):
    changed_cols = group.apply(lambda x: x.nunique()).drop(['OriginalPaperDOI', 'Record ID'])
    value = changed_cols[changed_cols>1].index.to_list()
    return value

filtered_dupes[(filtered_dupes['Record ID'] == 8429) | (filtered_dupes['Record ID'] == 6000)].groupby('OriginalPaperDOI').apply(find_changed_columns).reset_index()
# Out:
#                 OriginalPaperDOI                0
# 0  10.3109/02699052.2016.1162060  [Title, Author]

# %%
pd.set_option('display.max_colwidth', None)  # Show full content of columns
pd.set_option('display.max_rows', None)      # Display all rows

# %%
filtered_dupes[(filtered_dupes['Record ID'] == 30679) | (filtered_dupes['Record ID'] == 30686)]['Title']
# Out:
# 11353    Acute kidney injury and collapsing glomerulopathy associated with COVID-19 and APOL1 high risk genotype Abstract 621
# 11352    Acute kidney injury and collapsing glomerulopathy associated with COVID-19 and APOL1 high risk genotype Abstract 111
# Name: Title, dtype: object

# %%
filtered_dupes[(filtered_dupes['Record ID'] == 30687) | (filtered_dupes['Record ID'] == 30691)]['Title']
# Out:
# 11365    Filter clotting, anticoagulation and duration of sled in patients with COVID-19 and acute kidney injury Abstract 643
# 11364    Filter clotting, anticoagulation and duration of sled in patients with COVID-19 and acute kidney injury Abstract 112
# Name: Title, dtype: object

# %%
pd.reset_option('display.max_colwidth')
pd.reset_option('display.max_rows')

# %%
# records that should be deleted
records_to_delete = [6000, 2175, 7242]
rwd = rwd[~rwd['Record ID'].isin(records_to_delete)]

# %%
rwd.sort_values(by=['OriginalPaperDOI', 'OriginalPaperDate'], ascending=[True, False], inplace=True)

# Keep only the first occurrence of each unique DOI (the most recent date)
filtered_rwd = rwd.drop_duplicates(subset='OriginalPaperDOI')

# %% [markdown]
# ### Title analysis

# %%
rwd[rwd['Title'].str.startswith("Retracted:")]
# Out:
#        Record ID                                              Title  \
# 13359      45110  Retracted: Lifting the lid on lobbying in Indi...
# 1326       46570  Retracted: miR-214-3p Protects and Restores th...
#
#                                                  Subject  \
# 13359                                  (B/T) Government;
# 1326   (BLS) Biology - Molecular;(BLS) Genetics;(HSC)...
#
#                                              Institution  \
# 13359  Department of Management Studies, Indian Insti...
# 1326   Key Laboratory of Advanced Technologies of Mat...
#
#                                                  Journal Publisher Country  \
# 13359                          Journal of Public Affairs     Wiley   India
# 1326   Evidence-Based Complementary and Alternative M...   Hindawi   China
#
#                                     Author  \
# 13359  Pankaj K P Shreyaskar;Pramod Pathak
# 1326      Yuan Cheng;Qing He;Tao Jin;Na Li
#
#                                                     URLS        ArticleType  \
# 13359                                                NaN  Research Article;
# 1326   https://retractionwatch.com/2022/09/28/exclusi...  Research Article;
#
#       RetractionDate         RetractionDOI RetractionPubMedID  \
# 13359     2020-09-21       10.1002/pa.2423                  0
# 1326      2023-06-21  10.1155/2023/9823451           37388114
#
#       OriginalPaperDate      OriginalPaperDOI OriginalPaperPubMedID  \
# 13359        2020-09-21       10.1002/pa.2423                     0
# 1326         2022-07-18  10.1155/2022/1175935              35899226
#
#       RetractionNature                                             Reason  \
# 13359       Retraction  +Date of Retraction/Other Unknown;+Euphemisms ...
# 1326        Retraction  +Concerns/Issues About Data;+Concerns/Issues a...
#
#       Paywalled                                              Notes
# 13359        No                                                NaN
# 1326         No  See also: https://pubpeer.com/publications/C08...

# %%
rwd['Title'] = rwd['Title'].str.replace('Retracted:', '')

# %%
rwd[rwd['Title'].str.startswith("Retracted:")]
# Out:
# Empty DataFrame
# Columns: [Record ID, Title, Subject, Institution, Journal, Publisher, Country, Author, URLS, ArticleType, RetractionDate, RetractionDOI, RetractionPubMedID, OriginalPaperDate, OriginalPaperDOI, OriginalPaperPubMedID, RetractionNature, Reason, Paywalled, Notes]
# Index: []

# %%
rwd.iloc[[1326,13359]]
# Out:
#        Record ID                                              Title  \
# 12550      25797  LncRNA ATB promotes proliferation and metastas...
# 11996      44387  Preparation of self-healing anti-corrosion coa...
#
#                                                  Subject  \
# 12550  (BLS) Biochemistry;(BLS) Biology - Cancer;(BLS...
# 11996  (PHY) Engineering - Chemical;(PHY) Materials S...
#
#                                              Institution  \
# 12550  Department of Respiratory Medicine, The Affili...
# 11996  Department of Materials Engineering, Isfahan U...
#
#                                 Journal           Publisher Country  \
# 12550  Journal of Cellular Biochemistry               Wiley   China
# 11996               Surface Engineering  Taylor and Francis    Iran
#
#                                                   Author  \
# 12550  Yiwei Cao;Xiangjun Luo;Xiaoqian Ding;Shichao C...
# 11996          Sogand Abbaspour;Ali Ashrafi;Mehdi Salehi
#
#                                                     URLS        ArticleType  \
# 12550  http://retractionwatch.com/2021/03/08/journal-...  Research Article;
# 11996                                                NaN  Research Article;
#
#       RetractionDate                  RetractionDOI RetractionPubMedID  \
# 12550     2020-12-15              10.1002/jcb.29877           33590514
# 11996     2021-02-01  10.1080/02670844.2021.1883242                  0
#
#       OriginalPaperDate               OriginalPaperDOI OriginalPaperPubMedID  \
# 12550        2018-04-25              10.1002/jcb.26894              29693289
# 11996        2019-11-21  10.1080/02670844.2019.1689641                     0
#
#       RetractionNature                                             Reason  \
# 12550       Retraction  +Concerns/Issues About Data;+Concerns/Issues a...
# 11996       Retraction  +Concerns/Issues About Image;+Concerns/Issues ...
#
#       Paywalled                                              Notes
# 12550        No  see also: https://pubpeer.com/publications/B2B...
# 11996        No                                                NaN

# %%
rwd[rwd['Title'].str.contains("(Withdrawn Publication)")]
# Out:
# C:\Users\isabe\AppData\Local\Temp\ipykernel_29732\2493679348.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   rwd[rwd['Title'].str.contains("(Withdrawn Publication)")]
# Empty DataFrame
# Columns: [Record ID, Title, Subject, Institution, Journal, Publisher, Country, Author, URLS, ArticleType, RetractionDate, RetractionDOI, RetractionPubMedID, OriginalPaperDate, OriginalPaperDOI, OriginalPaperPubMedID, RetractionNature, Reason, Paywalled, Notes]
# Index: []

# %% [markdown]
# ## Title Analysis

# %%
# Remove spaces at the end of the string
rwd['Title'] = rwd['Title'].str.rstrip()

#lower case string
rwd['Title'] = rwd['Title'].str.lower()

# %%
rwd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 42697 entries, 29155 to 42695
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Record ID              42697 non-null  int64
#  1   Title                  42697 non-null  object
#  2   Subject                42697 non-null  object
#  3   Institution            42696 non-null  object
#  4   Journal                42697 non-null  object
#  5   Publisher              42697 non-null  object
#  6   Country                42697 non-null  object
#  7   Author                 42697 non-null  object
#  8   URLS                   21686 non-null  object
#  9   ArticleType            42697 non-null  object
#  10  RetractionDate         42697 non-null  datetime64[ns]
#  11  RetractionDOI          42206 non-null  object
#  12  RetractionPubMedID     37596 non-null  object
#  13  OriginalPaperDate      42697 non-null  datetime64[ns]
#  14  OriginalPaperDOI       40170 non-null  object
#  15  OriginalPaperPubMedID  37561 non-null  object
#  16  RetractionNature       42697 non-null  object
#  17  Reason                 42697 non-null  object
#  18  Paywalled              42697 non-null  object
#  19  Notes                  10251 non-null  object
# dtypes: datetime64[ns](2), int64(1), object(17)
# memory usage: 6.8+ MB

# %% [markdown]
# <a class="anchor">
#
# ## 1.2 - Control Set (CS) <a class="anchor" id="section_1_2"></a>

# %%
control_set_imported = pd.DataFrame()

# %%
import glob
import pyarrow.parquet as pq

# %%
glob.glob("../thesis_data/processed_data/*.parquet")
# Out:
# ['../thesis_data/processed_data\\WoS_journals0-99_Rdata.parquet',
#  '../thesis_data/processed_data\\WoS_journals1400-1499_Rdata.parquet',
#  '../thesis_data/processed_data\\WoS_journals1600-1803_P1_Rdata.parquet',
#  '../thesis_data/processed_data\\WoS_journals1600-1803_P2_Rdata.parquet',
#  '../thesis_data/processed_data\\WoS_journalsleft_Rdata.parquet']

# %%
for file in glob.glob("../thesis_data/processed_data/*.parquet"):
    parquet_file = pq.read_table(file).to_pandas()
    control_set_imported = pd.concat([control_set_imported, parquet_file], ignore_index = True)

# %%
control_set_imported.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943818 entries, 0 to 943817
# Columns: 212 entries, AU to X.....................and....i
# dtypes: float64(2), object(210)
# memory usage: 1.5+ GB

# %%
control_set = control_set_imported.copy()

# %%
control_set.filter(like='X.').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943818 entries, 0 to 943817
# Columns: 154 entries, X....paidb..ext.link.type to X.....................and....i
# dtypes: object(154)
# memory usage: 1.1+ GB

# %%
control_set.drop(columns=control_set.filter(like='X.').columns, inplace=True)

# %%
control_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943818 entries, 0 to 943817
# Data columns (total 58 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   AU                          943818 non-null  object
#  1   DE                          544644 non-null  object
#  2   ID                          883685 non-null  object
#  3   C1                          940677 non-null  object
#  4   CR                          940482 non-null  object
#  5   AB                          912823 non-null  object
#  6   PA                          943818 non-null  object
#  7   affiliations                924960 non-null  object
#  8   AR                          136585 non-null  object
#  9   EM                          858780 non-null  object
#  10  book.author                 145 non-null     object
#  11  BO                          16783 non-null   object
#  12  da                          943818 non-null  object
#  13  DI                          930355 non-null  object
#  14  GA                          943818 non-null  object
#  15  eissn                       730427 non-null  object
#  16  esi.highly.cited.paper      37895 non-null   object
#  17  esi.hot.paper               37895 non-null   object
#  18  earlyaccessdate             109270 non-null  object
#  19  BE                          16267 non-null   object
#  20  FU                          578103 non-null  object
#  21  FX                          532315 non-null  object
#  22  BN                          15712 non-null   object
#  23  SN                          922400 non-null  object
#  24  JI                          943818 non-null  object
#  25  SO                          943818 non-null  object
#  26  LA                          943818 non-null  object
#  27  month                       872009 non-null  object
#  28  note                        35554 non-null   object
#  29  NR                          943818 non-null  object
#  30  PN                          723042 non-null  object
#  31  oa                          420579 non-null  object
#  32  orcid.numbers               707045 non-null  object
#  33  organization                23043 non-null   object
#  34  PP                          815488 non-null  object
#  35  PU                          943818 non-null  object
#  36  SC                          943818 non-null  object
#  37  researcherid.numbers        633371 non-null  object
#  38  SE                          17636 non-null   object
#  39  TC                          943818 non-null  float64
#  40  TI                          943818 non-null  object
#  41  DT                          943818 non-null  object
#  42  UT                          943818 non-null  object
#  43  usage.count.last.180.days   943818 non-null  object
#  44  U2                          943818 non-null  object
#  45  VL                          941847 non-null  object
#  46  web.of.science.categories.  943818 non-null  object
#  47  web.of.science.index        943818 non-null  object
#  48  PY                          943818 non-null  float64
#  49  RP                          940677 non-null  object
#  50  DB                          943818 non-null  object
#  51  J9                          943818 non-null  object
#  52  AU_UN                       940576 non-null  object
#  53  AU1_UN                      943818 non-null  object
#  54  AU_UN_NR                    0 non-null       object
#  55  SR_FULL                     943818 non-null  object
#  56  SR                          943818 non-null  object
#  57  book.group.author           386 non-null     object
# dtypes: float64(2), object(56)
# memory usage: 417.6+ MB

# %%
control_set.columns
# Out:
# Index(['AU', 'DE', 'ID', 'C1', 'CR', 'AB', 'PA', 'affiliations', 'AR', 'EM',
#        'book.author', 'BO', 'da', 'DI', 'GA', 'eissn',
#        'esi.highly.cited.paper', 'esi.hot.paper', 'earlyaccessdate', 'BE',
#        'FU', 'FX', 'BN', 'SN', 'JI', 'SO', 'LA', 'month', 'note', 'NR', 'PN',
#        'oa', 'orcid.numbers', 'organization', 'PP', 'PU', 'SC',
#        'researcherid.numbers', 'SE', 'TC', 'TI', 'DT', 'UT',
#        'usage.count.last.180.days', 'U2', 'VL', 'web.of.science.categories.',
#        'web.of.science.index', 'PY', 'RP', 'DB', 'J9', 'AU_UN', 'AU1_UN',
#        'AU_UN_NR', 'SR_FULL', 'SR', 'book.group.author'],
#       dtype='object')

# %%
rename_columns = {
    'AU': "authors", 
    'DE': "author_keywords", 
    'ID': "keywords_plus", 
    'C1': "author_address", 
    'CR': "cited_references", 
    'AB': "abstract", 
    'PA': "publisher_address", 
    #'affiliations', 
    'AR': "article_number", 
    'EM': "email_address",
    'book.author': "book_author", 
    ###'BO': "book",  -> n está na documentação
    'da': "date_report_generated", 
    'DI': "doi", 
    'GA': "document_delivery_number", 
    #'eissn',
    'esi.highly.cited.paper': "esi_highly_cited_paper", 
    'esi.hot.paper': "esi_hot_paper", 
    'earlyaccessdate': "early_access_date", 
    'BE': "editors",
    'FU': "funding_agency_and_grant_number", 
    'FX': "funding_text", 
    'BN': "isbn", 
    'SN': "issn", 
    'JI': "iso_source_abv", 
    'SO': "publication_name", 
    'LA': "language", 
    #'month', 
    #'note', 
    'NR': "cited_reference_count", 
    'PN': "part_number",
    'oa': "open_access_indicator", 
    'orcid.numbers': "orcid_numbers", 
    #'organization', 
    ###'PP', -> n está na documentação
    'PU': "publisher", 
    'SC': "research_areas",
    'researcherid.numbers': "researcher_id_numbers", 
    'SE': "book_series_title", 
    'TC': "wos_core_collection_times_cited_count", 
    'TI': "document_title", 
    'DT': "document_type", 
    'UT': "accession_number",
    'usage.count.last.180.days': "usage_count_last_180_days", 
    'U2': "usage_count_since_2013", 
    'VL': "volume", 
    'web.of.science.categories.': "wos_categories",
    'web.of.science.index': "wos_index", 
    'PY': "year_published", 
    'RP': "reprint_address", 
    'DB': "database", 
    'J9': "29_character_source_abv", 
    'AU_UN': "authors_affiliations", 
    'AU1_UN': "corresponding_author_affiliation",
    'AU_UN_NR': "not_recognized_affiliations", 
    'SR_FULL': "short_full_reference", 
    'SR': "short_reference"
}

control_set.rename(columns = rename_columns, inplace = True)
control_set.columns
# Out:
# Index(['authors', 'author_keywords', 'keywords_plus', 'author_address',
#        'cited_references', 'abstract', 'publisher_address', 'affiliations',
#        'article_number', 'email_address', 'book_author', 'BO',
#        'date_report_generated', 'doi', 'document_delivery_number', 'eissn',
#        'esi_highly_cited_paper', 'esi_hot_paper', 'early_access_date',
#        'editors', 'funding_agency_and_grant_number', 'funding_text', 'isbn',
#        'issn', 'iso_source_abv', 'publication_name', 'language', 'month',
#        'note', 'cited_reference_count', 'part_number', 'open_access_indicator',
#        'orcid_numbers', 'organization', 'PP', 'publisher', 'research_areas',
#        'researcher_id_numbers', 'book_series_title',
#        'wos_core_collection_times_cited_count', 'document_title',
#        'document_type', 'accession_number', 'usage_count_last_180_days',
#        'usage_count_since_2013', 'volume', 'wos_categories', 'wos_index',
#        'year_published', 'reprint_address', 'database',
#        '29_character_source_abv', 'authors_affiliations',
#        'corresponding_author_affiliation', 'not_recognized_affiliations',
#        'short_full_reference', 'short_reference', 'book.group.author'],
#       dtype='object')

# %%
control_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943818 entries, 0 to 943817
# Data columns (total 58 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   authors                                943818 non-null  object
#  1   author_keywords                        544644 non-null  object
#  2   keywords_plus                          883685 non-null  object
#  3   author_address                         940677 non-null  object
#  4   cited_references                       940482 non-null  object
#  5   abstract                               912823 non-null  object
#  6   publisher_address                      943818 non-null  object
#  7   affiliations                           924960 non-null  object
#  8   article_number                         136585 non-null  object
#  9   email_address                          858780 non-null  object
#  10  book_author                            145 non-null     object
#  11  BO                                     16783 non-null   object
#  12  date_report_generated                  943818 non-null  object
#  13  doi                                    930355 non-null  object
#  14  document_delivery_number               943818 non-null  object
#  15  eissn                                  730427 non-null  object
#  16  esi_highly_cited_paper                 37895 non-null   object
#  17  esi_hot_paper                          37895 non-null   object
#  18  early_access_date                      109270 non-null  object
#  19  editors                                16267 non-null   object
#  20  funding_agency_and_grant_number        578103 non-null  object
#  21  funding_text                           532315 non-null  object
#  22  isbn                                   15712 non-null   object
#  23  issn                                   922400 non-null  object
#  24  iso_source_abv                         943818 non-null  object
#  25  publication_name                       943818 non-null  object
#  26  language                               943818 non-null  object
#  27  month                                  872009 non-null  object
#  28  note                                   35554 non-null   object
#  29  cited_reference_count                  943818 non-null  object
#  30  part_number                            723042 non-null  object
#  31  open_access_indicator                  420579 non-null  object
#  32  orcid_numbers                          707045 non-null  object
#  33  organization                           23043 non-null   object
#  34  PP                                     815488 non-null  object
#  35  publisher                              943818 non-null  object
#  36  research_areas                         943818 non-null  object
#  37  researcher_id_numbers                  633371 non-null  object
#  38  book_series_title                      17636 non-null   object
#  39  wos_core_collection_times_cited_count  943818 non-null  float64
#  40  document_title                         943818 non-null  object
#  41  document_type                          943818 non-null  object
#  42  accession_number                       943818 non-null  object
#  43  usage_count_last_180_days              943818 non-null  object
#  44  usage_count_since_2013                 943818 non-null  object
#  45  volume                                 941847 non-null  object
#  46  wos_categories                         943818 non-null  object
#  47  wos_index                              943818 non-null  object
#  48  year_published                         943818 non-null  float64
#  49  reprint_address                        940677 non-null  object
#  50  database                               943818 non-null  object
#  51  29_character_source_abv                943818 non-null  object
#  52  authors_affiliations                   940576 non-null  object
#  53  corresponding_author_affiliation       943818 non-null  object
#  54  not_recognized_affiliations            0 non-null       object
#  55  short_full_reference                   943818 non-null  object
#  56  short_reference                        943818 non-null  object
#  57  book.group.author                      386 non-null     object
# dtypes: float64(2), object(56)
# memory usage: 417.6+ MB

# %%
cols_to_drop = ['author_address', 'publisher_address',  'email_address', 'date_report_generated', 'document_delivery_number', 'editors', 'article_number', 'book_author', 'BO', 'funding_text', 'part_number', 'orcid_numbers', 'PP',  'accession_number', 'usage_count_last_180_days',
'usage_count_since_2013', 'volume', 'reprint_address', 'database', '29_character_source_abv', 'wos_index', 'not_recognized_affiliations',
'short_full_reference', 'short_reference']

control_set = control_set.drop(cols_to_drop, axis=1)

# %%
new_data_types = {'cited_reference_count': 'Int64', 
                'wos_core_collection_times_cited_count': 'Int64', 
                'year_published': 'Int64'}


for col, dtype in new_data_types.items():
    control_set[col] = pd.array(control_set[col],dtype = pd.Int64Dtype())

control_set['early_access_date'] = pd.to_datetime(control_set['early_access_date'], format='%b %Y')

# %%
control_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943818 entries, 0 to 943817
# Data columns (total 34 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   authors                                943818 non-null  object
#  1   author_keywords                        544644 non-null  object
#  2   keywords_plus                          883685 non-null  object
#  3   cited_references                       940482 non-null  object
#  4   abstract                               912823 non-null  object
#  5   affiliations                           924960 non-null  object
#  6   doi                                    930355 non-null  object
#  7   eissn                                  730427 non-null  object
#  8   esi_highly_cited_paper                 37895 non-null   object
#  9   esi_hot_paper                          37895 non-null   object
#  10  early_access_date                      109270 non-null  datetime64[ns]
#  11  funding_agency_and_grant_number        578103 non-null  object
#  12  isbn                                   15712 non-null   object
#  13  issn                                   922400 non-null  object
#  14  iso_source_abv                         943818 non-null  object
#  15  publication_name                       943818 non-null  object
#  16  language                               943818 non-null  object
#  17  month                                  872009 non-null  object
#  18  note                                   35554 non-null   object
#  19  cited_reference_count                  943818 non-null  Int64
#  20  open_access_indicator                  420579 non-null  object
#  21  organization                           23043 non-null   object
#  22  publisher                              943818 non-null  object
#  23  research_areas                         943818 non-null  object
#  24  researcher_id_numbers                  633371 non-null  object
#  25  book_series_title                      17636 non-null   object
#  26  wos_core_collection_times_cited_count  943818 non-null  Int64
#  27  document_title                         943818 non-null  object
#  28  document_type                          943818 non-null  object
#  29  wos_categories                         943818 non-null  object
#  30  year_published                         943818 non-null  Int64
#  31  authors_affiliations                   940576 non-null  object
#  32  corresponding_author_affiliation       943818 non-null  object
#  33  book.group.author                      386 non-null     object
# dtypes: Int64(3), datetime64[ns](1), object(30)
# memory usage: 247.5+ MB

# %%
control_set = control_set[control_set['year_published']<2023]

# %%
control_set.describe().T
# Out:
#                                           count  \
# early_access_date                        103985
# cited_reference_count                  938418.0
# wos_core_collection_times_cited_count  938418.0
# year_published                         938418.0
#
#                                                                 mean  \
# early_access_date                      2021-08-14 17:11:16.309082624
# cited_reference_count                                      52.958932
# wos_core_collection_times_cited_count                      99.088385
# year_published                                           2013.203568
#
#                                                        min  \
# early_access_date                      2017-10-01 00:00:00
# cited_reference_count                                  0.0
# wos_core_collection_times_cited_count                  0.0
# year_published                                      2000.0
#
#                                                        25%  \
# early_access_date                      2021-03-01 00:00:00
# cited_reference_count                                 29.0
# wos_core_collection_times_cited_count                 12.0
# year_published                                      2008.0
#
#                                                        50%  \
# early_access_date                      2021-09-01 00:00:00
# cited_reference_count                                 42.0
# wos_core_collection_times_cited_count                 30.0
# year_published                                      2014.0
#
#                                                        75%  \
# early_access_date                      2022-04-01 00:00:00
# cited_reference_count                                 59.0
# wos_core_collection_times_cited_count                 80.0
# year_published                                      2019.0
#
#                                                        max         std
# early_access_date                      2023-09-01 00:00:00         NaN
# cited_reference_count                               4723.0   55.109981
# wos_core_collection_times_cited_count              67880.0  337.584042
# year_published                                      2022.0    6.484763

# %%
control_set[control_set.duplicated()].shape[0]
# Out:
# 4784

# %%
control_set.shape
# Out:
# (938418, 34)

# %%
# Replace all NaN values with a common value (e.g., a string)
control_set = control_set.fillna('This is a missing value')

# Use drop_duplicates to remove duplicates with 'NaN' values
control_set.drop_duplicates(inplace=True)

# Now, you can replace the 'NaN' values with NaN again if needed
control_set = control_set.replace('This is a missing value', np.nan)

# %%
control_set.shape
# Out:
# (933634, 34)

# %%
control_set['month']
# Out:
# 0         JAN 28
# 1         JAN 28
# 2            MAR
# 3          NOV 7
# 4         JAN 28
#            ...
# 943812    NOV 26
# 943813       APR
# 943815     APR 1
# 943816    FEB 15
# 943817    SEP 25
# Name: month, Length: 933634, dtype: object

# %%
control_set['month'].fillna('JAN 1', inplace=True)

control_set['publication_date'] = pd.to_datetime(control_set['month'] + ' ' + control_set['year_published'].astype(str), errors='coerce')
control_set['publication_date'].fillna(pd.to_datetime('JAN 01 ' + control_set['year_published'].astype(str), format='%b %d %Y'), inplace=True)

# Sort the DataFrame by DOI and 'Publication Date' in descending order
control_set.sort_values(by=['doi', 'publication_date'], ascending=[True, False], inplace=True)
# Out:
# C:\Users\isabe\AppData\Local\Temp\ipykernel_29732\3746235765.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   control_set['publication_date'] = pd.to_datetime(control_set['month'] + ' ' + control_set['year_published'].astype(str), errors='coerce')

# %%
# Check for NaN values in 'doi' column
control_set_filtered = control_set.dropna(subset=['doi'])

# Filter rows starting with "http://dx.doi.org/"
control_set_filtered[control_set_filtered['doi'].str.startswith("http://dx.doi.org/")]['doi']
# Out:
# Series([], Name: doi, dtype: object)

# %%
control_set['doi'] = control_set['doi'].str.replace('http://dx.doi.org/', '')

# %% [markdown]
# ### Title Analysis

# %%
control_set.columns
# Out:
# Index(['authors', 'author_keywords', 'keywords_plus', 'cited_references',
#        'abstract', 'affiliations', 'doi', 'eissn', 'esi_highly_cited_paper',
#        'esi_hot_paper', 'early_access_date', 'funding_agency_and_grant_number',
#        'isbn', 'issn', 'iso_source_abv', 'publication_name', 'language',
#        'month', 'note', 'cited_reference_count', 'open_access_indicator',
#        'organization', 'publisher', 'research_areas', 'researcher_id_numbers',
#        'book_series_title', 'wos_core_collection_times_cited_count',
#        'document_title', 'document_type', 'wos_categories', 'year_published',
#        'authors_affiliations', 'corresponding_author_affiliation',
#        'book.group.author', 'publication_date'],
#       dtype='object')

# %%
control_set[(~control_set['document_title'].str.startswith("RETRACTED: ")) & (~control_set['document_title'].str.contains("(Withdrawn Publication)")) & ((~control_set['document_title'].str.contains("Retracted Article. See")))]
# Out:
# C:\Users\isabe\AppData\Local\Temp\ipykernel_29732\2247677768.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   control_set[(~control_set['document_title'].str.startswith("RETRACTED: ")) & (~control_set['document_title'].str.contains("(Withdrawn Publication)")) & ((~control_set['document_title'].str.contains("Retracted Article. See")))]
#                                                   authors  \
# 484329                                      KHOSHNAVAZ MJ
# 91310      CARTENI G;FIORENTINO R;VECCHIONE L;CHIURAZZI C
# 180029                LEE H;SMITH KG;GRIMM CM;SCHOMBURG A
# 179248                                   SIMERLY RL;LI MF
# 180038                     GERINGER JM;TALLMAN S;OLSEN DM
# ...                                                   ...
# 877831                                      [ANONYMOUS] A
# 878180  MAYFIELD JA;REIBER GE;SANDERS LJ;JANISSE D;POG...
# 878610                                      [ANONYMOUS] A
# 926523  O'BRIEN T;JOHNSON LH;ALDRICH JL;ALLEN SG;LIANG...
# 926825  O'CONNOR SM;ANDREADIS JD;SHAFFER KM;MA W;PANCR...
#
#                                           author_keywords  \
# 484329                                                NaN
# 91310   COLORECTAL CANCER; FULLY HUMAN MONOCLONAL ANTI...
# 180029  COMPETITIVE DYNAMICS; FIRST MOVER ADVANTAGE; E...
# 179248  ENVIRONMENTAL DYNAMISM; ORGANIZATIONAL ECONOMI...
# 180038        DIVERSIFICATION; MULTINATIONAL; PERFORMANCE
# ...                                                   ...
# 877831                                                NaN
# 878180                                                NaN
# 878610                                                NaN
# 926523  IMMUNOASSAYS; BIDIFFRACTIVE GRATING BIOSENSOR;...
# 926825  CELL IMMOBILIZATION; NEURONS; ASTROCYTES; NEUR...
#
#                                             keywords_plus  \
# 484329   TIME MIGRATION; INVERSION; LOCATION; DOMAIN; GAS
# 91310   GROWTH-FACTOR RECEPTOR; MONOCLONAL-ANTIBODY; C...
# 180029                            RETURNS; RIVALRY; EVENT
# 179248  TRANSACTION COST ECONOMICS; CORPORATE-STRATEGY...
# 180038  RESOURCE-BASED VIEW; PROFIT PERFORMANCE; COMPE...
# ...                                                   ...
# 877831                                                NaN
# 878180                                                NaN
# 878610                                                NaN
# 926523                                            SURFACE
# 926825  NERVOUS-SYSTEM; STEM-CELLS; NEURONS; GROWTH; M...
#
#                                          cited_references  \
# 484329  ALONAIZI F, 2013, GEOPHYS PROSPECT, V61, P1206...
# 91310   BASELGA J, 2000, J CLIN ONCOL, V18, P904, DOI ...
# 180029  BALDWIN WL, 1969, SOUTHERN ECON J, V36, P18, D...
# 179248  AIKEN L. S., 1991, MULTIPLE REGRESSION: TESTIN...
# 180038  AAKER DA, 1987, ACAD MANAGE J, V30, P277, DOI ...
# ...                                                   ...
# 877831                                                NaN
# 878180  AMERICAN DIABETES ASSOCIATION, 1999, DIABETES ...
# 878610                                                NaN
# 926523  ANDERSON GP, 1996, ASAIO J, V42, P942, DOI 10....
# 926825  ALVAREZ-BUYLLA A, 1998, J NEUROBIOL, V36, P105...
#
#                                                  abstract  \
# 484329  BUILDING AN ACCURATE VELOCITY MODEL PLAYS A VI...
# 91310   THE EPIDERMAL GROWTH FACTOR RECEPTOR (EGFR) IS...
# 180029  THIS RESEARCH EXAMINED THE EFFECTS OF TIMING, ...
# 179248  AN ONGOING ARGUMENT IN FINANCIAL MANAGEMENT HA...
# 180038  THIS PAPER EXAMINES THE RELATIONSHIP OF PERFOR...
# ...                                                   ...
# 877831                                                NaN
# 878180                                                NaN
# 878610                                                NaN
# 926523  A CRITICAL NEED EXISTS FOR A FIELD DEPLOYABLE ...
# 926825  TO OVERCOME LOGISTICAL DIFFICULTIES WITH CURRE...
#
#                                              affiliations  \
# 484329                               UNIVERSITY OF TEHRAN
# 91310   ANTONIO CARDARELLI HOSPITAL; UNIVERSITA DELLA ...
# 180029  GEORGE MASON UNIVERSITY; UNIVERSITY SYSTEM OF ...
# 179248  CALIFORNIA STATE UNIVERSITY SYSTEM; CALIFORNIA...
# 180038  UTAH SYSTEM OF HIGHER EDUCATION; UNIVERSITY OF...
# ...                                                   ...
# 877831                                                NaN
# 878180                                                NaN
# 878610                                                NaN
# 926523  UNITED STATES DEPARTMENT OF DEFENSE; UNITED ST...
# 926825  UNITED STATES DEPARTMENT OF DEFENSE; UNITED ST...
#
#                                                       doi      eissn  \
# 484329                             10.0090/geo2021-0173.1  1942-2156
# 91310                               10.0093/annonc/mdm218  1569-8041
# 180029  10.1002/(SICI)1097-0266(200001)21:1<23::AID-SM...        NaN
# 179248  10.1002/(SICI)1097-0266(200001)21:1<31::AID-SM...  1097-0266
# 180038  10.1002/(SICI)1097-0266(200001)21:1<51::AID-SM...        NaN
# ...                                                   ...        ...
# 877831                                                NaN  1476-5608
# 878180                                                NaN        NaN
# 878610                                                NaN  1365-2907
# 926523                                                NaN        NaN
# 926825                                                NaN        NaN
#
#        esi_highly_cited_paper esi_hot_paper  ... book_series_title  \
# 484329                    NaN           NaN  ...               NaN
# 91310                     NaN           NaN  ...               NaN
# 180029                    NaN           NaN  ...               NaN
# 179248                    NaN           NaN  ...               NaN
# 180038                    NaN           NaN  ...               NaN
# ...                       ...           ...  ...               ...
# 877831                    NaN           NaN  ...               NaN
# 878180                    NaN           NaN  ...               NaN
# 878610                    NaN           NaN  ...               NaN
# 926523                    NaN           NaN  ...               NaN
# 926825                    NaN           NaN  ...               NaN
#
#        wos_core_collection_times_cited_count  \
# 484329                                     4
# 91310                                     22
# 180029                                   205
# 179248                                   256
# 180038                                   383
# ...                                      ...
# 877831                                     0
# 878180                                     2
# 878610                                     0
# 926523                                    53
# 926825                                    76
#
#                                            document_title  \
# 484329  HIGH-RESOLUTION SEISMIC VELOCITY ANALYSIS BY S...
# 91310        PANITUMUMAB A NOVEL DRUG IN CANCER TREATMENT
# 180029  TIMING, ORDER AND DURABILITY OF NEW PRODUCT AD...
# 179248  ENVIRONMENTAL DYNAMISM, CAPITAL STRUCTURE AND ...
# 180038  PRODUCT AND INTERNATIONAL DIVERSIFICATION AMON...
# ...                                                   ...
# 877831  THE BRITISH PROSTATE GROUP SPRING MEETING, 16-...
# 878180       PREVENTIVE FOOT CARE IN PEOPLE WITH DIABETES
# 878610  THE PROCEEDINGS OF A SYMPOSIUM HELD AT THE THI...
# 926523  THE DEVELOPMENT OF IMMUNOASSAYS TO FOUR BIOLOG...
# 926825  IMMOBILIZATION OF NEURAL CELLS IN THREE-DIMENS...
#
#                      document_type  \
# 484329                     ARTICLE
# 91310   ARTICLE; PROCEEDINGS PAPER
# 180029                     ARTICLE
# 179248                      REVIEW
# 180038                     ARTICLE
# ...                            ...
# 877831                     ARTICLE
# 878180                     ARTICLE
# 878610                     ARTICLE
# 926523                     ARTICLE
# 926825                     ARTICLE
#
#                                            wos_categories year_published  \
# 484329                         GEOCHEMISTRY \& GEOPHYSICS           2021
# 91310                                            ONCOLOGY           2007
# 180029                               BUSINESS; MANAGEMENT           2000
# 179248                               BUSINESS; MANAGEMENT           2000
# 180038                               BUSINESS; MANAGEMENT           2000
# ...                                                   ...            ...
# 877831                    ONCOLOGY; UROLOGY \& NEPHROLOGY           2000
# 878180                                        ORTHOPEDICS           2000
# 878610                                   ECOLOGY; ZOOLOGY           2000
# 926523  BIOPHYSICS; BIOTECHNOLOGY \& APPLIED MICROBIOL...           2000
# 926825  BIOPHYSICS; BIOTECHNOLOGY \& APPLIED MICROBIOL...           2000
#
#                                      authors_affiliations  \
# 484329                            UNIV TEHRAN;UNIV TEHRAN
# 91310                     C (CORRESPONDING AUTHOR);NAPLES
# 180029  GEORGE MASON UNIV;GEORGE MASON UNIV;UNIV MARYL...
# 179248  CALIF STATE UNIV NORTHRIDGE;CALIF STATE UNIV N...
# 180038  UNIV UTAH;UNIV UTAH;CRANFIELD UNIV;CALIF POLYT...
# ...                                                   ...
# 877831                                                NaN
# 878180                                                NaN
# 878610                                                NaN
# 926523  T (CORRESPONDING AUTHOR);MED RES CTR;BATTELLE ...
# 926825  CTR BIOMOL SCI AND ENGN;CTR BIOMOL SCI AND ENG...
#
#        corresponding_author_affiliation book.group.author  publication_date
# 484329                      UNIV TEHRAN               NaN        2021-01-01
# 91310          C (CORRESPONDING AUTHOR)               NaN        2007-01-01
# 180029                GEORGE MASON UNIV               NaN        2000-01-01
# 179248      CALIF STATE UNIV NORTHRIDGE               NaN        2000-01-01
# 180038                        UNIV UTAH               NaN        2000-01-01
# ...                                 ...               ...               ...
# 877831                      NOTREPORTED               NaN        2000-01-01
# 878180                      NOTREPORTED               NaN        2000-01-01
# 878610                      NOTREPORTED               NaN        2000-01-01
# 926523         T (CORRESPONDING AUTHOR)               NaN        2000-01-01
# 926825          CTR BIOMOL SCI AND ENGN               NaN        2000-01-01
#
# [933172 rows x 35 columns]

# %%
control_set[(control_set['document_title'].str.startswith("RETRACTED: ")) | (control_set['document_title'].str.contains("(Withdrawn Publication)")) | ((control_set['document_title'].str.contains("Retracted Article. See")))]
# Out:
# C:\Users\isabe\AppData\Local\Temp\ipykernel_29732\2198231540.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   control_set[(control_set['document_title'].str.startswith("RETRACTED: ")) | (control_set['document_title'].str.contains("(Withdrawn Publication)")) | ((control_set['document_title'].str.contains("Retracted Article. See")))]
#                                                   authors  \
# 275054          SCHÖN JH;KLOC C;WILDEMAN J;HADZIIOANNOU G
# 275784                                KUMAR G;HO CC;CO CC
# 145097  YU LW;CHEN KJ;SONG J;XU J;LI HM;WANG M;LI XF;H...
# 274423  GHAFFARI M;ZHOU Y;XU H;LIN M;KIM TY;RUOFF RS;Z...
# 151506  GHAFFARI M;KINSMAN W;ZHOU Y;MURALI S;BURLINGAM...
# ...                                                   ...
# 311196  BAI R;YUAN C;SUN W;ZHANG J;LUO Y;GAO Y;LI Y;GO...
# 305862  ZHANG QQ;DING Y;LEI Y;QI CL;HE XD;LAN T;LI JC;...
# 802659                GUILLEMINAULT C;QUO S;HUYNH NT;LI K
# 619961                     KOUTKIA P;MYLONAKIS E;LEVIN RM
# 584418                                          BRODIE SJ
#
#                                           author_keywords  \
# 275054                                                NaN
# 275784                                                NaN
# 145097                                                NaN
# 274423  NANO-POROUS MICROWAVE EXFOLIATED GRAPHITE OXID...
# 151506                                                NaN
# ...                                                   ...
# 311196  NEK2; NSCLC; TUMORIGENESIS; WNT/BETA-CATENIN; ...
# 305862                ANDROGRAPHOLIDE; INSULINOMA; GROWTH
# 802659  PREPUBERTAL CHILDREN; PEDIATRIC OBSTRUCTIVE SL...
# 619961                                                NaN
# 584418  BALT; GALT; MACROPHAGES; FOLLICULAR DENDRITIC ...
#
#                                             keywords_plus  \
# 275054                                                NaN
# 275784  ENDOTHELIAL-CELLS; GEOMETRIC CONTROL; ADHESION...
# 145097  THIN-FILMS; ARRAYS; COALESCENCE; NUCLEATION; S...
# 274423  DOUBLE-LAYER CAPACITORS; WALLED CARBON NANOTUB...
# 151506  POLYMER ACTUATORS; ELECTROMECHANICAL RESPONSE;...
# ...                                                   ...
# 311196  DRUG-RESISTANCE; POOR-PROGNOSIS; IMMUNOTHERAPY...
# 305862  NF-KAPPA-B; MOUSE MODELS; CANCER; APOPTOSIS; C...
# 802659  RAPID MAXILLARY EXPANSION; NASAL AIRWAY-RESIST...
# 619961  PNEUMOCYSTIS-CARINII INFECTION; IMMUNE-DEFICIE...
# 584418  HUMAN-IMMUNODEFICIENCY-VIRUS; FOLLICULAR DENDR...
#
#                                          cited_references  \
# 275054  AHN CH, 1999, SCIENCE, V284, P1152, DOI 10.112...
# 275784  BARRY JJA, 2006, ADV MATER, V18, P1406, DOI 10...
# 145097  ANONYMOUS, 1983, RCA ENG; BANIN U, 1999, NATUR...
# 274423  BARBIERI O, 2005, CARBON, V43, P1303, DOI 10.1...
# 151506  ANONYMOUS, APPL PHYS LETT; BAR-COHEN Y, 2008, ...
# ...                                                   ...
# 311196  BURGER PE, 2005, P NATL ACAD SCI USA, V102, P7...
# 305862  BERGERS G, 1999, SCIENCE, V284, P808, DOI 10.1...
# 802659  ANONYMOUS, 1968, MANUAL STANDARDIZED; BONNET M...
# 619961  BASILIO-DE-OLIVEIRA C A, 2000, BRAZ J INFECT D...
# 584418  AN SF, 1999, J NEUROPATH EXP NEUR, V58, P1156,...
#
#                                                  abstract  \
# 275054                                                NaN
# 275784                                                NaN
# 145097  SELF-ASSEMBLED SI QUANTUM-RING STRUCTURES ON A...
# 274423                                                NaN
# 151506  A HIGH-DENSITY ALIGNED NANOPOROUS ACTIVATED MI...
# ...                                                   ...
# 311196  ABNORMAL EXPRESSION AND DYSFUNCTION OF NEVER-I...
# 305862  INSULINOMAS ARE RARE TUMORS, AND APPROXIMATELY...
# 802659  STUDY OBJECTIVE: RAPID MAXILLARY EXPANSION AND...
# 619961  ABNORMALITIES OF THYROID FUNCTION ARE ASSOCIAT...
# 584418  AUTOPSY TISSUES FROM 2 COHORTS OF AGE-MATCHED ...
#
#                                              affiliations  \
# 275054  ALCATEL-LUCENT; LUCENT TECHNOLOGIES; AT\&T; UN...
# 275784  UNIVERSITY SYSTEM OF OHIO; UNIVERSITY OF CINCI...
# 145097                                 NANJING UNIVERSITY
# 274423  PENNSYLVANIA COMMONWEALTH SYSTEM OF HIGHER EDU...
# 151506  PENNSYLVANIA COMMONWEALTH SYSTEM OF HIGHER EDU...
# ...                                                   ...
# 311196  WUHAN UNIVERSITY; WUHAN UNIVERSITY; WUHAN UNIV...
# 305862  GUANGDONG PHARMACEUTICAL UNIVERSITY; UNIVERSIT...
# 802659  STANFORD UNIVERSITY; UNIVERSITY OF CALIFORNIA ...
# 619961  BOSTON UNIVERSITY; HARVARD UNIVERSITY; MASSACH...
# 584418  UNIVERSITY OF WASHINGTON; UNIVERSITY OF WASHIN...
#
#                                                       doi      eissn  \
# 275054  10.1002/1521-4095(200108)13:16<1273::AID-ADMA1...  1521-4095
# 275784                             10.1002/adma.200601629  1521-4095
# 145097                             10.1002/adma.200602804  1521-4095
# 274423                             10.1002/adma.201301243  1521-4095
# 151506                             10.1002/adma.201301370  1521-4095
# ...                                                   ...        ...
# 311196                                 10.7150/ijbs.59019        NaN
# 305862                                  10.7150/ijbs.7723        NaN
# 802659                                                NaN  1550-9109
# 619961                                                NaN  1557-9077
# 584418                                                NaN  1938-3673
#
#        esi_highly_cited_paper esi_hot_paper  ... book_series_title  \
# 275054                    NaN           NaN  ...               NaN
# 275784                    NaN           NaN  ...               NaN
# 145097                    NaN           NaN  ...               NaN
# 274423                    NaN           NaN  ...               NaN
# 151506                    NaN           NaN  ...               NaN
# ...                       ...           ...  ...               ...
# 311196                    NaN           NaN  ...               NaN
# 305862                    NaN           NaN  ...               NaN
# 802659                    NaN           NaN  ...               NaN
# 619961                    NaN           NaN  ...               NaN
# 584418                    NaN           NaN  ...               NaN
#
#        wos_core_collection_times_cited_count  \
# 275054                                     6
# 275784                                    87
# 145097                                    10
# 274423                                   103
# 151506                                    11
# ...                                      ...
# 311196                                    10
# 305862                                    42
# 802659                                    27
# 619961                                    10
# 584418                                    15
#
#                                            document_title  \
# 275054  RETRACTED: GATE-INDUCED SUPERCONDUCTIVITY IN O...
# 275784  RETRACTED: GUIDING CELL MIGRATION USING ONE-WA...
# 145097  RETRACTED: SELF-ASSEMBLED SI QUANTUM-RING STRU...
# 274423  RETRACTED: HIGH-VOLUMETRIC PERFORMANCE ALIGNED...
# 151506  RETRACTED: ALIGNED NANO-POROUS MICROWAVE EXFOL...
# ...                                                   ...
# 311196  RETRACTED: NEK2 PLAYS AN ACTIVE ROLE IN TUMORI...
# 305862  RETRACTED: ANDROGRAPHOLIDE SUPPRESS TUMOR GROW...
# 802659  RETRACTED: ORTHODONTIC EXPANSION TREATMENT AND...
# 619961  RETRACTED: HUMAN IMMUNODEFICIENCY VIRUS INFECT...
# 584418  RETRACTED: NONLYMPHOID RESERVOIRS OF HIV REPLI...
#
#                                             document_type  \
# 275054                     ARTICLE; RETRACTED PUBLICATION
# 275784                     ARTICLE; RETRACTED PUBLICATION
# 145097                     ARTICLE; RETRACTED PUBLICATION
# 274423                     ARTICLE; RETRACTED PUBLICATION
# 151506                     ARTICLE; RETRACTED PUBLICATION
# ...                                                   ...
# 311196                     ARTICLE; RETRACTED PUBLICATION
# 305862                     ARTICLE; RETRACTED PUBLICATION
# 802659                     ARTICLE; RETRACTED PUBLICATION
# 619961                      REVIEW; RETRACTED PUBLICATION
# 584418  ARTICLE; PROCEEDINGS PAPER; RETRACTED PUBLICATION
#
#                                            wos_categories year_published  \
# 275054  CHEMISTRY, MULTIDISCIPLINARY; CHEMISTRY, PHYSI...           2001
# 275784  CHEMISTRY, MULTIDISCIPLINARY; CHEMISTRY, PHYSI...           2007
# 145097  CHEMISTRY, MULTIDISCIPLINARY; CHEMISTRY, PHYSI...           2007
# 274423  CHEMISTRY, MULTIDISCIPLINARY; CHEMISTRY, PHYSI...           2013
# 151506  CHEMISTRY, MULTIDISCIPLINARY; CHEMISTRY, PHYSI...           2013
# ...                                                   ...            ...
# 311196         BIOCHEMISTRY \& MOLECULAR BIOLOGY; BIOLOGY           2021
# 305862         BIOCHEMISTRY \& MOLECULAR BIOLOGY; BIOLOGY           2014
# 802659                  CLINICAL NEUROLOGY; NEUROSCIENCES           2008
# 619961                        ENDOCRINOLOGY \& METABOLISM           2002
# 584418               CELL BIOLOGY; HEMATOLOGY; IMMUNOLOGY           2000
#
#                                      authors_affiliations  \
# 275054                           BELL LABS;UNIV GRONINGEN
# 275784                    UNIV CINCINNATI;UNIV CINCINNATI
# 145097                          NANJING UNIV;NANJING UNIV
# 274423  PENN STATE UNIV;PENN STATE UNIV;PENN STATE UNI...
# 151506  PENN STATE UNIV;PENN STATE UNIV;PENN STATE UNI...
# ...                                                   ...
# 311196  WUHAN UNIV;WUHAN UNIV;WUHAN UNIV;WUHAN UNIV;WU...
# 305862  GUANGDONG PHARMACEUT UNIV;GUANGDONG PHARMACEUT...
# 802659  STANFORD UNIV;STANFORD UNIV;UNIV CALIF SAN FRA...
# 619961               BOSTON UNIV;BOSTON UNIV;HARVARD UNIV
# 584418                    UNIV WASHINGTON;UNIV WASHINGTON
#
#        corresponding_author_affiliation book.group.author  publication_date
# 275054                        BELL LABS               NaN        2001-08-16
# 275784                  UNIV CINCINNATI               NaN        2007-04-20
# 145097                     NANJING UNIV               NaN        2007-06-18
# 274423                  PENN STATE UNIV               NaN        2013-09-20
# 151506                  PENN STATE UNIV               NaN        2013-11-20
# ...                                 ...               ...               ...
# 311196                       WUHAN UNIV               NaN        2021-01-01
# 305862        GUANGDONG PHARMACEUT UNIV               NaN        2014-01-01
# 802659                    STANFORD UNIV               NaN        2008-07-01
# 619961                      BOSTON UNIV               NaN        2002-07-01
# 584418                  UNIV WASHINGTON               NaN        2000-09-01
#
# [462 rows x 35 columns]

# %%
# Remove the Alterations to the name of the article
control_set['document_title'] = control_set['document_title'].str.replace('RETRACTED: ', '')
control_set['document_title'] = control_set['document_title'].str.replace('(Withdrawn Publication)', '')
control_set['document_title'] = control_set['document_title'].str.replace('(Withdrawn publication)', '')
control_set['document_title'] = control_set['document_title'].str.replace('</bold>', '')
control_set['document_title'] = control_set['document_title'].str.replace('<bold>', '')

# %%
# Some records include variations of the phrase "(Retracted article. See XX)". 
# Where XX is has variable length and characters, but always ends with ")"
def remove_retraction_phrase(title):

    # Define the pattern to match the retraction phrase
    pattern = r'\(retracted article\. see [^\)]+\)'
    return re.sub(pattern, '', str.lower(title)).strip()

# Apply the function to the 'Document Title' column
control_set['document_title'] = control_set['document_title'].apply(remove_retraction_phrase)

# %%
def remove_retraction_phrase(title):

    # Define the pattern to match the retraction phrase
    pattern = r'\(withdrawal of [^\)]+\)'
    return re.sub(pattern, '', str.lower(title)).strip()

# Apply the function to the 'Document Title' column
control_set['document_title'] = control_set['document_title'].apply(remove_retraction_phrase)

# %%
# Remove spaces at the end of the string
control_set['document_title'] = control_set['document_title'].str.rstrip()

#lower case string
control_set['document_title'] = control_set['document_title'].str.lower()

# %%
#wos_rd[(~wos_rd['Document Title'].str.startswith("RETRACTED: ")) & (~wos_rd['Document Title'].str.contains("(Withdrawn Publication)"))]

# %% [markdown]
# ### Duplicates

# %%
control_set[control_set.duplicated(subset='doi', keep=False)].shape
# Out:
# (20850, 35)

# %%
control_set['doi'].nunique()
# Out:
# 916488

# %%
control_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 933634 entries, 484329 to 926825
# Data columns (total 35 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   authors                                933634 non-null  object
#  1   author_keywords                        539770 non-null  object
#  2   keywords_plus                          873956 non-null  object
#  3   cited_references                       930337 non-null  object
#  4   abstract                               902793 non-null  object
#  5   affiliations                           914940 non-null  object
#  6   doi                                    920195 non-null  object
#  7   eissn                                  722054 non-null  object
#  8   esi_highly_cited_paper                 37361 non-null   object
#  9   esi_hot_paper                          37361 non-null   object
#  10  early_access_date                      103645 non-null  datetime64[ns]
#  11  funding_agency_and_grant_number        571252 non-null  object
#  12  isbn                                   15564 non-null   object
#  13  issn                                   912242 non-null  object
#  14  iso_source_abv                         933634 non-null  object
#  15  publication_name                       933634 non-null  object
#  16  language                               933634 non-null  object
#  17  month                                  933634 non-null  object
#  18  note                                   35524 non-null   object
#  19  cited_reference_count                  933634 non-null  Int64
#  20  open_access_indicator                  416134 non-null  object
#  21  organization                           23018 non-null   object
#  22  publisher                              933634 non-null  object
#  23  research_areas                         933634 non-null  object
#  24  researcher_id_numbers                  627068 non-null  object
#  25  book_series_title                      17305 non-null   object
#  26  wos_core_collection_times_cited_count  933634 non-null  Int64
#  27  document_title                         933634 non-null  object
#  28  document_type                          933634 non-null  object
#  29  wos_categories                         933634 non-null  object
#  30  year_published                         933634 non-null  Int64
#  31  authors_affiliations                   930434 non-null  object
#  32  corresponding_author_affiliation       933634 non-null  object
#  33  book.group.author                      386 non-null     object
#  34  publication_date                       933634 non-null  datetime64[ns]
# dtypes: Int64(3), datetime64[ns](2), object(30)
# memory usage: 259.1+ MB

# %%
#control_set.iloc[[2,6,36,58,60,65,67,68]]

# %%
control_set['doi'].value_counts()
# Out:
# doi
# 10.1093/nar/gkl022                 3
# 10.1093/nar/gkg112                 3
# 10.1016/j.lungcan.2004.07.000      3
# 10.1038/s41586-021-03689-8         2
# 10.1093/nar/29.9.1960              2
#                                   ..
# 10.1016/j.jcis.2015.01.002         1
# 10.1016/j.jcis.2015.01.003         1
# 10.1016/j.jcis.2015.01.004         1
# 10.1016/j.jcis.2015.01.005         1
# y10.1016/j.physletb.2019.03.059    1
# Name: count, Length: 916488, dtype: int64

# %%
control_set.shape
# Out:
# (933634, 35)

# %%
control_set[control_set.duplicated(subset='doi', keep=False)]
# Out:
#                                                   authors  \
# 178879                               BOWEN HP;WIERSEMA MF
# 179945                                          KUMAR MVS
# 689937       RODRÍGUEZ JR;GONZÁLEZ-PÉREZ A;DEL CASTILLO J
# 690682                                          NGUYEN AV
# 737916                   LAI WA;REKHA PD;ARUN AB;YOUNG CC
# ...                                                   ...
# 877831                                      [ANONYMOUS] A
# 878180  MAYFIELD JA;REIBER GE;SANDERS LJ;JANISSE D;POG...
# 878610                                      [ANONYMOUS] A
# 926523  O'BRIEN T;JOHNSON LH;ALDRICH JL;ALLEN SG;LIANG...
# 926825  O'CONNOR SM;ANDREADIS JD;SHAFFER KM;MA W;PANCR...
#
#                                           author_keywords  \
# 178879  FOREIGN COMPETITION; DIVERSIFICATION; CORPORAT...
# 179945  JOINT VENTURES; REAL OPTIONS; TERMINATION; EVE...
# 689937  ALKYLDIMETHYLBENZYLAMMONIUM CHLORIDE; CMC; TEM...
# 690682  MENISCUS; GAS-LIQUID INTERFACE; YOUNG-LAPLACE ...
# 737916  AZOSPIRILLUM; PLANT GROWTH PROMOTION; CHEMICAL...
# ...                                                   ...
# 877831                                                NaN
# 878180                                                NaN
# 878610                                                NaN
# 926523  IMMUNOASSAYS; BIDIFFRACTIVE GRATING BIOSENSOR;...
# 926825  CELL IMMOBILIZATION; NEURONS; ASTROCYTES; NEUR...
#
#                                             keywords_plus  \
# 178879  BUSINESS CYCLES; PERFORMANCE; PRODUCT; UNCERTA...
# 179945  STRATEGIC ALLIANCES; MARKET VALUATION; PERFORM...
# 689937  CRITICAL MICELLE CONCENTRATIONS; ENTHALPY-ENTR...
# 690682                                                NaN
# 737916  PLANT-GROWTH; ROOT DEVELOPMENT; ACC DEAMINASE;...
# ...                                                   ...
# 877831                                                NaN
# 878180                                                NaN
# 878610                                                NaN
# 926523                                            SURFACE
# 926825  NERVOUS-SYSTEM; STEM-CELLS; NEURONS; GROWTH; M...
#
#                                          cited_references  \
# 178879  ABOWD JM, 1990, W3351 NBER; AI CR, 2003, ECON ...
# 179945  ADNER R, 2004, ACAD MANAGE REV, V29, P74, DOI ...
# 689937  CHEN LJ, 1998, J PHYS CHEM B, V102, P4350, DOI...
# 690682  ADAMSON AW, 1997, PHYSICAL CHEM SURFAC; DERJAG...
# 737916  ADEGBIDI HG, 2003, BIOMASS BIOENERG, V25, P389...
# ...                                                   ...
# 877831                                                NaN
# 878180  AMERICAN DIABETES ASSOCIATION, 1999, DIABETES ...
# 878610                                                NaN
# 926523  ANDERSON GP, 1996, ASAIO J, V42, P942, DOI 10....
# 926825  ALVAREZ-BUYLLA A, 1998, J NEUROBIOL, V36, P105...
#
#                                                  abstract  \
# 178879  SINCE THE MID-1980S U.S. DOMESTIC FIT-INS HAVE...
# 179945  THIS STUDY EXAMINES THE VALUE CREATED FROM ACQ...
# 689937  SPECIFIC CONDUCTIVITIES OF ALKYLDIMETHYLBENZYL...
# 690682  IN THIS PAPER THE PROBLEM OF CALCULATING THE D...
# 737916  BENEFITS FROM THE APPLICATION OF PLANT GROWTH-...
# ...                                                   ...
# 877831                                                NaN
# 878180                                                NaN
# 878610                                                NaN
# 926523  A CRITICAL NEED EXISTS FOR A FIELD DEPLOYABLE ...
# 926825  TO OVERCOME LOGISTICAL DIFFICULTIES WITH CURRE...
#
#                                              affiliations  \
# 178879  UNIVERSITY OF CALIFORNIA SYSTEM; UNIVERSITY OF...
# 179945  CITY UNIVERSITY OF NEW YORK (CUNY) SYSTEM; BAR...
# 689937  UNIVERSIDADE DE SANTIAGO DE COMPOSTELA; JAGIEL...
# 690682                            UNIVERSITY OF NEWCASTLE
# 737916                    NATIONAL CHUNG HSING UNIVERSITY
# ...                                                   ...
# 877831                                                NaN
# 878180                                                NaN
# 878610                                                NaN
# 926523  UNITED STATES DEPARTMENT OF DEFENSE; UNITED ST...
# 926825  UNITED STATES DEPARTMENT OF DEFENSE; UNITED ST...
#
#                               doi      eissn esi_highly_cited_paper  \
# 178879            10.1002/smj.499  1097-0266                    NaN
# 179945            10.1002/smj.499  1097-0266                    NaN
# 689937     10.1006/jcis.2002.8263        NaN                    NaN
# 690682     10.1006/jcis.2002.8263        NaN                    NaN
# 737916  10.1007/s00374-008-0313-3  1432-0789                    NaN
# ...                           ...        ...                    ...
# 877831                        NaN  1476-5608                    NaN
# 878180                        NaN        NaN                    NaN
# 878610                        NaN  1365-2907                    NaN
# 926523                        NaN        NaN                    NaN
# 926825                        NaN        NaN                    NaN
#
#        esi_hot_paper  ... book_series_title  \
# 178879           NaN  ...               NaN
# 179945           NaN  ...               NaN
# 689937           NaN  ...               NaN
# 690682           NaN  ...               NaN
# 737916           NaN  ...               NaN
# ...              ...  ...               ...
# 877831           NaN  ...               NaN
# 878180           NaN  ...               NaN
# 878610           NaN  ...               NaN
# 926523           NaN  ...               NaN
# 926825           NaN  ...               NaN
#
#        wos_core_collection_times_cited_count  \
# 178879                                   126
# 179945                                    91
# 689937                                    68
# 690682                                    21
# 737916                                     0
# ...                                      ...
# 877831                                     0
# 878180                                     2
# 878610                                     0
# 926523                                    53
# 926825                                    76
#
#                                            document_title document_type  \
# 178879  foreign-based competition and corporate divers...       ARTICLE
# 179945  the value from acquiring and divesting a joint...       ARTICLE
# 689937  thermodynamics of micellization of alkyldimeth...       ARTICLE
# 690682  empirical equations for meniscus depression by...       ARTICLE
# 737916  effect of mineral fertilizer, pig manure, and ...       ARTICLE
# ...                                                   ...           ...
# 877831  the british prostate group spring meeting, 16-...       ARTICLE
# 878180       preventive foot care in people with diabetes       ARTICLE
# 878610  the proceedings of a symposium held at the thi...       ARTICLE
# 926523  the development of immunoassays to four biolog...       ARTICLE
# 926825  immobilization of neural cells in three-dimens...       ARTICLE
#
#                                            wos_categories year_published  \
# 178879                               BUSINESS; MANAGEMENT           2005
# 179945                               BUSINESS; MANAGEMENT           2005
# 689937                                CHEMISTRY, PHYSICAL           2002
# 690682                                CHEMISTRY, PHYSICAL           2002
# 737916                                       SOIL SCIENCE           2008
# ...                                                   ...            ...
# 877831                    ONCOLOGY; UROLOGY \& NEPHROLOGY           2000
# 878180                                        ORTHOPEDICS           2000
# 878610                                   ECOLOGY; ZOOLOGY           2000
# 926523  BIOPHYSICS; BIOTECHNOLOGY \& APPLIED MICROBIOL...           2000
# 926825  BIOPHYSICS; BIOTECHNOLOGY \& APPLIED MICROBIOL...           2000
#
#                                      authors_affiliations  \
# 178879  UNIV CALIF IRVINE;UNIV CALIF IRVINE;VLERICK LE...
# 179945  CUNY BERNARD M BARUCH COLL;CUNY BERNARD M BARU...
# 689937  UNIV SANTIAGO COMPOSTELA;UNIV SANTIAGO COMPOST...
# 690682                      UNIV NEWCASTLE;UNIV NEWCASTLE
# 737916        NATL CHUNG HSING UNIV;NATL CHUNG HSING UNIV
# ...                                                   ...
# 877831                                                NaN
# 878180                                                NaN
# 878610                                                NaN
# 926523  T (CORRESPONDING AUTHOR);MED RES CTR;BATTELLE ...
# 926825  CTR BIOMOL SCI AND ENGN;CTR BIOMOL SCI AND ENG...
#
#        corresponding_author_affiliation book.group.author  publication_date
# 178879                UNIV CALIF IRVINE               NaN        2005-12-01
# 179945       CUNY BERNARD M BARUCH COLL               NaN        2005-04-01
# 689937         UNIV SANTIAGO COMPOSTELA               NaN        2002-06-15
# 690682                   UNIV NEWCASTLE               NaN        2002-05-01
# 737916            NATL CHUNG HSING UNIV               NaN        2008-11-01
# ...                                 ...               ...               ...
# 877831                      NOTREPORTED               NaN        2000-01-01
# 878180                      NOTREPORTED               NaN        2000-01-01
# 878610                      NOTREPORTED               NaN        2000-01-01
# 926523         T (CORRESPONDING AUTHOR)               NaN        2000-01-01
# 926825          CTR BIOMOL SCI AND ENGN               NaN        2000-01-01
#
# [20850 rows x 35 columns]

# %%
testing_dupes = control_set[control_set.duplicated(subset='doi', keep=False)]
testing_dupes['doi'].value_counts()
# Out:
# doi
# 10.1016/j.lungcan.2004.07.000    3
# 10.1093/nar/gkl022               3
# 10.1093/nar/gkg112               3
# 10.1093/nar/29.1.277             2
# 10.1093/nar/29.1.294             2
#                                 ..
# 10.1039/c3nr01739g               2
# 10.1039/c3nr01847d               2
# 10.1039/c3nr01889j               2
# 10.1039/c3nr02076b               2
# 10.4244/EIJY16M06\_02            2
# Name: count, Length: 3704, dtype: int64

# %%
testing_dupes = testing_dupes.sort_values('doi')

# %%
testing_dupes
# Out:
#                                                   authors  \
# 178879                               BOWEN HP;WIERSEMA MF
# 179945                                          KUMAR MVS
# 689937       RODRÍGUEZ JR;GONZÁLEZ-PÉREZ A;DEL CASTILLO J
# 690682                                          NGUYEN AV
# 737916                   LAI WA;REKHA PD;ARUN AB;YOUNG CC
# ...                                                   ...
# 877831                                      [ANONYMOUS] A
# 878180  MAYFIELD JA;REIBER GE;SANDERS LJ;JANISSE D;POG...
# 878610                                      [ANONYMOUS] A
# 926523  O'BRIEN T;JOHNSON LH;ALDRICH JL;ALLEN SG;LIANG...
# 926825  O'CONNOR SM;ANDREADIS JD;SHAFFER KM;MA W;PANCR...
#
#                                           author_keywords  \
# 178879  FOREIGN COMPETITION; DIVERSIFICATION; CORPORAT...
# 179945  JOINT VENTURES; REAL OPTIONS; TERMINATION; EVE...
# 689937  ALKYLDIMETHYLBENZYLAMMONIUM CHLORIDE; CMC; TEM...
# 690682  MENISCUS; GAS-LIQUID INTERFACE; YOUNG-LAPLACE ...
# 737916  AZOSPIRILLUM; PLANT GROWTH PROMOTION; CHEMICAL...
# ...                                                   ...
# 877831                                                NaN
# 878180                                                NaN
# 878610                                                NaN
# 926523  IMMUNOASSAYS; BIDIFFRACTIVE GRATING BIOSENSOR;...
# 926825  CELL IMMOBILIZATION; NEURONS; ASTROCYTES; NEUR...
#
#                                             keywords_plus  \
# 178879  BUSINESS CYCLES; PERFORMANCE; PRODUCT; UNCERTA...
# 179945  STRATEGIC ALLIANCES; MARKET VALUATION; PERFORM...
# 689937  CRITICAL MICELLE CONCENTRATIONS; ENTHALPY-ENTR...
# 690682                                                NaN
# 737916  PLANT-GROWTH; ROOT DEVELOPMENT; ACC DEAMINASE;...
# ...                                                   ...
# 877831                                                NaN
# 878180                                                NaN
# 878610                                                NaN
# 926523                                            SURFACE
# 926825  NERVOUS-SYSTEM; STEM-CELLS; NEURONS; GROWTH; M...
#
#                                          cited_references  \
# 178879  ABOWD JM, 1990, W3351 NBER; AI CR, 2003, ECON ...
# 179945  ADNER R, 2004, ACAD MANAGE REV, V29, P74, DOI ...
# 689937  CHEN LJ, 1998, J PHYS CHEM B, V102, P4350, DOI...
# 690682  ADAMSON AW, 1997, PHYSICAL CHEM SURFAC; DERJAG...
# 737916  ADEGBIDI HG, 2003, BIOMASS BIOENERG, V25, P389...
# ...                                                   ...
# 877831                                                NaN
# 878180  AMERICAN DIABETES ASSOCIATION, 1999, DIABETES ...
# 878610                                                NaN
# 926523  ANDERSON GP, 1996, ASAIO J, V42, P942, DOI 10....
# 926825  ALVAREZ-BUYLLA A, 1998, J NEUROBIOL, V36, P105...
#
#                                                  abstract  \
# 178879  SINCE THE MID-1980S U.S. DOMESTIC FIT-INS HAVE...
# 179945  THIS STUDY EXAMINES THE VALUE CREATED FROM ACQ...
# 689937  SPECIFIC CONDUCTIVITIES OF ALKYLDIMETHYLBENZYL...
# 690682  IN THIS PAPER THE PROBLEM OF CALCULATING THE D...
# 737916  BENEFITS FROM THE APPLICATION OF PLANT GROWTH-...
# ...                                                   ...
# 877831                                                NaN
# 878180                                                NaN
# 878610                                                NaN
# 926523  A CRITICAL NEED EXISTS FOR A FIELD DEPLOYABLE ...
# 926825  TO OVERCOME LOGISTICAL DIFFICULTIES WITH CURRE...
#
#                                              affiliations  \
# 178879  UNIVERSITY OF CALIFORNIA SYSTEM; UNIVERSITY OF...
# 179945  CITY UNIVERSITY OF NEW YORK (CUNY) SYSTEM; BAR...
# 689937  UNIVERSIDADE DE SANTIAGO DE COMPOSTELA; JAGIEL...
# 690682                            UNIVERSITY OF NEWCASTLE
# 737916                    NATIONAL CHUNG HSING UNIVERSITY
# ...                                                   ...
# 877831                                                NaN
# 878180                                                NaN
# 878610                                                NaN
# 926523  UNITED STATES DEPARTMENT OF DEFENSE; UNITED ST...
# 926825  UNITED STATES DEPARTMENT OF DEFENSE; UNITED ST...
#
#                               doi      eissn esi_highly_cited_paper  \
# 178879            10.1002/smj.499  1097-0266                    NaN
# 179945            10.1002/smj.499  1097-0266                    NaN
# 689937     10.1006/jcis.2002.8263        NaN                    NaN
# 690682     10.1006/jcis.2002.8263        NaN                    NaN
# 737916  10.1007/s00374-008-0313-3  1432-0789                    NaN
# ...                           ...        ...                    ...
# 877831                        NaN  1476-5608                    NaN
# 878180                        NaN        NaN                    NaN
# 878610                        NaN  1365-2907                    NaN
# 926523                        NaN        NaN                    NaN
# 926825                        NaN        NaN                    NaN
#
#        esi_hot_paper  ... book_series_title  \
# 178879           NaN  ...               NaN
# 179945           NaN  ...               NaN
# 689937           NaN  ...               NaN
# 690682           NaN  ...               NaN
# 737916           NaN  ...               NaN
# ...              ...  ...               ...
# 877831           NaN  ...               NaN
# 878180           NaN  ...               NaN
# 878610           NaN  ...               NaN
# 926523           NaN  ...               NaN
# 926825           NaN  ...               NaN
#
#        wos_core_collection_times_cited_count  \
# 178879                                   126
# 179945                                    91
# 689937                                    68
# 690682                                    21
# 737916                                     0
# ...                                      ...
# 877831                                     0
# 878180                                     2
# 878610                                     0
# 926523                                    53
# 926825                                    76
#
#                                            document_title document_type  \
# 178879  foreign-based competition and corporate divers...       ARTICLE
# 179945  the value from acquiring and divesting a joint...       ARTICLE
# 689937  thermodynamics of micellization of alkyldimeth...       ARTICLE
# 690682  empirical equations for meniscus depression by...       ARTICLE
# 737916  effect of mineral fertilizer, pig manure, and ...       ARTICLE
# ...                                                   ...           ...
# 877831  the british prostate group spring meeting, 16-...       ARTICLE
# 878180       preventive foot care in people with diabetes       ARTICLE
# 878610  the proceedings of a symposium held at the thi...       ARTICLE
# 926523  the development of immunoassays to four biolog...       ARTICLE
# 926825  immobilization of neural cells in three-dimens...       ARTICLE
#
#                                            wos_categories year_published  \
# 178879                               BUSINESS; MANAGEMENT           2005
# 179945                               BUSINESS; MANAGEMENT           2005
# 689937                                CHEMISTRY, PHYSICAL           2002
# 690682                                CHEMISTRY, PHYSICAL           2002
# 737916                                       SOIL SCIENCE           2008
# ...                                                   ...            ...
# 877831                    ONCOLOGY; UROLOGY \& NEPHROLOGY           2000
# 878180                                        ORTHOPEDICS           2000
# 878610                                   ECOLOGY; ZOOLOGY           2000
# 926523  BIOPHYSICS; BIOTECHNOLOGY \& APPLIED MICROBIOL...           2000
# 926825  BIOPHYSICS; BIOTECHNOLOGY \& APPLIED MICROBIOL...           2000
#
#                                      authors_affiliations  \
# 178879  UNIV CALIF IRVINE;UNIV CALIF IRVINE;VLERICK LE...
# 179945  CUNY BERNARD M BARUCH COLL;CUNY BERNARD M BARU...
# 689937  UNIV SANTIAGO COMPOSTELA;UNIV SANTIAGO COMPOST...
# 690682                      UNIV NEWCASTLE;UNIV NEWCASTLE
# 737916        NATL CHUNG HSING UNIV;NATL CHUNG HSING UNIV
# ...                                                   ...
# 877831                                                NaN
# 878180                                                NaN
# 878610                                                NaN
# 926523  T (CORRESPONDING AUTHOR);MED RES CTR;BATTELLE ...
# 926825  CTR BIOMOL SCI AND ENGN;CTR BIOMOL SCI AND ENG...
#
#        corresponding_author_affiliation book.group.author  publication_date
# 178879                UNIV CALIF IRVINE               NaN        2005-12-01
# 179945       CUNY BERNARD M BARUCH COLL               NaN        2005-04-01
# 689937         UNIV SANTIAGO COMPOSTELA               NaN        2002-06-15
# 690682                   UNIV NEWCASTLE               NaN        2002-05-01
# 737916            NATL CHUNG HSING UNIV               NaN        2008-11-01
# ...                                 ...               ...               ...
# 877831                      NOTREPORTED               NaN        2000-01-01
# 878180                      NOTREPORTED               NaN        2000-01-01
# 878610                      NOTREPORTED               NaN        2000-01-01
# 926523         T (CORRESPONDING AUTHOR)               NaN        2000-01-01
# 926825          CTR BIOMOL SCI AND ENGN               NaN        2000-01-01
#
# [20850 rows x 35 columns]

# %%
testing_dupes.to_excel('../testing_dupes_control_set.xlsx', index= False)

# %%
control_set['document_type'].value_counts()
# Out:
# document_type
# ARTICLE                                              809132
# REVIEW                                                82678
# ARTICLE; PROCEEDINGS PAPER                            35443
# REVIEW; BOOK CHAPTER                                   2995
# ARTICLE; EARLY ACCESS                                  1132
# ARTICLE; BOOK CHAPTER                                  1088
# ARTICLE; RETRACTED PUBLICATION                          439
# EDITORIAL MATERIAL; EARLY ACCESS                        417
# REVIEW; EARLY ACCESS                                    118
# CORRECTION; EARLY ACCESS                                 49
# ARTICLE; PUBLICATION WITH EXPRESSION OF CONCERN          37
# LETTER; EARLY ACCESS                                     32
# ARTICLE; DATA PAPER                                      20
# NEWS ITEM; EARLY ACCESS                                  14
# BOOK REVIEW; EARLY ACCESS                                14
# ARTICLE; PROCEEDINGS PAPER; RETRACTED PUBLICATION        12
# REVIEW; RETRACTED PUBLICATION                             8
# ARTICLE; WITHDRAWN PUBLICATION                            3
# RETRACTION; EARLY ACCESS                                  1
# BIOGRAPHICAL-ITEM; EARLY ACCESS                           1
# ARTICLE; EARLY ACCESS; RETRACTED PUBLICATION              1
# Name: count, dtype: int64

# %%
control_set['publication_name'].value_counts()
# Out:
# publication_name
# MATERIALS SCIENCE AND ENGINEERING A-STRUCTURAL MATERIALS PROPERTIES MICROSTRUCTURE AND PROCESSING    29925
# NUCLEIC ACIDS RESEARCH                                                                               27961
# JOURNAL OF COLLOID AND INTERFACE SCIENCE                                                             23707
# NATURE                                                                                               20875
# NANOSCALE                                                                                            20827
#                                                                                                      ...
# AUTOIMMUNITY, PT D                                                                                       1
# THERAPEUTICS FOR COGNITIVE AGING                                                                         1
# MEETING THE HUMAN IMMUNOLOGY CHALLENGE                                                                   1
# PROBIOTICS: FROM BENCH TO MARKET                                                                         1
# PROBIOTIC FOODS AND SUPPLEMENTS                                                                          1
# Name: count, Length: 913, dtype: int64

# %%
unique_counts = testing_dupes[testing_dupes['doi']=='10.1038/nrm1196'].nunique()
unique_counts[unique_counts > 1].index
# Out:
# Index(['keywords_plus', 'cited_references', 'affiliations', 'eissn', 'issn',
#        'iso_source_abv', 'publication_name', 'month', 'document_type',
#        'authors_affiliations', 'publication_date'],
#       dtype='object')

# %%
control_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 933634 entries, 484329 to 926825
# Data columns (total 35 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   authors                                933634 non-null  object
#  1   author_keywords                        539770 non-null  object
#  2   keywords_plus                          873956 non-null  object
#  3   cited_references                       930337 non-null  object
#  4   abstract                               902793 non-null  object
#  5   affiliations                           914940 non-null  object
#  6   doi                                    920195 non-null  object
#  7   eissn                                  722054 non-null  object
#  8   esi_highly_cited_paper                 37361 non-null   object
#  9   esi_hot_paper                          37361 non-null   object
#  10  early_access_date                      103645 non-null  datetime64[ns]
#  11  funding_agency_and_grant_number        571252 non-null  object
#  12  isbn                                   15564 non-null   object
#  13  issn                                   912242 non-null  object
#  14  iso_source_abv                         933634 non-null  object
#  15  publication_name                       933634 non-null  object
#  16  language                               933634 non-null  object
#  17  month                                  933634 non-null  object
#  18  note                                   35524 non-null   object
#  19  cited_reference_count                  933634 non-null  Int64
#  20  open_access_indicator                  416134 non-null  object
#  21  organization                           23018 non-null   object
#  22  publisher                              933634 non-null  object
#  23  research_areas                         933634 non-null  object
#  24  researcher_id_numbers                  627068 non-null  object
#  25  book_series_title                      17305 non-null   object
#  26  wos_core_collection_times_cited_count  933634 non-null  Int64
#  27  document_title                         933634 non-null  object
#  28  document_type                          933634 non-null  object
#  29  wos_categories                         933634 non-null  object
#  30  year_published                         933634 non-null  Int64
#  31  authors_affiliations                   930434 non-null  object
#  32  corresponding_author_affiliation       933634 non-null  object
#  33  book.group.author                      386 non-null     object
#  34  publication_date                       933634 non-null  datetime64[ns]
# dtypes: Int64(3), datetime64[ns](2), object(30)
# memory usage: 259.1+ MB

# %%
# number of different values per DOI
aux = testing_dupes.groupby('doi').nunique()

# number of variables that differ for each DOI
aux.gt(1).sum(axis=1).sort_values()
# Out:
# doi
# 10.1111/cpsp.12377             1
# 10.1039/c7nr01116d             1
# 10.1039/c7nr01755c             1
# 10.1039/c7nr01845b             1
# 10.1039/c7nr01894k             1
#                               ..
# 10.1016/j.msea.2006.03.011    15
# 10.3389/fncel.2015.00310      15
# 10.4244/EIJY16M06\_02         15
# 10.1196/annals.1322.002       19
# 10.1196/annals.1322.021       20
# Length: 3704, dtype: int64

# %%
# variables that differ in duplicates
aux.columns[aux.max() > 1]
# Out:
# Index(['authors', 'author_keywords', 'keywords_plus', 'cited_references',
#        'abstract', 'affiliations', 'eissn', 'funding_agency_and_grant_number',
#        'isbn', 'issn', 'iso_source_abv', 'publication_name', 'month', 'note',
#        'cited_reference_count', 'open_access_indicator', 'organization',
#        'publisher', 'research_areas', 'researcher_id_numbers',
#        'wos_core_collection_times_cited_count', 'document_title',
#        'document_type', 'wos_categories', 'year_published',
#        'authors_affiliations', 'corresponding_author_affiliation',
#        'publication_date'],
#       dtype='object')

# %% [markdown]
# From the list of variables that were listed above as having different values for the same DOI, only the variables that are going to be necessary in the methodology will be individually inspected. That includes the following:
# - 'authors',
# - 'author_keywords',
# - 'keywords_plus',
# - 'cited_references',
# - 'abstract',
# - 'affiliations',
# - 'eissn',
# - 'funding_agency_and_grant_number',
# - 'issn',
# - 'iso_source_abv',
# - 'publication_name',
# - 'month',
# - 'cited_reference_count',
# - 'open_access_indicator',
# - 'publisher',
# - 'research_areas',
# - 'researcher_id_numbers',
# - 'wos_core_collection_times_cited_count',
# - 'document_title',
# - 'document_type',
# - 'wos_categories',
# - 'year_published',
# - 'authors_affiliations',
# - 'corresponding_author_affiliation',
# - 'publication_date'

# %%
# Keep only the first occurrence of each unique DOI (the most recent date)
filtered_wos = control_set.drop_duplicates(subset='doi')

# %%
control_set.to_parquet('./retractions_data/control_set.parquet', index = False)

# %% [markdown]
# <div class="alert alert-block alert-info" style = "background:#d0de6f; color:#000000; border:0;">
#
# # Chapter 2 - Merge Data <a class="anchor" id="chapter2"></a>

# %% [markdown]
# <a class="anchor">
#
# ## 2.1 -Retractions Data (rwd+control_set) <a class="anchor" id="section_4_1"></a>

# %%
filtered_rwd.shape
#filtered_wos.shape
# Out:
# (36847, 20)

# %%
processed_data_retractions = filtered_rwd.merge(filtered_wos, how= 'inner', left_on= 'OriginalPaperDOI', right_on= 'doi')
processed_data_retractions
# Out:
#      Record ID                                              Title  \
# 0        19131  Guiding Cell Migration Using One-Way Micropatt...
# 1         5767  Self-Assembled Si Quantum-Ring Structures on a...
# 2         5650  High-volumetric performance aligned nano-porou...
# 3         6221  Aligned Nano-Porous Microwave Exfoliated Graph...
# 4        45124  Highly Sensitive MoS2 Humidity Sensors Array f...
# ..         ...                                                ...
# 655      38204  miR-1204 promotes hepatocellular carcinoma pro...
# 656      34228  HCRP-1 regulates cell migration, invasion and ...
# 657      38203  NEK2 plays an active role in Tumorigenesis and...
# 658      34229  Andrographolide Suppress Tumor Growth by Inhib...
# 659       8591  CD117 immunohistochemical expression correlate...
#
#                                                Subject  \
# 0         (BLS) Biochemistry;(BLS) Biology - Cellular;
# 1        (PHY) Materials Science;(PHY) Nanotechnology;
# 2    (PHY) Engineering - Chemical;(PHY) Engineering...
# 3    (PHY) Engineering - Chemical;(PHY) Engineering...
# 4                        (PHY) Engineering - Chemical;
# ..                                                 ...
# 655  (BLS) Biochemistry;(BLS) Biology - Cancer;(BLS...
# 656   (BLS) Biology - Cancer;(BLS) Biology - Cellular;
# 657  (BLS) Biochemistry;(BLS) Biology - Cancer;(BLS...
# 658  (BLS) Biology - Cancer;(BLS) Biology - Cellula...
# 659  (BLS) Biochemistry;(HSC) Medicine - Immunology...
#
#                                            Institution  \
# 0    Chemical & Materials Engineering Department, U...
# 1    National Laboratory of Solid State Microstruct...
# 2    Department of Materials Science and Engineerin...
# 3    Department of Materials Science and Engineerin...
# 4    Beijing National Laboratory for Condensed Matt...
# ..                                                 ...
# 655  Department of Hepatobiliary Surgery, the First...
# 656  Cancer Institute, Xuzhou Medical University, X...
# 657  Department of Radiation and Medical Oncology, ...
# 658  Vascular Biology Research Institute, Guangdong...
# 659  Surgical oncology, Instituto Nacional de Cance...
#
#                                           Journal  \
# 0                              Advanced Materials
# 1                              Advanced Materials
# 2                              Advanced Materials
# 3                              Advanced Materials
# 4                              Advanced Materials
# ..                                            ...
# 655  International Journal of Biological Sciences
# 656  International Journal of Biological Sciences
# 657  International Journal of Biological Sciences
# 658  International Journal of Biological Sciences
# 659                  Iranian Journal of Pathology
#
#                                             Publisher              Country  \
# 0                                               Wiley        United States
# 1                                               Wiley                China
# 2                                               Wiley  China;United States
# 3                                               Wiley        United States
# 4                                               Wiley                China
# ..                                                ...                  ...
# 655                 Ivyspring International Publisher                China
# 656                 Ivyspring International Publisher                China
# 657                 Ivyspring International Publisher                China
# 658  IOS Publishing (Institute of Science Publishing)                China
# 659                      Iranian Society of Pathology               Mexico
#
#                                                 Author  \
# 0                 Girish Kumar;Chia Chi Ho;Carlos C Co
# 1    Lin Wei Yu;Kun Ji Chen;Jie Song;Jun Xu;Wei Li;...
# 2    Mehdi Ghaffari;Yue Zhou;Haiping Xu;Minren Lin;...
# 3    Mehdi Ghaffari;QM Zhang;W Kinsman;Yue Zhou;Sha...
# 4    Jing Zhao;Na Li;Zheng Wei;Mengzhou Liao;Peng C...
# ..                                                 ...
# 655  Liang Wang;Liankang Sun;Yufeng Wang;Bowen Yao;...
# 656  Feifei Chen;Jianqiang Wu;Jingwei Teng;Wang Li;...
# 657  Rui Bai;Cheng Yuan;Wenjie Sun;Jianguo Zhang;Yu...
# 658  Qian Qian Zhang;Yi Ding;Yan Lei;Cui Ling Qi;Xi...
# 659  Rosa A Salcedo-HernÃ¡ndez;Leonardo S Lino-Silv...
#
#                                                   URLS  \
# 0                                                  NaN
# 1                                                  NaN
# 2    http://retractionwatch.com/2016/10/28/material...
# 3    http://retractionwatch.com/2016/10/28/material...
# 4                                                  NaN
# ..                                                 ...
# 655                                                NaN
# 656                                                NaN
# 657                                                NaN
# 658                                                NaN
# 659                                                NaN
#
#                             ArticleType  ... book_series_title  \
# 0                     Research Article;  ...               NaN
# 1                     Research Article;  ...               NaN
# 2                     Research Article;  ...               NaN
# 3                     Research Article;  ...               NaN
# 4                     Research Article;  ...               NaN
# ..                                  ...  ...               ...
# 655                   Research Article;  ...               NaN
# 656                   Research Article;  ...               NaN
# 657                   Research Article;  ...               NaN
# 658                   Research Article;  ...               NaN
# 659  Article in Press;Research Article;  ...               NaN
#
#     wos_core_collection_times_cited_count  \
# 0                                      87
# 1                                      10
# 2                                     103
# 3                                      11
# 4                                     349
# ..                                    ...
# 655                                    24
# 656                                     8
# 657                                    10
# 658                                    42
# 659                                     3
#
#                                         document_title  \
# 0    guiding cell migration using one-way micropatt...
# 1    self-assembled si quantum-ring structures on a...
# 2    high-volumetric performance aligned nano-porou...
# 3    aligned nano-porous microwave exfoliated graph...
# 4    highly sensitive mos<sub>2</sub> humidity sens...
# ..                                                 ...
# 655  mir-1204 promotes hepatocellular carcinoma pro...
# 656  hcrp-1 regulates cell migration, invasion and ...
# 657  nek2 plays an active role in tumorigenesis and...
# 658  andrographolide suppress tumor growth by inhib...
# 659  covid-19 and other underlying causes of cancer...
#
#                       document_type  \
# 0    ARTICLE; RETRACTED PUBLICATION
# 1    ARTICLE; RETRACTED PUBLICATION
# 2    ARTICLE; RETRACTED PUBLICATION
# 3    ARTICLE; RETRACTED PUBLICATION
# 4    ARTICLE; RETRACTED PUBLICATION
# ..                              ...
# 655  ARTICLE; RETRACTED PUBLICATION
# 656  ARTICLE; RETRACTED PUBLICATION
# 657  ARTICLE; RETRACTED PUBLICATION
# 658  ARTICLE; RETRACTED PUBLICATION
# 659                         ARTICLE
#
#                                         wos_categories year_published  \
# 0    CHEMISTRY, MULTIDISCIPLINARY; CHEMISTRY, PHYSI...           2007
# 1    CHEMISTRY, MULTIDISCIPLINARY; CHEMISTRY, PHYSI...           2007
# 2    CHEMISTRY, MULTIDISCIPLINARY; CHEMISTRY, PHYSI...           2013
# 3    CHEMISTRY, MULTIDISCIPLINARY; CHEMISTRY, PHYSI...           2013
# 4    CHEMISTRY, MULTIDISCIPLINARY; CHEMISTRY, PHYSI...           2017
# ..                                                 ...            ...
# 655         BIOCHEMISTRY \& MOLECULAR BIOLOGY; BIOLOGY           2019
# 656         BIOCHEMISTRY \& MOLECULAR BIOLOGY; BIOLOGY           2020
# 657         BIOCHEMISTRY \& MOLECULAR BIOLOGY; BIOLOGY           2021
# 658         BIOCHEMISTRY \& MOLECULAR BIOLOGY; BIOLOGY           2014
# 659       PUBLIC, ENVIRONMENTAL \& OCCUPATIONAL HEALTH           2022
#
#                                   authors_affiliations  \
# 0                      UNIV CINCINNATI;UNIV CINCINNATI
# 1                            NANJING UNIV;NANJING UNIV
# 2    PENN STATE UNIV;PENN STATE UNIV;PENN STATE UNI...
# 3    PENN STATE UNIV;PENN STATE UNIV;PENN STATE UNI...
# 4    INST PHYS;BEJING INST NANOENRGY AND NANOSYST;U...
# ..                                                 ...
# 655          XI AN JIAO TONG UNIV;XI AN JIAO TONG UNIV
# 656  XUZHOU MED UNIV;XUZHOU MED COLL;XUZHOU MED UNI...
# 657  WUHAN UNIV;WUHAN UNIV;WUHAN UNIV;WUHAN UNIV;WU...
# 658  GUANGDONG PHARMACEUT UNIV;GUANGDONG PHARMACEUT...
# 659  NATL CTR CHRON DIS PREVENT AND HLTH PROMOT;NAT...
#
#                corresponding_author_affiliation book.group.author  \
# 0                               UNIV CINCINNATI               NaN
# 1                                  NANJING UNIV               NaN
# 2                               PENN STATE UNIV               NaN
# 3                               PENN STATE UNIV               NaN
# 4                                     INST PHYS               NaN
# ..                                          ...               ...
# 655                        XI AN JIAO TONG UNIV               NaN
# 656                 NOTREPORTED;XUZHOU MED UNIV               NaN
# 657                                  WUHAN UNIV               NaN
# 658                   GUANGDONG PHARMACEUT UNIV               NaN
# 659  NATL CTR CHRON DIS PREVENT AND HLTH PROMOT               NaN
#
#     publication_date
# 0         2007-04-20
# 1         2007-06-18
# 2         2013-09-20
# 3         2013-11-20
# 4         2017-09-13
# ..               ...
# 655       2019-01-01
# 656       2020-01-01
# 657       2021-01-01
# 658       2014-01-01
# 659       2022-12-16
#
# [660 rows x 55 columns]

# %%
processed_data_retractions['doi'].value_counts()
# Out:
# doi
# 10.1002/adma.200601629           1
# 10.1056/NEJM200104263441702      1
# 10.1056/NEJMoa033374             1
# 10.1056/NEJMoa060467             1
# 10.1056/NEJMoa1101324            1
#                                 ..
# 10.1016/j.lungcan.2010.06.005    1
# 10.1016/j.lungcan.2014.08.015    1
# 10.1016/j.matdes.2009.01.022     1
# 10.1016/j.matdes.2015.07.028     1
# 10.7150/ijbs.7723                1
# Name: count, Length: 659, dtype: int64

# %%
rwd_wo_doi = rwd[rwd['OriginalPaperDOI'].isnull() | (rwd['OriginalPaperDOI'] == '')]
control_set_wo_doi = control_set[control_set['doi'].isnull() | (control_set['doi'] == '')]
data_retractions_by_title = rwd_wo_doi.merge(control_set_wo_doi, how= 'inner', left_on= 'Title', right_on= 'document_title')
processed_data_retractions = pd.concat([processed_data_retractions, data_retractions_by_title], ignore_index = True)
processed_data_retractions = processed_data_retractions.drop_duplicates()

# %%
data_retractions_by_title
# Out:
#    Record ID                                              Title  \
# 0      13650                                       introduction
# 1       4261  nonlymphoid reservoirs of hiv replication in c...
#
#                                              Subject  \
# 0  (B/T) Business - Economics;(HUM) History - Eur...
# 1  (BLS) Biology - Cellular;(BLS) Biology - Molec...
#
#                                          Institution  \
# 0                                       Unavailable;
# 1  University of Washington School of Medicine, V...
#
#                               Journal  \
# 0       Journal of Markets & Morality
# 1  Journal of Leukocyte Biology (JLB)
#
#                                            Publisher        Country  \
# 0  Acton Institute for the Study of Religion & Li...        Unknown
# 1                      Society for Leukocyte Biology  United States
#
#                      Author  \
# 0  Francisco GÃ³mez Camacho
# 1            Scott J Brodie
#
#                                                 URLS  \
# 0  http://retractionwatch.com/2015/07/20/two-retr...
# 1  http://retractionwatch.com/2016/06/13/fraudste...
#
#                     ArticleType  ... book_series_title  \
# 0  Book Chapter/Reference Work;  ...               NaN
# 1             Research Article;  ...               NaN
#
#   wos_core_collection_times_cited_count  \
# 0                                     2
# 1                                    15
#
#                                       document_title  \
# 0                                       introduction
# 1  nonlymphoid reservoirs of hiv replication in c...
#
#                                        document_type  \
# 0                                            ARTICLE
# 1  ARTICLE; PROCEEDINGS PAPER; RETRACTED PUBLICATION
#
#                          wos_categories year_published  \
# 0                           ORTHOPEDICS           2014
# 1  CELL BIOLOGY; HEMATOLOGY; IMMUNOLOGY           2000
#
#               authors_affiliations corresponding_author_affiliation  \
# 0              LUND UNIV;LUND UNIV                        LUND UNIV
# 1  UNIV WASHINGTON;UNIV WASHINGTON                  UNIV WASHINGTON
#
#   book.group.author publication_date
# 0               NaN       2014-12-01
# 1               NaN       2000-09-01
#
# [2 rows x 55 columns]

# %%
#data_retractions_by_title['doi'].value_counts()

# %%
processed_data_retractions.columns
# Out:
# Index(['Record ID', 'Title', 'Subject', 'Institution', 'Journal', 'Publisher',
#        'Country', 'Author', 'URLS', 'ArticleType', 'RetractionDate',
#        'RetractionDOI', 'RetractionPubMedID', 'OriginalPaperDate',
#        'OriginalPaperDOI', 'OriginalPaperPubMedID', 'RetractionNature',
#        'Reason', 'Paywalled', 'Notes', 'authors', 'author_keywords',
#        'keywords_plus', 'cited_references', 'abstract', 'affiliations', 'doi',
#        'eissn', 'esi_highly_cited_paper', 'esi_hot_paper', 'early_access_date',
#        'funding_agency_and_grant_number', 'isbn', 'issn', 'iso_source_abv',
#        'publication_name', 'language', 'month', 'note',
#        'cited_reference_count', 'open_access_indicator', 'organization',
#        'publisher', 'research_areas', 'researcher_id_numbers',
#        'book_series_title', 'wos_core_collection_times_cited_count',
#        'document_title', 'document_type', 'wos_categories', 'year_published',
#        'authors_affiliations', 'corresponding_author_affiliation',
#        'book.group.author', 'publication_date'],
#       dtype='object')

# %%
processed_data_retractions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 662 entries, 0 to 661
# Data columns (total 55 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Record ID                              662 non-null    int64
#  1   Title                                  662 non-null    object
#  2   Subject                                662 non-null    object
#  3   Institution                            662 non-null    object
#  4   Journal                                662 non-null    object
#  5   Publisher                              662 non-null    object
#  6   Country                                662 non-null    object
#  7   Author                                 662 non-null    object
#  8   URLS                                   327 non-null    object
#  9   ArticleType                            662 non-null    object
#  10  RetractionDate                         662 non-null    object
#  11  RetractionDOI                          647 non-null    object
#  12  RetractionPubMedID                     640 non-null    object
#  13  OriginalPaperDate                      662 non-null    object
#  14  OriginalPaperDOI                       659 non-null    object
#  15  OriginalPaperPubMedID                  644 non-null    object
#  16  RetractionNature                       662 non-null    object
#  17  Reason                                 662 non-null    object
#  18  Paywalled                              662 non-null    object
#  19  Notes                                  188 non-null    object
#  20  authors                                662 non-null    object
#  21  author_keywords                        268 non-null    object
#  22  keywords_plus                          642 non-null    object
#  23  cited_references                       662 non-null    object
#  24  abstract                               653 non-null    object
#  25  affiliations                           656 non-null    object
#  26  doi                                    659 non-null    object
#  27  eissn                                  553 non-null    object
#  28  esi_highly_cited_paper                 11 non-null     object
#  29  esi_hot_paper                          11 non-null     object
#  30  early_access_date                      25 non-null     object
#  31  funding_agency_and_grant_number        412 non-null    object
#  32  isbn                                   4 non-null      object
#  33  issn                                   631 non-null    object
#  34  iso_source_abv                         662 non-null    object
#  35  publication_name                       662 non-null    object
#  36  language                               662 non-null    object
#  37  month                                  662 non-null    object
#  38  note                                   15 non-null     object
#  39  cited_reference_count                  662 non-null    Int64
#  40  open_access_indicator                  379 non-null    object
#  41  organization                           10 non-null     object
#  42  publisher                              662 non-null    object
#  43  research_areas                         662 non-null    object
#  44  researcher_id_numbers                  422 non-null    object
#  45  book_series_title                      4 non-null      object
#  46  wos_core_collection_times_cited_count  662 non-null    Int64
#  47  document_title                         662 non-null    object
#  48  document_type                          662 non-null    object
#  49  wos_categories                         662 non-null    object
#  50  year_published                         662 non-null    Int64
#  51  authors_affiliations                   660 non-null    object
#  52  corresponding_author_affiliation       662 non-null    object
#  53  book.group.author                      0 non-null      object
#  54  publication_date                       662 non-null    object
# dtypes: Int64(3), int64(1), object(51)
# memory usage: 286.5+ KB

# %%
datetime_variable_conversion = {"RetractionDate": "object",
                                "OriginalPaperDate": "object",
                                "publication_date": "object",
                                "early_access_date": "object"
                                }

processed_data_retractions = processed_data_retractions.astype(datetime_variable_conversion)

# %%
processed_data_retractions.to_excel('./retractions_data/processed_data_retractions.xlsx', index = False)

# %%
# Number of DOIs from filtered_wos not in filtered_rw
doi_not_in_rwd = filtered_wos[~filtered_wos['doi'].isin(filtered_rwd['OriginalPaperDOI'])]
num_dois_in_wos_not_in_rwd = len(doi_not_in_rwd)

# Number of DOIs from filtered_rw not in filtered_wos
doi_not_in_wos = filtered_rwd[~filtered_rwd['OriginalPaperDOI'].isin(filtered_wos['doi'])]
num_dois_in_rwd_not_in_wos = len(doi_not_in_wos)

# %%
print(f"Number of DOIs from filtered_wos that are not in filtered_rwd: {num_dois_in_wos_not_in_rwd}")
print(f"Number of DOIs from filtered_rwd that are not in filtered_wos: {num_dois_in_rwd_not_in_wos}")
# Out:
# Number of DOIs from filtered_wos that are not in filtered_rwd: 915829
# Number of DOIs from filtered_rwd that are not in filtered_wos: 36187

# %%
filtered_rwd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36847 entries, 29155 to 22442
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Record ID              36847 non-null  int64
#  1   Title                  36847 non-null  object
#  2   Subject                36847 non-null  object
#  3   Institution            36846 non-null  object
#  4   Journal                36847 non-null  object
#  5   Publisher              36847 non-null  object
#  6   Country                36847 non-null  object
#  7   Author                 36847 non-null  object
#  8   URLS                   19034 non-null  object
#  9   ArticleType            36847 non-null  object
#  10  RetractionDate         36847 non-null  datetime64[ns]
#  11  RetractionDOI          36604 non-null  object
#  12  RetractionPubMedID     34013 non-null  object
#  13  OriginalPaperDate      36847 non-null  datetime64[ns]
#  14  OriginalPaperDOI       36846 non-null  object
#  15  OriginalPaperPubMedID  33989 non-null  object
#  16  RetractionNature       36847 non-null  object
#  17  Reason                 36847 non-null  object
#  18  Paywalled              36847 non-null  object
#  19  Notes                  9815 non-null   object
# dtypes: datetime64[ns](2), int64(1), object(17)
# memory usage: 5.9+ MB

# %%
test = filtered_rwd.merge(filtered_wos, how= 'left', left_on= 'OriginalPaperDOI', right_on= 'doi')
test
# Out:
#        Record ID                                              Title  \
# 0            985  Early Depth Assessment of Local Burns by Dermo...
# 1           5729  The prevention of hip fracture with risedronat...
# 2           5728  Risedronate sodium therapy for prevention of h...
# 3            895  The Relation Between Pulse Pressure and Cardio...
# 4          19230  First Foods Most: After 18-Hour Fast, People D...
# ...          ...                                                ...
# 36842      44860  A consideration of the impact of contaminated ...
# 36843      43526  Study on the Waste Information and Statistics ...
# 36844      38531  On the Feasibility of Stealthily Introducing V...
# 36845      47227  Age, Gender Demographics and Comorbidity Preva...
# 36846       8591  CD117 immunohistochemical expression correlate...
#
#                                                  Subject  \
# 0      (HSC) Biostatistics/Epidemiology;(HSC) Medicin...
# 1      (HSC) Medicine - Geriatric;(HSC) Medicine - Ne...
# 2      (HSC) Medicine - Neurology;(HSC) Medicine - Re...
# 3      (HSC) Biostatistics/Epidemiology;(HSC) Medicin...
# 4                      (BLS) Nutrition;(SOC) Psychology;
# ...                                                  ...
# 36842  (ENV) Ground/Surface Water;(HSC) Public Health...
# 36843  (ENV) Environmental Sciences;(ENV) Ground/Surf...
# 36844           (B/T) Computer Science;(B/T) Technology;
# 36845  (HSC) Biostatistics/Epidemiology;(HSC) Medicin...
# 36846  (BLS) Biochemistry;(HSC) Medicine - Immunology...
#
#                                              Institution  \
# 0      Burns Unit, Department of Dermatology, Nagasak...
# 1      Department of Neurology, Mitate Hospital, Taga...
# 2      Department of Neurology, Mitate Hospital, Taga...
# 3      Department of Dietetics and Nutrition, Harokop...
# 4      Dyson School of Applied Economics and Manageme...
# ...                                                  ...
# 36842  Department of Communication and Culture, Facul...
# 36843  Member, Ph.D. Candidate, Department of Disaste...
# 36844                            University of Minnesota
# 36845  Department of Orthopaedics, Dhanalakshmi Srini...
# 36846  Surgical oncology, Instituto Nacional de Cance...
#
#                                                  Journal  \
# 0                                Archives of Dermatology
# 1                          Archives of Internal Medicine
# 2                          Archives of Internal Medicine
# 3                                 JAMA Internal Medicine
# 4                                 JAMA Internal Medicine
# ...                                                  ...
# 36842                        Human Life Culture Research
# 36843  Journal of the Korean Society of Hazard Mitiga...
# 36844        2021 IEEE Symposium on Security and Privacy
# 36845                   Journal of Coastal Life Medicine
# 36846                       Iranian Journal of Pathology
#
#                                                Publisher  \
# 0                                           JAMA Network
# 1                                           JAMA Network
# 2                                           JAMA Network
# 3                                           JAMA Network
# 4                           American Medical Association
# ...                                                  ...
# 36842  Otsuma Women's University Research Institute f...
# 36843                Korean Society of Hazard Mitigation
# 36844  IEEE: Institute of Electrical and Electronics ...
# 36845                   Journal of Coastal Life Medicine
# 36846                       Iranian Society of Pathology
#
#                                                  Country  \
# 0                                                  Japan
# 1                                                  Japan
# 2                                                  Japan
# 3      Finland;Greece;Italy;Japan;Netherlands;Serbia;...
# 4                                          United States
# ...                                                  ...
# 36842                                              Japan
# 36843                                        South Korea
# 36844                                      United States
# 36845                                              India
# 36846                                             Mexico
#
#                                                   Author  \
# 0      Kyomi Mihara;Hajime Shindo;Hiroya Mihara;Minak...
# 1      Yoshihiro Sato;Tomohiro Kanoko;Kei Satoh;Jun I...
# 2             Yoshihiro Sato;Jun Iwamoto;Tomohiro Kanoko
# 3      Demosthenes B Panagiotakos;Daan Kromhout;Aless...
# 4                 Brian Wansink;Aner Tal;Mitsuru Shimizu
# ...                                                  ...
# 36842                                      Atsushi Okeda
# 36843                             Eun-han Lee;Waon-ho Yi
# 36844                               Qiushi Wu;Kangjie Lu
# 36845  S Venkatesh Kumar;Mohith Singh;Gowtham Singh;K...
# 36846  Rosa A Salcedo-HernÃ¡ndez;Leonardo S Lino-Silv...
#
#                                                     URLS  \
# 0                                                    NaN
# 1      http://retractionwatch.com/2016/06/03/jama-jou...
# 2      http://retractionwatch.com/2016/06/03/jama-jou...
# 3                                                    NaN
# 4      http://retractionwatch.com/2018/04/13/caught-o...
# ...                                                  ...
# 36842                                                NaN
# 36843                                                NaN
# 36844                                                NaN
# 36845                                                NaN
# 36846                                                NaN
#
#                               ArticleType  ... book_series_title  \
# 0                       Research Article;  ...               NaN
# 1        Clinical Study;Research Article;  ...               NaN
# 2                       Research Article;  ...               NaN
# 3                       Research Article;  ...               NaN
# 4                Letter;Research Article;  ...               NaN
# ...                                   ...  ...               ...
# 36842                   Research Article;  ...               NaN
# 36843                   Research Article;  ...               NaN
# 36844          Conference Abstract/Paper;  ...               NaN
# 36845                   Research Article;  ...               NaN
# 36846  Article in Press;Research Article;  ...               NaN
#
#       wos_core_collection_times_cited_count  \
# 0                                      <NA>
# 1                                      <NA>
# 2                                      <NA>
# 3                                      <NA>
# 4                                      <NA>
# ...                                     ...
# 36842                                  <NA>
# 36843                                  <NA>
# 36844                                  <NA>
# 36845                                  <NA>
# 36846                                     3
#
#                                           document_title document_type  \
# 0                                                    NaN           NaN
# 1                                                    NaN           NaN
# 2                                                    NaN           NaN
# 3                                                    NaN           NaN
# 4                                                    NaN           NaN
# ...                                                  ...           ...
# 36842                                                NaN           NaN
# 36843                                                NaN           NaN
# 36844                                                NaN           NaN
# 36845                                                NaN           NaN
# 36846  covid-19 and other underlying causes of cancer...       ARTICLE
#
#                                      wos_categories year_published  \
# 0                                               NaN           <NA>
# 1                                               NaN           <NA>
# 2                                               NaN           <NA>
# 3                                               NaN           <NA>
# 4                                               NaN           <NA>
# ...                                             ...            ...
# 36842                                           NaN           <NA>
# 36843                                           NaN           <NA>
# 36844                                           NaN           <NA>
# 36845                                           NaN           <NA>
# 36846  PUBLIC, ENVIRONMENTAL \& OCCUPATIONAL HEALTH           2022
#
#                                     authors_affiliations  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 36842                                                NaN
# 36843                                                NaN
# 36844                                                NaN
# 36845                                                NaN
# 36846  NATL CTR CHRON DIS PREVENT AND HLTH PROMOT;NAT...
#
#                  corresponding_author_affiliation book.group.author  \
# 0                                             NaN               NaN
# 1                                             NaN               NaN
# 2                                             NaN               NaN
# 3                                             NaN               NaN
# 4                                             NaN               NaN
# ...                                           ...               ...
# 36842                                         NaN               NaN
# 36843                                         NaN               NaN
# 36844                                         NaN               NaN
# 36845                                         NaN               NaN
# 36846  NATL CTR CHRON DIS PREVENT AND HLTH PROMOT               NaN
#
#       publication_date
# 0                  NaT
# 1                  NaT
# 2                  NaT
# 3                  NaT
# 4                  NaT
# ...                ...
# 36842              NaT
# 36843              NaT
# 36844              NaT
# 36845              NaT
# 36846       2022-12-16
#
# [36847 rows x 55 columns]

# %%
test = filtered_rwd.merge(filtered_wos, how= 'right', left_on= 'OriginalPaperDOI', right_on= 'doi')
test
# Out:
#         Record ID                                              Title  \
# 0             NaN                                                NaN
# 1             NaN                                                NaN
# 2             NaN                                                NaN
# 3             NaN                                                NaN
# 4             NaN                                                NaN
# ...           ...                                                ...
# 916484        NaN                                                NaN
# 916485        NaN                                                NaN
# 916486        NaN                                                NaN
# 916487        NaN                                                NaN
# 916488     8591.0  CD117 immunohistochemical expression correlate...
#
#                                                   Subject  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 916484                                                NaN
# 916485                                                NaN
# 916486                                                NaN
# 916487                                                NaN
# 916488  (BLS) Biochemistry;(HSC) Medicine - Immunology...
#
#                                               Institution  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 916484                                                NaN
# 916485                                                NaN
# 916486                                                NaN
# 916487                                                NaN
# 916488  Surgical oncology, Instituto Nacional de Cance...
#
#                              Journal                     Publisher Country  \
# 0                                NaN                           NaN     NaN
# 1                                NaN                           NaN     NaN
# 2                                NaN                           NaN     NaN
# 3                                NaN                           NaN     NaN
# 4                                NaN                           NaN     NaN
# ...                              ...                           ...     ...
# 916484                           NaN                           NaN     NaN
# 916485                           NaN                           NaN     NaN
# 916486                           NaN                           NaN     NaN
# 916487                           NaN                           NaN     NaN
# 916488  Iranian Journal of Pathology  Iranian Society of Pathology  Mexico
#
#                                                    Author URLS  \
# 0                                                     NaN  NaN
# 1                                                     NaN  NaN
# 2                                                     NaN  NaN
# 3                                                     NaN  NaN
# 4                                                     NaN  NaN
# ...                                                   ...  ...
# 916484                                                NaN  NaN
# 916485                                                NaN  NaN
# 916486                                                NaN  NaN
# 916487                                                NaN  NaN
# 916488  Rosa A Salcedo-HernÃ¡ndez;Leonardo S Lino-Silv...  NaN
#
#                                ArticleType  ... book_series_title  \
# 0                                      NaN  ...               NaN
# 1                                      NaN  ...               NaN
# 2                                      NaN  ...               NaN
# 3                                      NaN  ...               NaN
# 4                                      NaN  ...               NaN
# ...                                    ...  ...               ...
# 916484                                 NaN  ...               NaN
# 916485                                 NaN  ...               NaN
# 916486                                 NaN  ...               NaN
# 916487                                 NaN  ...               NaN
# 916488  Article in Press;Research Article;  ...               NaN
#
#        wos_core_collection_times_cited_count  \
# 0                                          4
# 1                                         22
# 2                                        205
# 3                                        256
# 4                                        383
# ...                                      ...
# 916484                                    27
# 916485                                    38
# 916486                                    25
# 916487                                    58
# 916488                                     3
#
#                                            document_title  \
# 0       high-resolution seismic velocity analysis by s...
# 1            panitumumab a novel drug in cancer treatment
# 2       timing, order and durability of new product ad...
# 3       environmental dynamism, capital structure and ...
# 4       product and international diversification amon...
# ...                                                   ...
# 916484  decrease of let-7f in low-dose metronomic pacl...
# 916485  the prostate basal cell (bc) heterogeneity and...
# 916486  global costs, health benefits, and economic be...
# 916487  measurement and interpretation of differential...
# 916488  covid-19 and other underlying causes of cancer...
#
#                      document_type  \
# 0                          ARTICLE
# 1       ARTICLE; PROCEEDINGS PAPER
# 2                          ARTICLE
# 3                           REVIEW
# 4                          ARTICLE
# ...                            ...
# 916484                     ARTICLE
# 916485                     ARTICLE
# 916486                     ARTICLE
# 916487                     ARTICLE
# 916488                     ARTICLE
#
#                                            wos_categories year_published  \
# 0                              GEOCHEMISTRY \& GEOPHYSICS           2021
# 1                                                ONCOLOGY           2007
# 2                                    BUSINESS; MANAGEMENT           2000
# 3                                    BUSINESS; MANAGEMENT           2000
# 4                                    BUSINESS; MANAGEMENT           2000
# ...                                                   ...            ...
# 916484         BIOCHEMISTRY \& MOLECULAR BIOLOGY; BIOLOGY           2015
# 916485         BIOCHEMISTRY \& MOLECULAR BIOLOGY; BIOLOGY           2014
# 916486                                           ONCOLOGY           2021
# 916487  ASTRONOMY \& ASTROPHYSICS; PHYSICS, NUCLEAR; P...           2019
# 916488       PUBLIC, ENVIRONMENTAL \& OCCUPATIONAL HEALTH           2022
#
#                                      authors_affiliations  \
# 0                                 UNIV TEHRAN;UNIV TEHRAN
# 1                         C (CORRESPONDING AUTHOR);NAPLES
# 2       GEORGE MASON UNIV;GEORGE MASON UNIV;UNIV MARYL...
# 3       CALIF STATE UNIV NORTHRIDGE;CALIF STATE UNIV N...
# 4       UNIV UTAH;UNIV UTAH;CRANFIELD UNIV;CALIF POLYT...
# ...                                                   ...
# 916484  HARBIN MED UNIV;HARBIN MED UNIV;HARBIN MED UNI...
# 916485   BAYLOR COLL MED;TEXAS AANDM UNIV;LUZHOU MED COLL
# 916486  HARVARD UNIV;HARVARD UNIV;HARVARD UNIV;OLIVIA ...
# 916487  YEREVAN PHYS INST;YEREVAN PHYS INST;KRATSCHMER...
# 916488  NATL CTR CHRON DIS PREVENT AND HLTH PROMOT;NAT...
#
#                   corresponding_author_affiliation book.group.author  \
# 0                                      UNIV TEHRAN               NaN
# 1                         C (CORRESPONDING AUTHOR)               NaN
# 2                                GEORGE MASON UNIV               NaN
# 3                      CALIF STATE UNIV NORTHRIDGE               NaN
# 4                                        UNIV UTAH               NaN
# ...                                            ...               ...
# 916484                             HARBIN MED UNIV               NaN
# 916485                             BAYLOR COLL MED               NaN
# 916486                                HARVARD UNIV               NaN
# 916487                           YEREVAN PHYS INST               NaN
# 916488  NATL CTR CHRON DIS PREVENT AND HLTH PROMOT               NaN
#
#        publication_date
# 0            2021-01-01
# 1            2007-01-01
# 2            2000-01-01
# 3            2000-01-01
# 4            2000-01-01
# ...                 ...
# 916484       2015-01-01
# 916485       2014-01-01
# 916486       2021-03-01
# 916487       2019-05-10
# 916488       2022-12-16
#
# [916489 rows x 55 columns]

# %%
filtered_wos.shape
# Out:
# (916489, 35)
