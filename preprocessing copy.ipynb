# %% [markdown]
# The purpose of this Notebook is to join the datasets from the different sources into the following datasets:
# - *retractions*: this dataset will join data from retraction watch database (RW) and bibliometric data of retractions in Web of Science (RD).
# - *retracted_in_journals*: this dataset will join data from retraction watch database (RW), journal metrics from scimajor, and bibliometric data of all articles in best ranked journals (JD).

# %% [markdown]
# <div class="alert alert-block alert-info" style = "background:#d0de6f; color:#000000; border:0;">
#
# # Chapter 0 - Libraries <a class="anchor" id="chapter0"></a>

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import re
#import matplotlib.pyplot as plt
#import seaborn as sns
#import plotly.express as px

# %% [markdown]
# <div class="alert alert-block alert-info" style = "background:#d0de6f; color:#000000; border:0;">
#
# # Chapter 1 - Individual Analysis <a class="anchor" id="chapter1"></a>

# %% [markdown]
# <a class="anchor">
#
# ## 1.1 - Retraction Watch Database (RW) <a class="anchor" id="section_1_1"></a>

# %%
rw = pd.read_excel('./retractions_data/retraction_watch_database.xlsx', dtype={'RetractionPubMedID': object, 'OriginalPaperPubMedID': object})
rw.head()
# Out:
#    Record ID                                              Title  \
# 0      47271  Binding of DCC by Netrin-1 to Mediate Axon Gui...
# 1      47270  Hierarchical Organization of Guidance Receptor...
# 2      47243  Therapeutic potential of targeting IRES-depend...
# 3      47233  A classifier based on 273 urinary peptides pre...
# 4      47227  Age, Gender Demographics and Comorbidity Preva...
#
#                                              Subject  \
# 0  (BLS) Biology - Cellular;(BLS) Biology - Gener...
# 1  (BLS) Biochemistry;(BLS) Biology - General;(BL...
# 2  (BLS) Biochemistry;(BLS) Biology - Cancer;(BLS...
# 3  (BLS) Biochemistry;(HSC) Medicine - Cardiovasc...
# 4  (HSC) Biostatistics/Epidemiology;(HSC) Medicin...
#
#                                          Institution  \
# 0  Departments of Anatomy and of Biochemistry and...
# 1  Department of Anatomy and Department of Bioche...
# 2  Division of Hematology-Oncology, UCLA-Greater ...
# 3  Department of Nephrology, The Third Affiliated...
# 4  Department of Orthopaedics, Dhanalakshmi Srini...
#
#                             Journal  \
# 0                           Science
# 1                           Science
# 2                          Oncogene
# 3           Journal of Hypertension
# 4  Journal of Coastal Life Medicine
#
#                                            Publisher        Country  \
# 0  American Association for the Advancement of Sc...  United States
# 1  American Association for the Advancement of Sc...  United States
# 2                 Springer - Nature Publishing Group  United States
# 3     Wolters Kluwer - Lippincott Williams & Wilkins          China
# 4                   Journal of Coastal Life Medicine          India
#
#                                               Author  \
# 0  Elke Stein;Yimin Zou;Mu-ming Poo;Marc Tessier-...
# 1                    Elke Stein;Marc Tessier-Lavigne
# 2  Y Shi;Y Yang;C Bardeleben;B Holmes;J Gera;Alan...
# 3  Lirong Lin;Chunxuan Wang;Jiangwen Ren;Mei Mei;...
# 4  S Venkatesh Kumar;Mohith Singh;Gowtham Singh;K...
#
#                                                 URLS        ArticleType  \
# 0  https://retractionwatch.com/2023/08/31/stanfor...  Research Article;
# 1  https://retractionwatch.com/2023/08/31/stanfor...  Research Article;
# 2                                                NaN  Research Article;
# 3                                                NaN  Research Article;
# 4                                                NaN  Research Article;
#
#         RetractionDate                 RetractionDOI RetractionPubMedID  \
# 0  2023-08-31 00:00:00       10.1126/science.adk1521                  0
# 1  2023-08-31 00:00:00       10.1126/science.adk1517                  0
# 2  2023-08-31 00:00:00    10.1038/s41388-023-02820-5                  0
# 3  2023-08-30 00:00:00  10.1097/HJH.0000000000003551           37642599
# 4  2023-08-30 00:00:00                   unavailable                  0
#
#      OriginalPaperDate              OriginalPaperDOI OriginalPaperPubMedID  \
# 0  2001-03-09 00:00:00       10.1126/science.1059391              11239160
# 1  2001-02-08 00:00:00       10.1126/science.1058445              11239147
# 2  2015-05-11 00:00:00          10.1038/onc.2015.156              25961916
# 3  2023-08-01 00:00:00  10.1097/HJH.0000000000003467              37199562
# 4  2023-01-01 00:00:00                   unavailable                     0
#
#   RetractionNature                                             Reason  \
# 0       Retraction  +Investigation by Company/Institution;+Manipul...
# 1       Retraction  +Duplication of Image;+Investigation by Compan...
# 2       Retraction  +Concerns/Issues About Data;+Concerns/Issues A...
# 3       Retraction  +Concerns/Issues About Results;+Investigation ...
# 4       Retraction                     +Notice - Lack of;+Withdrawal;
#
#   Paywalled                                              Notes
# 0        No                                                NaN
# 1        No                                                NaN
# 2        No  see also: https://pubpeer.com/publications/704...
# 3        No  see also https://journals.lww.com/jhypertensio...
# 4        No  date of retraction unknown, article title repl...

# %%
rw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42700 entries, 0 to 42699
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Record ID              42700 non-null  int64
#  1   Title                  42700 non-null  object
#  2   Subject                42700 non-null  object
#  3   Institution            42699 non-null  object
#  4   Journal                42700 non-null  object
#  5   Publisher              42700 non-null  object
#  6   Country                42700 non-null  object
#  7   Author                 42700 non-null  object
#  8   URLS                   21687 non-null  object
#  9   ArticleType            42700 non-null  object
#  10  RetractionDate         42700 non-null  object
#  11  RetractionDOI          42209 non-null  object
#  12  RetractionPubMedID     37599 non-null  object
#  13  OriginalPaperDate      42700 non-null  object
#  14  OriginalPaperDOI       40173 non-null  object
#  15  OriginalPaperPubMedID  37564 non-null  object
#  16  RetractionNature       42700 non-null  object
#  17  Reason                 42700 non-null  object
#  18  Paywalled              42700 non-null  object
#  19  Notes                  10253 non-null  object
# dtypes: int64(1), object(19)
# memory usage: 6.5+ MB

# %%
# put date variables in correct format
rw['RetractionDate'] = pd.to_datetime(rw['RetractionDate'], errors='coerce') #, infer_datetime_format=True
rw['OriginalPaperDate'] = pd.to_datetime(rw['OriginalPaperDate'])

# %%
# Check for NaN values in 'Digital Object Identifier (DOI)' column
rw_filtered = rw.dropna(subset=['RetractionDOI'])

# Filter rows starting with "http://dx.doi.org/"
rw_filtered[rw_filtered['RetractionDOI'].str.startswith("http://dx.doi.org/")]['RetractionDOI']
# Out:
# Series([], Name: RetractionDOI, dtype: object)

# %% [markdown]
# ### Duplicates

# %% [markdown]
# In theory, there should only be one DOI per article, and each retracted paper should only have one record in the database. This means that all DOIs should be unique.

# %%
rw['OriginalPaperDOI'].nunique()
# Out:
# 36846

# %%
rw['RetractionDOI'].nunique()
# Out:
# 36506

# %%
testing_dupes = rw[rw.duplicated(subset='OriginalPaperDOI', keep=False)]
testing_dupes['OriginalPaperDOI'].value_counts()
# Out:
# OriginalPaperDOI
# Unavailable                        2234
# unavailable                        1074
# 10.1136/jim-2021-SRMC                 6
# 10.1002/tox.21941                     2
# 10.1016/j.lfs.2019.116709             2
# 10.1038/s41598-021-03765-z            2
# 10.1007/s12275-012-2294-z             2
# 10.1016/j.cej.2011.04.016             2
# 10.1016/j.swevo.2021.100868           2
# 10.1016/j.esxm.2021.100447            2
# 10.1093/jge/aabc74                    2
# 10.1088/1742-2140/aaaf57              2
# 10.1088/1742-2140/aa953a              2
# 10.1016/j.carbpol.2019.115799         2
# 10.1001/archpediatrics.2012.999       2
# 10.1007/s13277-014-2995-5             2
# 10.3109/02699052.2016.1162060         2
# 10.1016/j.rapm.2005.05.009            2
# 10.1524/9783486834062.275             2
# Name: count, dtype: int64

# %%
filtered_dupes = testing_dupes[testing_dupes['OriginalPaperDOI'].str.lower() != 'unavailable'].sort_values('OriginalPaperDOI')
filtered_dupes
# Out:
#        Record ID                                              Title  \
# 21229      14089               Can Branding Improve School Lunches?
# 21230      11994               Can Branding Improve School Lunches?
# 5685       38940  Erratum to: Î±,Î²-Unsaturated aldehyde polluta...
# 5696       38375  Î±,Î²-Unsaturated aldehyde pollutant acrolein ...
# 6643       37342  Identification of the Vibrio vulnificus htpG G...
# ...          ...                                                ...
# 42578       4780  Phenylephrine stress in the evaluation of pati...
# 42579       4781  Thallium pulmonary scintigraphy. Relationship ...
# 42611       1494  Specific antigen exclusion and non-specific fa...
# 42613       4249  Concurrent measurement of plasma levels of vit...
# 42695      10433           Change of Venue and the Conflict of Laws
#
#                                                  Subject  \
# 21229  (B/T) Business - Marketing;(BLS) Nutrition;(SO...
# 21230  (B/T) Business - Marketing;(BLS) Nutrition;(SO...
# 5685          (BLS) Biology - Cellular;(BLS) Toxicology;
# 5696          (BLS) Biology - Cellular;(BLS) Toxicology;
# 6643                  (BLS) Genetics;(BLS) Microbiology;
# ...                                                  ...
# 42578  (HSC) Medicine - Cardiology;(HSC) Medicine - P...
# 42579  (HSC) Medicine - Cardiology;(HSC) Medicine - P...
# 42611                         (BLS) Biology - Molecular;
# 42613  (HSC) Medicine - Cardiovascular;(HSC) Medicine...
# 42695                            (SOC) Law/Legal Issues;
#
#                                              Institution  \
# 21229  Charles H. Dyson School of Applied Economics a...
# 21230  Charles H. Dyson School of Applied Economics a...
# 5685   Department of Clinical Immunology, Xijing Hosp...
# 5696   Department of Clinical Immunology, Xijing Hosp...
# 6643   Department of Agricultural Biotechnology, Seou...
# ...                                                  ...
# 42578  Department of Radiology, University of Califor...
# 42579  Department of Radiology, University of Califor...
# 42611  Department of Immunology, Institute of Child H...
# 42613  Endocrinology-Mineral Metabolism and Nephrolog...
# 42695                             University of Chicago;
#
#                                                  Journal  \
# 21229                                    JAMA Pediatrics
# 21230                                    JAMA Pediatrics
# 5685                            Environmental Toxicology
# 5696                            Environmental Toxicology
# 6643                             Journal of Microbiology
# ...                                                  ...
# 42578                            Investigative Radiology
# 42579                            Investigative Radiology
# 42611               Clinical and Experimental Immunology
# 42613  Translational Research: The Journal of Laborat...
# 42695               The University of Chicago Law Review
#
#                               Publisher              Country  \
# 21229                      JAMA Network        United States
# 21230                      JAMA Network        United States
# 5685                              Wiley  China;United States
# 5696                              Wiley  China;United States
# 6643                           Springer          South Korea
# ...                                 ...                  ...
# 42578                    Wolters Kluwer        United States
# 42579                    Wolters Kluwer        United States
# 42611              Blackwell Publishing       United Kingdom
# 42613                          Elsevier        United States
# 42695  University of Chicago Law School        United States
#
#                                                   Author  \
# 21229          Brian Wansink;David R Just;Collin R Payne
# 21230          Brian Wansink;David R Just;Collin R Payne
# 5685       Zhenbiao Wu;Emily Y He;Glenda I Scott;Jun Ren
# 5696       Zhenbiao Wu;Emily Y He;Glenda I Scott;Jun Ren
# 6643   Slae Choi;Kyungku Jang;Seulah Choi;Hee Jee Yun...
# ...                                                  ...
# 42578                                   Robert A Slutsky
# 42579                                   Robert A Slutsky
# 42611  S A Roberts;M C Reinhardt;R Paganelli;R J Levi...
# 42613  PW Lambert;PB DeOreo;BW Hollis;IY Fu;DJ Ginsbe...
# 42695                                    Brainerd Currie
#
#                                                     URLS  \
# 21229  http://retractionwatch.com/?s=brian+wansink;ht...
# 21230  http://retractionwatch.com/?s=brian+wansink;ht...
# 5685   https://retractionwatch.com/2022/07/25/univers...
# 5696   https://retractionwatch.com/2022/07/25/univers...
# 6643                                                 NaN
# ...                                                  ...
# 42578  http://retractionwatch.com/the-retraction-watc...
# 42579  http://retractionwatch.com/the-retraction-watc...
# 42611                                                NaN
# 42613                                                NaN
# 42695                                                NaN
#
#                                       ArticleType RetractionDate  \
# 21229  Letter;Research Article;Retracted Article;     2017-10-20
# 21230                    Letter;Research Article;     2017-09-21
# 5685              Correction/Erratum/Corrigendum;     2022-07-27
# 5696                            Research Article;     2022-07-27
# 6643                            Research Article;     2022-05-23
# ...                                           ...            ...
# 42578                           Research Article;     1986-02-01
# 42579                           Research Article;     1986-02-01
# 42611                           Research Article;     1985-01-01
# 42613                           Research Article;     1984-10-01
# 42695                           Research Article;     1960-02-01
#
#                           RetractionDOI RetractionPubMedID OriginalPaperDate  \
# 21229  10.1001/jamapediatrics.2017.4603                  0        2012-10-01
# 21230  10.1001/jamapediatrics.2017.3136           28973133        2012-10-01
# 5685                  10.1002/tox.23620           35894684        2021-09-12
# 5696                  10.1002/tox.23620           35894684        2013-12-23
# 6643          10.1007/s12275-022-1680-4           35606641        2012-08-25
# ...                                 ...                ...               ...
# 42578                               NaN            3514538        1983-03-01
# 42579                               NaN            3514538        1984-11-01
# 42611                               NaN            3882286        1981-07-01
# 42613                               NaN            6384395        1981-10-01
# 42695                               NaN                NaN        1955-02-01
#
#                       OriginalPaperDOI OriginalPaperPubMedID RetractionNature  \
# 21229  10.1001/archpediatrics.2012.999              22911396       Retraction
# 21230  10.1001/archpediatrics.2012.999              22911396       Retraction
# 5685                 10.1002/tox.21941              34514704       Retraction
# 5696                 10.1002/tox.21941              24376112       Retraction
# 6643         10.1007/s12275-012-2294-z              22923124       Retraction
# ...                                ...                   ...              ...
# 42578                              NaN               6345451       Retraction
# 42579                              NaN               6392156       Retraction
# 42611                              NaN               6171369       Retraction
# 42613                              NaN               6270222       Retraction
# 42695                              NaN                   NaN       Retraction
#
#                                                   Reason Paywalled  \
# 21229  +Breach of Policy by Author;+Error in Data;+Er...        No
# 21230  +Error in Analyses;+Error in Data;+Error in Me...        No
# 5685                             +Updated to Retraction;        No
# 5696   +Falsification/Fabrication of Image;+Investiga...        No
# 6643   +Concerns/Issues About Authorship;+Upgrade/Upd...        No
# ...                                                  ...       ...
# 42578  +Concerns/Issues About Results;+Legal Reasons/...        No
# 42579  +Concerns/Issues About Results;+Legal Reasons/...        No
# 42611  +Error in Analyses;+Results Not Reproducible;+...        No
# 42613  +Notice - Unable to Access via current resources;   Unknown
# 42695  +Error in Results and/or Conclusions;+Unreliab...       Yes
#
#                                                    Notes
# 21229  Journal previously named Archives of Pediatric...
# 21230  note: the paper was retracted again on October...
# 5685                                                 NaN
# 5696                                                 NaN
# 6643                                                 NaN
# ...                                                  ...
# 42578                                                NaN
# 42579  Article is Nov/Dec 1984 (vol. 19, iss. 6, no d...
# 42611              No DOI for Original/Notice 3/24/2017;
# 42613  Journal formerly known as: The Journal of Labo...
# 42695                                                NaN
#
# [2565 rows x 20 columns]

# %%
def find_changed_columns(group):
    changed_cols = group.apply(lambda x: x.nunique()).drop(['OriginalPaperDOI', 'Record ID'])
    value = changed_cols[changed_cols>1].index.to_list()
    return value


filtered_dupes.groupby('OriginalPaperDOI').apply(find_changed_columns).reset_index()
# Out:
#                    OriginalPaperDOI  \
# 0   10.1001/archpediatrics.2012.999
# 1                 10.1002/tox.21941
# 2         10.1007/s12275-012-2294-z
# 3         10.1007/s13277-014-2995-5
# 4     10.1016/j.carbpol.2019.115799
# 5         10.1016/j.cej.2011.04.016
# 6        10.1016/j.esxm.2021.100447
# 7         10.1016/j.lfs.2019.116709
# 8        10.1016/j.rapm.2005.05.009
# 9       10.1016/j.swevo.2021.100868
# 10       10.1038/s41598-021-03765-z
# 11         10.1088/1742-2140/aa953a
# 12         10.1088/1742-2140/aaaf57
# 13               10.1093/jge/aabc74
# 14            10.1136/jim-2021-SRMC
# 15        10.1524/9783486834062.275
# 16    10.3109/02699052.2016.1162060
#
#                                                     0
# 0   [ArticleType, RetractionDate, RetractionDOI, R...
# 1   [Title, ArticleType, OriginalPaperDate, Origin...
# 2   [RetractionDate, RetractionDOI, RetractionPubM...
# 3   [ArticleType, RetractionDate, RetractionDOI, R...
# 4   [RetractionDate, RetractionDOI, RetractionPubM...
# 5              [RetractionDate, RetractionDOI, Notes]
# 6   [RetractionDate, RetractionDOI, RetractionPubM...
# 7   [Subject, RetractionDate, RetractionDOI, Retra...
# 8   [RetractionDate, RetractionDOI, RetractionPubM...
# 9              [RetractionDate, RetractionDOI, Notes]
# 10  [RetractionDate, RetractionDOI, RetractionPubM...
# 11            [RetractionDate, RetractionDOI, Reason]
# 12            [RetractionDate, RetractionDOI, Reason]
# 13            [RetractionDate, RetractionDOI, Reason]
# 14  [Title, Institution, Country, Author, Retracti...
# 15                                   [RetractionDate]
# 16                                    [Title, Author]

# %%
# following code commented so as to not override the changed made in the file
# with pd.ExcelWriter('./wos_rd/DOI_Duplicated_RWD.xlsx') as writer:
#     filtered_dupes.groupby('OriginalPaperDOI').apply(find_changed_columns).reset_index().to_excel(writer, sheet_name= "Differing vars",index = False)
#     filtered_dupes.to_excel(writer, sheet_name = "Duplicate records",index = False)

# %%
rw[rw['OriginalPaperDOI']=='10.1136/jim-2021-SRMC']
# Out:
#        Record ID                                              Title  \
# 11352      30679  Acute kidney injury and collapsing glomerulopa...
# 11353      30686  Acute kidney injury and collapsing glomerulopa...
# 11364      30687  Filter clotting, anticoagulation and duration ...
# 11365      30691  Filter clotting, anticoagulation and duration ...
# 11381      30693  Phenotype and outcomes of acute kidney injury ...
# 11382      30697  Phenotype and outcomes of acute kidney injury ...
#
#                                                  Subject  \
# 11352  (HSC) Medicine - Infectious Disease;(HSC) Medi...
# 11353  (HSC) Medicine - Infectious Disease;(HSC) Medi...
# 11364  (HSC) Medicine - Infectious Disease;(HSC) Medi...
# 11365  (HSC) Medicine - Infectious Disease;(HSC) Medi...
# 11381  (HSC) Medicine - Infectious Disease;(HSC) Medi...
# 11382  (HSC) Medicine - Infectious Disease;(HSC) Medi...
#
#                                              Institution  \
# 11352  Arkana Laboratories, Little Rock, Arkansas; De...
# 11353  Arkana Laboratories, Little Rock, Arkansas; De...
# 11364  Department of Nephrology, Ochsner Health Syste...
# 11365  Department of Nephrology, Ochsner Health Syste...
# 11381  Department of Nephrology, Ochsner Health Syste...
# 11382  Department of Nephrology, Ochsner Health Syste...
#
#                                                  Journal       Publisher  \
# 11352  Journal of Investigative Medicine: The Officia...  BMJ Publishing
# 11353  Journal of Investigative Medicine: The Officia...  BMJ Publishing
# 11364  Journal of Investigative Medicine: The Officia...  BMJ Publishing
# 11365  Journal of Investigative Medicine: The Officia...  BMJ Publishing
# 11381  Journal of Investigative Medicine: The Officia...  BMJ Publishing
# 11382  Journal of Investigative Medicine: The Officia...  BMJ Publishing
#
#                        Country  \
# 11352  Australia;United States
# 11353  Australia;United States
# 11364            United States
# 11365            United States
# 11381  Australia;United States
# 11382  Australia;United States
#
#                                                   Author  \
# 11352  Cesar F Hernandez-Arroyo;Christopher P Larson;...
# 11353  Cesar F Hernandez-Arroyo;Christopher P Larson;...
# 11364  Yuang Wen;Jason R LeDoux;Akanksh Ramanand;Kevi...
# 11365  Yuang Wen;Jason R LeDoux;Akanksh Ramanand;Kevi...
# 11381  Aldo E Torres-Ortiz;Muner M Mohamed;Joseph B W...
# 11382  Aldo E Torres-Ortiz;Muner M Mohamed;Joseph B W...
#
#                                                     URLS  \
# 11352  http://retractionwatch.com/retracted-coronavir...
# 11353  http://retractionwatch.com/retracted-coronavir...
# 11364  http://retractionwatch.com/retracted-coronavir...
# 11365  http://retractionwatch.com/retracted-coronavir...
# 11381  http://retractionwatch.com/retracted-coronavir...
# 11382  http://retractionwatch.com/retracted-coronavir...
#
#                       ArticleType RetractionDate  \
# 11352  Conference Abstract/Paper;     2021-04-01
# 11353  Conference Abstract/Paper;     2021-04-01
# 11364  Conference Abstract/Paper;     2021-04-01
# 11365  Conference Abstract/Paper;     2021-04-01
# 11381  Conference Abstract/Paper;     2021-04-01
# 11382  Conference Abstract/Paper;     2021-04-01
#
#                           RetractionDOI RetractionPubMedID OriginalPaperDate  \
# 11352  10.1136/jim-2021-SRMC.111.621wit                  0        2021-01-25
# 11353  10.1136/jim-2021-SRMC.111.621wit                  0        2021-01-25
# 11364  10.1136/jim-2021-SRMC.112.643wit                  0        2021-01-25
# 11365  10.1136/jim-2021-SRMC.112.643wit                  0        2021-01-25
# 11381  10.1136/jim-2021-SRMC.113.445wit                  0        2021-01-25
# 11382  10.1136/jim-2021-SRMC.113.445wit                  0        2021-01-25
#
#             OriginalPaperDOI OriginalPaperPubMedID RetractionNature  \
# 11352  10.1136/jim-2021-SRMC                     0       Retraction
# 11353  10.1136/jim-2021-SRMC                     0       Retraction
# 11364  10.1136/jim-2021-SRMC                     0       Retraction
# 11365  10.1136/jim-2021-SRMC                     0       Retraction
# 11381  10.1136/jim-2021-SRMC                     0       Retraction
# 11382  10.1136/jim-2021-SRMC                     0       Retraction
#
#                                      Reason Paywalled  \
# 11352  +Duplication of Article;+Withdrawal;       Yes
# 11353  +Duplication of Article;+Withdrawal;       Yes
# 11364  +Duplication of Article;+Withdrawal;       Yes
# 11365  +Duplication of Article;+Withdrawal;       Yes
# 11381              +Duplication of Article;       Yes
# 11382              +Duplication of Article;       Yes
#
#                                                    Notes
# 11352  There are two withdrawn abstracts with the sam...
# 11353  There are two withdrawn abstracts with the sam...
# 11364  There are two withdrawn abstracts with the sam...
# 11365  There are two withdrawn abstracts with the sam...
# 11381  There are two withdrawn abstracts with the sam...
# 11382  There are two withdrawn abstracts with the sam...

# %%
# records that should be deleted
records_to_delete = [6000, 2175, 7242]
rw = rw[~rw['Record ID'].isin(records_to_delete)]

# %%
rw.sort_values(by=['OriginalPaperDOI', 'OriginalPaperDate'], ascending=[True, False], inplace=True)

# Keep only the first occurrence of each unique DOI (the most recent date)
filtered_rw = rw.drop_duplicates(subset='OriginalPaperDOI')

# %% [markdown]
# ### Title analysis

# %%
rw[rw['Title'].str.startswith("Retracted:")]
# Out:
#        Record ID                                              Title  \
# 13359      45110  Retracted: Lifting the lid on lobbying in Indi...
# 1326       46570  Retracted: miR-214-3p Protects and Restores th...
#
#                                                  Subject  \
# 13359                                  (B/T) Government;
# 1326   (BLS) Biology - Molecular;(BLS) Genetics;(HSC)...
#
#                                              Institution  \
# 13359  Department of Management Studies, Indian Insti...
# 1326   Key Laboratory of Advanced Technologies of Mat...
#
#                                                  Journal Publisher Country  \
# 13359                          Journal of Public Affairs     Wiley   India
# 1326   Evidence-Based Complementary and Alternative M...   Hindawi   China
#
#                                     Author  \
# 13359  Pankaj K P Shreyaskar;Pramod Pathak
# 1326      Yuan Cheng;Qing He;Tao Jin;Na Li
#
#                                                     URLS        ArticleType  \
# 13359                                                NaN  Research Article;
# 1326   https://retractionwatch.com/2022/09/28/exclusi...  Research Article;
#
#       RetractionDate         RetractionDOI RetractionPubMedID  \
# 13359     2020-09-21       10.1002/pa.2423                  0
# 1326      2023-06-21  10.1155/2023/9823451           37388114
#
#       OriginalPaperDate      OriginalPaperDOI OriginalPaperPubMedID  \
# 13359        2020-09-21       10.1002/pa.2423                     0
# 1326         2022-07-18  10.1155/2022/1175935              35899226
#
#       RetractionNature                                             Reason  \
# 13359       Retraction  +Date of Retraction/Other Unknown;+Euphemisms ...
# 1326        Retraction  +Concerns/Issues About Data;+Concerns/Issues a...
#
#       Paywalled                                              Notes
# 13359        No                                                NaN
# 1326         No  See also: https://pubpeer.com/publications/C08...

# %%
rw['Title'] = rw['Title'].str.replace('Retracted:', '')

# %%
rw[rw['Title'].str.startswith("Retracted:")]
# Out:
# Empty DataFrame
# Columns: [Record ID, Title, Subject, Institution, Journal, Publisher, Country, Author, URLS, ArticleType, RetractionDate, RetractionDOI, RetractionPubMedID, OriginalPaperDate, OriginalPaperDOI, OriginalPaperPubMedID, RetractionNature, Reason, Paywalled, Notes]
# Index: []

# %%
rw.iloc[[1326,13359]]
# Out:
#        Record ID                                              Title  \
# 12550      25797  LncRNA ATB promotes proliferation and metastas...
# 11996      44387  Preparation of self-healing anti-corrosion coa...
#
#                                                  Subject  \
# 12550  (BLS) Biochemistry;(BLS) Biology - Cancer;(BLS...
# 11996  (PHY) Engineering - Chemical;(PHY) Materials S...
#
#                                              Institution  \
# 12550  Department of Respiratory Medicine, The Affili...
# 11996  Department of Materials Engineering, Isfahan U...
#
#                                 Journal           Publisher Country  \
# 12550  Journal of Cellular Biochemistry               Wiley   China
# 11996               Surface Engineering  Taylor and Francis    Iran
#
#                                                   Author  \
# 12550  Yiwei Cao;Xiangjun Luo;Xiaoqian Ding;Shichao C...
# 11996          Sogand Abbaspour;Ali Ashrafi;Mehdi Salehi
#
#                                                     URLS        ArticleType  \
# 12550  http://retractionwatch.com/2021/03/08/journal-...  Research Article;
# 11996                                                NaN  Research Article;
#
#       RetractionDate                  RetractionDOI RetractionPubMedID  \
# 12550     2020-12-15              10.1002/jcb.29877           33590514
# 11996     2021-02-01  10.1080/02670844.2021.1883242                  0
#
#       OriginalPaperDate               OriginalPaperDOI OriginalPaperPubMedID  \
# 12550        2018-04-25              10.1002/jcb.26894              29693289
# 11996        2019-11-21  10.1080/02670844.2019.1689641                     0
#
#       RetractionNature                                             Reason  \
# 12550       Retraction  +Concerns/Issues About Data;+Concerns/Issues a...
# 11996       Retraction  +Concerns/Issues About Image;+Concerns/Issues ...
#
#       Paywalled                                              Notes
# 12550        No  see also: https://pubpeer.com/publications/B2B...
# 11996        No                                                NaN

# %%
rw[rw['Title'].str.contains("(Withdrawn Publication)")]
# Out:
# C:\Users\isabe\AppData\Local\Temp\ipykernel_26800\3311889512.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   rw[rw['Title'].str.contains("(Withdrawn Publication)")]
# Empty DataFrame
# Columns: [Record ID, Title, Subject, Institution, Journal, Publisher, Country, Author, URLS, ArticleType, RetractionDate, RetractionDOI, RetractionPubMedID, OriginalPaperDate, OriginalPaperDOI, OriginalPaperPubMedID, RetractionNature, Reason, Paywalled, Notes]
# Index: []

# %%
rw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 42697 entries, 29155 to 42695
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Record ID              42697 non-null  int64
#  1   Title                  42697 non-null  object
#  2   Subject                42697 non-null  object
#  3   Institution            42696 non-null  object
#  4   Journal                42697 non-null  object
#  5   Publisher              42697 non-null  object
#  6   Country                42697 non-null  object
#  7   Author                 42697 non-null  object
#  8   URLS                   21686 non-null  object
#  9   ArticleType            42697 non-null  object
#  10  RetractionDate         42697 non-null  datetime64[ns]
#  11  RetractionDOI          42206 non-null  object
#  12  RetractionPubMedID     37596 non-null  object
#  13  OriginalPaperDate      42697 non-null  datetime64[ns]
#  14  OriginalPaperDOI       40170 non-null  object
#  15  OriginalPaperPubMedID  37561 non-null  object
#  16  RetractionNature       42697 non-null  object
#  17  Reason                 42697 non-null  object
#  18  Paywalled              42697 non-null  object
#  19  Notes                  10251 non-null  object
# dtypes: datetime64[ns](2), int64(1), object(17)
# memory usage: 6.8+ MB

# %% [markdown]
# <a class="anchor">
#
# ## 1.2 - Retractions from WoS (RD) <a class="anchor" id="section_2_2"></a>

# %%
wos_rd = pd.read_csv('./retractions_data/journals_data100-199.csv', dtype={'PubMed ID': object, 'PubMed ID': object})
wos_rd.info()
# Out:
# C:\Users\isabe\AppData\Local\Temp\ipykernel_26800\116829994.py:1: DtypeWarning: Columns (3,4,7,10,11,14,15,16,17,18,19,32,36,41,42,46,47,48,49,50,51,52,53,55,58,59,60,65,67,68) have mixed types. Specify dtype option on import or set low_memory=False.
#   wos_rd = pd.read_csv('./retractions_data/journals_data100-199.csv', dtype={'PubMed ID': object, 'PubMed ID': object})
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 471543 entries, 0 to 471542
# Data columns (total 71 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   PT      471543 non-null  object
#  1   AU      471004 non-null  object
#  2   BA      0 non-null       float64
#  3   BE      2529 non-null    object
#  4   GP      3 non-null       object
#  5   AF      471004 non-null  object
#  6   BF      0 non-null       float64
#  7   CA      8671 non-null    object
#  8   TI      471543 non-null  object
#  9   SO      471543 non-null  object
#  10  SE      3521 non-null    object
#  11  BS      16 non-null      object
#  12  LA      471543 non-null  object
#  13  DT      471541 non-null  object
#  14  CT      24713 non-null   object
#  15  CY      24711 non-null   object
#  16  CL      24711 non-null   object
#  17  SP      23239 non-null   object
#  18  HO      566 non-null     object
#  19  DE      96472 non-null   object
#  20  ID      261715 non-null  object
#  21  AB      242397 non-null  object
#  22  C1      373494 non-null  object
#  23  C3      359633 non-null  object
#  24  RP      331391 non-null  object
#  25  EM      253613 non-null  object
#  26  RI      203698 non-null  object
#  27  OI      227639 non-null  object
#  28  FU      153440 non-null  object
#  29  FP      153312 non-null  object
#  30  FX      120232 non-null  object
#  31  CR      419572 non-null  object
#  32  NR      471540 non-null  object
#  33  TC      471541 non-null  float64
#  34  Z9      471543 non-null  int64
#  35  U1      471542 non-null  float64
#  36  U2      471528 non-null  object
#  37  PU      471530 non-null  object
#  38  PI      471529 non-null  object
#  39  PA      471527 non-null  object
#  40  SN      462420 non-null  object
#  41  EI      276234 non-null  object
#  42  BN      2335 non-null    object
#  43  J9      471543 non-null  object
#  44  JI      471020 non-null  object
#  45  PD      396585 non-null  object
#  46  PY      471531 non-null  object
#  47  VL      467556 non-null  object
#  48  IS      421957 non-null  object
#  49  PN      468 non-null     object
#  50  SU      35420 non-null   object
#  51  SI      2752 non-null    object
#  52  MA      29841 non-null   object
#  53  BP      434224 non-null  object
#  54  EP      434210 non-null  object
#  55  AR      22104 non-null   object
#  56  DI      401521 non-null  object
#  57  DL      401513 non-null  object
#  58  D2      1 non-null       object
#  59  EA      34810 non-null   object
#  60  PG      471527 non-null  object
#  61  WC      471527 non-null  object
#  62  WE      471527 non-null  object
#  63  SC      471527 non-null  object
#  64  GA      471523 non-null  object
#  65  PM      258207 non-null  object
#  66  OA      214593 non-null  object
#  67  HC      11597 non-null   object
#  68  HP      11604 non-null   object
#  69  DA      471527 non-null  object
#  70  UT      471519 non-null  object
# dtypes: float64(4), int64(1), object(66)
# memory usage: 255.4+ MB

# %%
rename_columns = {
    "FN": "File Name",
    "VR": "Version Number",
    "PT": "Publication Type", # (J=Journal; B=Book; S=Series; P=Patent)
    "AU": "Authors",
    "AF": "Author Full Name",
    "BA": "Book Authors",
    "BF": "Book Authors Full Name",
    "CA": "Group Authors",
    "GP": "Book Group Authors",
    "BE": "Editors",
    "TI": "Document Title",
    "SO": "Publication Name",
    "SE": "Book Series Title",
    "BS": "Book Series Subtitle",
    "LA": "Language",
    "DT": "Document Type",
    "CT": "Conference Title",
    "CY": "Conference Date",
    "CL": "Conference Location",
    "SP": "Conference Sponsors",
    "HO": "Conference Host",
    "DE": "Author Keywords",
    "ID": "Keywords Plus",
    "AB": "Abstract",
    "C1": "Author Address",
    "RP": "Reprint Address",
    "EM": "E-mail Address",
    "RI": "ResearcherID Number",
    "OI": "ORCID Identifier (Open Researcher and Contributor ID)",
    "FU": "Funding Agency and Grant Number",
    "FX": "Funding Text",
    "CR": "Cited References",
    "NR": "Cited Reference Count",
    "TC": "Web of Science Core Collection Times Cited Count",
    "Z9": "Total Times Cited Count",
    "U1": "Usage Count (Last 180 Days)",
    "U2": "Usage Count (Since 2013)",
    "PU": "Publisher",
    "PI": "Publisher City",
    "PA": "Publisher Address",
    "SN": "International Standard Serial Number (ISSN)",
    "EI": "Electronic International Standard Serial Number (eISSN)",
    "BN": "International Standard Book Number (ISBN)",
    "J9": "29-Character Source Abbreviation",
    "JI": "ISO Source Abbreviation",
    "PD": "Publication Date",
    "PY": "Year Published",
    "VL": "Volume",
    "IS": "Issue",
    "SI": "Special Issue",
    "PN": "Part Number",
    "SU": "Supplement",
    "MA": "Meeting Abstract",
    "BP": "Beginning Page",
    "EP": "Ending Page",
    "AR": "Article Number",
    "DI": "Digital Object Identifier (DOI)",
    "D2": "Book Digital Object Identifier (DOI)",
    "EA": "Early access date",
    "EY": "Early access year",
    "PG": "Page Count",
    "P2": "Chapter Count (Book Citation Index)",
    "WC": "Web of Science Categories",
    "SC": "Research Areas",
    "GA": "Document Delivery Number",
    "PM": "PubMed ID",
    "UT": "Accession Number",
    "OA": "Open Access Indicator",
    "HP": "ESI Hot Paper", # Note that this field is valued only for ESI subscribers.
    "HC": "ESI Highly Cited Paper", # Note that this field is valued only for ESI subscribers.
    "DA": "Date this report was generated",
    "ER": "End of Record",
    "EF": "End of File"
}

wos_rd.rename(columns = rename_columns, inplace = True)
wos_rd.columns
# Out:
# Index(['Publication Type', 'Authors', 'Book Authors', 'Editors',
#        'Book Group Authors', 'Author Full Name', 'Book Authors Full Name',
#        'Group Authors', 'Document Title', 'Publication Name',
#        'Book Series Title', 'Book Series Subtitle', 'Language',
#        'Document Type', 'Conference Title', 'Conference Date',
#        'Conference Location', 'Conference Sponsors', 'Conference Host',
#        'Author Keywords', 'Keywords Plus', 'Abstract', 'Author Address', 'C3',
#        'Reprint Address', 'E-mail Address', 'ResearcherID Number',
#        'ORCID Identifier (Open Researcher and Contributor ID)',
#        'Funding Agency and Grant Number', 'FP', 'Funding Text',
#        'Cited References', 'Cited Reference Count',
#        'Web of Science Core Collection Times Cited Count',
#        'Total Times Cited Count', 'Usage Count (Last 180 Days)',
#        'Usage Count (Since 2013)', 'Publisher', 'Publisher City',
#        'Publisher Address', 'International Standard Serial Number (ISSN)',
#        'Electronic International Standard Serial Number (eISSN)',
#        'International Standard Book Number (ISBN)',
#        '29-Character Source Abbreviation', 'ISO Source Abbreviation',
#        'Publication Date', 'Year Published', 'Volume', 'Issue', 'Part Number',
#        'Supplement', 'Special Issue', 'Meeting Abstract', 'Beginning Page',
#        'Ending Page', 'Article Number', 'Digital Object Identifier (DOI)',
#        'DL', 'Book Digital Object Identifier (DOI)', 'Early access date',
#        'Page Count', 'Web of Science Categories', 'WE', 'Research Areas',
#        'Document Delivery Number', 'PubMed ID', 'Open Access Indicator',
#        'ESI Highly Cited Paper', 'ESI Hot Paper',
#        'Date this report was generated', 'Accession Number'],
#       dtype='object')

# %%
#wos_rd.dtypes[[2,6,36,58,60,65,67,68]]

# %%
columns_to_convert = ['Usage Count (Since 2013)', 'Page Count', 'PubMed ID', 'Year Published']
new_data_types = {'Usage Count (Since 2013)': 'int64', 'Page Count': 'int64', 'PubMed ID': 'object', 'Year Published': 'int64'}

for col in columns_to_convert:
    try:
        wos_rd[col] = pd.to_numeric(wos_rd[col], errors='coerce').astype(new_data_types[col])
    except ValueError:
        wos_rd[col] = pd.to_numeric(wos_rd[col], errors='coerce')

# %%
wos_rd.describe().T
# Out:
#                                                      count         mean  \
# Book Authors                                           0.0          NaN
# Book Authors Full Name                                 0.0          NaN
# Web of Science Core Collection Times Cited Count  471541.0    75.503125
# Total Times Cited Count                           471543.0    78.089661
# Usage Count (Last 180 Days)                       471542.0     1.794612
# Usage Count (Since 2013)                          471519.0    24.878480
# Year Published                                    471529.0  2086.243048
# Page Count                                        471519.0     9.471427
#
#                                                            std  min     25%  \
# Book Authors                                               NaN  NaN     NaN
# Book Authors Full Name                                     NaN  NaN     NaN
# Web of Science Core Collection Times Cited Count    269.042517  0.0     1.0
# Total Times Cited Count                             277.848086  0.0     1.0
# Usage Count (Last 180 Days)                           8.272906  0.0     0.0
# Usage Count (Since 2013)                             89.359259  0.0     0.0
# Year Published                                    40343.100244  6.0  1996.0
# Page Count                                           20.787054  0.0     2.0
#
#                                                      50%     75%         max
# Book Authors                                         NaN     NaN         NaN
# Book Authors Full Name                               NaN     NaN         NaN
# Web of Science Core Collection Times Cited Count    17.0    73.0     57414.0
# Total Times Cited Count                             18.0    75.0     57919.0
# Usage Count (Last 180 Days)                          0.0     1.0      1933.0
# Usage Count (Since 2013)                             3.0    16.0     12137.0
# Year Published                                    2010.0  2017.0  19590850.0
# Page Count                                           7.0    13.0      7002.0

# %%
wos_rd[wos_rd.duplicated()].shape[0]
# Out:
# 71701

# %%
wos_rd['Year Published'] = np.where(wos_rd['Year Published'] < 1000, 2000, wos_rd['Year Published'])

# %%
wos_rd['Publication Date']
# Out:
# 0         DEC
# 1         SEP
# 2         JUN
# 3         JUN
# 4         APR
#          ...
# 471538    JUN
# 471539    JUN
# 471540    FEB
# 471541    JAN
# 471542    JAN
# Name: Publication Date, Length: 471543, dtype: object

# %%
wos_rd['Year Published'].astype(str).value_counts()
# Out:
# Year Published
# 2014.0        22284
# 2021.0        21154
# 2022.0        21004
# 2020.0        19100
# 2010.0        18017
#               ...
# 1903.0           20
# 1902.0           18
# nan              14
# 2024.0            8
# 19590850.0        2
# Name: count, Length: 127, dtype: int64

# %%
wos_rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 471543 entries, 0 to 471542
# Data columns (total 71 columns):
#  #   Column                                                   Non-Null Count   Dtype
# ---  ------                                                   --------------   -----
#  0   Publication Type                                         471543 non-null  object
#  1   Authors                                                  471004 non-null  object
#  2   Book Authors                                             0 non-null       float64
#  3   Editors                                                  2529 non-null    object
#  4   Book Group Authors                                       3 non-null       object
#  5   Author Full Name                                         471004 non-null  object
#  6   Book Authors Full Name                                   0 non-null       float64
#  7   Group Authors                                            8671 non-null    object
#  8   Document Title                                           471543 non-null  object
#  9   Publication Name                                         471543 non-null  object
#  10  Book Series Title                                        3521 non-null    object
#  11  Book Series Subtitle                                     16 non-null      object
#  12  Language                                                 471543 non-null  object
#  13  Document Type                                            471541 non-null  object
#  14  Conference Title                                         24713 non-null   object
#  15  Conference Date                                          24711 non-null   object
#  16  Conference Location                                      24711 non-null   object
#  17  Conference Sponsors                                      23239 non-null   object
#  18  Conference Host                                          566 non-null     object
#  19  Author Keywords                                          96472 non-null   object
#  20  Keywords Plus                                            261715 non-null  object
#  21  Abstract                                                 242397 non-null  object
#  22  Author Address                                           373494 non-null  object
#  23  C3                                                       359633 non-null  object
#  24  Reprint Address                                          331391 non-null  object
#  25  E-mail Address                                           253613 non-null  object
#  26  ResearcherID Number                                      203698 non-null  object
#  27  ORCID Identifier (Open Researcher and Contributor ID)    227639 non-null  object
#  28  Funding Agency and Grant Number                          153440 non-null  object
#  29  FP                                                       153312 non-null  object
#  30  Funding Text                                             120232 non-null  object
#  31  Cited References                                         419572 non-null  object
#  32  Cited Reference Count                                    471540 non-null  object
#  33  Web of Science Core Collection Times Cited Count         471541 non-null  float64
#  34  Total Times Cited Count                                  471543 non-null  int64
#  35  Usage Count (Last 180 Days)                              471542 non-null  float64
#  36  Usage Count (Since 2013)                                 471519 non-null  float64
#  37  Publisher                                                471530 non-null  object
#  38  Publisher City                                           471529 non-null  object
#  39  Publisher Address                                        471527 non-null  object
#  40  International Standard Serial Number (ISSN)              462420 non-null  object
#  41  Electronic International Standard Serial Number (eISSN)  276234 non-null  object
#  42  International Standard Book Number (ISBN)                2335 non-null    object
#  43  29-Character Source Abbreviation                         471543 non-null  object
#  44  ISO Source Abbreviation                                  471020 non-null  object
#  45  Publication Date                                         396585 non-null  object
#  46  Year Published                                           471529 non-null  float64
#  47  Volume                                                   467556 non-null  object
#  48  Issue                                                    421957 non-null  object
#  49  Part Number                                              468 non-null     object
#  50  Supplement                                               35420 non-null   object
#  51  Special Issue                                            2752 non-null    object
#  52  Meeting Abstract                                         29841 non-null   object
#  53  Beginning Page                                           434224 non-null  object
#  54  Ending Page                                              434210 non-null  object
#  55  Article Number                                           22104 non-null   object
#  56  Digital Object Identifier (DOI)                          401521 non-null  object
#  57  DL                                                       401513 non-null  object
#  58  Book Digital Object Identifier (DOI)                     1 non-null       object
#  59  Early access date                                        34810 non-null   object
#  60  Page Count                                               471519 non-null  float64
#  61  Web of Science Categories                                471527 non-null  object
#  62  WE                                                       471527 non-null  object
#  63  Research Areas                                           471527 non-null  object
#  64  Document Delivery Number                                 471523 non-null  object
#  65  PubMed ID                                                258199 non-null  object
#  66  Open Access Indicator                                    214593 non-null  object
#  67  ESI Highly Cited Paper                                   11597 non-null   object
#  68  ESI Hot Paper                                            11604 non-null   object
#  69  Date this report was generated                           471527 non-null  object
#  70  Accession Number                                         471519 non-null  object
# dtypes: float64(7), int64(1), object(63)
# memory usage: 255.4+ MB

# %%
wos_rd['Year Published'].fillna(2000).astype(int).astype(str).value_counts()
# Out:
# Year Published
# 2014        22284
# 2021        21154
# 2022        21004
# 2020        19100
# 2010        18017
#             ...
# 1931           37
# 1903           20
# 1902           18
# 2024            8
# 19590850        2
# Name: count, Length: 126, dtype: int64

# %%
wos_rd['Year Published'].sort_values()
# Out:
# 240226    1900.0
# 239741    1900.0
# 261973    1900.0
# 178693    1900.0
# 178888    1900.0
#            ...
# 187733       NaN
# 189215       NaN
# 190151       NaN
# 281783       NaN
# 307970       NaN
# Name: Year Published, Length: 471543, dtype: float64

# %%
wos_rd['Publication Date'].fillna('JAN', inplace=True)

wos_rd['Publication Date'] = pd.to_datetime(wos_rd['Publication Date'] + ' ' + wos_rd['Year Published'].astype(str), errors='coerce')
wos_rd['Publication Date'].fillna(pd.to_datetime('JAN 01 ' + wos_rd['Year Published'].fillna(2000).astype(int).astype(str), format='%b %d %Y'), inplace=True)

# Sort the DataFrame by DOI and 'Publication Date' in descending order
wos_rd.sort_values(by=['Digital Object Identifier (DOI)', 'Publication Date'], ascending=[True, False], inplace=True)
# Out:
# C:\Users\isabe\AppData\Local\Temp\ipykernel_26800\1594137410.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   wos_rd['Publication Date'] = pd.to_datetime(wos_rd['Publication Date'] + ' ' + wos_rd['Year Published'].astype(str), errors='coerce')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 4
#       1 wos_rd['Publication Date'].fillna('JAN', inplace=True)
#       3 wos_rd['Publication Date'] = pd.to_datetime(wos_rd['Publication Date'] + ' ' + wos_rd['Year Published'].astype(str), errors='coerce')
# ----> 4 wos_rd['Publication Date'].fillna(pd.to_datetime('JAN 01 ' + wos_rd['Year Published'].fillna(2000).astype(int).astype(str), format='%b %d %Y'), inplace=True)
#       6 # Sort the DataFrame by DOI and 'Publication Date' in descending order
#       7 wos_rd.sort_values(by=['Digital Object Identifier (DOI)', 'Publication Date'], ascending=[True, False], inplace=True)
#
# File c:\Users\isabe\Desktop\Tese\tese\lib\site-packages\pandas\core\tools\datetimes.py:1046, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1044             result = arg.tz_localize("utc")
#    1045 elif isinstance(arg, ABCSeries):
# -> 1046     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1047     if not cache_array.empty:
#    1048         result = arg.map(cache_array)
#
# File c:\Users\isabe\Desktop\Tese\tese\lib\site-packages\pandas\core\tools\datetimes.py:250, in _maybe_cache(arg, format, cache, convert_listlike)
#     248 unique_dates = unique(arg)
#     249 if len(unique_dates) < len(arg):
# --> 250     cache_dates = convert_listlike(unique_dates, format)
#     251     # GH#45319
#     252     try:
#
# File c:\Users\isabe\Desktop\Tese\tese\lib\site-packages\pandas\core\tools\datetimes.py:453, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     451 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     452 if format is not None and format != "mixed":
# --> 453     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     455 result, tz_parsed = objects_to_datetime64ns(
#     456     arg,
#     457     dayfirst=dayfirst,
#    (...)
#     461     allow_object=True,
#     462 )
#     464 if tz_parsed is not None:
#     465     # We can take a shortcut since the datetime64 numpy array
#     466     # is in UTC
#
# File c:\Users\isabe\Desktop\Tese\tese\lib\site-packages\pandas\core\tools\datetimes.py:484, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     473 def _array_strptime_with_fallback(
#     474     arg,
#     475     name,
#    (...)
#     479     errors: str,
#     480 ) -> Index:
#     481     """
#     482     Call array_strptime, with fallback behavior depending on 'errors'.
#     483     """
# --> 484     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     485     if any(tz is not None for tz in timezones):
#     486         return _return_parsed_timezone_results(result, timezones, utc, name)
#
# File c:\Users\isabe\Desktop\Tese\tese\lib\site-packages\pandas\_libs\tslibs\strptime.pyx:530, in pandas._libs.tslibs.strptime.array_strptime()
#
# File c:\Users\isabe\Desktop\Tese\tese\lib\site-packages\pandas\_libs\tslibs\strptime.pyx:355, in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: unconverted data remains when parsing with format "%b %d %Y": "0850", at position 125. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
# Check for NaN values in 'Digital Object Identifier (DOI)' column
wos_rd_filtered = wos_rd.dropna(subset=['Digital Object Identifier (DOI)'])

# Filter rows starting with "http://dx.doi.org/"
wos_rd_filtered[wos_rd_filtered['Digital Object Identifier (DOI)'].str.startswith("http://dx.doi.org/")]['Digital Object Identifier (DOI)']
# Out:
# 732       http://dx.doi.org/10.1016/j.jhydrol.2021.127122
# 3324      http://dx.doi.org/10.1016/j.jhydrol.2021.127122
# 5962     http://dx.doi.org/10.1016/j.theochem.2009.04.010
# 22123    http://dx.doi.org/10.1016/j.theochem.2009.04.010
# 2426           http://dx.doi.org/10.1021/acsomega.0c04799
# Name: Digital Object Identifier (DOI), dtype: object

# %%
wos_rd['Digital Object Identifier (DOI)'] = wos_rd['Digital Object Identifier (DOI)'].str.replace('http://dx.doi.org/', '')

# %% [markdown]
# ### Title Analysis

# %%
wos_rd[(~wos_rd['Document Title'].str.startswith("RETRACTED: ")) & (~wos_rd['Document Title'].str.contains("(Withdrawn Publication)")) & ((~wos_rd['Document Title'].str.contains("Retracted Article. See")))]
# Out:
# C:\Users\isabe\AppData\Local\Temp\ipykernel_10920\1807034496.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   wos_rd[(~wos_rd['Document Title'].str.startswith("RETRACTED: ")) & (~wos_rd['Document Title'].str.contains("(Withdrawn Publication)")) & ((~wos_rd['Document Title'].str.contains("Retracted Article. See")))]
#       Publication Type                     Authors Book Authors Editors  \
# 15076                J  Gangidi, PR; Souriyasak, N          NaN     NaN
# 14979                J           Lyu, WH; Zhang, J          NaN     NaN
#
#       Book Group Authors                          Author Full Name  \
# 15076                NaN  Gangidi, Prashant Reddy; Souriyasak, Noy
# 14979                NaN                  Lyu, Weihua; Zhang, Jian
#
#       Book Authors Full Name Group Authors  \
# 15076                    NaN           NaN
# 14979                    NaN           NaN
#
#                                           Document Title  \
# 15076  Solder Selection for Reflowing Large Ceramic S...
# 14979  The Influence of Childhood Psychological Maltr...
#
#                                         Publication Name  ...  \
# 15076         JOURNAL OF FAILURE ANALYSIS AND PREVENTION  ...
# 14979  EURASIA JOURNAL OF MATHEMATICS SCIENCE AND TEC...  ...
#
#               Web of Science Categories  \
# 15076    Engineering, Multidisciplinary
# 14979  Education & Educational Research
#
#                                            WE  \
# 15076  Emerging Sources Citation Index (ESCI)
# 14979    Social Science Citation Index (SSCI)
#
#                          Research Areas Document Delivery Number PubMed ID  \
# 15076                       Engineering                    FH4QU       NaN
# 14979  Education & Educational Research                    FO1JZ       NaN
#
#       Open Access Indicator ESI Highly Cited Paper ESI Hot Paper  \
# 15076                   NaN                    NaN           NaN
# 14979                  gold                    NaN           NaN
#
#       Date this report was generated     Accession Number
# 15076                     05/11/2023  WOS:000411144100009
# 14979                     05/11/2023  WOS:000416517000040
#
# [2 rows x 71 columns]

# %%
# Remove the Alterations to the name of the article
wos_rd['Document Title'] = wos_rd['Document Title'].str.replace('RETRACTED: ', '')
wos_rd['Document Title'] = wos_rd['Document Title'].str.replace('(Withdrawn Publication)', '')
wos_rd['Document Title'] = wos_rd['Document Title'].str.replace('(Withdrawn publication)', '')
wos_rd['Document Title'] = wos_rd['Document Title'].str.replace('</bold>', '')
wos_rd['Document Title'] = wos_rd['Document Title'].str.replace('<bold>', '')

# %%
# Some records include variations of the phrase "(Retracted article. See XX)". 
# Where XX is has variable length and characters, but always ends with ")"
def remove_retraction_phrase(title):

    # Define the pattern to match the retraction phrase
    pattern = r'\(retracted article\. see [^\)]+\)'
    return re.sub(pattern, '', str.lower(title)).strip()

# Apply the function to the 'Document Title' column
wos_rd['Document Title'] = wos_rd['Document Title'].apply(remove_retraction_phrase)

# %%
def remove_retraction_phrase(title):

    # Define the pattern to match the retraction phrase
    pattern = r'\(withdrawal of [^\)]+\)'
    return re.sub(pattern, '', str.lower(title)).strip()

# Apply the function to the 'Document Title' column
wos_rd['Document Title'] = wos_rd['Document Title'].apply(remove_retraction_phrase)

# %%
# Remove spaces at the end of the string
wos_rd['Document Title'] = wos_rd['Document Title'].str.rstrip()

# %%
#wos_rd[(~wos_rd['Document Title'].str.startswith("RETRACTED: ")) & (~wos_rd['Document Title'].str.contains("(Withdrawn Publication)"))]

# %% [markdown]
# ### Duplicates

# %%
# Replace all NaN values with a common value (e.g., a string)
wos_rd = wos_rd.fillna('This is a missing value')

# Use drop_duplicates to remove duplicates with 'NaN' values
wos_rd.drop_duplicates(inplace=True)

# Now, you can replace the 'NaN' values with NaN again if needed
wos_rd = wos_rd.replace('This is a missing value', np.nan)

# %%
wos_rd[wos_rd.duplicated(subset='Digital Object Identifier (DOI)', keep=False)].shape
# Out:
# (531, 71)

# %%
wos_rd['Digital Object Identifier (DOI)'].nunique()
# Out:
# 12335

# %%
wos_rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12858 entries, 13322 to 23067
# Data columns (total 71 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Publication Type                                         12858 non-null  object
#  1   Authors                                                  12856 non-null  object
#  2   Book Authors                                             43 non-null     object
#  3   Editors                                                  1244 non-null   object
#  4   Book Group Authors                                       714 non-null    object
#  5   Author Full Name                                         12856 non-null  object
#  6   Book Authors Full Name                                   43 non-null     object
#  7   Group Authors                                            30 non-null     object
#  8   Document Title                                           12858 non-null  object
#  9   Publication Name                                         12858 non-null  object
#  10  Book Series Title                                        1261 non-null   object
#  11  Book Series Subtitle                                     0 non-null      float64
#  12  Language                                                 12858 non-null  object
#  13  Document Type                                            12858 non-null  object
#  14  Conference Title                                         2190 non-null   object
#  15  Conference Date                                          2190 non-null   object
#  16  Conference Location                                      2190 non-null   object
#  17  Conference Sponsors                                      1968 non-null   object
#  18  Conference Host                                          107 non-null    object
#  19  Author Keywords                                          9427 non-null   object
#  20  Keywords Plus                                            10141 non-null  object
#  21  Abstract                                                 12456 non-null  object
#  22  Author Address                                           12744 non-null  object
#  23  C3                                                       11719 non-null  object
#  24  Reprint Address                                          12608 non-null  object
#  25  E-mail Address                                           12134 non-null  object
#  26  ResearcherID Number                                      5320 non-null   object
#  27  ORCID Identifier (Open Researcher and Contributor ID)    4515 non-null   object
#  28  Funding Agency and Grant Number                          5245 non-null   object
#  29  FP                                                       5229 non-null   object
#  30  Funding Text                                             4839 non-null   object
#  31  Cited References                                         12763 non-null  object
#  32  Cited Reference Count                                    12858 non-null  int64
#  33  Web of Science Core Collection Times Cited Count         12858 non-null  int64
#  34  Total Times Cited Count                                  12858 non-null  int64
#  35  Usage Count (Last 180 Days)                              12858 non-null  int64
#  36  Usage Count (Since 2013)                                 12855 non-null  float64
#  37  Publisher                                                12858 non-null  object
#  38  Publisher City                                           12858 non-null  object
#  39  Publisher Address                                        12858 non-null  object
#  40  International Standard Serial Number (ISSN)              11329 non-null  object
#  41  Electronic International Standard Serial Number (eISSN)  8824 non-null   object
#  42  International Standard Book Number (ISBN)                1243 non-null   object
#  43  29-Character Source Abbreviation                         12104 non-null  object
#  44  ISO Source Abbreviation                                  10843 non-null  object
#  45  Publication Date                                         12858 non-null  datetime64[ns]
#  46  Year Published                                           12858 non-null  int64
#  47  Volume                                                   11547 non-null  object
#  48  Issue                                                    8268 non-null   object
#  49  Part Number                                              242 non-null    object
#  50  Supplement                                               136 non-null    object
#  51  Special Issue                                            217 non-null    object
#  52  Meeting Abstract                                         30 non-null     object
#  53  Beginning Page                                           10037 non-null  object
#  54  Ending Page                                              10036 non-null  object
#  55  Article Number                                           2251 non-null   object
#  56  Digital Object Identifier (DOI)                          12343 non-null  object
#  57  DL                                                       12340 non-null  object
#  58  Book Digital Object Identifier (DOI)                     2 non-null      object
#  59  Early access date                                        771 non-null    object
#  60  Page Count                                               12855 non-null  float64
#  61  Web of Science Categories                                12858 non-null  object
#  62  WE                                                       12858 non-null  object
#  63  Research Areas                                           12858 non-null  object
#  64  Document Delivery Number                                 12856 non-null  object
#  65  PubMed ID                                                7406 non-null   float64
#  66  Open Access Indicator                                    6192 non-null   object
#  67  ESI Highly Cited Paper                                   1 non-null      object
#  68  ESI Hot Paper                                            4 non-null      object
#  69  Date this report was generated                           12858 non-null  object
#  70  Accession Number                                         12855 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(5), object(61)
# memory usage: 7.1+ MB

# %%
#wos_rd.iloc[[2,6,36,58,60,65,67,68]]

# %%
wos_rd['Digital Object Identifier (DOI)'].value_counts()
# Out:
# Digital Object Identifier (DOI)
# 10.1016/j.anbehav.2009.11.027    2
# 10.1109/EEM.2015.7216687         2
# 10.1007/s10735-016-9659-2        2
# 10.1021/acsomega.1c02942         2
# 10.1088/1402-4896/aa6e8b         2
#                                 ..
# 10.1016/j.micpro.2020.103683     1
# 10.1016/j.micpro.2020.103688     1
# 10.1016/j.micpro.2020.103689     1
# 10.1016/j.micpro.2020.103691     1
# 10.1021/acsomega.0c04799         1
# Name: count, Length: 12335, dtype: int64

# %%
wos_rd.shape
# Out:
# (12858, 71)

# %%
wos_rd[wos_rd.duplicated(subset='Digital Object Identifier (DOI)', keep=False)]
# Out:
#       Publication Type                                            Authors  \
# 13875                J  Gao, SM; Cheng, C; Chen, HW; Li, M; Liu, KH; W...
# 13876                J  Gao, SM; Cheng, C; Chen, HW; Li, M; Liu, KH; W...
# 6906                 J  Fernández-Gil, A; Swenson, JE; Granda, C; Pére...
# 7068                 J  Fernández-Gil, A; Swenson, JE; Granda, C; Pére...
# 14544                J                Iwamoto, J; Takeda, T; Matsumoto, H
# ...                ...                                                ...
# 2377                 J       BOLDT, J; KLING, D; DAPPER, F; HEMPELMANN, G
# 2325                 J  BOLDT, J; KLING, D; VONBORMANN, B; ZUGE, M; SC...
# 11636                J  BOLDT, J; VONBORMANN, B; KLING, D; BORNER, U; ...
# 23516                J  GLUECK, CJ; MELLIES, MJ; DINE, M; PERRY, T; LA...
# 23067                J                                      NINNEMANN, JL
#
#       Book Authors Editors Book Group Authors  \
# 13875          NaN     NaN                NaN
# 13876          NaN     NaN                NaN
# 6906           NaN     NaN                NaN
# 7068           NaN     NaN                NaN
# 14544          NaN     NaN                NaN
# ...            ...     ...                ...
# 2377           NaN     NaN                NaN
# 2325           NaN     NaN                NaN
# 11636          NaN     NaN                NaN
# 23516          NaN     NaN                NaN
# 23067          NaN     NaN                NaN
#
#                                         Author Full Name  \
# 13875  Gao, Shuming; Cheng, Cai; Chen, Hanwen; Li, Mi...
# 13876  Gao, Shuming; Cheng, Cai; Chen, Hanwen; Li, Mi...
# 6906   Fernandez-Gil, Alberto; Swenson, Jon E.; Grand...
# 7068   Fernandez-Gil, Alberto; Swenson, Jon E.; Grand...
# 14544             Iwamoto, J.; Takeda, T.; Matsumoto, H.
# ...                                                  ...
# 2377        BOLDT, J; KLING, D; DAPPER, F; HEMPELMANN, G
# 2325   BOLDT, J; KLING, D; VONBORMANN, B; ZUGE, M; SC...
# 11636  BOLDT, J; VONBORMANN, B; KLING, D; BORNER, U; ...
# 23516  GLUECK, CJ; MELLIES, MJ; DINE, M; PERRY, T; LA...
# 23067                                      NINNEMANN, JL
#
#       Book Authors Full Name Group Authors  \
# 13875                    NaN           NaN
# 13876                    NaN           NaN
# 6906                     NaN           NaN
# 7068                     NaN           NaN
# 14544                    NaN           NaN
# ...                      ...           ...
# 2377                     NaN           NaN
# 2325                     NaN           NaN
# 11636                    NaN           NaN
# 23516                    NaN           NaN
# 23067                    NaN           NaN
#
#                                           Document Title  \
# 13875  igf1 3′utr functions as a cerna in promoting a...
# 13876  igf1 3'utr functions as a cerna in promoting a...
# 6906   evidence of sexually selected infanticide in a...
# 7068   evidence of sexually selected infanticide in a...
# 14544  efficacy of risedronate against hip fracture i...
# ...                                                  ...
# 2377   myocardial temperature during cardiac operatio...
# 2325   blood conservation in cardiac operations - cel...
# 11636  volume replacement with a new hydroxyethylstar...
# 23516  safety and efficacy of long-term diet and diet...
# 23067  melanoma-associated immunosuppression through ...
#
#                                      Publication Name  ...  \
# 13875                  JOURNAL OF MOLECULAR HISTOLOGY  ...
# 13876                  JOURNAL OF MOLECULAR HISTOLOGY  ...
# 6906                                 ANIMAL BEHAVIOUR  ...
# 7068                                 ANIMAL BEHAVIOUR  ...
# 14544                                            BONE  ...
# ...                                               ...  ...
# 2377   JOURNAL OF THORACIC AND CARDIOVASCULAR SURGERY  ...
# 2325   JOURNAL OF THORACIC AND CARDIOVASCULAR SURGERY  ...
# 11636       INFUSIONSTHERAPIE UND KLINISCHE ERNAHRUNG  ...
# 23516                                      PEDIATRICS  ...
# 23067                           JOURNAL OF IMMUNOLOGY  ...
#
#                                Web of Science Categories  \
# 13875                                       Cell Biology
# 13876                                       Cell Biology
# 6906                        Behavioral Sciences; Zoology
# 7068                        Behavioral Sciences; Zoology
# 14544                         Endocrinology & Metabolism
# ...                                                  ...
# 2377   Cardiac & Cardiovascular Systems; Respiratory ...
# 2325   Cardiac & Cardiovascular Systems; Respiratory ...
# 11636                       Medicine, General & Internal
# 23516                                         Pediatrics
# 23067                                         Immunology
#
#                                                       WE  \
# 13875     Science Citation Index Expanded (SCI-EXPANDED)
# 13876     Science Citation Index Expanded (SCI-EXPANDED)
# 6906      Science Citation Index Expanded (SCI-EXPANDED)
# 7068      Science Citation Index Expanded (SCI-EXPANDED)
# 14544  Science Citation Index Expanded (SCI-EXPANDED)...
# ...                                                  ...
# 2377      Science Citation Index Expanded (SCI-EXPANDED)
# 2325      Science Citation Index Expanded (SCI-EXPANDED)
# 11636     Science Citation Index Expanded (SCI-EXPANDED)
# 23516     Science Citation Index Expanded (SCI-EXPANDED)
# 23067     Science Citation Index Expanded (SCI-EXPANDED)
#
#                                           Research Areas  \
# 13875                                       Cell Biology
# 13876                                       Cell Biology
# 6906                        Behavioral Sciences; Zoology
# 7068                        Behavioral Sciences; Zoology
# 14544                         Endocrinology & Metabolism
# ...                                                  ...
# 2377   Cardiovascular System & Cardiology; Respirator...
# 2325   Cardiovascular System & Cardiology; Respirator...
# 11636                        General & Internal Medicine
# 23516                                         Pediatrics
# 23067                                         Immunology
#
#       Document Delivery Number  PubMed ID Open Access Indicator  \
# 13875                    VL7MI        NaN                   NaN
# 13876                    DH9MA        NaN                   NaN
# 6906                     548SJ        NaN                   NaN
# 7068                     548SJ        NaN                   NaN
# 14544                    436SP        NaN                   NaN
# ...                        ...        ...                   ...
# 2377                     EC910  2214832.0                   NaN
# 2325                     AA700  2786116.0                   NaN
# 11636                    D1812  2427448.0                   NaN
# 23516                    D4187  3526270.0                   NaN
# 23067                    EZ986   307018.0                   NaN
#
#       ESI Highly Cited Paper ESI Hot Paper Date this report was generated  \
# 13875                    NaN           NaN                     05/11/2023
# 13876                    NaN           NaN                     05/11/2023
# 6906                     NaN           NaN                     05/11/2023
# 7068                     NaN           NaN                     05/11/2023
# 14544                    NaN           NaN                     05/11/2023
# ...                      ...           ...                            ...
# 2377                     NaN           NaN                     05/11/2023
# 2325                     NaN           NaN                     05/11/2023
# 11636                    NaN           NaN                     05/11/2023
# 23516                    NaN           NaN                     05/11/2023
# 23067                    NaN           NaN                     05/11/2023
#
#           Accession Number
# 13875  WOS:000908834400001
# 13876  WOS:000373119000006
# 6906   WOS:000273986300034
# 7068   WOS:000273986300034
# 14544  WOS:000265436200053
# ...                    ...
# 2377   WOS:A1990EC91000010
# 2325   WOS:A1989AA70000004
# 11636  WOS:A1986D181200006
# 23516  WOS:A1986D418700025
# 23067  WOS:A1978EZ98600022
#
# [531 rows x 71 columns]

# %%
testing_dupes = wos_rd[wos_rd.duplicated(subset='Digital Object Identifier (DOI)', keep=False)]
testing_dupes['Digital Object Identifier (DOI)'].value_counts()
# Out:
# Digital Object Identifier (DOI)
# 10.1007/s10735-016-9659-2        2
# 10.1016/j.anbehav.2009.11.027    2
# 10.1016/j.bone.2009.01.095       2
# 10.1021/acsomega.1c02942         2
# 10.1088/1402-4896/aa6e8b         2
# 10.1093/icc/dtq041               2
# 10.1109/EEM.2015.7216687         2
# 10.1109/NISS.2009.21             2
# Name: count, dtype: int64

# %%
unique_counts = testing_dupes[testing_dupes['Digital Object Identifier (DOI)']=='10.1093/aje/kwq207'].nunique()
unique_counts[unique_counts > 1].index
# Out:
# Index([], dtype='object')

# %%
wos_rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12858 entries, 13322 to 23067
# Data columns (total 71 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Publication Type                                         12858 non-null  object
#  1   Authors                                                  12856 non-null  object
#  2   Book Authors                                             43 non-null     object
#  3   Editors                                                  1244 non-null   object
#  4   Book Group Authors                                       714 non-null    object
#  5   Author Full Name                                         12856 non-null  object
#  6   Book Authors Full Name                                   43 non-null     object
#  7   Group Authors                                            30 non-null     object
#  8   Document Title                                           12858 non-null  object
#  9   Publication Name                                         12858 non-null  object
#  10  Book Series Title                                        1261 non-null   object
#  11  Book Series Subtitle                                     0 non-null      float64
#  12  Language                                                 12858 non-null  object
#  13  Document Type                                            12858 non-null  object
#  14  Conference Title                                         2190 non-null   object
#  15  Conference Date                                          2190 non-null   object
#  16  Conference Location                                      2190 non-null   object
#  17  Conference Sponsors                                      1968 non-null   object
#  18  Conference Host                                          107 non-null    object
#  19  Author Keywords                                          9427 non-null   object
#  20  Keywords Plus                                            10141 non-null  object
#  21  Abstract                                                 12456 non-null  object
#  22  Author Address                                           12744 non-null  object
#  23  C3                                                       11719 non-null  object
#  24  Reprint Address                                          12608 non-null  object
#  25  E-mail Address                                           12134 non-null  object
#  26  ResearcherID Number                                      5320 non-null   object
#  27  ORCID Identifier (Open Researcher and Contributor ID)    4515 non-null   object
#  28  Funding Agency and Grant Number                          5245 non-null   object
#  29  FP                                                       5229 non-null   object
#  30  Funding Text                                             4839 non-null   object
#  31  Cited References                                         12763 non-null  object
#  32  Cited Reference Count                                    12858 non-null  int64
#  33  Web of Science Core Collection Times Cited Count         12858 non-null  int64
#  34  Total Times Cited Count                                  12858 non-null  int64
#  35  Usage Count (Last 180 Days)                              12858 non-null  int64
#  36  Usage Count (Since 2013)                                 12855 non-null  float64
#  37  Publisher                                                12858 non-null  object
#  38  Publisher City                                           12858 non-null  object
#  39  Publisher Address                                        12858 non-null  object
#  40  International Standard Serial Number (ISSN)              11329 non-null  object
#  41  Electronic International Standard Serial Number (eISSN)  8824 non-null   object
#  42  International Standard Book Number (ISBN)                1243 non-null   object
#  43  29-Character Source Abbreviation                         12104 non-null  object
#  44  ISO Source Abbreviation                                  10843 non-null  object
#  45  Publication Date                                         12858 non-null  datetime64[ns]
#  46  Year Published                                           12858 non-null  int64
#  47  Volume                                                   11547 non-null  object
#  48  Issue                                                    8268 non-null   object
#  49  Part Number                                              242 non-null    object
#  50  Supplement                                               136 non-null    object
#  51  Special Issue                                            217 non-null    object
#  52  Meeting Abstract                                         30 non-null     object
#  53  Beginning Page                                           10037 non-null  object
#  54  Ending Page                                              10036 non-null  object
#  55  Article Number                                           2251 non-null   object
#  56  Digital Object Identifier (DOI)                          12343 non-null  object
#  57  DL                                                       12340 non-null  object
#  58  Book Digital Object Identifier (DOI)                     2 non-null      object
#  59  Early access date                                        771 non-null    object
#  60  Page Count                                               12855 non-null  float64
#  61  Web of Science Categories                                12858 non-null  object
#  62  WE                                                       12858 non-null  object
#  63  Research Areas                                           12858 non-null  object
#  64  Document Delivery Number                                 12856 non-null  object
#  65  PubMed ID                                                7406 non-null   float64
#  66  Open Access Indicator                                    6192 non-null   object
#  67  ESI Highly Cited Paper                                   1 non-null      object
#  68  ESI Hot Paper                                            4 non-null      object
#  69  Date this report was generated                           12858 non-null  object
#  70  Accession Number                                         12855 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(5), object(61)
# memory usage: 7.1+ MB

# %%
# number of different values per DOI
aux = testing_dupes.groupby('Digital Object Identifier (DOI)').nunique()

# number of variables that differ for each DOI
aux.gt(1).sum(axis=1).sort_values()
# Out:
# Digital Object Identifier (DOI)
# 10.1016/j.anbehav.2009.11.027     1
# 10.1016/j.bone.2009.01.095        1
# 10.1088/1402-4896/aa6e8b          1
# 10.1093/icc/dtq041                1
# 10.1007/s10735-016-9659-2         7
# 10.1021/acsomega.1c02942          8
# 10.1109/EEM.2015.7216687         13
# 10.1109/NISS.2009.21             13
# dtype: int64

# %%
# variables that differ in duplicates
aux.columns[aux.max() > 1]
# Out:
# Index(['Document Title', 'Publication Name', 'Conference Title',
#        'Conference Date', 'Conference Location', 'Keywords Plus', 'Abstract',
#        'Author Address', 'C3', 'Reprint Address', 'Cited References',
#        'Cited Reference Count', 'Usage Count (Since 2013)',
#        'International Standard Book Number (ISBN)', 'Meeting Abstract',
#        'Beginning Page', 'Article Number', 'Page Count',
#        'Web of Science Categories', 'Research Areas',
#        'Document Delivery Number', 'Accession Number'],
#       dtype='object')

# %% [markdown]
# From the list of variables that were listed above as having different values for the same DOI, only the variables that are going to be necessary in the methodology will be individually inspected. That includes the following:
# - 'Document Title'
# - 'Keywords Plus'
# - 'Abstract'
# - 'C3'
# - 'Cited References'
# - 'Cited Reference Count'
# - 'Article Number'
# - 'Web of Science Categories'
# - 'Research Areas'

# %%
variable = 'Document Title'
pd.set_option('display.max_colwidth', None)  # Show full content of columns
pd.set_option('display.max_rows', None)      # Display all rows
testing_dupes.groupby('Digital Object Identifier (DOI)').filter(lambda x: x[variable].nunique() > 1)[variable]
# Out:
# 13875    igf1 3′utr functions as a cerna in promoting angiogenesis by sponging mir-29 family in osteosarcoma
# 13876    igf1 3'utr functions as a cerna in promoting angiogenesis by sponging mir-29 family in osteosarcoma
# Name: Document Title, dtype: object

# %%
# Since it is a formatting issue, the text will be formatted the same
wos_rd.at[13875, 'Document Title'] = wos_rd.at[13876, 'Document Title']

# %%
pd.reset_option('display.max_colwidth')
pd.reset_option('display.max_rows')

# %%
variable = 'Abstract'
testing_dupes.groupby('Digital Object Identifier (DOI)').filter(lambda x: x[variable].nunique() > 1)[['Digital Object Identifier (DOI)',variable]].sort_values('Digital Object Identifier (DOI)')
# Out:
#       Digital Object Identifier (DOI)  \
# 13875       10.1007/s10735-016-9659-2
# 13876       10.1007/s10735-016-9659-2
# 3382         10.1021/acsomega.1c02942
# 3383         10.1021/acsomega.1c02942
# 12103        10.1109/EEM.2015.7216687
# 12299        10.1109/EEM.2015.7216687
#
#                                                 Abstract
# 13875  Osteosarcoma is one of the most common maligna...
# 13876  Osteosarcoma is one of the most common maligna...
# 3382   The physicochemical approaches and biological ...
# 3383   The physicochemical approaches and biological ...
# 12103  Demand response has been identified as a solut...
# 12299  Demand response has been identified as a solut...

# %%
wos_rd.at[13875, 'Abstract'] = wos_rd.at[13876, 'Abstract']
wos_rd.at[3383, 'Abstract'] = wos_rd.at[3382, 'Abstract']
wos_rd.at[12103, 'Abstract'] = wos_rd.at[12299, 'Abstract']

# %%
variable = 'C3'
testing_dupes.groupby('Digital Object Identifier (DOI)').filter(lambda x: x[variable].nunique() > 1)[['Digital Object Identifier (DOI)',variable]].sort_values('Digital Object Identifier (DOI)')
# Out:
#       Digital Object Identifier (DOI)  \
# 22201            10.1109/NISS.2009.21
# 22581            10.1109/NISS.2009.21
#
#                                                       C3
# 22201  Beijing University of Posts & Telecommunicatio...
# 22581   Beijing University of Posts & Telecommunications

# %%
wos_rd.at[22581, 'C3'] = wos_rd.at[22201, 'C3']

# %%
variable = 'Cited Reference Count' #'Cited References'
testing_dupes.groupby('Digital Object Identifier (DOI)').filter(lambda x: x[variable].nunique() > 1)[['Digital Object Identifier (DOI)',variable]].sort_values('Digital Object Identifier (DOI)')
# Out:
#       Digital Object Identifier (DOI)  Cited Reference Count
# 3382         10.1021/acsomega.1c02942                    105
# 3383         10.1021/acsomega.1c02942                    101
# 12103        10.1109/EEM.2015.7216687                     14
# 12299        10.1109/EEM.2015.7216687                     15

# %%
variable = 'Web of Science Categories'
testing_dupes.groupby('Digital Object Identifier (DOI)').filter(lambda x: x[variable].nunique() > 1)[['Digital Object Identifier (DOI)',variable]].sort_values('Digital Object Identifier (DOI)')
# Out:
#       Digital Object Identifier (DOI)  \
# 12103        10.1109/EEM.2015.7216687
# 12299        10.1109/EEM.2015.7216687
# 22201            10.1109/NISS.2009.21
# 22581            10.1109/NISS.2009.21
#
#                                Web of Science Categories
# 12103               Engineering, Electrical & Electronic
# 12299  Energy & Fuels; Engineering, Electrical & Elec...
# 22201  Computer Science, Information Systems; Compute...
# 22581  Engineering, Electrical & Electronic; Telecomm...

# %%
#wos_rd.at[12103, 'Web of Science Categories'] = wos_rd.at[12299, 'Web of Science Categories']

# %%
variable = 'Article Number' 
testing_dupes.groupby('Digital Object Identifier (DOI)').filter(lambda x: x[variable].nunique() > 1)[['Digital Object Identifier (DOI)',variable]].sort_values('Digital Object Identifier (DOI)')
# Out:
#       Digital Object Identifier (DOI) Article Number
# 15151        10.1088/1402-4896/aa6e8b         064004
# 23406        10.1088/1402-4896/aa6e8b          64004

# %%
wos_rd.at[23406, 'Article Number'] = wos_rd.at[15151, 'Article Number']

# %%
variable = 'Research Areas'
testing_dupes.groupby('Digital Object Identifier (DOI)').filter(lambda x: x[variable].nunique() > 1)[['Digital Object Identifier (DOI)',variable]].sort_values('Digital Object Identifier (DOI)')
# Out:
#       Digital Object Identifier (DOI)                   Research Areas
# 12103        10.1109/EEM.2015.7216687                      Engineering
# 12299        10.1109/EEM.2015.7216687      Energy & Fuels; Engineering
# 22201            10.1109/NISS.2009.21    Computer Science; Engineering
# 22581            10.1109/NISS.2009.21  Engineering; Telecommunications

# %%
testing_dupes.groupby('Digital Object Identifier (DOI)').nunique()
# Out:
#                                  Publication Type  Authors  Book Authors  \
# Digital Object Identifier (DOI)
# 10.1007/s10735-016-9659-2                       1        1             0
# 10.1016/j.anbehav.2009.11.027                   1        1             0
# 10.1016/j.bone.2009.01.095                      1        1             0
# 10.1021/acsomega.1c02942                        1        1             0
# 10.1088/1402-4896/aa6e8b                        1        1             0
# 10.1093/icc/dtq041                              1        1             0
# 10.1109/EEM.2015.7216687                        1        1             0
# 10.1109/NISS.2009.21                            1        1             0
#
#                                  Editors  Book Group Authors  \
# Digital Object Identifier (DOI)
# 10.1007/s10735-016-9659-2              0                   0
# 10.1016/j.anbehav.2009.11.027          0                   0
# 10.1016/j.bone.2009.01.095             0                   0
# 10.1021/acsomega.1c02942               0                   0
# 10.1088/1402-4896/aa6e8b               0                   0
# 10.1093/icc/dtq041                     0                   0
# 10.1109/EEM.2015.7216687               0                   1
# 10.1109/NISS.2009.21                   0                   1
#
#                                  Author Full Name  Book Authors Full Name  \
# Digital Object Identifier (DOI)
# 10.1007/s10735-016-9659-2                       1                       0
# 10.1016/j.anbehav.2009.11.027                   1                       0
# 10.1016/j.bone.2009.01.095                      1                       0
# 10.1021/acsomega.1c02942                        1                       0
# 10.1088/1402-4896/aa6e8b                        1                       0
# 10.1093/icc/dtq041                              1                       0
# 10.1109/EEM.2015.7216687                        1                       0
# 10.1109/NISS.2009.21                            1                       0
#
#                                  Group Authors  Document Title  \
# Digital Object Identifier (DOI)
# 10.1007/s10735-016-9659-2                    0               2
# 10.1016/j.anbehav.2009.11.027                0               1
# 10.1016/j.bone.2009.01.095                   0               1
# 10.1021/acsomega.1c02942                     0               1
# 10.1088/1402-4896/aa6e8b                     0               1
# 10.1093/icc/dtq041                           0               1
# 10.1109/EEM.2015.7216687                     0               1
# 10.1109/NISS.2009.21                         0               1
#
#                                  Publication Name  ...  \
# Digital Object Identifier (DOI)                    ...
# 10.1007/s10735-016-9659-2                       1  ...
# 10.1016/j.anbehav.2009.11.027                   1  ...
# 10.1016/j.bone.2009.01.095                      1  ...
# 10.1021/acsomega.1c02942                        1  ...
# 10.1088/1402-4896/aa6e8b                        1  ...
# 10.1093/icc/dtq041                              1  ...
# 10.1109/EEM.2015.7216687                        2  ...
# 10.1109/NISS.2009.21                            2  ...
#
#                                  Web of Science Categories  WE  \
# Digital Object Identifier (DOI)
# 10.1007/s10735-016-9659-2                                1   1
# 10.1016/j.anbehav.2009.11.027                            1   1
# 10.1016/j.bone.2009.01.095                               1   1
# 10.1021/acsomega.1c02942                                 1   1
# 10.1088/1402-4896/aa6e8b                                 1   1
# 10.1093/icc/dtq041                                       1   1
# 10.1109/EEM.2015.7216687                                 2   1
# 10.1109/NISS.2009.21                                     2   1
#
#                                  Research Areas  Document Delivery Number  \
# Digital Object Identifier (DOI)
# 10.1007/s10735-016-9659-2                     1                         2
# 10.1016/j.anbehav.2009.11.027                 1                         1
# 10.1016/j.bone.2009.01.095                    1                         1
# 10.1021/acsomega.1c02942                      1                         2
# 10.1088/1402-4896/aa6e8b                      1                         1
# 10.1093/icc/dtq041                            1                         1
# 10.1109/EEM.2015.7216687                      2                         2
# 10.1109/NISS.2009.21                          2                         2
#
#                                  PubMed ID  Open Access Indicator  \
# Digital Object Identifier (DOI)
# 10.1007/s10735-016-9659-2                0                      0
# 10.1016/j.anbehav.2009.11.027            0                      0
# 10.1016/j.bone.2009.01.095               0                      0
# 10.1021/acsomega.1c02942                 0                      1
# 10.1088/1402-4896/aa6e8b                 0                      0
# 10.1093/icc/dtq041                       0                      0
# 10.1109/EEM.2015.7216687                 0                      0
# 10.1109/NISS.2009.21                     0                      0
#
#                                  ESI Highly Cited Paper  ESI Hot Paper  \
# Digital Object Identifier (DOI)
# 10.1007/s10735-016-9659-2                             0              0
# 10.1016/j.anbehav.2009.11.027                         0              0
# 10.1016/j.bone.2009.01.095                            0              0
# 10.1021/acsomega.1c02942                              0              0
# 10.1088/1402-4896/aa6e8b                              0              0
# 10.1093/icc/dtq041                                    0              0
# 10.1109/EEM.2015.7216687                              0              0
# 10.1109/NISS.2009.21                                  0              0
#
#                                  Date this report was generated  \
# Digital Object Identifier (DOI)
# 10.1007/s10735-016-9659-2                                     1
# 10.1016/j.anbehav.2009.11.027                                 1
# 10.1016/j.bone.2009.01.095                                    1
# 10.1021/acsomega.1c02942                                      1
# 10.1088/1402-4896/aa6e8b                                      1
# 10.1093/icc/dtq041                                            1
# 10.1109/EEM.2015.7216687                                      1
# 10.1109/NISS.2009.21                                          1
#
#                                  Accession Number
# Digital Object Identifier (DOI)
# 10.1007/s10735-016-9659-2                       2
# 10.1016/j.anbehav.2009.11.027                   1
# 10.1016/j.bone.2009.01.095                      1
# 10.1021/acsomega.1c02942                        2
# 10.1088/1402-4896/aa6e8b                        1
# 10.1093/icc/dtq041                              1
# 10.1109/EEM.2015.7216687                        2
# 10.1109/NISS.2009.21                            2
#
# [8 rows x 70 columns]

# %%
# Keep only the first occurrence of each unique DOI (the most recent date)
filtered_wos = wos_rd.drop_duplicates(subset='Digital Object Identifier (DOI)')

# %% [markdown]
# <div class="alert alert-block alert-info" style = "background:#d0de6f; color:#000000; border:0;">
#
# # Chapter 2 - Merge Data <a class="anchor" id="chapter2"></a>

# %% [markdown]
# <a class="anchor">
#
# ## 2.1 -Retractions Data (RW+Wos_rd) <a class="anchor" id="section_4_1"></a>

# %%
filtered_rw.shape
#filtered_wos.shape
# Out:
# (36847, 20)

# %%
test = filtered_rw.merge(filtered_wos, how= 'inner', left_on= 'OriginalPaperDOI', right_on= 'Digital Object Identifier (DOI)')
test
# Out:
#       Record ID                                              Title  \
# 0          5729  The prevention of hip fracture with risedronat...
# 1          5728  Risedronate sodium therapy for prevention of h...
# 2           895  The Relation Between Pulse Pressure and Cardio...
# 3           938  A Randomized Clinical Trial of a Single Dose o...
# 4         14089               Can Branding Improve School Lunches?
# ...         ...                                                ...
# 9707      37586  Birth Weight Predicts Anthropometric and Body ...
# 9708      21244  The seasonal reproduction number of dengue fev...
# 9709      18340  Evaluation of Impact of Pregnancy on Oral Heal...
# 9710      30813  Correlation Curve Correction and Spinal Length...
# 9711       8591  CD117 immunohistochemical expression correlate...
#
#                                                 Subject  \
# 0     (HSC) Medicine - Geriatric;(HSC) Medicine - Ne...
# 1     (HSC) Medicine - Neurology;(HSC) Medicine - Re...
# 2     (HSC) Biostatistics/Epidemiology;(HSC) Medicin...
# 3     (HSC) Medicine - Ophthalmology;(HSC) Medicine ...
# 4     (B/T) Business - Marketing;(BLS) Nutrition;(SO...
# ...                                                 ...
# 9707                          (HSC) Medicine - General;
# 9708  (ENV) Climatology;(HSC) Biostatistics/Epidemio...
# 9709  (HSC) Medicine - Dentistry;(HSC) Medicine - Ob...
# 9710  (HSC) Biostatistics/Epidemiology;(HSC) Medicin...
# 9711  (BLS) Biochemistry;(HSC) Medicine - Immunology...
#
#                                             Institution  \
# 0     Department of Neurology, Mitate Hospital, Taga...
# 1     Department of Neurology, Mitate Hospital, Taga...
# 2     Department of Dietetics and Nutrition, Harokop...
# 3     Department of Anesthesiology, Toride Kyodo Gen...
# 4     Charles H. Dyson School of Applied Economics a...
# ...                                                 ...
# 9707  Medicine Department, The Royal Hospital, Musca...
# 9708  Department of Mathematics, Faculty of Science,...
# 9709  Department of Public Health Dentistry, Governm...
# 9710  Department of Orthopaedic, Bone and Joint Reco...
# 9711  Surgical oncology, Instituto Nacional de Cance...
#
#                                                 Journal  \
# 0                         Archives of Internal Medicine
# 1                         Archives of Internal Medicine
# 2                                JAMA Internal Medicine
# 3                                    JAMA Ophthalmology
# 4                                       JAMA Pediatrics
# ...                                                 ...
# 9707    Journal of Obesity & Metabolic Syndrome (JOMES)
# 9708                                              PeerJ
# 9709  Journal of Clinical and Diagnostic Research (J...
# 9710  Journal of Clinical and Diagnostic Research (J...
# 9711                       Iranian Journal of Pathology
#
#                                   Publisher_x  \
# 0                                JAMA Network
# 1                                JAMA Network
# 2                                JAMA Network
# 3                American Medical Association
# 4                                JAMA Network
# ...                                       ...
# 9707  Korean Society for the Study of Obesity
# 9708                                    PeerJ
# 9709   JCDR Research and Publications Limited
# 9710   JCDR Research and Publications Limited
# 9711             Iranian Society of Pathology
#
#                                                 Country  \
# 0                                                 Japan
# 1                                                 Japan
# 2     Finland;Greece;Italy;Japan;Netherlands;Serbia;...
# 3                                                 Japan
# 4                                         United States
# ...                                                 ...
# 9707                          Oman;United Arab Emirates
# 9708                                           Thailand
# 9709                               India;Nepal;Pakistan
# 9710                                               Iran
# 9711                                             Mexico
#
#                                                  Author  \
# 0     Yoshihiro Sato;Tomohiro Kanoko;Kei Satoh;Jun I...
# 1            Yoshihiro Sato;Jun Iwamoto;Tomohiro Kanoko
# 2     Demosthenes B Panagiotakos;Daan Kromhout;Aless...
# 3          Yoshitaka Fujii;Hiroyoshi Tanaka;Mutsuko Ito
# 4             Brian Wansink;David R Just;Collin R Payne
# ...                                                 ...
# 9707                         Issa Al Salmi;Suad Hannawi
# 9708                                 Sittisede Polwiang
# 9709       Aasim Farooq Shah;Manu Batra;Ambrina Qureshi
# 9710  Hasan Ghandhari;Mir Bahram Safari;Ebrahim Amer...
# 9711  Rosa A Salcedo-HernÃ¡ndez;Leonardo S Lino-Silv...
#
#                                                    URLS  \
# 0     http://retractionwatch.com/2016/06/03/jama-jou...
# 1     http://retractionwatch.com/2016/06/03/jama-jou...
# 2                                                   NaN
# 3     http://retractionwatch.com/2012/06/18/three-mo...
# 4     http://retractionwatch.com/?s=brian+wansink;ht...
# ...                                                 ...
# 9707                                                NaN
# 9708                                                NaN
# 9709                                                NaN
# 9710                                                NaN
# 9711                                                NaN
#
#                                      ArticleType  ...  \
# 0               Clinical Study;Research Article;  ...
# 1                              Research Article;  ...
# 2                              Research Article;  ...
# 3                                Clinical Study;  ...
# 4     Letter;Research Article;Retracted Article;  ...
# ...                                          ...  ...
# 9707                           Research Article;  ...
# 9708                           Research Article;  ...
# 9709                           Research Article;  ...
# 9710                             Clinical Study;  ...
# 9711          Article in Press;Research Article;  ...
#
#          Web of Science Categories  \
# 0     Medicine, General & Internal
# 1     Medicine, General & Internal
# 2     Medicine, General & Internal
# 3                    Ophthalmology
# 4                       Pediatrics
# ...                            ...
# 9707    Endocrinology & Metabolism
# 9708    Multidisciplinary Sciences
# 9709  Medicine, General & Internal
# 9710  Medicine, General & Internal
# 9711            Engineering, Civil
#
#                                                   WE  \
# 0     Science Citation Index Expanded (SCI-EXPANDED)
# 1     Science Citation Index Expanded (SCI-EXPANDED)
# 2     Science Citation Index Expanded (SCI-EXPANDED)
# 3     Science Citation Index Expanded (SCI-EXPANDED)
# 4     Science Citation Index Expanded (SCI-EXPANDED)
# ...                                              ...
# 9707          Emerging Sources Citation Index (ESCI)
# 9708  Science Citation Index Expanded (SCI-EXPANDED)
# 9709          Emerging Sources Citation Index (ESCI)
# 9710          Emerging Sources Citation Index (ESCI)
# 9711  Science Citation Index Expanded (SCI-EXPANDED)
#
#                            Research Areas Document Delivery Number  \
# 0             General & Internal Medicine                    952VW
# 1             General & Internal Medicine                    952VW
# 2             General & Internal Medicine                    974FN
# 3                           Ophthalmology                    886RL
# 4                              Pediatrics                    014ZL
# ...                                   ...                      ...
# 9707           Endocrinology & Metabolism                    WR7JE
# 9708  Science & Technology - Other Topics                    CN8KV
# 9709          General & Internal Medicine                    FA1IY
# 9710          General & Internal Medicine                    FV2VD
# 9711                          Engineering                    YR3TB
#
#        PubMed ID                   Open Access Indicator  \
# 0     16087821.0                                     NaN
# 1     16087822.0                                     NaN
# 2     16217005.0                                     NaN
# 3     15642807.0                                     NaN
# 4     22911396.0                                     NaN
# ...          ...                                     ...
# 9707  34446614.0                   Green Published, gold
# 9708  26213648.0  Green Submitted, Green Published, gold
# 9709  28658896.0                   Green Published, gold
# 9710         NaN                                    gold
# 9711         NaN                                     NaN
#
#      ESI Highly Cited Paper ESI Hot Paper Date this report was generated  \
# 0                       NaN           NaN                     05/11/2023
# 1                       NaN           NaN                     05/11/2023
# 2                       NaN           NaN                     05/11/2023
# 3                       NaN           NaN                     05/11/2023
# 4                       NaN           NaN                     05/11/2023
# ...                     ...           ...                            ...
# 9707                    NaN           NaN                     05/11/2023
# 9708                    NaN           NaN                     05/11/2023
# 9709                    NaN           NaN                     05/11/2023
# 9710                    NaN           NaN                     05/11/2023
# 9711                    NaN           NaN                     05/11/2023
#
#          Accession Number
# 0     WOS:000231034800010
# 1     WOS:000231034800011
# 2     WOS:000232576800013
# 3     WOS:000226245900002
# 4     WOS:000309414400018
# ...                   ...
# 9707  WOS:000714671900010
# 9708  WOS:000358690200002
# 9709  WOS:000405194100123
# 9710  WOS:000424425200031
# 9711  WOS:000749915700001
#
# [9712 rows x 91 columns]

# %%
# Number of DOIs from filtered_wos not in filtered_rw
doi_not_in_rw = filtered_wos[~filtered_wos['Digital Object Identifier (DOI)'].isin(filtered_rw['OriginalPaperDOI'])]
num_dois_in_wos_not_in_rw = len(doi_not_in_rw)

# Number of DOIs from filtered_rw not in filtered_wos
doi_not_in_wos = filtered_rw[~filtered_rw['OriginalPaperDOI'].isin(filtered_wos['Digital Object Identifier (DOI)'])]
num_dois_in_rw_not_in_wos = len(doi_not_in_wos)

# %%
filtered_rw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36847 entries, 29155 to 22442
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Record ID              36847 non-null  int64
#  1   Title                  36847 non-null  object
#  2   Subject                36847 non-null  object
#  3   Institution            36846 non-null  object
#  4   Journal                36847 non-null  object
#  5   Publisher              36847 non-null  object
#  6   Country                36847 non-null  object
#  7   Author                 36847 non-null  object
#  8   URLS                   19034 non-null  object
#  9   ArticleType            36847 non-null  object
#  10  RetractionDate         36847 non-null  datetime64[ns]
#  11  RetractionDOI          36604 non-null  object
#  12  RetractionPubMedID     34013 non-null  object
#  13  OriginalPaperDate      36847 non-null  datetime64[ns]
#  14  OriginalPaperDOI       36846 non-null  object
#  15  OriginalPaperPubMedID  33989 non-null  object
#  16  RetractionNature       36847 non-null  object
#  17  Reason                 36847 non-null  object
#  18  Paywalled              36847 non-null  object
#  19  Notes                  9815 non-null   object
# dtypes: datetime64[ns](2), int64(1), object(17)
# memory usage: 5.9+ MB

# %%
print(f"Number of DOIs from filtered_wos that are not in filtered_rw: {num_dois_in_wos_not_in_rw}")
print(f"Number of DOIs from filtered_rw that are not in filtered_wos: {num_dois_in_rw_not_in_wos}")
# Out:
# Number of DOIs from filtered_wos that are not in filtered_rw: 2624
# Number of DOIs from filtered_rw that are not in filtered_wos: 27135

# %%
test = filtered_rw.merge(filtered_wos, how= 'left', left_on= 'OriginalPaperDOI', right_on= 'Digital Object Identifier (DOI)')
test
# Out:
#        Record ID                                              Title  \
# 0            985  Early Depth Assessment of Local Burns by Dermo...
# 1           5729  The prevention of hip fracture with risedronat...
# 2           5728  Risedronate sodium therapy for prevention of h...
# 3            895  The Relation Between Pulse Pressure and Cardio...
# 4          19230  First Foods Most: After 18-Hour Fast, People D...
# ...          ...                                                ...
# 36842      44860  A consideration of the impact of contaminated ...
# 36843      43526  Study on the Waste Information and Statistics ...
# 36844      38531  On the Feasibility of Stealthily Introducing V...
# 36845      47227  Age, Gender Demographics and Comorbidity Preva...
# 36846       8591  CD117 immunohistochemical expression correlate...
#
#                                                  Subject  \
# 0      (HSC) Biostatistics/Epidemiology;(HSC) Medicin...
# 1      (HSC) Medicine - Geriatric;(HSC) Medicine - Ne...
# 2      (HSC) Medicine - Neurology;(HSC) Medicine - Re...
# 3      (HSC) Biostatistics/Epidemiology;(HSC) Medicin...
# 4                      (BLS) Nutrition;(SOC) Psychology;
# ...                                                  ...
# 36842  (ENV) Ground/Surface Water;(HSC) Public Health...
# 36843  (ENV) Environmental Sciences;(ENV) Ground/Surf...
# 36844           (B/T) Computer Science;(B/T) Technology;
# 36845  (HSC) Biostatistics/Epidemiology;(HSC) Medicin...
# 36846  (BLS) Biochemistry;(HSC) Medicine - Immunology...
#
#                                              Institution  \
# 0      Burns Unit, Department of Dermatology, Nagasak...
# 1      Department of Neurology, Mitate Hospital, Taga...
# 2      Department of Neurology, Mitate Hospital, Taga...
# 3      Department of Dietetics and Nutrition, Harokop...
# 4      Dyson School of Applied Economics and Manageme...
# ...                                                  ...
# 36842  Department of Communication and Culture, Facul...
# 36843  Member, Ph.D. Candidate, Department of Disaste...
# 36844                            University of Minnesota
# 36845  Department of Orthopaedics, Dhanalakshmi Srini...
# 36846  Surgical oncology, Instituto Nacional de Cance...
#
#                                                  Journal  \
# 0                                Archives of Dermatology
# 1                          Archives of Internal Medicine
# 2                          Archives of Internal Medicine
# 3                                 JAMA Internal Medicine
# 4                                 JAMA Internal Medicine
# ...                                                  ...
# 36842                        Human Life Culture Research
# 36843  Journal of the Korean Society of Hazard Mitiga...
# 36844        2021 IEEE Symposium on Security and Privacy
# 36845                   Journal of Coastal Life Medicine
# 36846                       Iranian Journal of Pathology
#
#                                              Publisher_x  \
# 0                                           JAMA Network
# 1                                           JAMA Network
# 2                                           JAMA Network
# 3                                           JAMA Network
# 4                           American Medical Association
# ...                                                  ...
# 36842  Otsuma Women's University Research Institute f...
# 36843                Korean Society of Hazard Mitigation
# 36844  IEEE: Institute of Electrical and Electronics ...
# 36845                   Journal of Coastal Life Medicine
# 36846                       Iranian Society of Pathology
#
#                                                  Country  \
# 0                                                  Japan
# 1                                                  Japan
# 2                                                  Japan
# 3      Finland;Greece;Italy;Japan;Netherlands;Serbia;...
# 4                                          United States
# ...                                                  ...
# 36842                                              Japan
# 36843                                        South Korea
# 36844                                      United States
# 36845                                              India
# 36846                                             Mexico
#
#                                                   Author  \
# 0      Kyomi Mihara;Hajime Shindo;Hiroya Mihara;Minak...
# 1      Yoshihiro Sato;Tomohiro Kanoko;Kei Satoh;Jun I...
# 2             Yoshihiro Sato;Jun Iwamoto;Tomohiro Kanoko
# 3      Demosthenes B Panagiotakos;Daan Kromhout;Aless...
# 4                 Brian Wansink;Aner Tal;Mitsuru Shimizu
# ...                                                  ...
# 36842                                      Atsushi Okeda
# 36843                             Eun-han Lee;Waon-ho Yi
# 36844                               Qiushi Wu;Kangjie Lu
# 36845  S Venkatesh Kumar;Mohith Singh;Gowtham Singh;K...
# 36846  Rosa A Salcedo-HernÃ¡ndez;Leonardo S Lino-Silv...
#
#                                                     URLS  \
# 0                                                    NaN
# 1      http://retractionwatch.com/2016/06/03/jama-jou...
# 2      http://retractionwatch.com/2016/06/03/jama-jou...
# 3                                                    NaN
# 4      http://retractionwatch.com/2018/04/13/caught-o...
# ...                                                  ...
# 36842                                                NaN
# 36843                                                NaN
# 36844                                                NaN
# 36845                                                NaN
# 36846                                                NaN
#
#                               ArticleType  ...     Web of Science Categories  \
# 0                       Research Article;  ...                           NaN
# 1        Clinical Study;Research Article;  ...  Medicine, General & Internal
# 2                       Research Article;  ...  Medicine, General & Internal
# 3                       Research Article;  ...  Medicine, General & Internal
# 4                Letter;Research Article;  ...                           NaN
# ...                                   ...  ...                           ...
# 36842                   Research Article;  ...                           NaN
# 36843                   Research Article;  ...                           NaN
# 36844          Conference Abstract/Paper;  ...                           NaN
# 36845                   Research Article;  ...                           NaN
# 36846  Article in Press;Research Article;  ...            Engineering, Civil
#
#                                                    WE  \
# 0                                                 NaN
# 1      Science Citation Index Expanded (SCI-EXPANDED)
# 2      Science Citation Index Expanded (SCI-EXPANDED)
# 3      Science Citation Index Expanded (SCI-EXPANDED)
# 4                                                 NaN
# ...                                               ...
# 36842                                             NaN
# 36843                                             NaN
# 36844                                             NaN
# 36845                                             NaN
# 36846  Science Citation Index Expanded (SCI-EXPANDED)
#
#                     Research Areas Document Delivery Number   PubMed ID  \
# 0                              NaN                      NaN         NaN
# 1      General & Internal Medicine                    952VW  16087821.0
# 2      General & Internal Medicine                    952VW  16087822.0
# 3      General & Internal Medicine                    974FN  16217005.0
# 4                              NaN                      NaN         NaN
# ...                            ...                      ...         ...
# 36842                          NaN                      NaN         NaN
# 36843                          NaN                      NaN         NaN
# 36844                          NaN                      NaN         NaN
# 36845                          NaN                      NaN         NaN
# 36846                  Engineering                    YR3TB         NaN
#
#       Open Access Indicator ESI Highly Cited Paper ESI Hot Paper  \
# 0                       NaN                    NaN           NaN
# 1                       NaN                    NaN           NaN
# 2                       NaN                    NaN           NaN
# 3                       NaN                    NaN           NaN
# 4                       NaN                    NaN           NaN
# ...                     ...                    ...           ...
# 36842                   NaN                    NaN           NaN
# 36843                   NaN                    NaN           NaN
# 36844                   NaN                    NaN           NaN
# 36845                   NaN                    NaN           NaN
# 36846                   NaN                    NaN           NaN
#
#       Date this report was generated     Accession Number
# 0                                NaN                  NaN
# 1                         05/11/2023  WOS:000231034800010
# 2                         05/11/2023  WOS:000231034800011
# 3                         05/11/2023  WOS:000232576800013
# 4                                NaN                  NaN
# ...                              ...                  ...
# 36842                            NaN                  NaN
# 36843                            NaN                  NaN
# 36844                            NaN                  NaN
# 36845                            NaN                  NaN
# 36846                     05/11/2023  WOS:000749915700001
#
# [36847 rows x 91 columns]

# %%
test = filtered_rw.merge(filtered_wos, how= 'right', left_on= 'OriginalPaperDOI', right_on= 'Digital Object Identifier (DOI)')
test
# Out:
#        Record ID                                              Title  \
# 0         5729.0  The prevention of hip fracture with risedronat...
# 1         5728.0  Risedronate sodium therapy for prevention of h...
# 2          895.0  The Relation Between Pulse Pressure and Cardio...
# 3          938.0  A Randomized Clinical Trial of a Single Dose o...
# 4        14089.0               Can Branding Improve School Lunches?
# ...          ...                                                ...
# 12331        NaN                                                NaN
# 12332    38977.0  Determining the accuracy of different water in...
# 12333     5478.0  Theoretical study of the mechanism, regio- and...
# 12334    32100.0  Roflumilast Ameliorates Isoflurane-Induced Inf...
# 12335     8591.0  CD117 immunohistochemical expression correlate...
#
#                                                  Subject  \
# 0      (HSC) Medicine - Geriatric;(HSC) Medicine - Ne...
# 1      (HSC) Medicine - Neurology;(HSC) Medicine - Re...
# 2      (HSC) Biostatistics/Epidemiology;(HSC) Medicin...
# 3      (HSC) Medicine - Ophthalmology;(HSC) Medicine ...
# 4      (B/T) Business - Marketing;(BLS) Nutrition;(SO...
# ...                                                  ...
# 12331                                                NaN
# 12332  (BLS) Agriculture;(ENV) Environmental Sciences...
# 12333                 (PHY) Chemistry;(PHY) Mathematics;
# 12334  (BLS) Anatomy/Physiology;(BLS) Biology - Cellu...
# 12335  (BLS) Biochemistry;(HSC) Medicine - Immunology...
#
#                                              Institution  \
# 0      Department of Neurology, Mitate Hospital, Taga...
# 1      Department of Neurology, Mitate Hospital, Taga...
# 2      Department of Dietetics and Nutrition, Harokop...
# 3      Department of Anesthesiology, Toride Kyodo Gen...
# 4      Charles H. Dyson School of Applied Economics a...
# ...                                                  ...
# 12331                                                NaN
# 12332  Department of Irrigation and Drainage, Faculty...
# 12333  DÃ©partement de Chimie, FacultÃ© des Sciences,...
# 12334  Department of Anesthesiology, the Affiliated B...
# 12335  Surgical oncology, Instituto Nacional de Cance...
#
#                                         Journal  \
# 0                 Archives of Internal Medicine
# 1                 Archives of Internal Medicine
# 2                        JAMA Internal Medicine
# 3                            JAMA Ophthalmology
# 4                               JAMA Pediatrics
# ...                                         ...
# 12331                                       NaN
# 12332                      Journal of Hydrology
# 12333  Journal of Molecular Structure: THEOCHEM
# 12334                                 ACS Omega
# 12335              Iranian Journal of Pathology
#
#                            Publisher_x  \
# 0                         JAMA Network
# 1                         JAMA Network
# 2                         JAMA Network
# 3         American Medical Association
# 4                         JAMA Network
# ...                                ...
# 12331                              NaN
# 12332                         Elsevier
# 12333                         Elsevier
# 12334  American Chemical Society (ACS)
# 12335     Iranian Society of Pathology
#
#                                                  Country  \
# 0                                                  Japan
# 1                                                  Japan
# 2      Finland;Greece;Italy;Japan;Netherlands;Serbia;...
# 3                                                  Japan
# 4                                          United States
# ...                                                  ...
# 12331                                                NaN
# 12332                                               Iran
# 12333                                            Algeria
# 12334                                              China
# 12335                                             Mexico
#
#                                                   Author  \
# 0      Yoshihiro Sato;Tomohiro Kanoko;Kei Satoh;Jun I...
# 1             Yoshihiro Sato;Jun Iwamoto;Tomohiro Kanoko
# 2      Demosthenes B Panagiotakos;Daan Kromhout;Aless...
# 3           Yoshitaka Fujii;Hiroyoshi Tanaka;Mutsuko Ito
# 4              Brian Wansink;David R Just;Collin R Payne
# ...                                                  ...
# 12331                                                NaN
# 12332  Ahmad Khasraei;Hamid Zare Abyaneh;Mehdi Jovzi;...
# 12333                           H Chemouri;SM Mekelleche
# 12334  Chunyuan Zhang;Zeting Xing;Meiyun Tan;Yanwen W...
# 12335  Rosa A Salcedo-HernÃ¡ndez;Leonardo S Lino-Silv...
#
#                                                     URLS  \
# 0      http://retractionwatch.com/2016/06/03/jama-jou...
# 1      http://retractionwatch.com/2016/06/03/jama-jou...
# 2                                                    NaN
# 3      http://retractionwatch.com/2012/06/18/three-mo...
# 4      http://retractionwatch.com/?s=brian+wansink;ht...
# ...                                                  ...
# 12331                                                NaN
# 12332                                                NaN
# 12333                                                NaN
# 12334                                                NaN
# 12335                                                NaN
#
#                                       ArticleType  ...  \
# 0                Clinical Study;Research Article;  ...
# 1                               Research Article;  ...
# 2                               Research Article;  ...
# 3                                 Clinical Study;  ...
# 4      Letter;Research Article;Retracted Article;  ...
# ...                                           ...  ...
# 12331                                         NaN  ...
# 12332                           Research Article;  ...
# 12333                           Research Article;  ...
# 12334                           Research Article;  ...
# 12335          Article in Press;Research Article;  ...
#
#                             Web of Science Categories  \
# 0                        Medicine, General & Internal
# 1                        Medicine, General & Internal
# 2                        Medicine, General & Internal
# 3                                       Ophthalmology
# 4                                          Pediatrics
# ...                                               ...
# 12331                    Medicine, General & Internal
# 12332  Science Citation Index Expanded (SCI-EXPANDED)
# 12333  Science Citation Index Expanded (SCI-EXPANDED)
# 12334  Science Citation Index Expanded (SCI-EXPANDED)
# 12335                              Engineering, Civil
#
#                                                    WE  \
# 0      Science Citation Index Expanded (SCI-EXPANDED)
# 1      Science Citation Index Expanded (SCI-EXPANDED)
# 2      Science Citation Index Expanded (SCI-EXPANDED)
# 3      Science Citation Index Expanded (SCI-EXPANDED)
# 4      Science Citation Index Expanded (SCI-EXPANDED)
# ...                                               ...
# 12331  Science Citation Index Expanded (SCI-EXPANDED)
# 12332           Engineering; Geology; Water Resources
# 12333                                       Chemistry
# 12334                                       Chemistry
# 12335  Science Citation Index Expanded (SCI-EXPANDED)
#
#                     Research Areas Document Delivery Number   PubMed ID  \
# 0      General & Internal Medicine                    952VW  16087821.0
# 1      General & Internal Medicine                    952VW  16087822.0
# 2      General & Internal Medicine                    974FN  16217005.0
# 3                    Ophthalmology                    886RL  15642807.0
# 4                       Pediatrics                    014ZL  22911396.0
# ...                            ...                      ...         ...
# 12331  General & Internal Medicine                    EZ345   2101137.0
# 12332                        XQ7GG                      NaN         NaN
# 12333                        471GB                      NaN         NaN
# 12334                        QL2PM                 33644540         NaN
# 12335                  Engineering                    YR3TB         NaN
#
#       Open Access Indicator ESI Highly Cited Paper ESI Hot Paper  \
# 0                       NaN                    NaN           NaN
# 1                       NaN                    NaN           NaN
# 2                       NaN                    NaN           NaN
# 3                       NaN                    NaN           NaN
# 4                       NaN                    NaN           NaN
# ...                     ...                    ...           ...
# 12331                Bronze                    NaN           NaN
# 12332                   NaN                    NaN    05/11/2023
# 12333                   NaN                    NaN    05/11/2023
# 12334                   NaN                    NaN    05/11/2023
# 12335                   NaN                    NaN           NaN
#
#       Date this report was generated     Accession Number
# 0                         05/11/2023  WOS:000231034800010
# 1                         05/11/2023  WOS:000231034800011
# 2                         05/11/2023  WOS:000232576800013
# 3                         05/11/2023  WOS:000226245900002
# 4                         05/11/2023  WOS:000309414400018
# ...                              ...                  ...
# 12331                     05/11/2023  WOS:A1990EZ34500002
# 12332            WOS:000731712200002                  NaN
# 12333            WOS:000268042900002                  NaN
# 12334            WOS:000620923200008                  NaN
# 12335                     05/11/2023  WOS:000749915700001
#
# [12336 rows x 91 columns]

# %%
filtered_rw.shape
# Out:
# (36847, 20)

# %%
test = rw.merge(wos_rd, how= 'inner', left_on= 'Title', right_on= 'Document Title')
test
# Out:
#    Record ID                                              Title  \
# 0       6180  latrogenic perforation of the right pulmonary ...
# 1       2257                           100 years of lung cancer
# 2      24730  24-h ambulatory blood pressure versus clinic b...
# 3      44233  p300 promotes proliferation, migration, and in...
#
#                                              Subject  \
# 0  (HSC) Medicine - Cardiology;(HSC) Medicine - C...
# 1  (HSC) Medicine - Oncology;(HSC) Medicine - Pul...
# 2  (HSC) Biostatistics/Epidemiology;(HSC) Medicin...
# 3  (BLS) Biology - Cancer;(BLS) Biology - Cellula...
#
#                                          Institution  \
# 0  Department of Cardiac Surgery, Clinica Capio, ...
# 1  Department of Anesthesiology and Critical Care...
# 2  Department of Social Medicine and Health Educa...
# 3  Department of Medical Oncology, Sun Yat-sen Un...
#
#                                              Journal  \
# 0  European Journal of Cardio-Thoracic Surgery: O...
# 1                               Respiratory Medicine
# 2                            Journal of Hypertension
# 3                                         BMC Cancer
#
#                                       Publisher_x               Country  \
# 0                                 Oxford Academic                 Spain
# 1                                        Elsevier                Poland
# 2  Wolters Kluwer - Lippincott Williams & Wilkins  China;United Kingdom
# 3                 Springer - Biomed Central (BMC)                 China
#
#                                               Author URLS        ArticleType  \
# 0  John J Trujillo;Sergio Beltrame;Stefano Urso;G...  NaN  Research Article;
# 1                                 Michael Pirozynski  NaN    Review Article;
# 2           Hong Fan;Igho J Onakpoya;Carl J Heneghan  NaN     Meta-Analysis;
# 3  Xue Hou;Run Gong;Jianhua Zhan;Ting Zhou;Yuxian...  NaN  Research Article;
#
#    ...                          Web of Science Categories  \
# 0  ...  Cardiac & Cardiovascular Systems; Respiratory ...
# 1  ...  Cardiac & Cardiovascular Systems; Respiratory ...
# 2  ...                        Peripheral Vascular Disease
# 3  ...                                           Oncology
#
#                                                WE  \
# 0  Science Citation Index Expanded (SCI-EXPANDED)
# 1  Science Citation Index Expanded (SCI-EXPANDED)
# 2  Science Citation Index Expanded (SCI-EXPANDED)
# 3  Science Citation Index Expanded (SCI-EXPANDED)
#
#                                       Research Areas Document Delivery Number  \
# 0  Cardiovascular System & Cardiology; Respirator...                    384DN
# 1  Cardiovascular System & Cardiology; Respirator...                    124NO
# 2                 Cardiovascular System & Cardiology                    OQ0PL
# 3                                           Oncology                    GI6DT
#
#     PubMed ID  Open Access Indicator ESI Highly Cited Paper ESI Hot Paper  \
# 0  18951035.0                 Bronze                    NaN           NaN
# 1  17056245.0                 Bronze                    NaN           NaN
# 2  32618886.0                    NaN                    NaN           NaN
# 3  29879950.0  Green Published, gold                    NaN           NaN
#
#   Date this report was generated     Accession Number
# 0                     05/11/2023  WOS:000261724600021
# 1                     05/11/2023  WOS:000243374700001
# 2                     05/11/2023  WOS:000588494400001
# 3                     05/11/2023  WOS:000434460400003
#
# [4 rows x 91 columns]

# %%
test = rw.merge(wos_rd, how= 'right', left_on= 'Title', right_on= 'Document Title')
test
# Out:
#        Record ID Title Subject Institution Journal Publisher_x Country Author  \
# 0            NaN   NaN     NaN         NaN     NaN         NaN     NaN    NaN
# 1            NaN   NaN     NaN         NaN     NaN         NaN     NaN    NaN
# 2            NaN   NaN     NaN         NaN     NaN         NaN     NaN    NaN
# 3            NaN   NaN     NaN         NaN     NaN         NaN     NaN    NaN
# 4            NaN   NaN     NaN         NaN     NaN         NaN     NaN    NaN
# ...          ...   ...     ...         ...     ...         ...     ...    ...
# 12853        NaN   NaN     NaN         NaN     NaN         NaN     NaN    NaN
# 12854        NaN   NaN     NaN         NaN     NaN         NaN     NaN    NaN
# 12855        NaN   NaN     NaN         NaN     NaN         NaN     NaN    NaN
# 12856        NaN   NaN     NaN         NaN     NaN         NaN     NaN    NaN
# 12857        NaN   NaN     NaN         NaN     NaN         NaN     NaN    NaN
#
#       URLS ArticleType  ...  \
# 0      NaN         NaN  ...
# 1      NaN         NaN  ...
# 2      NaN         NaN  ...
# 3      NaN         NaN  ...
# 4      NaN         NaN  ...
# ...    ...         ...  ...
# 12853  NaN         NaN  ...
# 12854  NaN         NaN  ...
# 12855  NaN         NaN  ...
# 12856  NaN         NaN  ...
# 12857  NaN         NaN  ...
#
#                                Web of Science Categories  \
# 0                           Medicine, General & Internal
# 1                           Medicine, General & Internal
# 2                           Medicine, General & Internal
# 3                                          Ophthalmology
# 4                                             Pediatrics
# ...                                                  ...
# 12853  Cardiac & Cardiovascular Systems; Respiratory ...
# 12854  Cardiac & Cardiovascular Systems; Respiratory ...
# 12855                       Medicine, General & Internal
# 12856                                         Pediatrics
# 12857                                         Immunology
#
#                                                    WE  \
# 0      Science Citation Index Expanded (SCI-EXPANDED)
# 1      Science Citation Index Expanded (SCI-EXPANDED)
# 2      Science Citation Index Expanded (SCI-EXPANDED)
# 3      Science Citation Index Expanded (SCI-EXPANDED)
# 4      Science Citation Index Expanded (SCI-EXPANDED)
# ...                                               ...
# 12853  Science Citation Index Expanded (SCI-EXPANDED)
# 12854  Science Citation Index Expanded (SCI-EXPANDED)
# 12855  Science Citation Index Expanded (SCI-EXPANDED)
# 12856  Science Citation Index Expanded (SCI-EXPANDED)
# 12857  Science Citation Index Expanded (SCI-EXPANDED)
#
#                                           Research Areas  \
# 0                            General & Internal Medicine
# 1                            General & Internal Medicine
# 2                            General & Internal Medicine
# 3                                          Ophthalmology
# 4                                             Pediatrics
# ...                                                  ...
# 12853  Cardiovascular System & Cardiology; Respirator...
# 12854  Cardiovascular System & Cardiology; Respirator...
# 12855                        General & Internal Medicine
# 12856                                         Pediatrics
# 12857                                         Immunology
#
#       Document Delivery Number   PubMed ID Open Access Indicator  \
# 0                        952VW  16087821.0                   NaN
# 1                        952VW  16087822.0                   NaN
# 2                        974FN  16217005.0                   NaN
# 3                        886RL  15642807.0                   NaN
# 4                        014ZL  22911396.0                   NaN
# ...                        ...         ...                   ...
# 12853                    EC910   2214832.0                   NaN
# 12854                    AA700   2786116.0                   NaN
# 12855                    D1812   2427448.0                   NaN
# 12856                    D4187   3526270.0                   NaN
# 12857                    EZ986    307018.0                   NaN
#
#       ESI Highly Cited Paper ESI Hot Paper Date this report was generated  \
# 0                        NaN           NaN                     05/11/2023
# 1                        NaN           NaN                     05/11/2023
# 2                        NaN           NaN                     05/11/2023
# 3                        NaN           NaN                     05/11/2023
# 4                        NaN           NaN                     05/11/2023
# ...                      ...           ...                            ...
# 12853                    NaN           NaN                     05/11/2023
# 12854                    NaN           NaN                     05/11/2023
# 12855                    NaN           NaN                     05/11/2023
# 12856                    NaN           NaN                     05/11/2023
# 12857                    NaN           NaN                     05/11/2023
#
#           Accession Number
# 0      WOS:000231034800010
# 1      WOS:000231034800011
# 2      WOS:000232576800013
# 3      WOS:000226245900002
# 4      WOS:000309414400018
# ...                    ...
# 12853  WOS:A1990EC91000010
# 12854  WOS:A1989AA70000004
# 12855  WOS:A1986D181200006
# 12856  WOS:A1986D418700025
# 12857  WOS:A1978EZ98600022
#
# [12858 rows x 91 columns]
